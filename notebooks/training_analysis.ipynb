# %%
import pandas as pd
from process_results import process_results_folder_json
from training_logs_analysis import parse_client_csv, process_fp_logs

# %%
import os
import pathlib

def find_repo_root(start=None):
    p = pathlib.Path(start or os.getcwd()).resolve()
    for parent in [p, *p.parents]:
        if (parent / "conf" / "base.yaml").exists():
            return parent
    return p

PROJECT_ROOT = find_repo_root()

gat_cora_csv = str(
    PROJECT_ROOT
    / "src"
    / "results"
    / "GAT_final"
    / "planetoid_300_rounds_pe"
    / "Cora_diffusion_GAT_beta10000_clients10"
    / "training_Cora_diffusion_GAT_beta10000_clients10_20250605_194510.csv"
)

gat_cora_logs = parse_client_csv(gat_cora_csv)

# %%
acc_df = gat_cora_logs['acc_df']
acc_df.head()

# %%
acc_df_step = gat_cora_logs['acc_df_step']

acc_df_step.head(20)

# %%
final_acc_df = gat_cora_logs['final_acc_df']
final_acc_df.head(50)
