# %%
import pandas as pd
from process_results import process_results_folder_json
from training_logs_analysis import parse_client_csv, process_fp_logs

# %%
path = "/home/brian_bosho/FP/FP/federated-gnn/src/results/multi_ablation_test_100_rounds_PE"

# %%
df = process_results_folder_json(path)

# %%
df

# %%
df_iid = df[df['beta'] == 10000]
df_iid

df_non_iid = df[df['beta'] == 1]
df_non_iid

# drop rows with nan
df_iid = df_iid.dropna()
df_iid

# drop rows with nan
df_non_iid = df_non_iid.dropna()
df_non_iid

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_avg_client_results_by_loading_option(df):
    # Group data by dataset and data_loading_option, get average_client_result
    grouped = df.groupby(['dataset', 'data_loading_option'])['average_client_result'].mean().unstack()

    # Plotting
    ax = grouped.plot(kind='bar', figsize=(10, 6))
    ax.set_ylabel("Average Client Result")
    ax.set_title("Average Client Results by Data Loading Option per Dataset")
    ax.legend(title="Data Loading Option")
    plt.xticks(rotation=0)
    plt.tight_layout()
    plt.show()

# Example usage:
# plot_avg_client_results_by_loading_option(df)
plot_avg_client_results_by_loading_option(df_iid)

# %%
plot_avg_client_results_by_loading_option(df_non_iid)

# %%
import pandas as pd

def tabulate(df):
    # Group and aggregate mean and std
    grouped = df.groupby(['data_loading_option', 'dataset'])[['average_client_result', 'std_client']].mean()

    # Format as "mean ± std"
    formatted = grouped.apply(
        lambda x: f"{x['average_client_result']:.3f} ± {x['std_client']:.3f}", axis=1
    ).unstack()

    return formatted

# %%
tabulate(df_iid)

# %%
tabulate(df_non_iid)

# %% [markdown]
# ### No PE

# %%
no_pe_path = "/home/brian_bosho/FP/FP/federated-gnn/src/results/multi_ablation_test_100_rounds_NO_PE"

# %%
df_no_pe = process_results_folder_json(no_pe_path)
df_no_pe
### Training logs

# %%
df_no_pe_iid = df_no_pe[df_no_pe['beta'] == 10000]
df_no_pe_iid
df_no_pe_iid = df_no_pe_iid.dropna()
df_no_pe_iid
### Training logs

df_no_pe_non_iid = df_no_pe[df_no_pe['beta'] == 1]
df_no_pe_non_iid
df_no_pe_non_iid = df_no_pe_non_iid.dropna()
df_no_pe_non_iid
### Training logs

# %%
tabulate(df_no_pe_iid)

# %%
tabulate(df_iid)

# %%
tabulate(df_no_pe_non_iid)

# %%
tabulate(df_non_iid)

# %%
plot_avg_client_results_by_loading_option(df_no_pe_iid)

# %%
plot_avg_client_results_by_loading_option(df_no_pe_non_iid)

# %%
# nw lets compare PE vs No PE

# %% [markdown]
# ### Training logs

# %%
final_loss_df = dfs['final_loss_df']
final_loss_df

# %%
# plot final loss
import matplotlib.pyplot as plt
final_loss_df.plot(figsize=(10, 6), marker='o')
plt.title("Final Loss per Round")
plt.xlabel("Round")
plt.ylabel("Loss")
plt.grid(True)
plt.legend(title="Client ID")

# %% [markdown]
# ### lets review the results folder results

# %%
from process_results import process_results_folder_json

# %%
test_results = "/home/brian_bosho/FP/FP/federated-gnn/src/results/yaml_test_results_5clients"

# %%
df = process_results_folder_json(test_results)
df

# %% [markdown]
# ### FP logs

# %%
iid_json = "/home/brian_bosho/FP/FP/federated-gnn/src/results/multi_ablation_test_100_rounds_NO_PE/propagation_stats/prop_exp_20250504-195317_adjacency_beta_10000_hop_1.json"
non_iid_json = "/home/brian_bosho/FP/FP/federated-gnn/src/results/multi_ablation_test_100_rounds_NO_PE/propagation_stats/prop_exp_20250504-174349_diffusion_beta_1_hop_1.json"
stats = process_fp_logs(non_iid_json)

stats.keys()

# %%
iid_energy_per_node_df = stats["energy_per_node_df"]
iid_energy_per_node_df

# plot
import matplotlib.pyplot as plt
iid_energy_per_node_df.plot(figsize=(10, 6), marker='o')
plt.title("Energies per Node per Iteration iid")
plt.xlabel("Iteration")
plt.ylabel("Energy per Node")
plt.grid(True)
plt.legend(title="Client ID")

# %%
deltas = stats["deltas_df"]
deltas

# %%
# lets do delta for each client againt the iteration step
deltas.plot(figsize=(10, 6), marker='o')
plt.title("Delta per Iteration iid")
plt.xlabel("Iteration")
plt.ylabel("Delta")
plt.grid(True)
plt.show()

# %%
deltas["mean"] = deltas.mean(axis=1)
deltas
# plot the mean of the deltas
deltas["mean"].plot(figsize=(10, 6), marker='o')
plt.title("Mean Delta per Iteration iid")
plt.xlabel("Iteration")
plt.ylabel("Mean Delta")
plt.grid(True)
plt.legend(title="Client ID")
