# %%
# !python -m src.experiments.run_experiments --config conf/cora_config.yaml
# Out:
# [config] WARNING: unknown top-level key(s) in /home/bosho/FP/conf/cora_config.yaml: ['wandb']. Check for misspellings — unknown keys are silently ignored.
#
# Experiment Configuration:
# - Clients: [10]
# - Rounds: 200
# - Epochs: 3
# - Learning Rate: 0.5
# - Beta values: [10000]
# - Datasets: ['Cora']
# - Data Loading Options: ['diffusion', 'full', 'zero_hop', 'adjacency']
# - Model Types: ['GCN', 'GAT']
# - Results Directory: /home/bosho/FP/results/IEEE/cora
# - Save Detailed Results: True
# - Resume Completed: False
# - Hop: [1]
# - Full Training Flag: False
# 2026-05-08 13:43:32,761	INFO worker.py:1783 -- Started a local Ray instance.
#
# ================================================================================
# Running experiment: Cora_diffusion_GCN_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_pe
# ================================================================================
# 2026-05-08 13:43:33,551 - INFO - Memory before experiment - Allocated: 0.00GB, Cached: 0.00GB, Max: 0.00GB
# [client 0] FP on GPU succeeded
# [client 1] FP on GPU succeeded
# [client 2] FP on GPU succeeded
# [client 3] FP on GPU succeeded
# [client 4] FP on GPU succeeded
# [client 5] FP on GPU succeeded
# [client 6] FP on GPU succeeded
# [client 7] FP on GPU succeeded
# [client 8] FP on GPU succeeded
# [client 9] FP on GPU succeeded
# ✓ Subgraphs staying on cuda (keep_data_on_gpu=True)
# Model: GCN(hidden_dim=16, num_layers=2, dropout=0.5, normalization=none)
# [Server] Aggregation strategy: fedavg_weighted
# (FLClient pid=1948346) [Client 0] CVD=0 torch.cuda.is_available=True torch.cuda.device_count=1 requested_device=cuda
# (FLClient pid=1948346) Client 0: Using full-batch training for Cora dataset
# (FLClient pid=1948346) 2026-05-08 13:43:47,538 - INFO - Epoch   0| Train Loss: 1.942| Train Accuracy: 0.214| Val Loss: 1.956| Val Accuracy: 0.163
# (FLClient pid=1948346) 2026-05-08 13:43:52,735 - INFO - Epoch   2| Train Loss: 1.131| Train Accuracy: 0.714| Val Loss: 1.740| Val Accuracy: 0.245 [repeated 572x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (FLClient pid=1948346) 2026-05-08 13:43:57,754 - INFO - Epoch   2| Train Loss: 0.483| Train Accuracy: 0.857| Val Loss: 1.217| Val Accuracy: 0.714 [repeated 609x across cluster]
#   [Memory cleanup at round 50]
# (FLClient pid=1948346) 2026-05-08 13:44:03,090 - INFO - Epoch   2| Train Loss: 0.277| Train Accuracy: 1.000| Val Loss: 0.972| Val Accuracy: 0.735 [repeated 621x across cluster]
# (FLClient pid=1948346) 2026-05-08 13:44:08,271 - INFO - Epoch   1| Train Loss: 0.182| Train Accuracy: 1.000| Val Loss: 0.780| Val Accuracy: 0.796 [repeated 629x across cluster]
#   [Memory cleanup at round 100]
# (FLClient pid=1948346) 2026-05-08 13:44:13,348 - INFO - Epoch   0| Train Loss: 0.264| Train Accuracy: 1.000| Val Loss: 0.724| Val Accuracy: 0.796 [repeated 599x across cluster]
# Early stopping triggered at round 116
# Training CSV results saved to /home/bosho/FP/results/IEEE/cora/Cora_diffusion_GCN_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_pe/training_Cora_diffusion_GCN_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_pe_20260508_134333.csv
#   Test Batch 1/1: Testing clients 0 to 9 (parallel)
# Client test acc (macro): 0.7537
# Client test acc (micro): 0.7540
# Global test acc (client_test_graphs): 0.754
# 2026-05-08 13:44:19,089 - INFO - Memory after experiment - Allocated: 0.00GB, Cached: 0.00GB, Max: 0.19GB
# The global test results: [0.754]
# The client test results: [0.7536903075465552]
# Successful reps: [1], failed reps: []
# The average global test results: 0.754
# The average client test results: 0.7536903075465552
# The standard deviation global is: 0.0
# The standard deviation client is: 0.0
# Cleaning up driver memory...
#
# FP CSV FORMAT RESULT:
# Dataset,Model,DataLoading,Beta,Clients,Hop,UsePE,Seed,Status,TotalTime[s],LoadTime[s],ShardTime[s],PartitionTime[s],PropTime[s],ActorInitTime[s],TrainTime[s],EvalTime[s],CommTime[s],FinalAcc,BestAcc,PeakCPU[MB],PeakDriverGPU[MB],PeakActorGPU[MB],CommCost[MB],ModelSize[MB],TotalParams,ResultPath
# Cora,GCN,diffusion,10000,10,1,True,,success,46.047,0.027,0.0,6.925,6.696,6.465,30.092,1.516,,0.754,0.759101,1879.098,191.601,38.5,617.54,0.154385,40471,/home/bosho/FP/results/IEEE/cora/Cora_diffusion_GCN_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_pe/results_Cora_diffusion_GCN_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_pe_20260508_134333.json
# Results saved to /home/bosho/FP/results/IEEE/cora/Cora_diffusion_GCN_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_pe/results_Cora_diffusion_GCN_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_pe_20260508_134333.json
# Training CSV results saved to /home/bosho/FP/results/IEEE/cora/Cora_diffusion_GCN_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_pe/training_Cora_diffusion_GCN_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_pe_20260508_134333.csv
#
# ================================================================================
# Running experiment: Cora_diffusion_GAT_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_pe
# ================================================================================
# 2026-05-08 13:44:19,980 - INFO - Memory before experiment - Allocated: 0.00GB, Cached: 0.00GB, Max: 0.00GB
# [client 0] FP on GPU succeeded
# [client 1] FP on GPU succeeded
# [client 2] FP on GPU succeeded
# [client 3] FP on GPU succeeded
# [client 4] FP on GPU succeeded
# [client 5] FP on GPU succeeded
# [client 6] FP on GPU succeeded
# [client 7] FP on GPU succeeded
# [client 8] FP on GPU succeeded
# [client 9] FP on GPU succeeded
# ✓ Subgraphs staying on cuda (keep_data_on_gpu=True)
# Model: GAT(hidden_dim=8, num_heads=8, num_layers=2)
# [Server] Aggregation strategy: fedavg_weighted
# (FLClient pid=1949288) [Client 0] CVD=0 torch.cuda.is_available=True torch.cuda.device_count=1 requested_device=cuda [repeated 10x across cluster]
# (FLClient pid=1949288) Client 0: Using full-batch training for Cora dataset [repeated 10x across cluster]
# (FLClient pid=1949290) 2026-05-08 13:44:34,361 - INFO - Epoch   2| Train Loss: 1.736| Train Accuracy: 0.267| Val Loss: 2.252| Val Accuracy: 0.109 [repeated 482x across cluster]
# (FLClient pid=1949290) 2026-05-08 13:44:39,439 - INFO - Epoch   2| Train Loss: 0.871| Train Accuracy: 0.933| Val Loss: 1.928| Val Accuracy: 0.283 [repeated 540x across cluster]
# (FLClient pid=1949290) 2026-05-08 13:44:44,379 - INFO - Epoch   2| Train Loss: 0.365| Train Accuracy: 0.933| Val Loss: 1.366| Val Accuracy: 0.478 [repeated 519x across cluster]
#   [Memory cleanup at round 50]
# (FLClient pid=1949290) 2026-05-08 13:44:49,620 - INFO - Epoch   2| Train Loss: 0.181| Train Accuracy: 0.933| Val Loss: 1.132| Val Accuracy: 0.565 [repeated 531x across cluster]
# (FLClient pid=1949290) 2026-05-08 13:44:54,559 - INFO - Epoch   2| Train Loss: 0.163| Train Accuracy: 1.000| Val Loss: 0.977| Val Accuracy: 0.652 [repeated 519x across cluster]
# (FLClient pid=1949290) 2026-05-08 13:44:59,930 - INFO - Epoch   0| Train Loss: 0.085| Train Accuracy: 1.000| Val Loss: 0.805| Val Accuracy: 0.739 [repeated 559x across cluster]
#   [Memory cleanup at round 100]
# (FLClient pid=1949290) 2026-05-08 13:45:05,090 - INFO - Epoch   2| Train Loss: 0.080| Train Accuracy: 1.000| Val Loss: 0.922| Val Accuracy: 0.696 [repeated 512x across cluster]
# (FLClient pid=1949290) 2026-05-08 13:45:10,299 - INFO - Epoch   1| Train Loss: 0.038| Train Accuracy: 1.000| Val Loss: 0.713| Val Accuracy: 0.783 [repeated 539x across cluster]
# Early stopping triggered at round 138
# Training CSV results saved to /home/bosho/FP/results/IEEE/cora/Cora_diffusion_GAT_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_pe/training_Cora_diffusion_GAT_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_pe_20260508_134419.csv
#   Test Batch 1/1: Testing clients 0 to 9 (parallel)
# Client test acc (macro): 0.7670
# Client test acc (micro): 0.7670
# Global test acc (client_test_graphs): 0.767
# 2026-05-08 13:45:16,294 - INFO - Memory after experiment - Allocated: 0.00GB, Cached: 0.00GB, Max: 0.19GB
# The global test results: [0.767]
# The client test results: [0.7669907586429427]
# Successful reps: [1], failed reps: []
# The average global test results: 0.767
# The average client test results: 0.7669907586429427
# The standard deviation global is: 0.0
# The standard deviation client is: 0.0
# Cleaning up driver memory...
#
# FP CSV FORMAT RESULT:
# Dataset,Model,DataLoading,Beta,Clients,Hop,UsePE,Seed,Status,TotalTime[s],LoadTime[s],ShardTime[s],PartitionTime[s],PropTime[s],ActorInitTime[s],TrainTime[s],EvalTime[s],CommTime[s],FinalAcc,BestAcc,PeakCPU[MB],PeakDriverGPU[MB],PeakActorGPU[MB],CommCost[MB],ModelSize[MB],TotalParams,ResultPath
# Cora,GAT,diffusion,10000,10,1,True,,success,56.84,0.507,0.0,6.652,6.472,6.439,40.489,1.541,,0.767,0.747477,1891.953,191.601,47.322,4941.832,1.235458,323868,/home/bosho/FP/results/IEEE/cora/Cora_diffusion_GAT_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_pe/results_Cora_diffusion_GAT_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_pe_20260508_134419.json
# Results saved to /home/bosho/FP/results/IEEE/cora/Cora_diffusion_GAT_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_pe/results_Cora_diffusion_GAT_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_pe_20260508_134419.json
# Training CSV results saved to /home/bosho/FP/results/IEEE/cora/Cora_diffusion_GAT_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_pe/training_Cora_diffusion_GAT_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_pe_20260508_134419.csv
#
# ================================================================================
# Running experiment: Cora_full_GCN_beta10000_clients10_hop1_iter80_t1.0_alpha0.5
# ================================================================================
# 2026-05-08 13:45:17,171 - INFO - Memory before experiment - Allocated: 0.00GB, Cached: 0.00GB, Max: 0.00GB
# ✓ Subgraphs staying on cuda (keep_data_on_gpu=True)
# Model: GCN(hidden_dim=16, num_layers=2, dropout=0.5, normalization=none)
# [Server] Aggregation strategy: fedavg_weighted
# (FLClient pid=1950173) [Client 1] CVD=0 torch.cuda.is_available=True torch.cuda.device_count=1 requested_device=cuda [repeated 10x across cluster]
# (FLClient pid=1950173) Client 1: Using full-batch training for Cora dataset [repeated 10x across cluster]
# (FLClient pid=1950174) 2026-05-08 13:45:24,947 - INFO - Epoch   0| Train Loss: 1.924| Train Accuracy: 0.200| Val Loss: 1.944| Val Accuracy: 0.152 [repeated 449x across cluster]
# (FLClient pid=1950186) 2026-05-08 13:45:29,857 - INFO - Epoch   2| Train Loss: 0.189| Train Accuracy: 0.929| Val Loss: 0.836| Val Accuracy: 0.741 [repeated 710x across cluster]
# (FLClient pid=1950186) 2026-05-08 13:45:35,099 - INFO - Epoch   1| Train Loss: 0.076| Train Accuracy: 1.000| Val Loss: 0.713| Val Accuracy: 0.793 [repeated 731x across cluster]
#   [Memory cleanup at round 50]
# Early stopping triggered at round 61
# Training CSV results saved to /home/bosho/FP/results/IEEE/cora/Cora_full_GCN_beta10000_clients10_hop1_iter80_t1.0_alpha0.5/training_Cora_full_GCN_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_20260508_134516.csv
#   Test Batch 1/1: Testing clients 0 to 9 (parallel)
# Client test acc (macro): 0.8039
# Client test acc (micro): 0.8030
# Global test acc (client_test_graphs): 0.803
# 2026-05-08 13:45:39,787 - INFO - Memory after experiment - Allocated: 0.00GB, Cached: 0.00GB, Max: 0.18GB
# The global test results: [0.803]
# The client test results: [0.8039476471430108]
# Successful reps: [1], failed reps: []
# The average global test results: 0.803
# The average client test results: 0.8039476471430108
# The standard deviation global is: 0.0
# The standard deviation client is: 0.0
# Cleaning up driver memory...
#
# FP CSV FORMAT RESULT:
# Dataset,Model,DataLoading,Beta,Clients,Hop,UsePE,Seed,Status,TotalTime[s],LoadTime[s],ShardTime[s],PartitionTime[s],PropTime[s],ActorInitTime[s],TrainTime[s],EvalTime[s],CommTime[s],FinalAcc,BestAcc,PeakCPU[MB],PeakDriverGPU[MB],PeakActorGPU[MB],CommCost[MB],ModelSize[MB],TotalParams,ResultPath
# Cora,GCN,full,10000,10,1,False,,success,23.142,0.366,0.0,0.174,,6.386,13.461,1.432,,0.803,0.793368,1843.965,188.994,29.353,351.912,0.087978,23063,/home/bosho/FP/results/IEEE/cora/Cora_full_GCN_beta10000_clients10_hop1_iter80_t1.0_alpha0.5/results_Cora_full_GCN_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_20260508_134516.json
# Results saved to /home/bosho/FP/results/IEEE/cora/Cora_full_GCN_beta10000_clients10_hop1_iter80_t1.0_alpha0.5/results_Cora_full_GCN_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_20260508_134516.json
# Training CSV results saved to /home/bosho/FP/results/IEEE/cora/Cora_full_GCN_beta10000_clients10_hop1_iter80_t1.0_alpha0.5/training_Cora_full_GCN_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_20260508_134516.csv
#
# ================================================================================
# Running experiment: Cora_full_GAT_beta10000_clients10_hop1_iter80_t1.0_alpha0.5
# ================================================================================
# 2026-05-08 13:45:40,671 - INFO - Memory before experiment - Allocated: 0.00GB, Cached: 0.00GB, Max: 0.00GB
# ✓ Subgraphs staying on cuda (keep_data_on_gpu=True)
# Model: GAT(hidden_dim=8, num_heads=8, num_layers=2)
# [Server] Aggregation strategy: fedavg_weighted
# (FLClient pid=1950947) [Client 0] CVD=0 torch.cuda.is_available=True torch.cuda.device_count=1 requested_device=cuda [repeated 10x across cluster]
# (FLClient pid=1950947) Client 0: Using full-batch training for Cora dataset [repeated 10x across cluster]
# (FLClient pid=1950947) 2026-05-08 13:45:48,439 - INFO - Epoch   0| Train Loss: 1.971| Train Accuracy: 0.143| Val Loss: 2.042| Val Accuracy: 0.041 [repeated 419x across cluster]
# (FLClient pid=1950947) 2026-05-08 13:45:53,436 - INFO - Epoch   2| Train Loss: 0.358| Train Accuracy: 0.929| Val Loss: 0.893| Val Accuracy: 0.755 [repeated 542x across cluster]
# (FLClient pid=1950947) 2026-05-08 13:45:58,571 - INFO - Epoch   0| Train Loss: 0.094| Train Accuracy: 1.000| Val Loss: 0.654| Val Accuracy: 0.776 [repeated 568x across cluster]
#   [Memory cleanup at round 50]
# (FLClient pid=1950947) 2026-05-08 13:46:03,689 - INFO - Epoch   0| Train Loss: 0.093| Train Accuracy: 1.000| Val Loss: 0.695| Val Accuracy: 0.755 [repeated 540x across cluster]
# Early stopping triggered at round 63
# Training CSV results saved to /home/bosho/FP/results/IEEE/cora/Cora_full_GAT_beta10000_clients10_hop1_iter80_t1.0_alpha0.5/training_Cora_full_GAT_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_20260508_134540.csv
#   Test Batch 1/1: Testing clients 0 to 9 (parallel)
# Client test acc (macro): 0.7847
# Client test acc (micro): 0.7850
# Global test acc (client_test_graphs): 0.785
# 2026-05-08 13:46:08,006 - INFO - Memory after experiment - Allocated: 0.00GB, Cached: 0.00GB, Max: 0.18GB
# The global test results: [0.785]
# The client test results: [0.7847054161168575]
# Successful reps: [1], failed reps: []
# The average global test results: 0.785
# The average client test results: 0.7847054161168575
# The standard deviation global is: 0.0
# The standard deviation client is: 0.0
# Cleaning up driver memory...
#
# FP CSV FORMAT RESULT:
# Dataset,Model,DataLoading,Beta,Clients,Hop,UsePE,Seed,Status,TotalTime[s],LoadTime[s],ShardTime[s],PartitionTime[s],PropTime[s],ActorInitTime[s],TrainTime[s],EvalTime[s],CommTime[s],FinalAcc,BestAcc,PeakCPU[MB],PeakDriverGPU[MB],PeakActorGPU[MB],CommCost[MB],ModelSize[MB],TotalParams,ResultPath
# Cora,GAT,full,10000,10,1,False,,success,27.877,0.442,0.0,0.258,,6.367,18.143,1.492,,0.785,0.780836,1845.461,188.994,37.795,2816.832,0.704208,184604,/home/bosho/FP/results/IEEE/cora/Cora_full_GAT_beta10000_clients10_hop1_iter80_t1.0_alpha0.5/results_Cora_full_GAT_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_20260508_134540.json
# Results saved to /home/bosho/FP/results/IEEE/cora/Cora_full_GAT_beta10000_clients10_hop1_iter80_t1.0_alpha0.5/results_Cora_full_GAT_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_20260508_134540.json
# Training CSV results saved to /home/bosho/FP/results/IEEE/cora/Cora_full_GAT_beta10000_clients10_hop1_iter80_t1.0_alpha0.5/training_Cora_full_GAT_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_20260508_134540.csv
#
# ================================================================================
# Running experiment: Cora_zero_hop_GCN_beta10000_clients10_hop1_iter80_t1.0_alpha0.5
# ================================================================================
# 2026-05-08 13:46:08,891 - INFO - Memory before experiment - Allocated: 0.00GB, Cached: 0.00GB, Max: 0.00GB
# ✓ Subgraphs staying on cuda (keep_data_on_gpu=True)
# Model: GCN(hidden_dim=16, num_layers=2, dropout=0.5, normalization=none)
# [Server] Aggregation strategy: fedavg_weighted
# (FLClient pid=1951741) [Client 0] CVD=0 torch.cuda.is_available=True torch.cuda.device_count=1 requested_device=cuda [repeated 10x across cluster]
# (FLClient pid=1951741) Client 0: Using full-batch training for Cora dataset [repeated 10x across cluster]
# (FLClient pid=1951742) 2026-05-08 13:46:16,488 - INFO - Epoch   2| Train Loss: 1.705| Train Accuracy: 0.438| Val Loss: 1.937| Val Accuracy: 0.105 [repeated 272x across cluster]
# (FLClient pid=1951742) 2026-05-08 13:46:21,532 - INFO - Epoch   2| Train Loss: 0.276| Train Accuracy: 0.938| Val Loss: 1.227| Val Accuracy: 0.579 [repeated 720x across cluster]
# Early stopping triggered at round 38
# Training CSV results saved to /home/bosho/FP/results/IEEE/cora/Cora_zero_hop_GCN_beta10000_clients10_hop1_iter80_t1.0_alpha0.5/training_Cora_zero_hop_GCN_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_20260508_134608.csv
#   Test Batch 1/1: Testing clients 0 to 9 (parallel)
# Client test acc (macro): 0.6056
# Client test acc (micro): 0.6060
# Global test acc (client_test_graphs): 0.606
# 2026-05-08 13:46:26,287 - INFO - Memory after experiment - Allocated: 0.00GB, Cached: 0.00GB, Max: 0.18GB
# The global test results: [0.606]
# The client test results: [0.6055999330500641]
# Successful reps: [1], failed reps: []
# The average global test results: 0.606
# The average client test results: 0.6055999330500641
# The standard deviation global is: 0.0
# The standard deviation client is: 0.0
# Cleaning up driver memory...
#
# FP CSV FORMAT RESULT:
# Dataset,Model,DataLoading,Beta,Clients,Hop,UsePE,Seed,Status,TotalTime[s],LoadTime[s],ShardTime[s],PartitionTime[s],PropTime[s],ActorInitTime[s],TrainTime[s],EvalTime[s],CommTime[s],FinalAcc,BestAcc,PeakCPU[MB],PeakDriverGPU[MB],PeakActorGPU[MB],CommCost[MB],ModelSize[MB],TotalParams,ResultPath
# Cora,GCN,zero_hop,10000,10,1,False,,success,17.925,0.218,0.0,0.05,,6.307,8.463,1.394,,0.606,0.594898,1833.855,188.994,20.211,351.912,0.087978,23063,/home/bosho/FP/results/IEEE/cora/Cora_zero_hop_GCN_beta10000_clients10_hop1_iter80_t1.0_alpha0.5/results_Cora_zero_hop_GCN_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_20260508_134608.json
# Results saved to /home/bosho/FP/results/IEEE/cora/Cora_zero_hop_GCN_beta10000_clients10_hop1_iter80_t1.0_alpha0.5/results_Cora_zero_hop_GCN_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_20260508_134608.json
# Training CSV results saved to /home/bosho/FP/results/IEEE/cora/Cora_zero_hop_GCN_beta10000_clients10_hop1_iter80_t1.0_alpha0.5/training_Cora_zero_hop_GCN_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_20260508_134608.csv
#
# ================================================================================
# Running experiment: Cora_zero_hop_GAT_beta10000_clients10_hop1_iter80_t1.0_alpha0.5
# ================================================================================
# 2026-05-08 13:46:27,170 - INFO - Memory before experiment - Allocated: 0.00GB, Cached: 0.00GB, Max: 0.00GB
# ✓ Subgraphs staying on cuda (keep_data_on_gpu=True)
# Model: GAT(hidden_dim=8, num_heads=8, num_layers=2)
# [Server] Aggregation strategy: fedavg_weighted
# (FLClient pid=1952494) [Client 0] CVD=0 torch.cuda.is_available=True torch.cuda.device_count=1 requested_device=cuda [repeated 10x across cluster]
# (FLClient pid=1952494) Client 0: Using full-batch training for Cora dataset [repeated 10x across cluster]
# (FLClient pid=1952498) 2026-05-08 13:46:34,883 - INFO - Epoch   2| Train Loss: 1.596| Train Accuracy: 0.357| Val Loss: 1.935| Val Accuracy: 0.224 [repeated 450x across cluster]
# (FLClient pid=1952498) 2026-05-08 13:46:39,988 - INFO - Epoch   2| Train Loss: 0.690| Train Accuracy: 0.857| Val Loss: 1.313| Val Accuracy: 0.552 [repeated 570x across cluster]
# (FLClient pid=1952498) 2026-05-08 13:46:45,203 - INFO - Epoch   2| Train Loss: 0.232| Train Accuracy: 0.929| Val Loss: 1.154| Val Accuracy: 0.621 [repeated 570x across cluster]
#   [Memory cleanup at round 50]
# Early stopping triggered at round 53
# Training CSV results saved to /home/bosho/FP/results/IEEE/cora/Cora_zero_hop_GAT_beta10000_clients10_hop1_iter80_t1.0_alpha0.5/training_Cora_zero_hop_GAT_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_20260508_134626.csv
#   Test Batch 1/1: Testing clients 0 to 9 (parallel)
# Client test acc (macro): 0.6106
# Client test acc (micro): 0.6110
# Global test acc (client_test_graphs): 0.611
# 2026-05-08 13:46:51,408 - INFO - Memory after experiment - Allocated: 0.00GB, Cached: 0.00GB, Max: 0.18GB
# The global test results: [0.611]
# The client test results: [0.6105771721599326]
# Successful reps: [1], failed reps: []
# The average global test results: 0.611
# The average client test results: 0.6105771721599326
# The standard deviation global is: 0.0
# The standard deviation client is: 0.0
# Cleaning up driver memory...
#
# FP CSV FORMAT RESULT:
# Dataset,Model,DataLoading,Beta,Clients,Hop,UsePE,Seed,Status,TotalTime[s],LoadTime[s],ShardTime[s],PartitionTime[s],PropTime[s],ActorInitTime[s],TrainTime[s],EvalTime[s],CommTime[s],FinalAcc,BestAcc,PeakCPU[MB],PeakDriverGPU[MB],PeakActorGPU[MB],CommCost[MB],ModelSize[MB],TotalParams,ResultPath
# Cora,GAT,zero_hop,10000,10,1,False,,success,24.766,0.219,0.0,0.047,,6.369,15.267,1.374,,0.611,0.606744,1837.844,188.994,22.231,2816.832,0.704208,184604,/home/bosho/FP/results/IEEE/cora/Cora_zero_hop_GAT_beta10000_clients10_hop1_iter80_t1.0_alpha0.5/results_Cora_zero_hop_GAT_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_20260508_134626.json
# Results saved to /home/bosho/FP/results/IEEE/cora/Cora_zero_hop_GAT_beta10000_clients10_hop1_iter80_t1.0_alpha0.5/results_Cora_zero_hop_GAT_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_20260508_134626.json
# Training CSV results saved to /home/bosho/FP/results/IEEE/cora/Cora_zero_hop_GAT_beta10000_clients10_hop1_iter80_t1.0_alpha0.5/training_Cora_zero_hop_GAT_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_20260508_134626.csv
#
# ================================================================================
# Running experiment: Cora_adjacency_GCN_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_pe
# ================================================================================
# 2026-05-08 13:46:52,291 - INFO - Memory before experiment - Allocated: 0.00GB, Cached: 0.00GB, Max: 0.00GB
# [client 0] FP on GPU succeeded
# [client 1] FP on GPU succeeded
# [client 2] FP on GPU succeeded
# [client 3] FP on GPU succeeded
# [client 4] FP on GPU succeeded
# [client 5] FP on GPU succeeded
# [client 6] FP on GPU succeeded
# [client 7] FP on GPU succeeded
# [client 8] FP on GPU succeeded
# [client 9] FP on GPU succeeded
# ✓ Subgraphs staying on cuda (keep_data_on_gpu=True)
# Model: GCN(hidden_dim=16, num_layers=2, dropout=0.5, normalization=none)
# [Server] Aggregation strategy: fedavg_weighted
# (FLClient pid=1953273) [Client 1] CVD=0 torch.cuda.is_available=True torch.cuda.device_count=1 requested_device=cuda [repeated 10x across cluster]
# (FLClient pid=1953273) Client 1: Using full-batch training for Cora dataset [repeated 10x across cluster]
# (FLClient pid=1953273) 2026-05-08 13:47:00,653 - INFO - Epoch   2| Train Loss: 1.847| Train Accuracy: 0.375| Val Loss: 2.005| Val Accuracy: 0.105 [repeated 480x across cluster]
# (FLClient pid=1953273) 2026-05-08 13:47:05,670 - INFO - Epoch   2| Train Loss: 1.123| Train Accuracy: 0.875| Val Loss: 1.702| Val Accuracy: 0.395 [repeated 609x across cluster]
# (FLClient pid=1953273) 2026-05-08 13:47:10,850 - INFO - Epoch   2| Train Loss: 0.541| Train Accuracy: 0.938| Val Loss: 1.265| Val Accuracy: 0.605 [repeated 630x across cluster]
#   [Memory cleanup at round 50]
# (FLClient pid=1953273) 2026-05-08 13:47:15,909 - INFO - Epoch   2| Train Loss: 0.330| Train Accuracy: 0.938| Val Loss: 1.019| Val Accuracy: 0.711 [repeated 609x across cluster]
# (FLClient pid=1953273) 2026-05-08 13:47:21,134 - INFO - Epoch   2| Train Loss: 0.166| Train Accuracy: 1.000| Val Loss: 0.959| Val Accuracy: 0.684 [repeated 612x across cluster]
#   [Memory cleanup at round 100]
# (FLClient pid=1953273) 2026-05-08 13:47:26,477 - INFO - Epoch   0| Train Loss: 0.067| Train Accuracy: 1.000| Val Loss: 0.803| Val Accuracy: 0.763 [repeated 628x across cluster]
# Early stopping triggered at round 118
# Training CSV results saved to /home/bosho/FP/results/IEEE/cora/Cora_adjacency_GCN_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_pe/training_Cora_adjacency_GCN_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_pe_20260508_134652.csv
#   Test Batch 1/1: Testing clients 0 to 9 (parallel)
# Client test acc (macro): 0.7469
# Client test acc (micro): 0.7460
# Global test acc (client_test_graphs): 0.746
# 2026-05-08 13:47:32,191 - INFO - Memory after experiment - Allocated: 0.00GB, Cached: 0.00GB, Max: 0.19GB
# The global test results: [0.746]
# The client test results: [0.746919492344205]
# Successful reps: [1], failed reps: []
# The average global test results: 0.746
# The average client test results: 0.746919492344205
# The standard deviation global is: 0.0
# The standard deviation client is: 0.0
# Cleaning up driver memory...
#
# FP CSV FORMAT RESULT:
# Dataset,Model,DataLoading,Beta,Clients,Hop,UsePE,Seed,Status,TotalTime[s],LoadTime[s],ShardTime[s],PartitionTime[s],PropTime[s],ActorInitTime[s],TrainTime[s],EvalTime[s],CommTime[s],FinalAcc,BestAcc,PeakCPU[MB],PeakDriverGPU[MB],PeakActorGPU[MB],CommCost[MB],ModelSize[MB],TotalParams,ResultPath
# Cora,GCN,adjacency,10000,10,1,True,,success,40.441,0.228,0.0,1.1,0.803,6.368,30.076,1.502,,0.746,0.736792,1894.965,192.155,38.5,617.54,0.154385,40471,/home/bosho/FP/results/IEEE/cora/Cora_adjacency_GCN_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_pe/results_Cora_adjacency_GCN_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_pe_20260508_134652.json
# Results saved to /home/bosho/FP/results/IEEE/cora/Cora_adjacency_GCN_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_pe/results_Cora_adjacency_GCN_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_pe_20260508_134652.json
# Training CSV results saved to /home/bosho/FP/results/IEEE/cora/Cora_adjacency_GCN_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_pe/training_Cora_adjacency_GCN_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_pe_20260508_134652.csv
#
# ================================================================================
# Running experiment: Cora_adjacency_GAT_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_pe
# ================================================================================
# 2026-05-08 13:47:33,084 - INFO - Memory before experiment - Allocated: 0.00GB, Cached: 0.00GB, Max: 0.00GB
# [client 0] FP on GPU succeeded
# [client 1] FP on GPU succeeded
# [client 2] FP on GPU succeeded
# [client 3] FP on GPU succeeded
# [client 4] FP on GPU succeeded
# [client 5] FP on GPU succeeded
# [client 6] FP on GPU succeeded
# [client 7] FP on GPU succeeded
# [client 8] FP on GPU succeeded
# [client 9] FP on GPU succeeded
# ✓ Subgraphs staying on cuda (keep_data_on_gpu=True)
# Model: GAT(hidden_dim=8, num_heads=8, num_layers=2)
# [Server] Aggregation strategy: fedavg_weighted
# (FLClient pid=1954129) [Client 1] CVD=0 torch.cuda.is_available=True torch.cuda.device_count=1 requested_device=cuda [repeated 10x across cluster]
# (FLClient pid=1954129) Client 1: Using full-batch training for Cora dataset [repeated 10x across cluster]
# (FLClient pid=1954128) 2026-05-08 13:47:41,605 - INFO - Epoch   2| Train Loss: 1.703| Train Accuracy: 0.357| Val Loss: 2.243| Val Accuracy: 0.041 [repeated 482x across cluster]
# (FLClient pid=1954128) 2026-05-08 13:47:46,805 - INFO - Epoch   0| Train Loss: 1.388| Train Accuracy: 0.714| Val Loss: 1.845| Val Accuracy: 0.122 [repeated 538x across cluster]
# (FLClient pid=1954128) 2026-05-08 13:47:51,902 - INFO - Epoch   0| Train Loss: 0.655| Train Accuracy: 0.857| Val Loss: 1.409| Val Accuracy: 0.408 [repeated 540x across cluster]
#   [Memory cleanup at round 50]
# (FLClient pid=1954128) 2026-05-08 13:47:56,845 - INFO - Epoch   2| Train Loss: 0.240| Train Accuracy: 1.000| Val Loss: 1.180| Val Accuracy: 0.592 [repeated 521x across cluster]
# (FLClient pid=1954128) 2026-05-08 13:48:02,229 - INFO - Epoch   0| Train Loss: 0.203| Train Accuracy: 1.000| Val Loss: 0.973| Val Accuracy: 0.673 [repeated 559x across cluster]
# Early stopping triggered at round 75
# Training CSV results saved to /home/bosho/FP/results/IEEE/cora/Cora_adjacency_GAT_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_pe/training_Cora_adjacency_GAT_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_pe_20260508_134732.csv
#   Test Batch 1/1: Testing clients 0 to 9 (parallel)
# Client test acc (macro): 0.7522
# Client test acc (micro): 0.7510
# Global test acc (client_test_graphs): 0.751
# 2026-05-08 13:48:05,183 - INFO - Memory after experiment - Allocated: 0.00GB, Cached: 0.00GB, Max: 0.19GB
# The global test results: [0.751]
# The client test results: [0.7522049564881124]
# Successful reps: [1], failed reps: []
# The average global test results: 0.751
# The average client test results: 0.7522049564881124
# The standard deviation global is: 0.0
# The standard deviation client is: 0.0
# Cleaning up driver memory...
#
# FP CSV FORMAT RESULT:
# Dataset,Model,DataLoading,Beta,Clients,Hop,UsePE,Seed,Status,TotalTime[s],LoadTime[s],ShardTime[s],PartitionTime[s],PropTime[s],ActorInitTime[s],TrainTime[s],EvalTime[s],CommTime[s],FinalAcc,BestAcc,PeakCPU[MB],PeakDriverGPU[MB],PeakActorGPU[MB],CommCost[MB],ModelSize[MB],TotalParams,ResultPath
# Cora,GAT,adjacency,10000,10,1,True,,success,32.629,0.365,0.0,0.91,0.651,6.442,22.156,1.518,,0.751,0.709119,1896.113,192.155,47.322,4941.832,1.235458,323868,/home/bosho/FP/results/IEEE/cora/Cora_adjacency_GAT_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_pe/results_Cora_adjacency_GAT_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_pe_20260508_134732.json
# Results saved to /home/bosho/FP/results/IEEE/cora/Cora_adjacency_GAT_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_pe/results_Cora_adjacency_GAT_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_pe_20260508_134732.json
# Training CSV results saved to /home/bosho/FP/results/IEEE/cora/Cora_adjacency_GAT_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_pe/training_Cora_adjacency_GAT_beta10000_clients10_hop1_iter80_t1.0_alpha0.5_pe_20260508_134732.csv
# (FLClient pid=1954137) [Client 9] CVD=0 torch.cuda.is_available=True torch.cuda.device_count=1 requested_device=cuda [repeated 9x across cluster]
# (FLClient pid=1954137) Client 9: Using full-batch training for Cora dataset [repeated 9x across cluster]
# (FLClient pid=1954137) 2026-05-08 13:48:03,163 - INFO - Epoch   2| Train Loss: 0.123| Train Accuracy: 1.000| Val Loss: 1.039| Val Accuracy: 0.733 [repeated 119x across cluster]
# - Provenance: /home/bosho/FP/results_summary/cora/provenance_sweep_20260508_134807.json
#
# Summary results saved to:
# - Text file: /home/bosho/FP/results_summary/cora/summary_results_20260508_134807.txt
# - JSON file: /home/bosho/FP/results_summary/cora/summary_results_20260508_134807.json
# - Scalability CSV: /home/bosho/FP/results_summary/cora/scalability_20260508_134807.csv
# - Detailed results saved to: /home/bosho/FP/results/IEEE/cora
#
#
#
# ================================================================================
# EXPERIMENT RESULTS SUMMARY
# ================================================================================
# +-----------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+--------+-----+---------+
# | Dataset   | Data Loading   | Model   |   Beta |   Clients |   Avg Global Result |   Avg Client Result |   client_std_dev |   global_std_dev | Duration   |   Hop | Use PE   |   Iter |   t |   alpha |
# +===========+================+=========+========+===========+=====================+=====================+==================+==================+============+=======+==========+========+=====+=========+
# | Cora      | diffusion      | GCN     |  10000 |        10 |               0.754 |              0.7537 |                0 |                0 | 00:00:46   |     1 | True     |     80 |   1 |     0.5 |
# +-----------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+--------+-----+---------+
# | Cora      | diffusion      | GAT     |  10000 |        10 |               0.767 |              0.767  |                0 |                0 | 00:00:56   |     1 | True     |     80 |   1 |     0.5 |
# +-----------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+--------+-----+---------+
# | Cora      | full           | GCN     |  10000 |        10 |               0.803 |              0.8039 |                0 |                0 | 00:00:23   |     1 | False    |     80 |   1 |     0.5 |
# +-----------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+--------+-----+---------+
# | Cora      | full           | GAT     |  10000 |        10 |               0.785 |              0.7847 |                0 |                0 | 00:00:27   |     1 | False    |     80 |   1 |     0.5 |
# +-----------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+--------+-----+---------+
# | Cora      | zero_hop       | GCN     |  10000 |        10 |               0.606 |              0.6056 |                0 |                0 | 00:00:17   |     1 | False    |     80 |   1 |     0.5 |
# +-----------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+--------+-----+---------+
# | Cora      | zero_hop       | GAT     |  10000 |        10 |               0.611 |              0.6106 |                0 |                0 | 00:00:24   |     1 | False    |     80 |   1 |     0.5 |
# +-----------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+--------+-----+---------+
# | Cora      | adjacency      | GCN     |  10000 |        10 |               0.746 |              0.7469 |                0 |                0 | 00:00:40   |     1 | True     |     80 |   1 |     0.5 |
# +-----------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+--------+-----+---------+
# | Cora      | adjacency      | GAT     |  10000 |        10 |               0.751 |              0.7522 |                0 |                0 | 00:00:32   |     1 | True     |     80 |   1 |     0.5 |
# +-----------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+--------+-----+---------+
#
#
# KEY RESULTS:
# --------------------------------------------------------------------------------
# Cora with diffusion using GCN (beta=10000.00, clients=10, hop=1, use_pe=True, iter=80, t=1.0, alpha=0.5):
#   - Average Global Result: 0.7540
#   - Average Client Result: 0.7537
#   - Client StdDev: 0.0000
#   - Global StdDev: 0.0000
#   - Experiment Duration: 00:00:46
# --------------------------------------------------------------------------------
# Cora with diffusion using GAT (beta=10000.00, clients=10, hop=1, use_pe=True, iter=80, t=1.0, alpha=0.5):
#   - Average Global Result: 0.7670
#   - Average Client Result: 0.7670
#   - Client StdDev: 0.0000
#   - Global StdDev: 0.0000
#   - Experiment Duration: 00:00:56
# --------------------------------------------------------------------------------
# Cora with full using GCN (beta=10000.00, clients=10, hop=1, use_pe=False, iter=80, t=1.0, alpha=0.5):
#   - Average Global Result: 0.8030
#   - Average Client Result: 0.8039
#   - Client StdDev: 0.0000
#   - Global StdDev: 0.0000
#   - Experiment Duration: 00:00:23
# --------------------------------------------------------------------------------
# Cora with full using GAT (beta=10000.00, clients=10, hop=1, use_pe=False, iter=80, t=1.0, alpha=0.5):
#   - Average Global Result: 0.7850
#   - Average Client Result: 0.7847
#   - Client StdDev: 0.0000
#   - Global StdDev: 0.0000
#   - Experiment Duration: 00:00:27
# --------------------------------------------------------------------------------
# Cora with zero_hop using GCN (beta=10000.00, clients=10, hop=1, use_pe=False, iter=80, t=1.0, alpha=0.5):
#   - Average Global Result: 0.6060
#   - Average Client Result: 0.6056
#   - Client StdDev: 0.0000
#   - Global StdDev: 0.0000
#   - Experiment Duration: 00:00:17
# --------------------------------------------------------------------------------
# Cora with zero_hop using GAT (beta=10000.00, clients=10, hop=1, use_pe=False, iter=80, t=1.0, alpha=0.5):
#   - Average Global Result: 0.6110
#   - Average Client Result: 0.6106
#   - Client StdDev: 0.0000
#   - Global StdDev: 0.0000
#   - Experiment Duration: 00:00:24
# --------------------------------------------------------------------------------
# Cora with adjacency using GCN (beta=10000.00, clients=10, hop=1, use_pe=True, iter=80, t=1.0, alpha=0.5):
#   - Average Global Result: 0.7460
#   - Average Client Result: 0.7469
#   - Client StdDev: 0.0000
#   - Global StdDev: 0.0000
#   - Experiment Duration: 00:00:40
# --------------------------------------------------------------------------------
# Cora with adjacency using GAT (beta=10000.00, clients=10, hop=1, use_pe=True, iter=80, t=1.0, alpha=0.5):
#   - Average Global Result: 0.7510
#   - Average Client Result: 0.7522
#   - Client StdDev: 0.0000
#   - Global StdDev: 0.0000
#   - Experiment Duration: 00:00:32
# --------------------------------------------------------------------------------

# %%
# !python -m src.experiments.run_experiments --config conf/photos_config.yaml

# %%
# !python -m src.experiments.run_experiments --config conf/photos_config.yaml

# %%
# !python -m src.experiments.run_experiments --config conf/ogbn-arxiv_config.yaml

# %%
# !python -m src.experiments.run_experiments --config conf/ogbn-arxiv_config.yaml

# %%
# !python -m src.experiments.run_experiments --config conf/ogbn-arxiv_config.yaml
