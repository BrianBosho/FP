# %%
# !python -m src.experiments.run_experiments --config conf/ablation/ogbn-arxiv_config.yaml

# %%
# !python -m src.experiments.run_experiments --config conf/ablation/cora_gcn_no_pe.yaml

# %%
# !python -m src.experiments.run_experiments --config conf/ablation/ogbn-arxiv_config.yaml
# Out:
# Experiment Configuration:
# - Clients: [1]
# - Rounds: 10
# - Epochs: 3
# - Learning Rate: 0.5
# - Beta values: [1]
# - Datasets: ['ogbn-arxiv']
# - Data Loading Options: ['full']
# - Model Types: ['GCN']
# - Results Directory: /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv
# - Save Detailed Results: False
# - Hop: 1
# - Full Training Flag: False
#
# ================================================================================
# Running experiment: ogbn-arxiv_full_GCN_beta1_clients1
# ================================================================================
# DEVICE: cuda
# Data loading option is full
# Model type is GCN
# 2025-10-07 12:13:41,368	INFO worker.py:1807 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# wandb: Currently logged in as: bosho to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /home/brian_bosho/FP/FP/federated-gnn/wandb/run-20251007_121342-64epvftq
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run eternal-cherry-544
# wandb: ⭐️ View project at https://wandb.ai/bosho/FGL3
# wandb: 🚀 View run at https://wandb.ai/bosho/FGL3/runs/64epvftq
# [WANDB DEBUG] Successfully initialized wandb run: eternal-cherry-544
# Wandb config is set to: {'dataset': 'ogbn-arxiv', 'model': 'GCN', 'data_loading': 'full', 'num_clients': [1], 'num_rounds': 10, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 1, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': 64, 'pe_P': 16, 'normalize': 'qr', 'run_index': 1, 'num_iterations': 80}
# {'dataset': 'ogbn-arxiv', 'model': 'GCN', 'data_loading': 'full', 'num_clients': [1], 'num_rounds': 10, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 1, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': 64, 'pe_P': 16, 'normalize': 'qr', 'run_index': 1, 'num_iterations': 80}
# data_loading_option: full
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/ogb/nodeproppred/dataset_pyg.py:69: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.data, self.slices = torch.load(self.processed_paths[0])
# Tolerance: 1e-6
# (raylet) [2025-10-07 12:13:51,258 E 2222436 2222466] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2025-10-07_12-13-40_168377_2222176 is over 95% full, available space: 29901484032; capacity: 1622224654336. Object creation will fail if spilling is required.
# partition_time_s: 8.25
# client[0] device: cuda:0 cuda:0
# client[0] feature_dim: 128
# config.use_pe: False num_iterations: 80 feature_prop_device: None
# data_loading_option: full hop: 1 num_clients: 1
#
# === DATA LOADING SUMMARY ===
# Full graph: 169343 nodes, 2484941 edges
# Number of client subgraphs: 1
# First client subgraph shape: torch.Size([169343, 128])
# Dataset: PygNodePropPredDataset()
# Device: cuda
#
# Full graph device (before): cuda:0
# Full graph staying on CPU to save GPU memory
# ===========================
#
# Model is GCN_arxiv(
#   (convs): ModuleList(
#     (0): GCNConv(128, 256)
#     (1): GCNConv(256, 256)
#     (2): GCNConv(256, 40)
#   )
#   (bns): ModuleList(
#     (0-1): 2 x BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
#
# === CLIENT DATA LOADING ===
# Full graph size: 169343 nodes
# Number of clients: 1
# Client 0 subgraph: 169343 nodes, 128 features
# ===========================
#
# Input dim of the model in server: 128
# (FLClient pid=2222525)
# (FLClient pid=2222525) [Client 0] Initializing with:
# (FLClient pid=2222525)   - Input data nodes: 169343
# (FLClient pid=2222525)   - Input data edges: 2484941
# (FLClient pid=2222525)   - Feature shape: torch.Size([169343, 128])
# (FLClient pid=2222525)   - Data device (before moving): cuda:0
# (FLClient pid=2222525)   - Input dim: 128
# (FLClient pid=2222525)   - Data device (after moving): cuda:0
# (FLClient pid=2222525) Client 0: Using full-batch training for ogbn-arxiv dataset
# (FLClient pid=2222525) 2025-10-07 12:13:57,519 - INFO - Epoch   0| Train Loss: 4.173| Train Accuracy: 0.027| Val Loss: 3.642| Val Accuracy: 0.051
# (FLClient pid=2222525) 2025-10-07 12:13:57,671 - INFO - Epoch   1| Train Loss: 3.151| Train Accuracy: 0.229| Val Loss: 3.563| Val Accuracy: 0.258
# (FLClient pid=2222525) 2025-10-07 12:13:57,822 - INFO - Epoch   2| Train Loss: 2.624| Train Accuracy: 0.356| Val Loss: 3.553| Val Accuracy: 0.239
# (FLClient pid=2222525) 2025-10-07 12:13:58,565 - INFO - Epoch   0| Train Loss: 2.325| Train Accuracy: 0.445| Val Loss: 3.493| Val Accuracy: 0.303
# (FLClient pid=2222525) 2025-10-07 12:13:58,716 - INFO - Epoch   1| Train Loss: 2.239| Train Accuracy: 0.443| Val Loss: 3.509| Val Accuracy: 0.239
# (FLClient pid=2222525) 2025-10-07 12:13:58,868 - INFO - Epoch   2| Train Loss: 2.056| Train Accuracy: 0.503| Val Loss: 3.444| Val Accuracy: 0.306
# (FLClient pid=2222525) 2025-10-07 12:14:04,972 - INFO - Epoch   1| Train Loss: 1.424| Train Accuracy: 0.623| Val Loss: 2.769| Val Accuracy: 0.433
# (FLClient pid=2222525) 2025-10-07 12:14:05,123 - INFO - Epoch   2| Train Loss: 1.416| Train Accuracy: 0.623| Val Loss: 2.720| Val Accuracy: 0.431
# (FLClient pid=2222525) 2025-10-07 12:14:05,859 - INFO - Epoch   0| Train Loss: 1.405| Train Accuracy: 0.626| Val Loss: 2.671| Val Accuracy: 0.447
# (FLClient pid=2222525) 2025-10-07 12:14:06,010 - INFO - Epoch   1| Train Loss: 1.392| Train Accuracy: 0.627| Val Loss: 2.617| Val Accuracy: 0.455
# (FLClient pid=2222525) 2025-10-07 12:14:06,162 - INFO - Epoch   2| Train Loss: 1.381| Train Accuracy: 0.631| Val Loss: 2.568| Val Accuracy: 0.459
# (FLClient pid=2222525) 2025-10-07 12:14:06,892 - INFO - Epoch   0| Train Loss: 1.372| Train Accuracy: 0.632| Val Loss: 2.513| Val Accuracy: 0.466
# (FLClient pid=2222525) 2025-10-07 12:14:07,044 - INFO - Epoch   1| Train Loss: 1.362| Train Accuracy: 0.635| Val Loss: 2.449| Val Accuracy: 0.476
# (FLClient pid=2222525) 2025-10-07 12:14:07,195 - INFO - Epoch   2| Train Loss: 1.357| Train Accuracy: 0.635| Val Loss: 2.390| Val Accuracy: 0.495
# training_time_s: 14.9
# Training done
# Round 1
# Train Loss: 3.553, Train Accuracy: 0.356
# Round 2
# Train Loss: 3.444, Train Accuracy: 0.503
# Round 3
# Train Loss: 3.370, Train Accuracy: 0.545
# Round 4
# Train Loss: 3.253, Train Accuracy: 0.582
# Round 5
# Train Loss: 3.139, Train Accuracy: 0.597
# Round 6
# Train Loss: 3.012, Train Accuracy: 0.609
# Round 7
# Train Loss: 2.869, Train Accuracy: 0.619
# Round 8
# Train Loss: 2.720, Train Accuracy: 0.623
# Round 9
# Train Loss: 2.568, Train Accuracy: 0.631
# Round 10
# Train Loss: 2.390, Train Accuracy: 0.635
# Validation Loss: 2.390, Validation Accuracy: 0.495
# Training CSV results saved to /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv/ogbn-arxiv_full_GCN_beta1_clients1/training_ogbn-arxiv_full_GCN_beta1_clients1_20251007_121340.csv
#
# --- Model Parameter Comparison ---
#
# Layer 0:
# Server param shape: (256,)
# Client param shapes: [(256,)]
# ✅ Parameters match!
#
# Layer 1:
# Server param shape: (256, 128)
# Client param shapes: [(256, 128)]
# ✅ Parameters match!
#
# Layer 2:
# Server param shape: (256,)
# Client param shapes: [(256,)]
# ✅ Parameters match!
#
# Layer 3:
# Server param shape: (256, 256)
# Client param shapes: [(256, 256)]
# ✅ Parameters match!
#
# Layer 4:
# Server param shape: (40,)
# Client param shapes: [(40,)]
# ✅ Parameters match!
#
# Layer 5:
# Server param shape: (40, 256)
# Client param shapes: [(40, 256)]
# ✅ Parameters match!
#
# Layer 6:
# Server param shape: (256,)
# Client param shapes: [(256,)]
# ✅ Parameters match!
#
# Layer 7:
# Server param shape: (256,)
# Client param shapes: [(256,)]
# ✅ Parameters match!
#
# Layer 8:
# Server param shape: (256,)
# Client param shapes: [(256,)]
# ✅ Parameters match!
#
# Layer 9:
# Server param shape: (256,)
# Client param shapes: [(256,)]
# ✅ Parameters match!
#
# All model parameters are identical: True
# Input dim of the model in server: 128
# Input dim of the test data in server: 128
# Server: Using mini-batch testing for large dataset with 169343 nodes
# (FLClient pid=2222525) Input dim of the model: 128
# (FLClient pid=2222525) Input dim of the data: 128
# [WANDB DEBUG] Logging test metrics - Global: 0.397809621031671, Clients: [0.5172725963417896], Epoch: 10
# [WANDB DEBUG] Logging metrics: {'round': 10, 'test/global_test_acc': 0.397809621031671, 'test/avg_client_test_acc': np.float64(0.5172725963417896), 'test/client_test_acc_std': np.float64(0.0), 'test/num_clients': 1, 'test/global_vs_avg_client_diff': np.float64(-0.11946297531011857)} with step: 10
# [WANDB DEBUG] Successfully logged test metrics
# The average client test results: 0.5172725963417896
# The final global test results: 0.397809621031671
# Round 1 is complete
# wandb: ⢿ uploading output.log 10.9KB/10.9KB (0.7s)
# wandb: ⢿ uploading config.yaml 2.5KB/2.5KB (0.4s)
# wandb: ⣻ uploading output.log 10.9KB/10.9KB (0.7s)
# wandb: ⣻ uploading config.yaml 2.5KB/2.5KB (0.4s)
# wandb: ⣽ uploading output.log 10.9KB/10.9KB (0.7s)
# wandb: ⣽ uploading config.yaml 2.5KB/2.5KB (0.4s)
# wandb: ⣾ uploading output.log 10.9KB/10.9KB (0.7s)
# wandb: ⣾ uploading config.yaml 2.5KB/2.5KB (0.4s)
# (raylet) [2025-10-07 12:14:11,267 E 2222436 2222466] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2025-10-07_12-13-40_168377_2222176 is over 95% full, available space: 29901471744; capacity: 1622224654336. Object creation will fail if spilling is required.
# wandb: ⣷ uploading output.log 10.9KB/10.9KB (0.7s)
# wandb: ⣷ uploading config.yaml 2.5KB/2.5KB (0.4s)
# wandb: ⣯ uploading output.log 10.9KB/10.9KB (0.7s)
# wandb: ⣯ uploading config.yaml 2.5KB/2.5KB (0.4s)
# wandb: ⣟ uploading output.log 10.9KB/10.9KB (0.7s)
# wandb: ⣟ uploading config.yaml 2.5KB/2.5KB (0.4s)
# wandb: ⡿ uploading output.log 10.9KB/10.9KB (0.7s)
# wandb: ⡿ uploading config.yaml 2.5KB/2.5KB (0.4s)
# wandb: ⢿ uploading output.log 10.9KB/10.9KB (0.7s)
# wandb: ⢿ uploading config.yaml 2.5KB/2.5KB (0.4s)
# wandb: ⣻ uploading history steps 0-10, summary, console lines 58-171 (0.4s)
# wandb: ⣽ uploading history steps 0-10, summary, console lines 58-171 (0.4s)
# wandb:
# wandb: ⣽ uploading history steps 0-10, summary, console lines 58-171 (0.4s)
# wandb:
# wandb: Run history:
# wandb:  federation/avg_client_train_acc ▁▅▆▇▇▇████
# wandb: federation/avg_client_train_loss █▇▇▆▆▅▄▃▂▁
# wandb:    federation/avg_client_val_acc ▁▃▁▃▃▅▆▆▇█
# wandb:   federation/avg_client_val_loss █▇▇▆▆▅▄▃▂▁
# wandb:                            round ▁▂▂▃▄▅▅▆▇▇█
# wandb:           run_client_test_result ▁
# wandb:           run_global_test_result ▁
# wandb:         test/avg_client_test_acc ▁
# wandb:         test/client_test_acc_std ▁
# wandb:             test/global_test_acc ▁
# wandb:   test/global_vs_avg_client_diff ▁
# wandb:                 test/num_clients ▁
# wandb:
# wandb: Run summary:
# wandb:  federation/avg_client_train_acc 0.6349
# wandb: federation/avg_client_train_loss 2.38964
# wandb:    federation/avg_client_val_acc 0.49502
# wandb:   federation/avg_client_val_loss 2.38964
# wandb:                            round 10
# wandb:           run_client_test_result 0.51727
# wandb:           run_global_test_result 0.39781
# wandb:         test/avg_client_test_acc 0.51727
# wandb:         test/client_test_acc_std 0
# wandb:             test/global_test_acc 0.39781
# wandb:   test/global_vs_avg_client_diff -0.11946
# wandb:                 test/num_clients 1
# wandb:
# wandb: 🚀 View run GCN_ogbn-arxiv_SGD_lr0.5_decay0.0005_beta1_run1 at: https://wandb.ai/bosho/FGL3/runs/64epvftq
# wandb: ⭐️ View project at: https://wandb.ai/bosho/FGL3
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251007_121342-64epvftq/logs
# The global test results: [0.397809621031671]
# The client test results: [0.5172725963417896]
# The average global test results: 0.397809621031671
# The average client test results: 0.5172725963417896
# The standard deviation global is: 0.0
# The standard deviation client is: 0.0
# Training CSV results saved to /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv/ogbn-arxiv_full_GCN_beta1_clients1/training_ogbn-arxiv_full_GCN_beta1_clients1_20251007_121340.csv
#
# Summary results saved to:
# - Text file: /home/brian_bosho/FP/FP/federated-gnn/results/review/results_summary/ogbn-arxiv/summary_results_20251007_121413.txt
# - JSON file: /home/brian_bosho/FP/FP/federated-gnn/results/review/results_summary/ogbn-arxiv/summary_results_20251007_121413.json
# - Detailed results saved to: /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv
#
#
#
# ================================================================================
# EXPERIMENT RESULTS SUMMARY
# ================================================================================
# +------------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+
# | Dataset    | Data Loading   | Model   |   Beta |   Clients |   Avg Global Result |   Avg Client Result |   client_std_dev |   global_std_dev | Duration   |   Hop | Use PE   |
# +============+================+=========+========+===========+=====================+=====================+==================+==================+============+=======+==========+
# | ogbn-arxiv | full           | GCN     |      1 |         1 |              0.3978 |              0.5173 |                0 |                0 | 00:00:33   |     1 | False    |
# +------------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+
#
#
# KEY RESULTS:
# --------------------------------------------------------------------------------
# ogbn-arxiv with full using GCN (beta=1.00, clients=1, hop=1, use_pe=False):
#   - Average Global Result: 0.3978
#   - Average Client Result: 0.5173
#   - Client StdDev: 0.0000
#   - Global StdDev: 0.0000
#   - Experiment Duration: 00:00:33
# --------------------------------------------------------------------------------

# %%
# !python -m src.experiments.run_experiments --config conf/ablation/ogbn-arxiv_config.yaml
# Out:
# Experiment Configuration:
# - Clients: [1]
# - Rounds: 10
# - Epochs: 3
# - Learning Rate: 0.5
# - Beta values: [1]
# - Datasets: ['ogbn-arxiv']
# - Data Loading Options: ['full']
# - Model Types: ['GCN']
# - Results Directory: /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv
# - Save Detailed Results: False
# - Hop: 1
# - Full Training Flag: False
#
# ================================================================================
# Running experiment: ogbn-arxiv_full_GCN_beta1_clients1
# ================================================================================
# DEVICE: cuda
# Data loading option is full
# Model type is GCN
# 2025-10-07 13:02:33,456	INFO worker.py:1807 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# wandb: Currently logged in as: bosho to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /home/brian_bosho/FP/FP/federated-gnn/wandb/run-20251007_130235-zwwagdpa
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run swept-glade-546
# wandb: ⭐️ View project at https://wandb.ai/bosho/FGL3
# wandb: 🚀 View run at https://wandb.ai/bosho/FGL3/runs/zwwagdpa
# [WANDB DEBUG] Successfully initialized wandb run: swept-glade-546
# Wandb config is set to: {'dataset': 'ogbn-arxiv', 'model': 'GCN', 'data_loading': 'full', 'num_clients': [1], 'num_rounds': 10, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 1, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': 64, 'pe_P': 16, 'normalize': 'qr', 'run_index': 1, 'num_iterations': 80}
# {'dataset': 'ogbn-arxiv', 'model': 'GCN', 'data_loading': 'full', 'num_clients': [1], 'num_rounds': 10, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 1, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': 64, 'pe_P': 16, 'normalize': 'qr', 'run_index': 1, 'num_iterations': 80}
# data_loading_option: full
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/ogb/nodeproppred/dataset_pyg.py:69: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.data, self.slices = torch.load(self.processed_paths[0])
# Tolerance: 1e-6
# (raylet) [2025-10-07 13:02:43,357 E 2244592 2244622] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2025-10-07_13-02-32_111222_2244314 is over 95% full, available space: 29542883328; capacity: 1622224654336. Object creation will fail if spilling is required.
# partition_time_s: 8.23
# client[0] device: cuda:0 cuda:0
# client[0] feature_dim: 128
# config.use_pe: False num_iterations: 80 feature_prop_device: None
# data_loading_option: full hop: 1 num_clients: 1
#
# === DATA LOADING SUMMARY ===
# Full graph: 169343 nodes, 2484941 edges
# Number of client subgraphs: 1
# First client subgraph shape: torch.Size([169343, 128])
# Dataset: PygNodePropPredDataset()
# Device: cuda
#
# Full graph device (before): cuda:0
# Full graph staying on CPU to save GPU memory
# ===========================
#
# Model is GCN_arxiv(
#   (convs): ModuleList(
#     (0): GCNConv(128, 256)
#     (1): GCNConv(256, 256)
#     (2): GCNConv(256, 40)
#   )
#   (bns): ModuleList(
#     (0-1): 2 x BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
#
# === CLIENT DATA LOADING ===
# Full graph size: 169343 nodes
# Number of clients: 1
# Client 0 subgraph: 169343 nodes, 128 features
# ===========================
#
# Input dim of the model in server: 128
# (FLClient pid=2244684)
# (FLClient pid=2244684) [Client 0] Initializing with:
# (FLClient pid=2244684)   - Input data nodes: 169343
# (FLClient pid=2244684)   - Input data edges: 2484941
# (FLClient pid=2244684)   - Feature shape: torch.Size([169343, 128])
# (FLClient pid=2244684)   - Data device (before moving): cuda:0
# (FLClient pid=2244684)   - Input dim: 128
# (FLClient pid=2244684)   - Data device (after moving): cuda:0
# (FLClient pid=2244684) Client 0: Using full-batch training for ogbn-arxiv dataset
# (FLClient pid=2244684) 2025-10-07 13:02:49,585 - INFO - Epoch   0| Train Loss: 4.110| Train Accuracy: 0.020| Val Loss: 3.633| Val Accuracy: 0.078
# (FLClient pid=2244684) 2025-10-07 13:02:49,737 - INFO - Epoch   1| Train Loss: 3.208| Train Accuracy: 0.239| Val Loss: 3.555| Val Accuracy: 0.265
# (FLClient pid=2244684) 2025-10-07 13:02:49,889 - INFO - Epoch   2| Train Loss: 2.661| Train Accuracy: 0.361| Val Loss: 3.545| Val Accuracy: 0.222
)]
# ✅ Parameters match!
#
# Layer 3:
# Server param shape: (256, 256)
# Client param shapes: [(256, 256)]
# ✅ Parameters match!
#
# Layer 4:
# Server param shape: (40,)
# Client param shapes: [(40,)]
# ✅ Parameters match!
#
# Layer 5:
# Server param shape: (40, 256)
# Client param shapes: [(40, 256)]
# ✅ Parameters match!
#
# Layer 6:
# Server param shape: (256,)
# Client param shapes: [(256,)]
# ✅ Parameters match!
#
# Layer 7:
# Server param shape: (256,)
# Client param shapes: [(256,)]
# ✅ Parameters match!
#
# Layer 8:
# Server param shape: (256,)
# Client param shapes: [(256,)]
# ✅ Parameters match!
#
# Layer 9:
# Server param shape: (256,)
# Client param shapes: [(256,)]
# ✅ Parameters match!
#
# All model parameters are identical: True
# Input dim of the model in server: 128
# Input dim of the test data in server: 128
# (FLClient pid=2244684) Input dim of the model: 128
# (FLClient pid=2244684) Input dim of the data: 128
# [WANDB DEBUG] Logging test metrics - Global: 0.41532415694504454, Clients: [0.5350081270703455], Epoch: 10
# [WANDB DEBUG] Logging metrics: {'round': 10, 'test/global_test_acc': 0.41532415694504454, 'test/avg_client_test_acc': np.float64(0.5350081270703455), 'test/client_test_acc_std': np.float64(0.0), 'test/num_clients': 1, 'test/global_vs_avg_client_diff': np.float64(-0.11968397012530096)} with step: 10
# [WANDB DEBUG] Successfully logged test metrics
# The average client test results: 0.5350081270703455
# The final global test results: 0.41532415694504454
# Round 1 is complete
# wandb: ⢿ uploading history steps 1-10, summary, console lines 58-170 (0.0s)
# wandb: ⣻ uploading history steps 1-10, summary, console lines 58-170 (0.0s)
# wandb: ⣽ uploading history steps 1-10, summary, console lines 58-170 (0.0s)
# wandb: ⣾ uploading history steps 1-10, summary, console lines 58-170 (0.0s)
# wandb: ⣷ uploading history steps 1-10, summary, console lines 58-170 (0.0s)
# wandb:
# wandb: ⣷ uploading history steps 1-10, summary, console lines 58-170 (0.0s)
# wandb:
# wandb: Run history:
# wandb:  federation/avg_client_train_acc ▁▅▅▇▇▇████
# wandb: federation/avg_client_train_loss ██▇▆▆▅▄▃▂▁
# wandb:    federation/avg_client_val_acc ▁▃▄▄▄▆▅▇▇█
# wandb:   federation/avg_client_val_loss ██▇▆▆▅▄▃▂▁
# wandb:                            round ▁▂▂▃▄▅▅▆▇▇█
# wandb:           run_client_test_result ▁
# wandb:           run_global_test_result ▁
# wandb:         test/avg_client_test_acc ▁
# wandb:         test/client_test_acc_std ▁
# wandb:             test/global_test_acc ▁
# wandb:   test/global_vs_avg_client_diff ▁
# wandb:                 test/num_clients ▁
# wandb:
# wandb: Run summary:
# wandb:  federation/avg_client_train_acc 0.63352
# wandb: federation/avg_client_train_loss 2.3715
# wandb:    federation/avg_client_val_acc 0.53438
# wandb:   federation/avg_client_val_loss 2.3715
# wandb:                            round 10
# wandb:           run_client_test_result 0.53501
# wandb:           run_global_test_result 0.41532
# wandb:         test/avg_client_test_acc 0.53501
# wandb:         test/client_test_acc_std 0
# wandb:             test/global_test_acc 0.41532
# wandb:   test/global_vs_avg_client_diff -0.11968
# wandb:                 test/num_clients 1
# wandb:
# wandb: 🚀 View run GCN_ogbn-arxiv_SGD_lr0.5_decay0.0005_beta1_run1 at: https://wandb.ai/bosho/FGL3/runs/zwwagdpa
# wandb: ⭐️ View project at: https://wandb.ai/bosho/FGL3
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251007_130235-zwwagdpa/logs
# The global test results: [0.41532415694504454]
# The client test results: [0.5350081270703455]
# The average global test results: 0.41532415694504454
# The average client test results: 0.5350081270703455
# The standard deviation global is: 0.0
# The standard deviation client is: 0.0
# Training CSV results saved to /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv/ogbn-arxiv_full_GCN_beta1_clients1/training_ogbn-arxiv_full_GCN_beta1_clients1_20251007_130232.csv
#
# Summary results saved to:
# - Text file: /home/brian_bosho/FP/FP/federated-gnn/results/review/results_summary/ogbn-arxiv/summary_results_20251007_130304.txt
# - JSON file: /home/brian_bosho/FP/FP/federated-gnn/results/review/results_summary/ogbn-arxiv/summary_results_20251007_130304.json
# - Detailed results saved to: /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv
#
#
#
# ================================================================================
# EXPERIMENT RESULTS SUMMARY
# ================================================================================
# +------------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+
# | Dataset    | Data Loading   | Model   |   Beta |   Clients |   Avg Global Result |   Avg Client Result |   client_std_dev |   global_std_dev | Duration   |   Hop | Use PE   |
# +============+================+=========+========+===========+=====================+=====================+==================+==================+============+=======+==========+
# | ogbn-arxiv | full           | GCN     |      1 |         1 |              0.4153 |               0.535 |                0 |                0 | 00:00:32   |     1 | False    |
# +------------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+
#
#
# KEY RESULTS:
# --------------------------------------------------------------------------------
# ogbn-arxiv with full using GCN (beta=1.00, clients=1, hop=1, use_pe=False):
#   - Average Global Result: 0.4153
#   - Average Client Result: 0.5350
#   - Client StdDev: 0.0000
#   - Global StdDev: 0.0000
#   - Experiment Duration: 00:00:32
# --------------------------------------------------------------------------------
