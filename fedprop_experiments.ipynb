# %%
# !python -m src.experiments.run_experiments --config conf/ablation/ogbn-arxiv_config.yaml

# %%
# !python -m src.experiments.run_experiments --config conf/ablation/ogbn-arxiv_config.yaml
# Out:
# Experiment Configuration:
# - Clients: [10]
# - Rounds: 10
# - Epochs: 3
# - Learning Rate: 0.5
# - Beta values: [1]
# - Datasets: ['FacebookPagePage']
# - Data Loading Options: ['full']
# - Model Types: ['GCN']
# - Results Directory: /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv
# - Save Detailed Results: False
# - Hop: 1
# - Full Training Flag: False
#
# ================================================================================
# Running experiment: FacebookPagePage_full_GCN_beta1_clients10
# ================================================================================
# DEVICE: cuda
# Data loading option is full
# Model type is GCN
# 2025-10-02 11:51:39,857	INFO worker.py:1807 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (raylet) [2025-10-02 11:51:39,840 E 1808601 1808630] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2025-10-02_11-51-38_576301_1808350 is over 95% full, available space: 33199542272; capacity: 1622224654336. Object creation will fail if spilling is required.
# wandb: Currently logged in as: bosho to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /home/brian_bosho/FP/FP/federated-gnn/wandb/run-20251002_115141-dtp2vly2
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run glad-planet-370
# wandb: ⭐️ View project at https://wandb.ai/bosho/FGL3
# wandb: 🚀 View run at https://wandb.ai/bosho/FGL3/runs/dtp2vly2
# [WANDB DEBUG] Successfully initialized wandb run: glad-planet-370
# Wandb config is set to: {'dataset': 'FacebookPagePage', 'model': 'GCN', 'data_loading': 'full', 'num_clients': [10], 'num_rounds': 10, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 1, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': 64, 'pe_P': 16, 'normalize': 'qr', 'run_index': 1, 'num_iterations': 10}
# {'dataset': 'FacebookPagePage', 'model': 'GCN', 'data_loading': 'full', 'num_clients': [10], 'num_rounds': 10, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 1, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': 64, 'pe_P': 16, 'normalize': 'qr', 'run_index': 1, 'num_iterations': 10}
# data_loading_option: full
# Downloading https://graphmining.ai/datasets/ptg/facebook.npz
# Error in round 1: HTTP Error 404: Not Found
# The global test results: []
# The client test results: []
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:3904: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/numpy/_core/_methods.py:147: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/numpy/_core/_methods.py:227: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/numpy/_core/_methods.py:184: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/numpy/_core/_methods.py:219: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# The average global test results: nan
# The average client test results: nan
# The standard deviation global is: nan
# The standard deviation client is: nan
# Training CSV results saved to /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv/FacebookPagePage_full_GCN_beta1_clients10/training_FacebookPagePage_full_GCN_beta1_clients10_20251002_115138.csv
#
# Summary results saved to:
# - Text file: /home/brian_bosho/FP/FP/federated-gnn/results/review/results_summary/ogbn-arxiv/summary_results_20251002_115145.txt
# - JSON file: /home/brian_bosho/FP/FP/federated-gnn/results/review/results_summary/ogbn-arxiv/summary_results_20251002_115145.json
# - Detailed results saved to: /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv
#
#
#
# ================================================================================
# EXPERIMENT RESULTS SUMMARY
# ================================================================================
# +------------------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+
# | Dataset          | Data Loading   | Model   |   Beta |   Clients |   Avg Global Result |   Avg Client Result |   client_std_dev |   global_std_dev | Duration   |   Hop | Use PE   |
# +==================+================+=========+========+===========+=====================+=====================+==================+==================+============+=======+==========+
# | FacebookPagePage | full           | GCN     |      1 |        10 |                 nan |                 nan |              nan |              nan | 00:00:07   |     1 | False    |
# +------------------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+
#
#
# KEY RESULTS:
# --------------------------------------------------------------------------------
# FacebookPagePage with full using GCN (beta=1.00, clients=10, hop=1, use_pe=False):
#   - Average Global Result: nan
#   - Average Client Result: nan
#   - Client StdDev: nan
#   - Global StdDev: nan
#   - Experiment Duration: 00:00:07
# --------------------------------------------------------------------------------
# wandb: ⢿ uploading output.log 4.0KB/4.0KB (0.6s)
# wandb: ⢿ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: ⣻ uploading output.log 4.0KB/4.0KB (0.6s)
# wandb: ⣻ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: ⣽ uploading output.log 4.0KB/4.0KB (0.6s)
# wandb: ⣽ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: ⣾ uploading output.log 4.0KB/4.0KB (0.6s)
# wandb: ⣾ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: ⣷ uploading output.log 4.0KB/4.0KB (0.6s)
# wandb: ⣷ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: ⣯ uploading output.log 4.0KB/4.0KB (0.6s)
# wandb: ⣯ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: ⣟ uploading output.log 4.0KB/4.0KB (0.6s)
# wandb: ⣟ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: ⡿ uploading output.log 4.0KB/4.0KB (0.6s)
# wandb: ⡿ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: ⢿ uploading output.log 4.0KB/4.0KB (0.6s)
# wandb: ⢿ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: ⣻ uploading summary, console lines 1-49 (0.3s)
# wandb: ⣽ uploading summary, console lines 1-49 (0.3s)
# wandb: ⣾ uploading summary, console lines 1-49 (0.3s)
# wandb:
# wandb: ⣾ uploading summary, console lines 1-49 (0.3s)
# wandb: 🚀 View run GCN_FacebookPagePage_SGD_lr0.5_decay0.0005_beta1_run1 at: https://wandb.ai/bosho/FGL3/runs/dtp2vly2
# wandb: ⭐️ View project at: https://wandb.ai/bosho/FGL3
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251002_115141-dtp2vly2/logs
