# %%
# !python -m src.experiments.run_experiments --config conf/ablation/ogbn-arxiv_config.yaml

# %%
# !python -m src.experiments.run_experiments --config conf/ablation/cora_gcn_no_pe.yaml

# %%
# !python -m src.experiments.run_experiments --config conf/ablation/ogbn-arxiv_config.yaml

# %%
# !python -m src.experiments.run_experiments --config conf/ablation/ogbn-arxiv_config.yaml
# Out:
# Experiment Configuration:
# - Clients: [5]
# - Rounds: 10
# - Epochs: 3
# - Learning Rate: 0.5
# - Beta values: [1]
# - Datasets: ['ogbn-arxiv']
# - Data Loading Options: ['full']
# - Model Types: ['GCN']
# - Results Directory: /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv
# - Save Detailed Results: False
# - Hop: 2
# - Full Training Flag: False
#
# ================================================================================
# Running experiment: ogbn-arxiv_full_GCN_beta1_clients5
# ================================================================================
# DEVICE: cuda
# Data loading option is full
# Model type is GCN
# 2025-10-07 13:51:26,658	INFO worker.py:1807 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# wandb: Currently logged in as: bosho to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /home/brian_bosho/FP/FP/federated-gnn/wandb/run-20251007_135128-7q93t0m8
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run fresh-water-557
# wandb: ⭐️ View project at https://wandb.ai/bosho/FGL3
# wandb: 🚀 View run at https://wandb.ai/bosho/FGL3/runs/7q93t0m8
# [WANDB DEBUG] Successfully initialized wandb run: fresh-water-557
# Wandb config is set to: {'dataset': 'ogbn-arxiv', 'model': 'GCN', 'data_loading': 'full', 'num_clients': [5], 'num_rounds': 10, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 2, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': 64, 'pe_P': 16, 'normalize': 'qr', 'run_index': 1, 'num_iterations': 80}
# {'dataset': 'ogbn-arxiv', 'model': 'GCN', 'data_loading': 'full', 'num_clients': [5], 'num_rounds': 10, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 2, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': 64, 'pe_P': 16, 'normalize': 'qr', 'run_index': 1, 'num_iterations': 80}
# data_loading_option: full
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/ogb/nodeproppred/dataset_pyg.py:69: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.data, self.slices = torch.load(self.processed_paths[0])
# Tolerance: 1e-6
# (raylet) [2025-10-07 13:51:36,560 E 2292294 2292324] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2025-10-07_13-51-25_472057_2292029 is over 95% full, available space: 30276481024; capacity: 1622224654336. Object creation will fail if spilling is required.
# partition_time_s: 9.07
# client[0] device: cuda:0 cuda:0
# client[0] feature_dim: 128
# config.use_pe: False num_iterations: 80 feature_prop_device: None
# data_loading_option: full hop: 2 num_clients: 5
#
# === DATA LOADING SUMMARY ===
# Full graph: 169343 nodes, 2484941 edges
# Number of client subgraphs: 5
# First client subgraph shape: torch.Size([157871, 128])
# Dataset: PygNodePropPredDataset()
# Device: cuda
#
# Full graph device (before): cuda:0
# Full graph staying on CPU to save GPU memory
# ===========================
#
# Model is GCN_arxiv(
#   (convs): ModuleList(
#     (0): GCNConv(128, 256)
#     (1): GCNConv(256, 256)
#     (2): GCNConv(256, 40)
#   )
#   (bns): ModuleList(
#     (0-1): 2 x BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
#
# === CLIENT DATA LOADING ===
# Full graph size: 169343 nodes
# Number of clients: 5
# Client 0 subgraph: 157871 nodes, 128 features
# Client 1 subgraph: 158579 nodes, 128 features
# Client 2 subgraph: 151795 nodes, 128 features
# Client 3 subgraph: 162112 nodes, 128 features
# Client 4 subgraph: 160370 nodes, 128 features
# ===========================
#
# Input dim of the model in server: 128
# (FLClient pid=2292406)
# (FLClient pid=2292406) [Client 0] Initializing with:
# (FLClient pid=2292406)   - Input data nodes: 157871
# (FLClient pid=2292406)   - Input data edges: 2433305
# (FLClient pid=2292406)   - Feature shape: torch.Size([157871, 128])
# (FLClient pid=2292406)   - Data device (before moving): cuda:0
# (FLClient pid=2292406)   - Input dim: 128
# (FLClient pid=2292406)   - Data device (after moving): cuda:0
# (FLClient pid=2292406) Client 0: Using full-batch training for ogbn-arxiv dataset
# (FLClient pid=2292402)
# (FLClient pid=2292406) 2025-10-07 13:51:44,648 - INFO - Epoch   0| Train Loss: 4.107| Train Accuracy: 0.013| Val Loss: 3.618| Val Accuracy: 0.154
# (FLClient pid=2292414)
# (FLClient pid=2292406) 2025-10-07 13:51:44,824 - INFO - Epoch   1| Train Loss: 2.764| Train Accuracy: 0.365| Val Loss: 3.543| Val Accuracy: 0.460
# (FLClient pid=2292406) 2025-10-07 13:51:45,060 - INFO - Epoch   2| Train Loss: 2.163| Train Accuracy: 0.529| Val Loss: 3.501| Val Accuracy: 0.387
# (FLClient pid=2292411)
# (FLClient pid=2292408)
# (raylet) [2025-10-07 13:51:46,565 E 2292294 2292324] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2025-10-07_13-51-25_472057_2292029 is over 95% full, available space: 30276153344; capacity: 1622224654336. Object creation will fail if spilling is required.
# (FLClient pid=2292414) Error in client 2 training: CUDA out of memory. Tried to allocate 2.29 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.46 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2292029 has 4.18 GiB memory in use. Process 2292406 has 8.01 GiB memory in use. Process 2292402 has 8.03 GiB memory in use. Including non-PyTorch memory, this process has 5.57 GiB memory in use. Process 2292411 has 8.15 GiB memory in use. Process 2292408 has 5.72 GiB memory in use. Of the allocated memory 3.12 GiB is allocated by PyTorch, and 1.95 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2292414) Traceback (most recent call last):
# (FLClient pid=2292414)   File "/home/brian_bosho/FP/FP/federated-gnn/src/client.py", line 134, in train_client
# (FLClient pid=2292414)     loss, acc, loss_list, acc_list = train(
# (FLClient pid=2292414)                                      ^^^^^^
# (FLClient pid=2292414)   File "/home/brian_bosho/FP/FP/federated-gnn/src/train.py", line 53, in train
# (FLClient pid=2292414)     output = model(data.x, data.edge_index)
# (FLClient pid=2292414)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=2292414)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
# (FLClient pid=2292414)     return self._call_impl(*args, **kwargs)
# (FLClient pid=2292414)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=2292414)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
# (FLClient pid=2292414)     return forward_call(*args, **kwargs)
# (FLClient pid=2292414)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=2292414)   File "/home/brian_bosho/FP/FP/federated-gnn/src/models.py", line 85, in forward
# (FLClient pid=2292414)     x = self.convs[1](x, adj_t)
# (FLClient pid=2292414)         ^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=2292414)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
# (FLClient pid=2292414)     return self._call_impl(*args, **kwargs)
# (FLClient pid=2292414)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=2292414)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
# (FLClient pid=2292414)     return forward_call(*args, **kwargs)
# (FLClient pid=2292414)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=2292414)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch_geometric/nn/conv/gcn_conv.py", line 263, in forward
# (FLClient pid=2292414)     out = self.propagate(edge_index, x=x, edge_weight=edge_weight)
# (FLClient pid=2292414)           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=2292414)   File "/tmp/torch_geometric.nn.conv.gcn_conv_GCNConv_propagate_o86ckc3x.py", line 209, in propagate
# (FLClient pid=2292414)     out = self.message(
# (FLClient pid=2292414)           ^^^^^^^^^^^^^
# (FLClient pid=2292414)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch_geometric/nn/conv/gcn_conv.py", line 271, in message
# (FLClient pid=2292414)     return x_j if edge_weight is None else edge_weight.view(-1, 1) * x_j
# (FLClient pid=2292414)                                            ~~~~~~~~~~~~~~~~~~~~~~~~^~~~~
# (FLClient pid=2292414) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.29 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.46 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2292029 has 4.18 GiB memory in use. Process 2292406 has 8.01 GiB memory in use. Process 2292402 has 8.03 GiB memory in use. Including non-PyTorch memory, this process has 5.57 GiB memory in use. Process 2292411 has 8.15 GiB memory in use. Process 2292408 has 5.72 GiB memory in use. Of the allocated memory 3.12 GiB is allocated by PyTorch, and 1.95 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2292414)
# (FLClient pid=2292408) Error in client 4 training: CUDA out of memory. Tried to allocate 2.34 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.50 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2292029 has 4.18 GiB memory in use. Process 2292406 has 8.01 GiB memory in use. Process 2292402 has 8.03 GiB memory in use. Process 2292414 has 5.57 GiB memory in use. Process 2292411 has 8.15 GiB memory in use. Including non-PyTorch memory, this process has 5.69 GiB memory in use. Of the allocated memory 3.21 GiB is allocated by PyTorch, and 1.98 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2292408)   File "/tmp/torch_geometric.nn.conv.gcn_conv_GCNConv_propagate_sitcrzox.py", line 209, in propagate
# (FLClient pid=2292408) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.34 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.50 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2292029 has 4.18 GiB memory in use. Process 2292406 has 8.01 GiB memory in use. Process 2292402 has 8.03 GiB memory in use. Process 2292414 has 5.57 GiB memory in use. Process 2292411 has 8.15 GiB memory in use. Including non-PyTorch memory, this process has 5.69 GiB memory in use. Of the allocated memory 3.21 GiB is allocated by PyTorch, and 1.98 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2292408)
# (FLClient pid=2292406) 2025-10-07 13:51:49,805 - INFO - Epoch   2| Train Loss: 1.716| Train Accuracy: 0.591| Val Loss: 3.351| Val Accuracy: 0.454 [repeated 19x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (FLClient pid=2292414) Error in client 2 training: CUDA out of memory. Tried to allocate 2.29 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.49 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2292029 has 4.18 GiB memory in use. Process 2292406 has 8.01 GiB memory in use. Process 2292402 has 8.03 GiB memory in use. Including non-PyTorch memory, this process has 5.57 GiB memory in use. Process 2292411 has 8.15 GiB memory in use. Process 2292408 has 5.69 GiB memory in use. Of the allocated memory 3.12 GiB is allocated by PyTorch, and 1.95 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2292414)   File "/tmp/torch_geometric.nn.conv.gcn_conv_GCNConv_propagate_o86ckc3x.py", line 209, in propagate
# (FLClient pid=2292414) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.29 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.49 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2292029 has 4.18 GiB memory in use. Process 2292406 has 8.01 GiB memory in use. Process 2292402 has 8.03 GiB memory in use. Including non-PyTorch memory, this process has 5.57 GiB memory in use. Process 2292411 has 8.15 GiB memory in use. Process 2292408 has 5.69 GiB memory in use. Of the allocated memory 3.12 GiB is allocated by PyTorch, and 1.95 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2292414)
# (FLClient pid=2292408) [Client 4] Initializing with: [repeated 4x across cluster]
# (FLClient pid=2292408)   - Input data nodes: 160370 [repeated 4x across cluster]
# (FLClient pid=2292408)   - Input data edges: 2447458 [repeated 4x across cluster]
# (FLClient pid=2292408)   - Feature shape: torch.Size([160370, 128]) [repeated 4x across cluster]
# (FLClient pid=2292408)   - Data device (before moving): cuda:0 [repeated 4x across cluster]
# (FLClient pid=2292408)   - Input dim: 128 [repeated 4x across cluster]
# (FLClient pid=2292408)   - Data device (after moving): cuda:0 [repeated 4x across cluster]
# (FLClient pid=2292408) Client 4: Using full-batch training for ogbn-arxiv dataset [repeated 4x across cluster]
# (FLClient pid=2292408) Error in client 4 training: CUDA out of memory. Tried to allocate 2.34 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.45 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2292029 has 4.18 GiB memory in use. Process 2292406 has 8.01 GiB memory in use. Process 2292402 has 8.03 GiB memory in use. Process 2292414 has 5.61 GiB memory in use. Process 2292411 has 8.15 GiB memory in use. Including non-PyTorch memory, this process has 5.69 GiB memory in use. Of the allocated memory 3.21 GiB is allocated by PyTorch, and 1.98 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2292408)   File "/tmp/torch_geometric.nn.conv.gcn_conv_GCNConv_propagate_sitcrzox.py", line 209, in propagate
# (FLClient pid=2292408) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.34 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.45 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2292029 has 4.18 GiB memory in use. Process 2292406 has 8.01 GiB memory in use. Process 2292402 has 8.03 GiB memory in use. Process 2292414 has 5.61 GiB memory in use. Process 2292411 has 8.15 GiB memory in use. Including non-PyTorch memory, this process has 5.69 GiB memory in use. Of the allocated memory 3.21 GiB is allocated by PyTorch, and 1.98 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2292408)
# (FLClient pid=2292411) Error in client 3 training: CUDA out of memory. Tried to allocate 2.34 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.64 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2292029 has 4.18 GiB memory in use. Process 2292406 has 8.01 GiB memory in use. Process 2292402 has 8.03 GiB memory in use. Process 2292414 has 7.89 GiB memory in use. Including non-PyTorch memory, this process has 3.31 GiB memory in use. Process 2292408 has 8.06 GiB memory in use. Of the allocated memory 2.68 GiB is allocated by PyTorch, and 135.94 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2292411) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.34 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.64 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2292029 has 4.18 GiB memory in use. Process 2292406 has 8.01 GiB memory in use. Process 2292402 has 8.03 GiB memory in use. Process 2292414 has 7.89 GiB memory in use. Including non-PyTorch memory, this process has 3.31 GiB memory in use. Process 2292408 has 8.06 GiB memory in use. Of the allocated memory 2.68 GiB is allocated by PyTorch, and 135.94 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2292411)
# (FLClient pid=2292411) Traceback (most recent call last): [repeated 4x across cluster]
# (FLClient pid=2292411)   File "/home/brian_bosho/FP/FP/federated-gnn/src/client.py", line 134, in train_client [repeated 4x across cluster]
# (FLClient pid=2292411)     loss, acc, loss_list, acc_list = train( [repeated 4x across cluster]
# (FLClient pid=2292411)                                      ^^^^^^ [repeated 4x across cluster]
# (FLClient pid=2292411)   File "/home/brian_bosho/FP/FP/federated-gnn/src/train.py", line 53, in train [repeated 4x across cluster]
# (FLClient pid=2292411)     output = model(data.x, data.edge_index) [repeated 4x across cluster]
# (FLClient pid=2292411)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 4x across cluster]
# (FLClient pid=2292411)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl [repeated 8x across cluster]
# (FLClient pid=2292411)     return self._call_impl(*args, **kwargs) [repeated 8x across cluster]
# (FLClient pid=2292411)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 8x across cluster]
# (FLClient pid=2292411)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl [repeated 8x across cluster]
# (FLClient pid=2292411)     return forward_call(*args, **kwargs) [repeated 8x across cluster]
# (FLClient pid=2292411)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 8x across cluster]
# (FLClient pid=2292411)   File "/home/brian_bosho/FP/FP/federated-gnn/src/models.py", line 80, in forward [repeated 4x across cluster]
# (FLClient pid=2292411)     x = self.convs[0](x, adj_t) [repeated 4x across cluster]
# (FLClient pid=2292411)         ^^^^^^^^^^^^^^^^^^^^^^^ [repeated 4x across cluster]
# (FLClient pid=2292411)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch_geometric/nn/conv/gcn_conv.py", line 263, in forward [repeated 4x across cluster]
# (FLClient pid=2292411)     out = self.propagate(edge_index, x=x, edge_weight=edge_weight) [repeated 4x across cluster]
# (FLClient pid=2292411)           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 4x across cluster]
# (FLClient pid=2292411)   File "/tmp/torch_geometric.nn.conv.gcn_conv_GCNConv_propagate_rknza9pb.py", line 209, in propagate
# (FLClient pid=2292411)     out = self.message( [repeated 4x across cluster]
# (FLClient pid=2292411)           ^^^^^^^^^^^^^ [repeated 4x across cluster]
# (FLClient pid=2292411)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch_geometric/nn/conv/gcn_conv.py", line 271, in message [repeated 4x across cluster]
# (FLClient pid=2292411)     return x_j if edge_weight is None else edge_weight.view(-1, 1) * x_j [repeated 4x across cluster]
# (FLClient pid=2292411)                                            ~~~~~~~~~~~~~~~~~~~~~~~~^~~~~ [repeated 4x across cluster]
# (FLClient pid=2292406) 2025-10-07 13:51:55,270 - INFO - Epoch   1| Train Loss: 1.546| Train Accuracy: 0.625| Val Loss: 3.309| Val Accuracy: 0.521 [repeated 16x across cluster]
# (raylet) [2025-10-07 13:51:56,571 E 2292294 2292324] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2025-10-07_13-51-25_472057_2292029 is over 95% full, available space: 30276042752; capacity: 1622224654336. Object creation will fail if spilling is required.
# (FLClient pid=2292414) Error in client 2 training: CUDA out of memory. Tried to allocate 2.29 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.45 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2292029 has 4.18 GiB memory in use. Process 2292406 has 8.01 GiB memory in use. Process 2292402 has 8.03 GiB memory in use. Including non-PyTorch memory, this process has 5.57 GiB memory in use. Process 2292411 has 8.15 GiB memory in use. Process 2292408 has 5.72 GiB memory in use. Of the allocated memory 3.12 GiB is allocated by PyTorch, and 1.95 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2292414)   File "/tmp/torch_geometric.nn.conv.gcn_conv_GCNConv_propagate_o86ckc3x.py", line 209, in propagate
# (FLClient pid=2292414) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.29 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.45 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2292029 has 4.18 GiB memory in use. Process 2292406 has 8.01 GiB memory in use. Process 2292402 has 8.03 GiB memory in use. Including non-PyTorch memory, this process has 5.57 GiB memory in use. Process 2292411 has 8.15 GiB memory in use. Process 2292408 has 5.72 GiB memory in use. Of the allocated memory 3.12 GiB is allocated by PyTorch, and 1.95 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2292414)
# (FLClient pid=2292408) Error in client 4 training: CUDA out of memory. Tried to allocate 2.34 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.49 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2292029 has 4.18 GiB memory in use. Process 2292406 has 8.01 GiB memory in use. Process 2292402 has 8.03 GiB memory in use. Process 2292414 has 5.57 GiB memory in use. Process 2292411 has 8.15 GiB memory in use. Including non-PyTorch memory, this process has 5.69 GiB memory in use. Of the allocated memory 3.21 GiB is allocated by PyTorch, and 1.98 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2292408)   File "/tmp/torch_geometric.nn.conv.gcn_conv_GCNConv_propagate_sitcrzox.py", line 209, in propagate
# (FLClient pid=2292408) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.34 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.49 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2292029 has 4.18 GiB memory in use. Process 2292406 has 8.01 GiB memory in use. Process 2292402 has 8.03 GiB memory in use. Process 2292414 has 5.57 GiB memory in use. Process 2292411 has 8.15 GiB memory in use. Including non-PyTorch memory, this process has 5.69 GiB memory in use. Of the allocated memory 3.21 GiB is allocated by PyTorch, and 1.98 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2292408)
# (FLClient pid=2292406) Error in client 0 training: CUDA out of memory. Tried to allocate 2.32 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.48 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2292029 has 4.18 GiB memory in use. Including non-PyTorch memory, this process has 5.67 GiB memory in use. Process 2292402 has 8.03 GiB memory in use. Process 2292414 has 7.89 GiB memory in use. Process 2292411 has 5.81 GiB memory in use. Process 2292408 has 8.06 GiB memory in use. Of the allocated memory 3.18 GiB is allocated by PyTorch, and 1.99 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2292406) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.32 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.48 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2292029 has 4.18 GiB memory in use. Including non-PyTorch memory, this process has 5.67 GiB memory in use. Process 2292402 has 8.03 GiB memory in use. Process 2292414 has 7.89 GiB memory in use. Process 2292411 has 5.81 GiB memory in use. Process 2292408 has 8.06 GiB memory in use. Of the allocated memory 3.18 GiB is allocated by PyTorch, and 1.99 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2292406)
# (FLClient pid=2292406) Traceback (most recent call last): [repeated 3x across cluster]
# (FLClient pid=2292406)   File "/home/brian_bosho/FP/FP/federated-gnn/src/client.py", line 134, in train_client [repeated 3x across cluster]
# (FLClient pid=2292406)     loss, acc, loss_list, acc_list = train( [repeated 3x across cluster]
# (FLClient pid=2292406)                                      ^^^^^^ [repeated 3x across cluster]
# (FLClient pid=2292406)   File "/home/brian_bosho/FP/FP/federated-gnn/src/train.py", line 53, in train [repeated 3x across cluster]
# (FLClient pid=2292406)     output = model(data.x, data.edge_index) [repeated 3x across cluster]
# (FLClient pid=2292406)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 3x across cluster]
# (FLClient pid=2292406)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl [repeated 6x across cluster]
# (FLClient pid=2292406)     return self._call_impl(*args, **kwargs) [repeated 6x across cluster]
# (FLClient pid=2292406)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 6x across cluster]
# (FLClient pid=2292406)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl [repeated 6x across cluster]
# (FLClient pid=2292406)     return forward_call(*args, **kwargs) [repeated 6x across cluster]
# (FLClient pid=2292406)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 6x across cluster]
# (FLClient pid=2292406)   File "/home/brian_bosho/FP/FP/federated-gnn/src/models.py", line 85, in forward [repeated 3x across cluster]
# (FLClient pid=2292406)     x = self.convs[1](x, adj_t) [repeated 3x across cluster]
# (FLClient pid=2292406)         ^^^^^^^^^^^^^^^^^^^^^^^ [repeated 3x across cluster]
# (FLClient pid=2292406)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch_geometric/nn/conv/gcn_conv.py", line 263, in forward [repeated 3x across cluster]
# (FLClient pid=2292406)     out = self.propagate(edge_index, x=x, edge_weight=edge_weight) [repeated 3x across cluster]
# (FLClient pid=2292406)           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 3x across cluster]
# (FLClient pid=2292406)     out = self.message( [repeated 3x across cluster]
# (FLClient pid=2292406)           ^^^^^^^^^^^^^ [repeated 3x across cluster]
# (FLClient pid=2292406)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch_geometric/nn/conv/gcn_conv.py", line 271, in message [repeated 3x across cluster]
# (FLClient pid=2292406)     return x_j if edge_weight is None else edge_weight.view(-1, 1) * x_j [repeated 3x across cluster]
# (FLClient pid=2292406)                                            ~~~~~~~~~~~~~~~~~~~~~~~~^~~~~ [repeated 3x across cluster]
# (FLClient pid=2292411) Error in client 3 training: CUDA out of memory. Tried to allocate 2.34 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.46 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2292029 has 4.18 GiB memory in use. Process 2292406 has 5.69 GiB memory in use. Process 2292402 has 8.03 GiB memory in use. Process 2292414 has 7.89 GiB memory in use. Including non-PyTorch memory, this process has 5.81 GiB memory in use. Process 2292408 has 8.06 GiB memory in use. Of the allocated memory 3.22 GiB is allocated by PyTorch, and 2.08 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2292411) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.34 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.46 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2292029 has 4.18 GiB memory in use. Process 2292406 has 5.69 GiB memory in use. Process 2292402 has 8.03 GiB memory in use. Process 2292414 has 7.89 GiB memory in use. Including non-PyTorch memory, this process has 5.81 GiB memory in use. Process 2292408 has 8.06 GiB memory in use. Of the allocated memory 3.22 GiB is allocated by PyTorch, and 2.08 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2292411)
# (FLClient pid=2292402) 2025-10-07 13:52:00,652 - INFO - Epoch   0| Train Loss: 2.368| Train Accuracy: 0.356| Val Loss: 3.268| Val Accuracy: 0.436 [repeated 17x across cluster]
# ^C
