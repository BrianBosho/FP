# %%
# !python -m src.experiments.run_experiments --config conf/ablation/ogbn-arxiv_config.yaml

# %%
# !python -m src.experiments.run_experiments --config conf/ablation/cora_gcn_no_pe.yaml

# %%
# !python -m src.experiments.run_experiments --config conf/ablation/ogbn-arxiv_config.yaml

# %%
# !python -m src.experiments.run_experiments --config conf/ablation/ogbn-arxiv_config.yaml
# Out:
# Experiment Configuration:
# - Clients: [5]
# - Rounds: 10
# - Epochs: 3
# - Learning Rate: 0.5
# - Beta values: [1]
# - Datasets: ['ogbn-arxiv']
# - Data Loading Options: ['full']
# - Model Types: ['GCN']
# - Results Directory: /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv
# - Save Detailed Results: False
# - Hop: 2
# - Full Training Flag: False
#
# ================================================================================
# Running experiment: ogbn-arxiv_full_GCN_beta1_clients5
# ================================================================================
# DEVICE: cuda
# Data loading option is full
# Model type is GCN
# 2025-10-07 14:14:43,828	INFO worker.py:1807 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# wandb: Currently logged in as: bosho to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /home/brian_bosho/FP/FP/federated-gnn/wandb/run-20251007_141445-zf0xc6ix
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run icy-fog-560
# wandb: ⭐️ View project at https://wandb.ai/bosho/FGL3
# wandb: 🚀 View run at https://wandb.ai/bosho/FGL3/runs/zf0xc6ix
# [WANDB DEBUG] Successfully initialized wandb run: icy-fog-560
# Wandb config is set to: {'dataset': 'ogbn-arxiv', 'model': 'GCN', 'data_loading': 'full', 'num_clients': [5], 'num_rounds': 10, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 2, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': 64, 'pe_P': 16, 'normalize': 'qr', 'run_index': 1, 'num_iterations': 80}
# {'dataset': 'ogbn-arxiv', 'model': 'GCN', 'data_loading': 'full', 'num_clients': [5], 'num_rounds': 10, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 2, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': 64, 'pe_P': 16, 'normalize': 'qr', 'run_index': 1, 'num_iterations': 80}
# data_loading_option: full
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/ogb/nodeproppred/dataset_pyg.py:69: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.data, self.slices = torch.load(self.processed_paths[0])
# Tolerance: 1e-6
# (raylet) [2025-10-07 14:14:53,722 E 2310192 2310222] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2025-10-07_14-14-42_447318_2309932 is over 95% full, available space: 30262730752; capacity: 1622224654336. Object creation will fail if spilling is required.
# partition_time_s: 9.21
# client[0] device: cuda:0 cuda:0
# client[0] feature_dim: 128
# config.use_pe: False num_iterations: 80 feature_prop_device: cpu
# data_loading_option: full hop: 2 num_clients: 5
#
# === DATA LOADING SUMMARY ===
# Full graph: 169343 nodes, 2484941 edges
# Number of client subgraphs: 5
# First client subgraph shape: torch.Size([157871, 128])
# Dataset: PygNodePropPredDataset()
# Device: cuda
#
# Full graph device (before): cuda:0
# Full graph staying on CPU to save GPU memory
# ===========================
#
# Model is GCN_arxiv(
#   (convs): ModuleList(
#     (0): GCNConv(128, 256)
#     (1): GCNConv(256, 256)
#     (2): GCNConv(256, 40)
#   )
#   (bns): ModuleList(
#     (0-1): 2 x BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
#
# === CLIENT DATA LOADING ===
# Full graph size: 169343 nodes
# Number of clients: 5
# Client 0 subgraph: 157871 nodes, 128 features
# Client 1 subgraph: 158579 nodes, 128 features
# Client 2 subgraph: 151795 nodes, 128 features
# Client 3 subgraph: 162112 nodes, 128 features
# Client 4 subgraph: 160370 nodes, 128 features
# ===========================
#
# Input dim of the model in server: 128
# (FLClient pid=2310284)
# (FLClient pid=2310284) [Client 0] Initializing with:
# (FLClient pid=2310284)   - Input data nodes: 157871
# (FLClient pid=2310284)   - Input data edges: 2433305
# (FLClient pid=2310284)   - Feature shape: torch.Size([157871, 128])
# (FLClient pid=2310284)   - Data device (before moving): cuda:0
# (FLClient pid=2310284)   - Input dim: 128
# (FLClient pid=2310284)   - Data device (after moving): cuda:0
# (FLClient pid=2310284) Client 0: Using full-batch training for ogbn-arxiv dataset
# (FLClient pid=2310282)
# (FLClient pid=2310284) 2025-10-07 14:15:01,799 - INFO - Epoch   0| Train Loss: 3.694| Train Accuracy: 0.086| Val Loss: 3.589| Val Accuracy: 0.338
# (FLClient pid=2310284) 2025-10-07 14:15:01,956 - INFO - Epoch   1| Train Loss: 2.697| Train Accuracy: 0.377| Val Loss: 3.527| Val Accuracy: 0.376
# (FLClient pid=2310289)
# (FLClient pid=2310284) 2025-10-07 14:15:02,176 - INFO - Epoch   2| Train Loss: 2.202| Train Accuracy: 0.524| Val Loss: 3.522| Val Accuracy: 0.471
# (FLClient pid=2310286)
# (FLClient pid=2310290)
# (raylet) [2025-10-07 14:15:03,729 E 2310192 2310222] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2025-10-07_14-14-42_447318_2309932 is over 95% full, available space: 30262423552; capacity: 1622224654336. Object creation will fail if spilling is required.
# (FLClient pid=2310290) Error in client 4 training: CUDA out of memory. Tried to allocate 2.34 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.51 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2309932 has 4.18 GiB memory in use. Process 2310284 has 8.01 GiB memory in use. Process 2310282 has 8.03 GiB memory in use. Process 2310289 has 7.89 GiB memory in use. Process 2310286 has 5.81 GiB memory in use. Including non-PyTorch memory, this process has 5.69 GiB memory in use. Of the allocated memory 3.21 GiB is allocated by PyTorch, and 1.98 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2310290) Traceback (most recent call last):
# (FLClient pid=2310290)   File "/home/brian_bosho/FP/FP/federated-gnn/src/client.py", line 134, in train_client
# (FLClient pid=2310290)     loss, acc, loss_list, acc_list = train(
# (FLClient pid=2310290)                                      ^^^^^^
# (FLClient pid=2310290)   File "/home/brian_bosho/FP/FP/federated-gnn/src/train.py", line 53, in train
# (FLClient pid=2310290)     output = model(data.x, data.edge_index)
# (FLClient pid=2310290)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=2310290)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
# (FLClient pid=2310290)     return self._call_impl(*args, **kwargs)
# (FLClient pid=2310290)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=2310290)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
# (FLClient pid=2310290)     return forward_call(*args, **kwargs)
# (FLClient pid=2310290)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=2310290)   File "/home/brian_bosho/FP/FP/federated-gnn/src/models.py", line 85, in forward
# (FLClient pid=2310290)     x = self.convs[1](x, adj_t)
# (FLClient pid=2310290)         ^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=2310290)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
# (FLClient pid=2310290)     return self._call_impl(*args, **kwargs)
# (FLClient pid=2310290)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=2310290)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
# (FLClient pid=2310290)     return forward_call(*args, **kwargs)
# (FLClient pid=2310290)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=2310290)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch_geometric/nn/conv/gcn_conv.py", line 263, in forward
# (FLClient pid=2310290)     out = self.propagate(edge_index, x=x, edge_weight=edge_weight)
# (FLClient pid=2310290)           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=2310290)   File "/tmp/torch_geometric.nn.conv.gcn_conv_GCNConv_propagate_7yw56ymm.py", line 209, in propagate
# (FLClient pid=2310290)     out = self.message(
# (FLClient pid=2310290)           ^^^^^^^^^^^^^
# (FLClient pid=2310290)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch_geometric/nn/conv/gcn_conv.py", line 271, in message
# (FLClient pid=2310290)     return x_j if edge_weight is None else edge_weight.view(-1, 1) * x_j
# (FLClient pid=2310290)                                            ~~~~~~~~~~~~~~~~~~~~~~~~^~~~~
# (FLClient pid=2310290) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.34 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.51 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2309932 has 4.18 GiB memory in use. Process 2310284 has 8.01 GiB memory in use. Process 2310282 has 8.03 GiB memory in use. Process 2310289 has 7.89 GiB memory in use. Process 2310286 has 5.81 GiB memory in use. Including non-PyTorch memory, this process has 5.69 GiB memory in use. Of the allocated memory 3.21 GiB is allocated by PyTorch, and 1.98 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2310290)
# (FLClient pid=2310286) Error in client 3 training: CUDA out of memory. Tried to allocate 2.34 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.51 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2309932 has 4.18 GiB memory in use. Process 2310284 has 8.01 GiB memory in use. Process 2310282 has 8.03 GiB memory in use. Process 2310289 has 7.89 GiB memory in use. Including non-PyTorch memory, this process has 5.81 GiB memory in use. Process 2310290 has 5.69 GiB memory in use. Of the allocated memory 3.22 GiB is allocated by PyTorch, and 2.08 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2310286) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.34 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.51 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2309932 has 4.18 GiB memory in use. Process 2310284 has 8.01 GiB memory in use. Process 2310282 has 8.03 GiB memory in use. Process 2310289 has 7.89 GiB memory in use. Including non-PyTorch memory, this process has 5.81 GiB memory in use. Process 2310290 has 5.69 GiB memory in use. Of the allocated memory 3.22 GiB is allocated by PyTorch, and 2.08 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2310286)
# (FLClient pid=2310284) 2025-10-07 14:15:07,030 - INFO - Epoch   2| Train Loss: 1.659| Train Accuracy: 0.602| Val Loss: 3.401| Val Accuracy: 0.397 [repeated 19x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (FLClient pid=2310289) Error in client 2 training: CUDA out of memory. Tried to allocate 2.29 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.45 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2309932 has 4.18 GiB memory in use. Process 2310284 has 8.01 GiB memory in use. Process 2310282 has 8.03 GiB memory in use. Including non-PyTorch memory, this process has 5.57 GiB memory in use. Process 2310286 has 8.15 GiB memory in use. Process 2310290 has 5.72 GiB memory in use. Of the allocated memory 3.12 GiB is allocated by PyTorch, and 1.95 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2310289) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.29 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.45 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2309932 has 4.18 GiB memory in use. Process 2310284 has 8.01 GiB memory in use. Process 2310282 has 8.03 GiB memory in use. Including non-PyTorch memory, this process has 5.57 GiB memory in use. Process 2310286 has 8.15 GiB memory in use. Process 2310290 has 5.72 GiB memory in use. Of the allocated memory 3.12 GiB is allocated by PyTorch, and 1.95 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2310289)
# (FLClient pid=2310290) [Client 4] Initializing with: [repeated 4x across cluster]
# (FLClient pid=2310290)   - Input data nodes: 160370 [repeated 4x across cluster]
# (FLClient pid=2310290)   - Input data edges: 2447458 [repeated 4x across cluster]
# (FLClient pid=2310290)   - Feature shape: torch.Size([160370, 128]) [repeated 4x across cluster]
# (FLClient pid=2310290)   - Data device (before moving): cuda:0 [repeated 4x across cluster]
# (FLClient pid=2310290)   - Input dim: 128 [repeated 4x across cluster]
# (FLClient pid=2310290)   - Data device (after moving): cuda:0 [repeated 4x across cluster]
# (FLClient pid=2310290) Client 4: Using full-batch training for ogbn-arxiv dataset [repeated 4x across cluster]
# (FLClient pid=2310290) Error in client 4 training: CUDA out of memory. Tried to allocate 2.34 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.49 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2309932 has 4.18 GiB memory in use. Process 2310284 has 8.01 GiB memory in use. Process 2310282 has 8.03 GiB memory in use. Process 2310289 has 5.57 GiB memory in use. Process 2310286 has 8.15 GiB memory in use. Including non-PyTorch memory, this process has 5.69 GiB memory in use. Of the allocated memory 3.21 GiB is allocated by PyTorch, and 1.98 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2310290) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.34 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.49 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2309932 has 4.18 GiB memory in use. Process 2310284 has 8.01 GiB memory in use. Process 2310282 has 8.03 GiB memory in use. Process 2310289 has 5.57 GiB memory in use. Process 2310286 has 8.15 GiB memory in use. Including non-PyTorch memory, this process has 5.69 GiB memory in use. Of the allocated memory 3.21 GiB is allocated by PyTorch, and 1.98 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2310290)
# (FLClient pid=2310284) Error in client 0 training: CUDA out of memory. Tried to allocate 2.32 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.46 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2309932 has 4.18 GiB memory in use. Including non-PyTorch memory, this process has 5.67 GiB memory in use. Process 2310282 has 8.03 GiB memory in use. Process 2310289 has 5.57 GiB memory in use. Process 2310286 has 8.15 GiB memory in use. Process 2310290 has 8.06 GiB memory in use. Of the allocated memory 3.18 GiB is allocated by PyTorch, and 1.99 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2310284) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.32 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.46 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2309932 has 4.18 GiB memory in use. Including non-PyTorch memory, this process has 5.67 GiB memory in use. Process 2310282 has 8.03 GiB memory in use. Process 2310289 has 5.57 GiB memory in use. Process 2310286 has 8.15 GiB memory in use. Process 2310290 has 8.06 GiB memory in use. Of the allocated memory 3.18 GiB is allocated by PyTorch, and 1.99 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2310284)
# (FLClient pid=2310284) Traceback (most recent call last): [repeated 4x across cluster]
# (FLClient pid=2310284)   File "/home/brian_bosho/FP/FP/federated-gnn/src/client.py", line 134, in train_client [repeated 4x across cluster]
# (FLClient pid=2310284)     loss, acc, loss_list, acc_list = train( [repeated 4x across cluster]
# (FLClient pid=2310284)                                      ^^^^^^ [repeated 4x across cluster]
# (FLClient pid=2310284)   File "/home/brian_bosho/FP/FP/federated-gnn/src/train.py", line 53, in train [repeated 4x across cluster]
# (FLClient pid=2310284)     output = model(data.x, data.edge_index) [repeated 4x across cluster]
# (FLClient pid=2310284)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 4x across cluster]
# (FLClient pid=2310284)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl [repeated 8x across cluster]
# (FLClient pid=2310284)     return self._call_impl(*args, **kwargs) [repeated 8x across cluster]
# (FLClient pid=2310284)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 8x across cluster]
# (FLClient pid=2310284)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl [repeated 8x across cluster]
# (FLClient pid=2310284)     return forward_call(*args, **kwargs) [repeated 8x across cluster]
# (FLClient pid=2310284)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 8x across cluster]
# (FLClient pid=2310284)   File "/home/brian_bosho/FP/FP/federated-gnn/src/models.py", line 85, in forward [repeated 4x across cluster]
# (FLClient pid=2310284)     x = self.convs[1](x, adj_t) [repeated 4x across cluster]
# (FLClient pid=2310284)         ^^^^^^^^^^^^^^^^^^^^^^^ [repeated 4x across cluster]
# (FLClient pid=2310284)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch_geometric/nn/conv/gcn_conv.py", line 263, in forward [repeated 4x across cluster]
# (FLClient pid=2310284)     out = self.propagate(edge_index, x=x, edge_weight=edge_weight) [repeated 4x across cluster]
# (FLClient pid=2310284)           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 4x across cluster]
# (FLClient pid=2310284)   File "/tmp/torch_geometric.nn.conv.gcn_conv_GCNConv_propagate_q43i2dk8.py", line 209, in propagate [repeated 4x across cluster]
# (FLClient pid=2310284)     out = self.message( [repeated 4x across cluster]
# (FLClient pid=2310284)           ^^^^^^^^^^^^^ [repeated 4x across cluster]
# (FLClient pid=2310284)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch_geometric/nn/conv/gcn_conv.py", line 271, in message [repeated 4x across cluster]
# (FLClient pid=2310284)     return x_j if edge_weight is None else edge_weight.view(-1, 1) * x_j [repeated 4x across cluster]
# (FLClient pid=2310284)                                            ~~~~~~~~~~~~~~~~~~~~~~~~^~~~~ [repeated 4x across cluster]
# (FLClient pid=2310289) Error in client 2 training: CUDA out of memory. Tried to allocate 2.29 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.44 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2309932 has 4.18 GiB memory in use. Process 2310284 has 5.69 GiB memory in use. Process 2310282 has 8.03 GiB memory in use. Including non-PyTorch memory, this process has 5.57 GiB memory in use. Process 2310286 has 8.15 GiB memory in use. Process 2310290 has 8.06 GiB memory in use. Of the allocated memory 3.12 GiB is allocated by PyTorch, and 1.95 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2310289) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.29 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.44 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2309932 has 4.18 GiB memory in use. Process 2310284 has 5.69 GiB memory in use. Process 2310282 has 8.03 GiB memory in use. Including non-PyTorch memory, this process has 5.57 GiB memory in use. Process 2310286 has 8.15 GiB memory in use. Process 2310290 has 8.06 GiB memory in use. Of the allocated memory 3.12 GiB is allocated by PyTorch, and 1.95 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2310289)
# (FLClient pid=2310282) 2025-10-07 14:15:12,151 - INFO - Epoch   1| Train Loss: 1.867| Train Accuracy: 0.545| Val Loss: 3.396| Val Accuracy: 0.361 [repeated 15x across cluster]
# (raylet) [2025-10-07 14:15:13,735 E 2310192 2310222] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2025-10-07_14-14-42_447318_2309932 is over 95% full, available space: 30262280192; capacity: 1622224654336. Object creation will fail if spilling is required.
# (FLClient pid=2310289) Error in client 2 training: CUDA out of memory. Tried to allocate 2.29 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.55 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2309932 has 4.18 GiB memory in use. Process 2310284 has 8.01 GiB memory in use. Process 2310282 has 8.03 GiB memory in use. Including non-PyTorch memory, this process has 3.14 GiB memory in use. Process 2310286 has 8.15 GiB memory in use. Process 2310290 has 8.06 GiB memory in use. Of the allocated memory 2.60 GiB is allocated by PyTorch, and 35.84 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2310289) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.29 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.55 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2309932 has 4.18 GiB memory in use. Process 2310284 has 8.01 GiB memory in use. Process 2310282 has 8.03 GiB memory in use. Including non-PyTorch memory, this process has 3.14 GiB memory in use. Process 2310286 has 8.15 GiB memory in use. Process 2310290 has 8.06 GiB memory in use. Of the allocated memory 2.60 GiB is allocated by PyTorch, and 35.84 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2310289)
# (FLClient pid=2310289) Error in client 2 training: CUDA out of memory. Tried to allocate 2.29 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.46 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2309932 has 4.18 GiB memory in use. Process 2310284 has 8.01 GiB memory in use. Process 2310282 has 8.03 GiB memory in use. Including non-PyTorch memory, this process has 5.57 GiB memory in use. Process 2310286 has 8.15 GiB memory in use. Process 2310290 has 5.69 GiB memory in use. Of the allocated memory 3.12 GiB is allocated by PyTorch, and 1.95 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2310289) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.29 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.46 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2309932 has 4.18 GiB memory in use. Process 2310284 has 8.01 GiB memory in use. Process 2310282 has 8.03 GiB memory in use. Including non-PyTorch memory, this process has 5.57 GiB memory in use. Process 2310286 has 8.15 GiB memory in use. Process 2310290 has 5.69 GiB memory in use. Of the allocated memory 3.12 GiB is allocated by PyTorch, and 1.95 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2310289)
# (FLClient pid=2310289) Traceback (most recent call last): [repeated 3x across cluster]
# (FLClient pid=2310289)   File "/home/brian_bosho/FP/FP/federated-gnn/src/client.py", line 134, in train_client [repeated 3x across cluster]
# (FLClient pid=2310289)     loss, acc, loss_list, acc_list = train( [repeated 3x across cluster]
# (FLClient pid=2310289)                                      ^^^^^^ [repeated 3x across cluster]
# (FLClient pid=2310289)   File "/home/brian_bosho/FP/FP/federated-gnn/src/train.py", line 53, in train [repeated 3x across cluster]
# (FLClient pid=2310289)     output = model(data.x, data.edge_index) [repeated 3x across cluster]
# (FLClient pid=2310289)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 3x across cluster]
# (FLClient pid=2310289)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl [repeated 6x across cluster]
# (FLClient pid=2310289)     return self._call_impl(*args, **kwargs) [repeated 6x across cluster]
# (FLClient pid=2310289)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 6x across cluster]
# (FLClient pid=2310289)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl [repeated 6x across cluster]
# (FLClient pid=2310289)     return forward_call(*args, **kwargs) [repeated 6x across cluster]
# (FLClient pid=2310289)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 6x across cluster]
# (FLClient pid=2310289)   File "/home/brian_bosho/FP/FP/federated-gnn/src/models.py", line 85, in forward [repeated 3x across cluster]
# (FLClient pid=2310289)     x = self.convs[1](x, adj_t) [repeated 3x across cluster]
# (FLClient pid=2310289)         ^^^^^^^^^^^^^^^^^^^^^^^ [repeated 3x across cluster]
# (FLClient pid=2310289)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch_geometric/nn/conv/gcn_conv.py", line 263, in forward [repeated 3x across cluster]
# (FLClient pid=2310289)     out = self.propagate(edge_index, x=x, edge_weight=edge_weight) [repeated 3x across cluster]
# (FLClient pid=2310289)           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 3x across cluster]
# (FLClient pid=2310289)   File "/tmp/torch_geometric.nn.conv.gcn_conv_GCNConv_propagate_5sptnen0.py", line 209, in propagate [repeated 3x across cluster]
# (FLClient pid=2310289)     out = self.message( [repeated 3x across cluster]
# (FLClient pid=2310289)           ^^^^^^^^^^^^^ [repeated 3x across cluster]
# (FLClient pid=2310289)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch_geometric/nn/conv/gcn_conv.py", line 271, in message [repeated 3x across cluster]
# (FLClient pid=2310289)     return x_j if edge_weight is None else edge_weight.view(-1, 1) * x_j [repeated 3x across cluster]
# (FLClient pid=2310289)                                            ~~~~~~~~~~~~~~~~~~~~~~~~^~~~~ [repeated 3x across cluster]
# (FLClient pid=2310290) Error in client 4 training: CUDA out of memory. Tried to allocate 2.34 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.50 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2309932 has 4.18 GiB memory in use. Process 2310284 has 8.01 GiB memory in use. Process 2310282 has 8.03 GiB memory in use. Process 2310289 has 5.57 GiB memory in use. Process 2310286 has 8.15 GiB memory in use. Including non-PyTorch memory, this process has 5.69 GiB memory in use. Of the allocated memory 3.21 GiB is allocated by PyTorch, and 1.98 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2310290) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.34 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.50 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2309932 has 4.18 GiB memory in use. Process 2310284 has 8.01 GiB memory in use. Process 2310282 has 8.03 GiB memory in use. Process 2310289 has 5.57 GiB memory in use. Process 2310286 has 8.15 GiB memory in use. Including non-PyTorch memory, this process has 5.69 GiB memory in use. Of the allocated memory 3.21 GiB is allocated by PyTorch, and 1.98 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2310290)
# (FLClient pid=2310284) 2025-10-07 14:15:17,815 - INFO - Epoch   0| Train Loss: 1.622| Train Accuracy: 0.610| Val Loss: 3.218| Val Accuracy: 0.405 [repeated 18x across cluster]
# (FLClient pid=2310282) Error in client 1 training: CUDA out of memory. Tried to allocate 2.33 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.48 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2309932 has 4.18 GiB memory in use. Process 2310284 has 8.01 GiB memory in use. Including non-PyTorch memory, this process has 5.68 GiB memory in use. Process 2310289 has 7.90 GiB memory in use. Process 2310286 has 5.81 GiB memory in use. Process 2310290 has 8.06 GiB memory in use. Of the allocated memory 3.19 GiB is allocated by PyTorch, and 1.99 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2310282) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.33 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.48 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2309932 has 4.18 GiB memory in use. Process 2310284 has 8.01 GiB memory in use. Including non-PyTorch memory, this process has 5.68 GiB memory in use. Process 2310289 has 7.90 GiB memory in use. Process 2310286 has 5.81 GiB memory in use. Process 2310290 has 8.06 GiB memory in use. Of the allocated memory 3.19 GiB is allocated by PyTorch, and 1.99 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2310282)
# (FLClient pid=2310286) Error in client 3 training: CUDA out of memory. Tried to allocate 2.34 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.48 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2309932 has 4.18 GiB memory in use. Process 2310284 has 8.01 GiB memory in use. Process 2310282 has 5.68 GiB memory in use. Process 2310289 has 7.90 GiB memory in use. Including non-PyTorch memory, this process has 5.81 GiB memory in use. Process 2310290 has 8.06 GiB memory in use. Of the allocated memory 3.22 GiB is allocated by PyTorch, and 2.08 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2310286) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.34 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.48 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2309932 has 4.18 GiB memory in use. Process 2310284 has 8.01 GiB memory in use. Process 2310282 has 5.68 GiB memory in use. Process 2310289 has 7.90 GiB memory in use. Including non-PyTorch memory, this process has 5.81 GiB memory in use. Process 2310290 has 8.06 GiB memory in use. Of the allocated memory 3.22 GiB is allocated by PyTorch, and 2.08 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2310286)
# (FLClient pid=2310289) Error in client 2 training: CUDA out of memory. Tried to allocate 2.29 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.56 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2309932 has 4.18 GiB memory in use. Process 2310284 has 8.01 GiB memory in use. Process 2310282 has 8.03 GiB memory in use. Including non-PyTorch memory, this process has 3.14 GiB memory in use. Process 2310286 has 8.15 GiB memory in use. Process 2310290 has 8.06 GiB memory in use. Of the allocated memory 2.60 GiB is allocated by PyTorch, and 35.84 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2310289) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.29 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.56 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2309932 has 4.18 GiB memory in use. Process 2310284 has 8.01 GiB memory in use. Process 2310282 has 8.03 GiB memory in use. Including non-PyTorch memory, this process has 3.14 GiB memory in use. Process 2310286 has 8.15 GiB memory in use. Process 2310290 has 8.06 GiB memory in use. Of the allocated memory 2.60 GiB is allocated by PyTorch, and 35.84 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2310289)
# (FLClient pid=2310289) Traceback (most recent call last): [repeated 4x across cluster]
# (FLClient pid=2310289)   File "/home/brian_bosho/FP/FP/federated-gnn/src/client.py", line 134, in train_client [repeated 4x across cluster]
# (FLClient pid=2310289)     loss, acc, loss_list, acc_list = train( [repeated 4x across cluster]
# (FLClient pid=2310289)                                      ^^^^^^ [repeated 4x across cluster]
# (FLClient pid=2310289)   File "/home/brian_bosho/FP/FP/federated-gnn/src/train.py", line 53, in train [repeated 4x across cluster]
# (FLClient pid=2310289)     output = model(data.x, data.edge_index) [repeated 4x across cluster]
# (FLClient pid=2310289)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 4x across cluster]
# (FLClient pid=2310289)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl [repeated 8x across cluster]
# (FLClient pid=2310289)     return self._call_impl(*args, **kwargs) [repeated 8x across cluster]
# (FLClient pid=2310289)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 8x across cluster]
# (FLClient pid=2310289)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl [repeated 8x across cluster]
# (FLClient pid=2310289)     return forward_call(*args, **kwargs) [repeated 8x across cluster]
# (FLClient pid=2310289)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 8x across cluster]
# (FLClient pid=2310289)   File "/home/brian_bosho/FP/FP/federated-gnn/src/models.py", line 80, in forward [repeated 4x across cluster]
# (FLClient pid=2310289)     x = self.convs[0](x, adj_t) [repeated 4x across cluster]
# (FLClient pid=2310289)         ^^^^^^^^^^^^^^^^^^^^^^^ [repeated 4x across cluster]
# (FLClient pid=2310289)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch_geometric/nn/conv/gcn_conv.py", line 263, in forward [repeated 4x across cluster]
# (FLClient pid=2310289)     out = self.propagate(edge_index, x=x, edge_weight=edge_weight) [repeated 4x across cluster]
# (FLClient pid=2310289)           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 4x across cluster]
# (FLClient pid=2310289)   File "/tmp/torch_geometric.nn.conv.gcn_conv_GCNConv_propagate_5sptnen0.py", line 209, in propagate [repeated 4x across cluster]
# (FLClient pid=2310289)     out = self.message( [repeated 4x across cluster]
# (FLClient pid=2310289)           ^^^^^^^^^^^^^ [repeated 4x across cluster]
# (FLClient pid=2310289)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch_geometric/nn/conv/gcn_conv.py", line 271, in message [repeated 4x across cluster]
# (FLClient pid=2310289)     return x_j if edge_weight is None else edge_weight.view(-1, 1) * x_j [repeated 4x across cluster]
# (FLClient pid=2310289)                                            ~~~~~~~~~~~~~~~~~~~~~~~~^~~~~ [repeated 4x across cluster]
# (FLClient pid=2310284) 2025-10-07 14:15:23,481 - INFO - Epoch   0| Train Loss: 1.472| Train Accuracy: 0.634| Val Loss: 3.029| Val Accuracy: 0.421 [repeated 18x across cluster]
# (raylet) [2025-10-07 14:15:23,741 E 2310192 2310222] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2025-10-07_14-14-42_447318_2309932 is over 95% full, available space: 30262169600; capacity: 1622224654336. Object creation will fail if spilling is required.
# (FLClient pid=2310290) Error in client 4 training: CUDA out of memory. Tried to allocate 2.34 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.66 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2309932 has 4.18 GiB memory in use. Process 2310284 has 8.01 GiB memory in use. Process 2310282 has 8.03 GiB memory in use. Process 2310289 has 7.90 GiB memory in use. Process 2310286 has 8.15 GiB memory in use. Including non-PyTorch memory, this process has 3.20 GiB memory in use. Of the allocated memory 2.67 GiB is allocated by PyTorch, and 32.55 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2310290) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.34 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.66 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2309932 has 4.18 GiB memory in use. Process 2310284 has 8.01 GiB memory in use. Process 2310282 has 8.03 GiB memory in use. Process 2310289 has 7.90 GiB memory in use. Process 2310286 has 8.15 GiB memory in use. Including non-PyTorch memory, this process has 3.20 GiB memory in use. Of the allocated memory 2.67 GiB is allocated by PyTorch, and 32.55 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2310290)
# (FLClient pid=2310286) Error in client 3 training: CUDA out of memory. Tried to allocate 2.34 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.47 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2309932 has 4.18 GiB memory in use. Process 2310284 has 8.01 GiB memory in use. Process 2310282 has 5.70 GiB memory in use. Process 2310289 has 7.89 GiB memory in use. Including non-PyTorch memory, this process has 5.81 GiB memory in use. Process 2310290 has 8.06 GiB memory in use. Of the allocated memory 3.22 GiB is allocated by PyTorch, and 2.08 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2310286) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.34 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.47 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2309932 has 4.18 GiB memory in use. Process 2310284 has 8.01 GiB memory in use. Process 2310282 has 5.70 GiB memory in use. Process 2310289 has 7.89 GiB memory in use. Including non-PyTorch memory, this process has 5.81 GiB memory in use. Process 2310290 has 8.06 GiB memory in use. Of the allocated memory 3.22 GiB is allocated by PyTorch, and 2.08 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2310286)
# (FLClient pid=2310286) Traceback (most recent call last): [repeated 2x across cluster]
# (FLClient pid=2310286)   File "/home/brian_bosho/FP/FP/federated-gnn/src/client.py", line 134, in train_client [repeated 2x across cluster]
# (FLClient pid=2310286)     loss, acc, loss_list, acc_list = train( [repeated 2x across cluster]
# (FLClient pid=2310286)                                      ^^^^^^ [repeated 2x across cluster]
# (FLClient pid=2310286)   File "/home/brian_bosho/FP/FP/federated-gnn/src/train.py", line 53, in train [repeated 2x across cluster]
# (FLClient pid=2310286)     output = model(data.x, data.edge_index) [repeated 2x across cluster]
# (FLClient pid=2310286)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 2x across cluster]
# (FLClient pid=2310286)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl [repeated 4x across cluster]
# (FLClient pid=2310286)     return self._call_impl(*args, **kwargs) [repeated 4x across cluster]
# (FLClient pid=2310286)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 4x across cluster]
# (FLClient pid=2310286)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl [repeated 4x across cluster]
# (FLClient pid=2310286)     return forward_call(*args, **kwargs) [repeated 4x across cluster]
# (FLClient pid=2310286)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 4x across cluster]
# (FLClient pid=2310286)   File "/home/brian_bosho/FP/FP/federated-gnn/src/models.py", line 85, in forward [repeated 2x across cluster]
# (FLClient pid=2310286)     x = self.convs[1](x, adj_t) [repeated 2x across cluster]
# (FLClient pid=2310286)         ^^^^^^^^^^^^^^^^^^^^^^^ [repeated 2x across cluster]
# (FLClient pid=2310286)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch_geometric/nn/conv/gcn_conv.py", line 263, in forward [repeated 2x across cluster]
# (FLClient pid=2310286)     out = self.propagate(edge_index, x=x, edge_weight=edge_weight) [repeated 2x across cluster]
# (FLClient pid=2310286)           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 2x across cluster]
# (FLClient pid=2310286)   File "/tmp/torch_geometric.nn.conv.gcn_conv_GCNConv_propagate_7ud6qi9l.py", line 209, in propagate [repeated 2x across cluster]
# (FLClient pid=2310286)     out = self.message( [repeated 2x across cluster]
# (FLClient pid=2310286)           ^^^^^^^^^^^^^ [repeated 2x across cluster]
# (FLClient pid=2310286)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch_geometric/nn/conv/gcn_conv.py", line 271, in message [repeated 2x across cluster]
# (FLClient pid=2310286)     return x_j if edge_weight is None else edge_weight.view(-1, 1) * x_j [repeated 2x across cluster]
# (FLClient pid=2310286)                                            ~~~~~~~~~~~~~~~~~~~~~~~~^~~~~ [repeated 2x across cluster]
# (FLClient pid=2310282) Error in client 1 training: CUDA out of memory. Tried to allocate 2.33 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.49 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2309932 has 4.18 GiB memory in use. Process 2310284 has 8.01 GiB memory in use. Including non-PyTorch memory, this process has 5.68 GiB memory in use. Process 2310289 has 7.89 GiB memory in use. Process 2310286 has 5.81 GiB memory in use. Process 2310290 has 8.06 GiB memory in use. Of the allocated memory 3.19 GiB is allocated by PyTorch, and 1.99 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2310282) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.33 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.49 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2309932 has 4.18 GiB memory in use. Process 2310284 has 8.01 GiB memory in use. Including non-PyTorch memory, this process has 5.68 GiB memory in use. Process 2310289 has 7.89 GiB memory in use. Process 2310286 has 5.81 GiB memory in use. Process 2310290 has 8.06 GiB memory in use. Of the allocated memory 3.19 GiB is allocated by PyTorch, and 1.99 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2310282)
# (FLClient pid=2310284) 2025-10-07 14:15:30,017 - INFO - Epoch   0| Train Loss: 1.389| Train Accuracy: 0.650| Val Loss: 2.798| Val Accuracy: 0.464 [repeated 24x across cluster]
# training_time_s: 33.49
# Training done
# Round 1
# Train Loss: 3.522, Train Accuracy: 0.524
# Train Loss: 3.528, Train Accuracy: 0.466
# Train Loss: 3.466, Train Accuracy: 0.527
# Train Loss: 3.539, Train Accuracy: 0.409
# Train Loss: 3.529, Train Accuracy: 0.481
# Round 2
# Train Loss: 3.401, Train Accuracy: 0.602
# Train Loss: 3.469, Train Accuracy: 0.546
# Train Loss: 3.343, Train Accuracy: 0.634
# Train Loss: 0.000, Train Accuracy: 0.000
# Train Loss: 0.000, Train Accuracy: 0.000
# Round 3
# Train Loss: 3.355, Train Accuracy: 0.611
# Train Loss: 3.413, Train Accuracy: 0.561
# Train Loss: 0.000, Train Accuracy: 0.000
# Train Loss: 3.367, Train Accuracy: 0.516
# Train Loss: 0.000, Train Accuracy: 0.000
# Round 4
# Train Loss: 0.000, Train Accuracy: 0.000
# Train Loss: 3.360, Train Accuracy: 0.575
# Train Loss: 0.000, Train Accuracy: 0.000
# Train Loss: 3.295, Train Accuracy: 0.586
# Train Loss: 3.328, Train Accuracy: 0.630
# Round 5
# Train Loss: 3.210, Train Accuracy: 0.646
# Train Loss: 3.306, Train Accuracy: 0.590
# Train Loss: 0.000, Train Accuracy: 0.000
# Train Loss: 3.206, Train Accuracy: 0.585
# Train Loss: 3.265, Train Accuracy: 0.619
# Round 6
# Train Loss: 3.091, Train Accuracy: 0.669
# Train Loss: 3.221, Train Accuracy: 0.604
# Train Loss: 0.000, Train Accuracy: 0.000
# Train Loss: 3.130, Train Accuracy: 0.618
# Train Loss: 0.000, Train Accuracy: 0.000
# Round 7
# Train Loss: 2.987, Train Accuracy: 0.673
# Train Loss: 0.000, Train Accuracy: 0.000
# Train Loss: 2.879, Train Accuracy: 0.702
# Train Loss: 0.000, Train Accuracy: 0.000
# Train Loss: 3.105, Train Accuracy: 0.670
# Round 8
# Train Loss: 2.903, Train Accuracy: 0.678
# Train Loss: 3.071, Train Accuracy: 0.619
# Train Loss: 0.000, Train Accuracy: 0.000
# Train Loss: 2.956, Train Accuracy: 0.628
# Train Loss: 2.997, Train Accuracy: 0.665
# Round 9
# Train Loss: 2.782, Train Accuracy: 0.688
# Train Loss: 2.963, Train Accuracy: 0.625
# Train Loss: 2.639, Train Accuracy: 0.718
# Train Loss: 2.850, Train Accuracy: 0.645
# Train Loss: 0.000, Train Accuracy: 0.000
# Round 10
# Train Loss: 2.676, Train Accuracy: 0.693
# Train Loss: 0.000, Train Accuracy: 0.000
# Train Loss: 2.464, Train Accuracy: 0.723
# Train Loss: 0.000, Train Accuracy: 0.000
# Train Loss: 2.741, Train Accuracy: 0.694
# Validation Loss: 2.842, Validation Accuracy: 0.515
# Validation Loss: 3.074, Validation Accuracy: 0.263
# Validation Loss: 2.808, Validation Accuracy: 0.423
# Validation Loss: 2.882, Validation Accuracy: 0.397
# Validation Loss: 2.933, Validation Accuracy: 0.314
# Training CSV results saved to /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv/ogbn-arxiv_full_GCN_beta1_clients5/training_ogbn-arxiv_full_GCN_beta1_clients5_20251007_141442.csv
#
# --- Model Parameter Comparison ---
#
# Layer 0:
# Server param shape: (256,)
# Client param shapes: [(256,), (256,), (256,), (256,), (256,)]
# ✅ Parameters match!
#
# Layer 1:
# Server param shape: (256, 128)
# Client param shapes: [(256, 128), (256, 128), (256, 128), (256, 128), (256, 128)]
# ✅ Parameters match!
#
# Layer 2:
# Server param shape: (256,)
# Client param shapes: [(256,), (256,), (256,), (256,), (256,)]
# ✅ Parameters match!
#
# Layer 3:
# Server param shape: (256, 256)
# Client param shapes: [(256, 256), (256, 256), (256, 256), (256, 256), (256, 256)]
# ✅ Parameters match!
#
# Layer 4:
# Server param shape: (40,)
# Client param shapes: [(40,), (40,), (40,), (40,), (40,)]
# ✅ Parameters match!
#
# Layer 5:
# Server param shape: (40, 256)
# Client param shapes: [(40, 256), (40, 256), (40, 256), (40, 256), (40, 256)]
# ✅ Parameters match!
#
# Layer 6:
# Server param shape: (256,)
# Client param shapes: [(256,), (256,), (256,), (256,), (256,)]
# ✅ Parameters match!
#
# Layer 7:
# Server param shape: (256,)
# Client param shapes: [(256,), (256,), (256,), (256,), (256,)]
# ✅ Parameters match!
#
# Layer 8:
# Server param shape: (256,)
# Client param shapes: [(256,), (256,), (256,), (256,), (256,)]
# ✅ Parameters match!
#
# Layer 9:
# Server param shape: (256,)
# Client param shapes: [(256,), (256,), (256,), (256,), (256,)]
# ✅ Parameters match!
#
# All model parameters are identical: True
# Input dim of the model in server: 128
# Input dim of the test data in server: 128
# (FLClient pid=2310284) Input dim of the model: 128
# (FLClient pid=2310284) Input dim of the data: 128
# (raylet) [2025-10-07 14:15:33,748 E 2310192 2310222] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2025-10-07_14-14-42_447318_2309932 is over 95% full, available space: 30262054912; capacity: 1622224654336. Object creation will fail if spilling is required.
# [WANDB DEBUG] Logging test metrics - Global: 0.43478797605086106, Clients: [0.5698034128330506, 0.2777931799279179, 0.4819437510401065, 0.46268811624286454, 0.32681420483787954], Epoch: 10
# [WANDB DEBUG] Logging metrics: {'round': 10, 'test/global_test_acc': 0.43478797605086106, 'test/avg_client_test_acc': np.float64(0.42380853297636384), 'test/client_test_acc_std': np.float64(0.1067091500627405), 'test/num_clients': 5, 'test/global_vs_avg_client_diff': np.float64(0.01097944307449722)} with step: 10
# [WANDB DEBUG] Successfully logged test metrics
# The average client test results: 0.42380853297636384
# The final global test results: 0.43478797605086106
# Round 1 is complete
# wandb: ⢿ uploading output.log 53.9KB/53.9KB (0.6s)
# wandb: ⢿ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣻ uploading output.log 53.9KB/53.9KB (0.6s)
# wandb: ⣻ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣽ uploading output.log 53.9KB/53.9KB (0.6s)
# wandb: ⣽ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣾ uploading output.log 53.9KB/53.9KB (0.6s)
# wandb: ⣾ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣷ uploading output.log 53.9KB/53.9KB (0.6s)
# wandb: ⣷ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣯ uploading output.log 53.9KB/53.9KB (0.6s)
# wandb: ⣯ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣟ uploading output.log 53.9KB/53.9KB (0.6s)
# wandb: ⣟ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⡿ uploading output.log 53.9KB/53.9KB (0.6s)
# wandb: ⡿ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⢿ uploading output.log 53.9KB/53.9KB (0.6s)
# wandb: ⢿ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣻ uploading history steps 9-10, summary, console lines 255-387 (0.1s)
# wandb: ⣽ uploading history steps 9-10, summary, console lines 255-387 (0.1s)
# wandb: ⣾ uploading history steps 9-10, summary, console lines 255-387 (0.1s)
# wandb: ⣷ uploading history steps 9-10, summary, console lines 255-387 (0.1s)
# wandb:
# wandb: ⣷ uploading history steps 9-10, summary, console lines 255-387 (0.1s)
# wandb:
# wandb: Run history:
# wandb:  federation/avg_client_train_acc ▆▂▁▂▆▂▄▇█▄
# wandb: federation/avg_client_train_loss █▃▃▃▅▂▂▄▃▁
# wandb:    federation/avg_client_val_acc █▇▆█▅▁▆▅▄█
# wandb:   federation/avg_client_val_loss ██▇▇▆▅▄▄▂▁
# wandb:                            round ▁▂▂▃▄▅▅▆▇▇█
# wandb:           run_client_test_result ▁
# wandb:           run_global_test_result ▁
# wandb:         test/avg_client_test_acc ▁
# wandb:         test/client_test_acc_std ▁
# wandb:             test/global_test_acc ▁
# wandb:   test/global_vs_avg_client_diff ▁
# wandb:                 test/num_clients ▁
# wandb:
# wandb: Run summary:
# wandb:  federation/avg_client_train_acc 0.422
# wandb: federation/avg_client_train_loss 1.57639
# wandb:    federation/avg_client_val_acc 0.38248
# wandb:   federation/avg_client_val_loss 2.90783
# wandb:                            round 10
# wandb:           run_client_test_result 0.42381
# wandb:           run_global_test_result 0.43479
# wandb:         test/avg_client_test_acc 0.42381
# wandb:         test/client_test_acc_std 0.10671
# wandb:             test/global_test_acc 0.43479
# wandb:   test/global_vs_avg_client_diff 0.01098
# wandb:                 test/num_clients 5
# wandb:
# wandb: 🚀 View run GCN_ogbn-arxiv_SGD_lr0.5_decay0.0005_beta1_run1 at: https://wandb.ai/bosho/FGL3/runs/zf0xc6ix
# wandb: ⭐️ View project at: https://wandb.ai/bosho/FGL3
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251007_141445-zf0xc6ix/logs
# The global test results: [0.43478797605086106]
# The client test results: [0.42380853297636384]
# The average global test results: 0.43478797605086106
# The average client test results: 0.42380853297636384
# The standard deviation global is: 0.0
# The standard deviation client is: 0.0
# (FLClient pid=2310282) Traceback (most recent call last):
# (FLClient pid=2310282)   File "/home/brian_bosho/FP/FP/federated-gnn/src/client.py", line 134, in train_client
# (FLClient pid=2310282)     loss, acc, loss_list, acc_list = train(
# (FLClient pid=2310282)                                      ^^^^^^
# (FLClient pid=2310282)   File "/home/brian_bosho/FP/FP/federated-gnn/src/train.py", line 53, in train
# (FLClient pid=2310282)     output = model(data.x, data.edge_index)
# (FLClient pid=2310282)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=2310282)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl [repeated 2x across cluster]
# (FLClient pid=2310282)     return self._call_impl(*args, **kwargs) [repeated 2x across cluster]
# (FLClient pid=2310282)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 2x across cluster]
# (FLClient pid=2310282)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl [repeated 2x across cluster]
# (FLClient pid=2310282)     return forward_call(*args, **kwargs) [repeated 2x across cluster]
# (FLClient pid=2310282)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 2x across cluster]
# (FLClient pid=2310282)   File "/home/brian_bosho/FP/FP/federated-gnn/src/models.py", line 85, in forward
# (FLClient pid=2310282)     x = self.convs[1](x, adj_t)
# (FLClient pid=2310282)         ^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=2310282)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch_geometric/nn/conv/gcn_conv.py", line 263, in forward
# (FLClient pid=2310282)     out = self.propagate(edge_index, x=x, edge_weight=edge_weight)
# (FLClient pid=2310282)           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=2310282)   File "/tmp/torch_geometric.nn.conv.gcn_conv_GCNConv_propagate_4j63uni7.py", line 209, in propagate
# (FLClient pid=2310282)     out = self.message(
# (FLClient pid=2310282)           ^^^^^^^^^^^^^
# (FLClient pid=2310282)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch_geometric/nn/conv/gcn_conv.py", line 271, in message
# (FLClient pid=2310282)     return x_j if edge_weight is None else edge_weight.view(-1, 1) * x_j
# (FLClient pid=2310282)                                            ~~~~~~~~~~~~~~~~~~~~~~~~^~~~~
# (FLClient pid=2310290) Input dim of the model: 128 [repeated 4x across cluster]
# (FLClient pid=2310290) Input dim of the data: 128 [repeated 4x across cluster]
# (FLClient pid=2310290) 2025-10-07 14:15:30,998 - INFO - Epoch   2| Train Loss: 1.265| Train Accuracy: 0.694| Val Loss: 2.741| Val Accuracy: 0.516 [repeated 8x across cluster]
# Training CSV results saved to /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv/ogbn-arxiv_full_GCN_beta1_clients5/training_ogbn-arxiv_full_GCN_beta1_clients5_20251007_141442.csv
#
# Summary results saved to:
# - Text file: /home/brian_bosho/FP/FP/federated-gnn/results/review/results_summary/ogbn-arxiv/summary_results_20251007_141538.txt
# - JSON file: /home/brian_bosho/FP/FP/federated-gnn/results/review/results_summary/ogbn-arxiv/summary_results_20251007_141538.json
# - Detailed results saved to: /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv
#
#
#
# ================================================================================
# EXPERIMENT RESULTS SUMMARY
# ================================================================================
# +------------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+
# | Dataset    | Data Loading   | Model   |   Beta |   Clients |   Avg Global Result |   Avg Client Result |   client_std_dev |   global_std_dev | Duration   |   Hop | Use PE   |
# +============+================+=========+========+===========+=====================+=====================+==================+==================+============+=======+==========+
# | ogbn-arxiv | full           | GCN     |      1 |         5 |              0.4348 |              0.4238 |                0 |                0 | 00:00:56   |     2 | False    |
# +------------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+
#
#
# KEY RESULTS:
# --------------------------------------------------------------------------------
# ogbn-arxiv with full using GCN (beta=1.00, clients=5, hop=2, use_pe=False):
#   - Average Global Result: 0.4348
#   - Average Client Result: 0.4238
#   - Client StdDev: 0.0000
#   - Global StdDev: 0.0000
#   - Experiment Duration: 00:00:56
# --------------------------------------------------------------------------------
