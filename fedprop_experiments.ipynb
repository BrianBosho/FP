# %%
# !python -m src.experiments.run_experiments --config conf/ablation/ogbn-arxiv_config.yaml

# %%
# !python -m src.experiments.run_experiments --config conf/ablation/cora_gcn_no_pe.yaml

# %%
# !python -m src.experiments.run_experiments --config conf/ablation/ogbn-arxiv_config.yaml

# %%
# !python -m src.experiments.run_experiments --config conf/ablation/ogbn-arxiv_config.yaml
# Out:
# Experiment Configuration:
# - Clients: [1]
# - Rounds: 10
# - Epochs: 3
# - Learning Rate: 0.5
# - Beta values: [1]
# - Datasets: ['Cora']
# - Data Loading Options: ['full']
# - Model Types: ['GCN']
# - Results Directory: /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv
# - Save Detailed Results: False
# - Hop: 1
# - Full Training Flag: False
#
# ================================================================================
# Running experiment: Cora_full_GCN_beta1_clients1
# ================================================================================
# DEVICE: cuda
# Data loading option is full
# Model type is GCN
# 2025-10-07 13:26:16,557	INFO worker.py:1807 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# wandb: Currently logged in as: bosho to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /home/brian_bosho/FP/FP/federated-gnn/wandb/run-20251007_132618-sbyp3fo7
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run swept-pine-548
# wandb: ⭐️ View project at https://wandb.ai/bosho/FGL3
# wandb: 🚀 View run at https://wandb.ai/bosho/FGL3/runs/sbyp3fo7
# [WANDB DEBUG] Successfully initialized wandb run: swept-pine-548
# Wandb config is set to: {'dataset': 'Cora', 'model': 'GCN', 'data_loading': 'full', 'num_clients': [1], 'num_rounds': 10, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 1, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': 64, 'pe_P': 16, 'normalize': 'qr', 'run_index': 1, 'num_iterations': 80}
# {'dataset': 'Cora', 'model': 'GCN', 'data_loading': 'full', 'num_clients': [1], 'num_rounds': 10, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 1, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': 64, 'pe_P': 16, 'normalize': 'qr', 'run_index': 1, 'num_iterations': 80}
# data_loading_option: full
# Tolerance: 1e-6
# partition_time_s: 0.56
# client[0] device: cuda:0 cuda:0
# client[0] feature_dim: 1433
# config.use_pe: False num_iterations: 80 feature_prop_device: None
# data_loading_option: full hop: 1 num_clients: 1
#
# === DATA LOADING SUMMARY ===
# Full graph: 2708 nodes, 10556 edges
# Number of client subgraphs: 1
# First client subgraph shape: torch.Size([2708, 1433])
# Dataset: Cora()
# Device: cuda
#
# Full graph device (before): cuda:0
# Full graph staying on CPU to save GPU memory
# ===========================
#
#
# === CLIENT DATA LOADING ===
# Full graph size: 2708 nodes
# Number of clients: 1
# Client 0 subgraph: 2708 nodes, 1433 features
# ===========================
#
# Input dim of the model in server: 1433
# (FLClient pid=2258876)
# (FLClient pid=2258876) [Client 0] Initializing with:
# (FLClient pid=2258876)   - Input data nodes: 2708
# (FLClient pid=2258876)   - Input data edges: 10556
# (FLClient pid=2258876)   - Feature shape: torch.Size([2708, 1433])
# (FLClient pid=2258876)   - Data device (before moving): cuda:0
# (FLClient pid=2258876)   - Input dim: 1433
# (FLClient pid=2258876)   - Data device (after moving): cuda:0
# (FLClient pid=2258876) Client 0: Using full-batch training for Cora dataset
# (FLClient pid=2258876) 2025-10-07 13:26:23,519 - INFO - Epoch   0| Train Loss: 1.950| Train Accuracy: 0.157| Val Loss: 1.950| Val Accuracy: 0.132
# (FLClient pid=2258876) 2025-10-07 13:26:23,524 - INFO - Epoch   1| Train Loss: 1.930| Train Accuracy: 0.236| Val Loss: 1.939| Val Accuracy: 0.154
# (FLClient pid=2258876) 2025-10-07 13:26:23,528 - INFO - Epoch   2| Train Loss: 1.910| Train Accuracy: 0.257| Val Loss: 1.928| Val Accuracy: 0.218
# (FLClient pid=2258876) 2025-10-07 13:26:23,945 - INFO - Epoch   0| Train Loss: 1.892| Train Accuracy: 0.271| Val Loss: 1.914| Val Accuracy: 0.274
# (FLClient pid=2258876) 2025-10-07 13:26:23,949 - INFO - Epoch   1| Train Loss: 1.868| Train Accuracy: 0.414| Val Loss: 1.900| Val Accuracy: 0.314
# (FLClient pid=2258876) 2025-10-07 13:26:23,953 - INFO - Epoch   2| Train Loss: 1.836| Train Accuracy: 0.500| Val Loss: 1.882| Val Accuracy: 0.386
# (FLClient pid=2258876) 2025-10-07 13:26:24,380 - INFO - Epoch   0| Train Loss: 1.812| Train Accuracy: 0.521| Val Loss: 1.867| Val Accuracy: 0.400
# (FLClient pid=2258876) 2025-10-07 13:26:24,384 - INFO - Epoch   1| Train Loss: 1.784| Train Accuracy: 0.579| Val Loss: 1.846| Val Accuracy: 0.444
# (FLClient pid=2258876) 2025-10-07 13:26:24,388 - INFO - Epoch   2| Train Loss: 1.729| Train Accuracy: 0.650| Val Loss: 1.825| Val Accuracy: 0.494
# (FLClient pid=2258876) 2025-10-07 13:26:24,804 - INFO - Epoch   0| Train Loss: 1.712| Train Accuracy: 0.636| Val Loss: 1.804| Val Accuracy: 0.540
# (FLClient pid=2258876) 2025-10-07 13:26:24,808 - INFO - Epoch   1| Train Loss: 1.672| Train Accuracy: 0.750| Val Loss: 1.782| Val Accuracy: 0.566
# Round 2
# Train Loss: 1.882, Train Accuracy: 0.500
# Round 3
# Train Loss: 1.825, Train Accuracy: 0.650
# Round 4
# Train Loss: 1.760, Train Accuracy: 0.757
# Round 5
# Train Loss: 1.680, Train Accuracy: 0.764
# Round 6
# Train Loss: 1.602, Train Accuracy: 0.800
# Round 7
# Train Loss: 1.510, Train Accuracy: 0.829
# Round 8
# Train Loss: 1.427, Train Accuracy: 0.879
# Round 9
# Train Loss: 1.342, Train Accuracy: 0.871
# Round 10
# Train Loss: 1.263, Train Accuracy: 0.821
# Validation Loss: 1.263, Validation Accuracy: 0.758
# Training CSV results saved to /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv/Cora_full_GCN_beta1_clients1/training_Cora_full_GCN_beta1_clients1_20251007_132615.csv
#
# --- Model Parameter Comparison ---
#
# Layer 0:
# Server param shape: (16,)
# Client param shapes: [(16,)]
# ✅ Parameters match!
#
# Layer 1:
# Server param shape: (16, 1433)
# Client param shapes: [(16, 1433)]
# ✅ Parameters match!
#
# Layer 2:
# Server param shape: (7,)
# Client param shapes: [(7,)]
# ✅ Parameters match!
#
# Layer 3:
# Server param shape: (7, 16)
# Client param shapes: [(7, 16)]
# ✅ Parameters match!
#
# All model parameters are identical: True
# Input dim of the model in server: 1433
# Input dim of the test data in server: 1433
# (FLClient pid=2258876) Input dim of the model: 1433
# (FLClient pid=2258876) Input dim of the data: 1433
#
# === DEBUG: Single-client cross-check ===
# Global test nodes: 1000
# Client0 test nodes: 1000
# Input dim of the model in server: 1433
# Input dim of the test data in server: 1433
# (FLClient pid=2258876) Input dim of the model: 1433
# (FLClient pid=2258876) Input dim of the data: 1433
# Server model on client graph acc: 0.786
# Client model on global graph acc: 0.786
# === END DEBUG ===
#
# [WANDB DEBUG] Logging test metrics - Global: 0.786, Clients: [0.786], Epoch: 10
# [WANDB DEBUG] Logging metrics: {'round': 10, 'test/global_test_acc': 0.786, 'test/avg_client_test_acc': np.float64(0.786), 'test/client_test_acc_std': np.float64(0.0), 'test/num_clients': 1, 'test/global_vs_avg_client_diff': np.float64(0.0)} with step: 10
# [WANDB DEBUG] Successfully logged test metrics
# The average client test results: 0.786
# The final global test results: 0.786
# Round 1 is complete
# wandb: ⢿ uploading history steps 0-10, summary, console lines 1-139 (0.0s)
# wandb: ⣻ uploading history steps 0-10, summary, console lines 1-139 (0.0s)
# wandb: ⣽ uploading history steps 0-10, summary, console lines 1-139 (0.0s)
# wandb:
# wandb: ⣽ uploading history steps 0-10, summary, console lines 1-139 (0.0s)
# wandb:
# wandb: Run history:
# wandb:  federation/avg_client_train_acc ▁▄▅▇▇▇▇██▇
# wandb: federation/avg_client_train_loss ██▇▆▅▅▄▃▂▁
# wandb:    federation/avg_client_val_acc ▁▃▅▆▇▇████
# wandb:   federation/avg_client_val_loss ██▇▆▅▅▄▃▂▁
# wandb:                            round ▁▂▂▃▄▅▅▆▇▇█
# wandb:           run_client_test_result ▁
# wandb:           run_global_test_result ▁
# wandb:         test/avg_client_test_acc ▁
# wandb:         test/client_test_acc_std ▁
# wandb:             test/global_test_acc ▁
# wandb:   test/global_vs_avg_client_diff ▁
# wandb:                 test/num_clients ▁
# wandb:
# wandb: Run summary:
# wandb:  federation/avg_client_train_acc 0.82143
# wandb: federation/avg_client_train_loss 1.26296
# wandb:    federation/avg_client_val_acc 0.758
# wandb:   federation/avg_client_val_loss 1.26296
# wandb:                            round 10
# wandb:           run_client_test_result 0.786
# wandb:           run_global_test_result 0.786
# wandb:         test/avg_client_test_acc 0.786
# wandb:         test/client_test_acc_std 0
# wandb:             test/global_test_acc 0.786
# wandb:   test/global_vs_avg_client_diff 0
# wandb:                 test/num_clients 1
# wandb:
# wandb: 🚀 View run GCN_Cora_SGD_lr0.5_decay0.0005_beta1_run1 at: https://wandb.ai/bosho/FGL3/runs/sbyp3fo7
# wandb: ⭐️ View project at: https://wandb.ai/bosho/FGL3
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251007_132618-sbyp3fo7/logs
# The global test results: [0.786]
# The client test results: [0.786]
# The average global test results: 0.786
# The average client test results: 0.786
# The standard deviation global is: 0.0
# The standard deviation client is: 0.0
# Training CSV results saved to /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv/Cora_full_GCN_beta1_clients1/training_Cora_full_GCN_beta1_clients1_20251007_132615.csv
#
# Summary results saved to:
# - Text file: /home/brian_bosho/FP/FP/federated-gnn/results/review/results_summary/ogbn-arxiv/summary_results_20251007_132631.txt
# - JSON file: /home/brian_bosho/FP/FP/federated-gnn/results/review/results_summary/ogbn-arxiv/summary_results_20251007_132631.json
# - Detailed results saved to: /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv
#
#
#
# ================================================================================
# EXPERIMENT RESULTS SUMMARY
# ================================================================================
# +-----------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+
# | Dataset   | Data Loading   | Model   |   Beta |   Clients |   Avg Global Result |   Avg Client Result |   client_std_dev |   global_std_dev | Duration   |   Hop | Use PE   |
# +===========+================+=========+========+===========+=====================+=====================+==================+==================+============+=======+==========+
# | Cora      | full           | GCN     |      1 |         1 |               0.786 |               0.786 |                0 |                0 | 00:00:15   |     1 | False    |
# +-----------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+
#
#
# KEY RESULTS:
# --------------------------------------------------------------------------------
# Cora with full using GCN (beta=1.00, clients=1, hop=1, use_pe=False):
#   - Average Global Result: 0.7860
#   - Average Client Result: 0.7860
#   - Client StdDev: 0.0000
#   - Global StdDev: 0.0000
#   - Experiment Duration: 00:00:15
# --------------------------------------------------------------------------------
