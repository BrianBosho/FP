# %%
# !python -m src.experiments.run_experiments --config conf/ablation/ogbn-arxiv_config.yaml

# %%
# !python -m src.experiments.run_experiments --config conf/ablation/amazon-computers_config.yaml

# %%
# !python -m src.experiments.run_experiments --config conf/ablation/ogbn-arxiv_config.yaml
# Out:
# Experiment Configuration:
# - Clients: [10]
# - Rounds: 5
# - Epochs: 3
# - Learning Rate: 0.5
# - Beta values: [1]
# - Datasets: ['Cora']
# - Data Loading Options: ['diffusion', 'chebyshev_diffusion', 'chebyshev_diffusion_operator']
# - Model Types: ['GCN']
# - Results Directory: /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv
# - Save Detailed Results: False
# - Hop: 1
# - Full Training Flag: False
#
# ...
# Running experiment: Cora_diffusion_GCN_beta1_clients10
# ...
# DEVICE: cuda
# Data loading option is diffusion
# Model type is GCN
# 2025-10-06 13:50:34,500	INFO worker.py:1807 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# wandb: Currently logged in as: bosho to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ creating run (0.4s)
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /home/brian_bosho/FP/FP/federated-gnn/wandb/run-20251006_135036-qrvzwpqq
# ...

# %%
# !python -m src.experiments.run_experiments --config conf/ablation/amazon-photo_config.yaml

# %%
# !python scripts/chebyshev_grid.py --base_config conf/ablation/ogbn-arxiv_config.yaml
# Out:
# === RUN: chebyshev_diffusion_t0p01_k3
# - config: /tmp/chebyshev_sweep_cfgs/ogbn-arxiv_config_chebyshev_diffusion_t0p01_k3.yaml
# Running: /home/brian_bosho/miniconda3/bin/python -m src.experiments.run_experiments --config /tmp/chebyshev_sweep_cfgs/ogbn-arxiv_config_chebyshev_diffusion_t0p01_k3.yaml
#
# Experiment Configuration:
# - Clients: [10]
# - Rounds: 5
# - Epochs: 3
# - Learning Rate: 0.5
# - Beta values: [1]
# - Datasets: ['Cora']
# - Data Loading Options: ['chebyshev_diffusion']
# - Model Types: ['GCN']
# - Results Directory: /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv
# - Save Detailed Results: False
# - Hop: 1
# - Full Training Flag: False
#
# ...
# Running experiment: Cora_chebyshev_diffusion_GCN_beta1_clients10
# ...
# DEVICE: cuda
# Data loading option is chebyshev_diffusion
# Model type is GCN
# 2025-10-06 13:55:51,182	INFO worker.py:1807 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# ...
