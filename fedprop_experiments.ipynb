# %%
# !python -m src.experiments.run_experiments --config conf/ablation/ogbn-arxiv_config.yaml
# Out:
# Experiment Configuration:
# - Clients: [5]
# - Rounds: 20
# - Epochs: 3
# - Learning Rate: 0.5
# - Beta values: [1]
# - Datasets: ['Cora']
# - Data Loading Options: ['full']
# - Model Types: ['GCN']
# - Results Directory: /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv
# - Save Detailed Results: False
# - Hop: 2
# - Full Training Flag: False
#
# ================================================================================
# Running experiment: Cora_full_GCN_beta1_clients5
# ================================================================================
# DEVICE: cuda
# Data loading option is full
# Model type is GCN
# 2025-10-08 10:46:59,416	INFO worker.py:1807 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# [WANDB DEBUG] Wandb logging disabled by configuration
# data_loading_option: full
# Tolerance: 1e-6
# partition_time_s: 0.61
# client[0] device: cuda:0 cuda:0
# client[0] feature_dim: 1433
# config.use_pe: False num_iterations: 80 feature_prop_device: cpu
# data_loading_option: full hop: 2 num_clients: 5
#
# === DATA LOADING SUMMARY ===
# Full graph: 2708 nodes, 10556 edges
# Number of client subgraphs: 5
# First client subgraph shape: torch.Size([1868, 1433])
# Dataset: Cora()
# Device: cuda
#
# Full graph device (before): cuda:0
# Full graph staying on CPU to save GPU memory
# ===========================
#
#
# === CLIENT DATA LOADING ===
# Full graph size: 2708 nodes
# Number of clients: 5
# Client 0 subgraph: 1868 nodes, 1433 features
# Client 1 subgraph: 2072 nodes, 1433 features
# Client 2 subgraph: 2069 nodes, 1433 features
# Client 3 subgraph: 2121 nodes, 1433 features
# Client 4 subgraph: 2222 nodes, 1433 features
# ===========================
#
# Input dim of the model in server: 1433
# (FLClient pid=2827327)
# (FLClient pid=2827327) [Client 0] Initializing with:
# (FLClient pid=2827327)   - Input data nodes: 1868
# (FLClient pid=2827327)   - Input data edges: 7680
# (FLClient pid=2827327)   - Feature shape: torch.Size([1868, 1433])
# (FLClient pid=2827327)   - Data device (before moving): cuda:0
# (FLClient pid=2827327)   - Input dim: 1433
# (FLClient pid=2827327)   - Data device (after moving): cuda:0
# (FLClient pid=2827327) Client 0: Using full-batch training for Cora dataset
# (FLClient pid=2827327) /home/brian_bosho/FP/FP/federated-gnn/src/train.py:38: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
# (FLClient pid=2827327)   scaler = torch.cuda.amp.GradScaler(enabled=use_amp)
# (FLClient pid=2827327) /home/brian_bosho/FP/FP/federated-gnn/src/train.py:55: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# (FLClient pid=2827327)   with torch.cuda.amp.autocast(enabled=use_amp):
# (FLClient pid=2827326)
# (FLClient pid=2827329)
# (FLClient pid=2827320)
# (FLClient pid=2827330)
# (FLClient pid=2827327) 2025-10-08 10:47:04,823 - INFO - Epoch   0| Train Loss: 1.957| Train Accuracy: 0.043| Val Loss: 1.808| Val Accuracy: 0.656
# (FLClient pid=2827327) 2025-10-08 10:47:04,829 - INFO - Epoch   1| Train Loss: 1.791| Train Accuracy: 0.522| Val Loss: 1.674| Val Accuracy: 0.656
# (FLClient pid=2827327) 2025-10-08 10:47:04,834 - INFO - Epoch   2| Train Loss: 1.692| Train Accuracy: 0.478| Val Loss: 1.551| Val Accuracy: 0.656
# (raylet) [2025-10-08 10:47:09,314 E 2827227 2827261] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2025-10-08_10-46-58_039037_2826940 is over 95% full, available space: 5117440000; capacity: 1622224654336. Object creation will fail if spilling is required.
# (FLClient pid=2827330) /home/brian_bosho/FP/FP/federated-gnn/src/train.py:38: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead. [repeated 4x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (FLClient pid=2827330)   scaler = torch.cuda.amp.GradScaler(enabled=use_amp) [repeated 4x across cluster]
# (FLClient pid=2827330) /home/brian_bosho/FP/FP/federated-gnn/src/train.py:55: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead. [repeated 4x across cluster]
# (FLClient pid=2827330)   with torch.cuda.amp.autocast(enabled=use_amp): [repeated 4x across cluster]
# (FLClient pid=2827327) 2025-10-08 10:47:10,039 - INFO - Epoch   1| Train Loss: 0.762| Train Accuracy: 0.783| Val Loss: 0.920| Val Accuracy: 0.705 [repeated 134x across cluster]
# (FLClient pid=2827327) 2025-10-08 10:47:15,230 - INFO - Epoch   0| Train Loss: 0.534| Train Accuracy: 0.826| Val Loss: 0.675| Val Accuracy: 0.803 [repeated 149x across cluster]
# training_time_s: 14.46
# Training done
# Round 1
# Train Loss: 1.551, Train Accuracy: 0.478
# Train Loss: 1.773, Train Accuracy: 0.545
# Train Loss: 1.604, Train Accuracy: 0.700
# Train Loss: 1.337, Train Accuracy: 0.632
# Train Loss: 1.338, Train Accuracy: 0.486
# Round 2
# Train Loss: 1.386, Train Accuracy: 0.522
# Train Loss: 1.679, Train Accuracy: 0.682
# Train Loss: 1.501, Train Accuracy: 0.600
# Train Loss: 1.210, Train Accuracy: 0.737
# Train Loss: 1.279, Train Accuracy: 0.514
# Round 3
# Train Loss: 1.286, Train Accuracy: 0.609
# Train Loss: 1.574, Train Accuracy: 0.773
# Train Loss: 1.404, Train Accuracy: 0.750
# Train Loss: 1.112, Train Accuracy: 0.632
# Train Loss: 1.209, Train Accuracy: 0.595
# Round 4
# Train Loss: 1.208, Train Accuracy: 0.652
# Train Loss: 1.470, Train Accuracy: 0.909
# Train Loss: 1.303, Train Accuracy: 0.750
# Train Loss: 1.027, Train Accuracy: 0.763
# Train Loss: 1.141, Train Accuracy: 0.703
# Round 5
# Train Loss: 1.135, Train Accuracy: 0.609
# Train Loss: 1.367, Train Accuracy: 0.864
# Train Loss: 1.182, Train Accuracy: 0.900
# Train Loss: 0.996, Train Accuracy: 0.816
# Train Loss: 1.081, Train Accuracy: 0.757
# Round 6
# Train Loss: 1.083, Train Accuracy: 0.652
# Train Loss: 1.279, Train Accuracy: 0.955
# Train Loss: 1.094, Train Accuracy: 0.850
# Train Loss: 0.938, Train Accuracy: 0.763
# Train Loss: 1.022, Train Accuracy: 0.757
# Round 7
# Train Loss: 1.033, Train Accuracy: 0.783
# Train Loss: 1.207, Train Accuracy: 0.864
# Train Loss: 1.018, Train Accuracy: 0.900
# Train Loss: 0.857, Train Accuracy: 0.816
# Train Loss: 0.963, Train Accuracy: 0.838
# Round 8
# Train Loss: 0.980, Train Accuracy: 0.783
# Train Loss: 1.131, Train Accuracy: 0.909
# Train Loss: 0.942, Train Accuracy: 0.950
# Train Loss: 0.819, Train Accuracy: 0.842
# Train Loss: 0.910, Train Accuracy: 0.865
# Round 9
# Train Loss: 0.925, Train Accuracy: 0.870
# Train Loss: 1.047, Train Accuracy: 0.955
# Train Loss: 0.893, Train Accuracy: 0.900
# Train Loss: 0.791, Train Accuracy: 0.816
# Train Loss: 0.858, Train Accuracy: 0.811
# Round 10
# Train Loss: 0.892, Train Accuracy: 0.783
# Train Loss: 1.007, Train Accuracy: 0.955
# Train Loss: 0.841, Train Accuracy: 1.000
# Training CSV results saved to /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv/Cora_full_GCN_beta1_clients5/training_Cora_full_GCN_beta1_clients5_20251008_104658.csv
#
# --- Model Parameter Comparison ---
#
# Layer 0:
# Server param shape: (16,)
# Client param shapes: [(16,), (16,), (16,), (16,), (16,)]
# ✅ Parameters match!
#
# Layer 1:
# Server param shape: (16, 1433)
# Client param shapes: [(16, 1433), (16, 1433), (16, 1433), (16, 1433), (16, 1433)]
# ✅ Parameters match!
#
# Layer 2:
# Server param shape: (7,)
# Client param shapes: [(7,), (7,), (7,), (7,), (7,)]
# ✅ Parameters match!
#
# Layer 3:
# Server param shape: (7, 16)
# Client param shapes: [(7, 16), (7, 16), (7, 16), (7, 16), (7, 16)]
# ✅ Parameters match!
#
# All model parameters are identical: True
# Input dim of the model in server: 1433
# Input dim of the test data in server: 1433
# (FLClient pid=2827327) Input dim of the model: 1433
# (FLClient pid=2827327) Input dim of the data: 1433
# (FLClient pid=2827330) [Client 4] Initializing with: [repeated 4x across cluster]
# (FLClient pid=2827330)   - Input data nodes: 2222 [repeated 4x across cluster]
# (FLClient pid=2827330)   - Input data edges: 9168 [repeated 4x across cluster]
# (FLClient pid=2827330)   - Feature shape: torch.Size([2222, 1433]) [repeated 4x across cluster]
# (FLClient pid=2827330)   - Data device (before moving): cuda:0 [repeated 4x across cluster]
# (FLClient pid=2827330)   - Input dim: 1433 [repeated 4x across cluster]
# (FLClient pid=2827330)   - Data device (after moving): cuda:0 [repeated 4x across cluster]
# (FLClient pid=2827330) Client 4: Using full-batch training for Cora dataset [repeated 4x across cluster]
# [WANDB DEBUG] Logging test metrics - Global: 0.779, Clients: [0.7801418439716312, 0.8571428571428571, 0.7947019867549668, 0.7296511627906976, 0.7695852534562212], Epoch: 20
# [WANDB DEBUG] Logging metrics: {'round': 20, 'test/global_test_acc': 0.779, 'test/avg_client_test_acc': np.float64(0.7862446208232747), 'test/client_test_acc_std': np.float64(0.04151068501045571), 'test/num_clients': 5, 'test/global_vs_avg_client_diff': np.float64(-0.007244620823274706)} with step: 20
# [WANDB ERROR] wandb.run is None - wandb may not be properly initialized
# The average client test results: 0.7862446208232747
# The final global test results: 0.779
# Round 1 is complete
# The global test results: [0.779]
# The client test results: [0.7862446208232747]
# The average global test results: 0.779
# The average client test results: 0.7862446208232747
# The standard deviation global is: 0.0
# The standard deviation client is: 0.0
# (FLClient pid=2827330) Input dim of the model: 1433 [repeated 4x across cluster]
# (FLClient pid=2827330) Input dim of the data: 1433 [repeated 4x across cluster]
# (FLClient pid=2827330) 2025-10-08 10:47:15,252 - INFO - Epoch   2| Train Loss: 0.245| Train Accuracy: 0.973| Val Loss: 0.593| Val Accuracy: 0.820 [repeated 14x across cluster]
# Training CSV results saved to /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv/Cora_full_GCN_beta1_clients5/training_Cora_full_GCN_beta1_clients5_20251008_104658.csv
#
# Summary results saved to:
# - Text file: /home/brian_bosho/FP/FP/federated-gnn/results/review/results_summary/ogbn-arxiv/summary_results_20251008_104718.txt
# - JSON file: /home/brian_bosho/FP/FP/federated-gnn/results/review/results_summary/ogbn-arxiv/summary_results_20251008_104718.json
# - Detailed results saved to: /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv
#
#
#
# ================================================================================
# EXPERIMENT RESULTS SUMMARY
# ================================================================================
# +-----------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+
# | Dataset   | Data Loading   | Model   |   Beta |   Clients |   Avg Global Result |   Avg Client Result |   client_std_dev |   global_std_dev | Duration   |   Hop | Use PE   |
# +===========+================+=========+========+===========+=====================+=====================+==================+==================+============+=======+==========+
# | Cora      | full           | GCN     |      1 |         5 |               0.779 |              0.7862 |                0 |                0 | 00:00:20   |     2 | False    |
# +-----------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+
#
#
# KEY RESULTS:
# --------------------------------------------------------------------------------
# Cora with full using GCN (beta=1.00, clients=5, hop=2, use_pe=False):
#   - Average Global Result: 0.7790
#   - Average Client Result: 0.7862
#   - Client StdDev: 0.0000
#   - Global StdDev: 0.0000
#   - Experiment Duration: 00:00:20
# --------------------------------------------------------------------------------

# %%
# !python -m src.experiments.run_experiments --config conf/ablation/ogbn-arxiv_config.yaml
