# %%
# !python -m src.experiments.run_experiments --config conf/ablation/ogbn-arxiv_config.yaml

# %%
# !python -m src.experiments.run_experiments --config conf/ablation/amazon-computers_config.yaml
# Out:
# Experiment Configuration:
# - Clients: [10]
# - Rounds: 5
# - Epochs: 3
# - Learning Rate: 0.5
# - Beta values: [1.0]
# - Datasets: ['Computers']
# - Data Loading Options: ['diffusion']
# - Model Types: ['GCN']
# - Results Directory: /home/brian_bosho/FP/FP/results/experiments/amazon_computers
# - Save Detailed Results: True
# - Hop: 1
# - Full Training Flag: False
#
# ================================================================================
# Running experiment: Computers_diffusion_GCN_beta1.0_clients10
# ================================================================================
# DEVICE: cuda
# Data loading option is diffusion
# Model type is GCN
# 2025-10-02 13:19:18,491	INFO worker.py:1807 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# wandb: Currently logged in as: bosho to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /home/brian_bosho/FP/FP/federated-gnn/wandb/run-20251002_131920-m9owi87b
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run astral-lake-375
# wandb: ⭐️ View project at https://wandb.ai/bosho/FGL3
# wandb: 🚀 View run at https://wandb.ai/bosho/FGL3/runs/m9owi87b
# [WANDB DEBUG] Successfully initialized wandb run: astral-lake-375
# Wandb config is set to: {'dataset': 'Computers', 'model': 'GCN', 'data_loading': 'diffusion', 'num_clients': [10], 'num_rounds': 5, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 1, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': None, 'pe_P': None, 'normalize': None, 'run_index': 1, 'num_iterations': None}
# {'dataset': 'Computers', 'model': 'GCN', 'data_loading': 'diffusion', 'num_clients': [10], 'num_rounds': 5, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 1, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': None, 'pe_P': None, 'normalize': None, 'run_index': 1, 'num_iterations': None}
# data_loading_option: diffusion
# Error in round 1: CUDA error: insufficient resources when calling `cusparseSpGEMM_workEstimation( handle, opA, opB, &alpha, matA, matB, &beta, matC, computeType, CUSPARSE_SPGEMM_DEFAULT, spgemmDesc, &bufferSize1, dBuffer1)`
# The global test results: []
# The client test results: []
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:3904: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/numpy/_core/_methods.py:147: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/numpy/_core/_methods.py:227: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/numpy/_core/_methods.py:184: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/numpy/_core/_methods.py:219: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# The average global test results: nan
# The average client test results: nan
# The standard deviation global is: nan
# The standard deviation client is: nan
# Results saved to /home/brian_bosho/FP/FP/results/experiments/amazon_computers/Computers_diffusion_GCN_beta1.0_clients10/results_Computers_diffusion_GCN_beta1.0_clients10_20251002_131917.json
# Training CSV results saved to /home/brian_bosho/FP/FP/results/experiments/amazon_computers/Computers_diffusion_GCN_beta1.0_clients10/training_Computers_diffusion_GCN_beta1.0_clients10_20251002_131917.csv
#
# Summary results saved to:
# - Text file: /home/brian_bosho/FP/FP/results/results_summary/amazon_computers/summary_results_20251002_131925.txt
# - JSON file: /home/brian_bosho/FP/FP/results/results_summary/amazon_computers/summary_results_20251002_131925.json
# - Detailed results saved to: /home/brian_bosho/FP/FP/results/experiments/amazon_computers
#
#
#
# ================================================================================
# EXPERIMENT RESULTS SUMMARY
# ================================================================================
# +-----------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+
# | Dataset   | Data Loading   | Model   |   Beta |   Clients |   Avg Global Result |   Avg Client Result |   client_std_dev |   global_std_dev | Duration   |   Hop | Use PE   |
# +===========+================+=========+========+===========+=====================+=====================+==================+==================+============+=======+==========+
# | Computers | diffusion      | GCN     |      1 |        10 |                 nan |                 nan |              nan |              nan | 00:00:08   |     1 | False    |
# +-----------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+
#
#
# KEY RESULTS:
# --------------------------------------------------------------------------------
# Computers with diffusion using GCN (beta=1.00, clients=10, hop=1, use_pe=False):
#   - Average Global Result: nan
#   - Average Client Result: nan
#   - Client StdDev: nan
#   - Global StdDev: nan
#   - Experiment Duration: 00:00:08
# --------------------------------------------------------------------------------
# wandb: ⢿ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: ⣻ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: ⣽ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: ⣾ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: ⣷ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: ⣯ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb:
# wandb: ⣯ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: 🚀 View run GCN_Computers_SGD_lr0.5_decay0.0005_beta1_run1 at: https://wandb.ai/bosho/FGL3/runs/m9owi87b
# wandb: ⭐️ View project at: https://wandb.ai/bosho/FGL3
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251002_131920-m9owi87b/logs

# %%
# !python -m src.experiments.run_experiments --config conf/ablation/ogbn-arxiv_config.yaml
