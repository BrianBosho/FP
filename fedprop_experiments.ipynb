# %%
# !python -m src.experiments.run_experiments --config conf/ablation/ogbn-arxiv_config.yaml

# %%
# !python -m src.experiments.run_experiments --config conf/ablation/cora_gcn_no_pe.yaml

# %%
# !python -m src.experiments.run_experiments --config conf/ablation/ogbn-arxiv_config.yaml

# %%
# !python -m src.experiments.run_experiments --config conf/ablation/ogbn-arxiv_config.yaml
# Out:
# Experiment Configuration:
# - Clients: [1]
# - Rounds: 10
# - Epochs: 3
# - Learning Rate: 0.5
# - Beta values: [1]
# - Datasets: ['ogbn-arxiv']
# - Data Loading Options: ['full']
# - Model Types: ['GCN']
# - Results Directory: /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv
# - Save Detailed Results: False
# - Hop: 1
# - Full Training Flag: False
#
# ================================================================================
# Running experiment: ogbn-arxiv_full_GCN_beta1_clients1
# ================================================================================
# DEVICE: cuda
# Data loading option is full
# Model type is GCN
# 2025-10-07 13:33:37,270	INFO worker.py:1807 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# wandb: Currently logged in as: bosho to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /home/brian_bosho/FP/FP/federated-gnn/wandb/run-20251007_133338-k4yq3cr7
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run charmed-surf-549
# wandb: ⭐️ View project at https://wandb.ai/bosho/FGL3
# wandb: 🚀 View run at https://wandb.ai/bosho/FGL3/runs/k4yq3cr7
# [WANDB DEBUG] Successfully initialized wandb run: charmed-surf-549
# Wandb config is set to: {'dataset': 'ogbn-arxiv', 'model': 'GCN', 'data_loading': 'full', 'num_clients': [1], 'num_rounds': 10, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 1, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': 64, 'pe_P': 16, 'normalize': 'qr', 'run_index': 1, 'num_iterations': 80}
# {'dataset': 'ogbn-arxiv', 'model': 'GCN', 'data_loading': 'full', 'num_clients': [1], 'num_rounds': 10, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 1, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': 64, 'pe_P': 16, 'normalize': 'qr', 'run_index': 1, 'num_iterations': 80}
# data_loading_option: full
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/ogb/nodeproppred/dataset_pyg.py:69: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.data, self.slices = torch.load(self.processed_paths[0])
# Tolerance: 1e-6
# (raylet) [2025-10-07 13:33:46,261 E 2264007 2264040] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2025-10-07_13-33-35_155138_2263725 is over 95% full, available space: 30287601664; capacity: 1622224654336. Object creation will fail if spilling is required.
# partition_time_s: 8.49
# client[0] device: cuda:0 cuda:0
# client[0] feature_dim: 128
# config.use_pe: False num_iterations: 80 feature_prop_device: None
# data_loading_option: full hop: 1 num_clients: 1
#
# === DATA LOADING SUMMARY ===
# Full graph: 169343 nodes, 2484941 edges
# Number of client subgraphs: 1
# First client subgraph shape: torch.Size([169343, 128])
# Dataset: PygNodePropPredDataset()
# Device: cuda
#
# Full graph device (before): cuda:0
# Full graph staying on CPU to save GPU memory
# ===========================
#
# Model is GCN_arxiv(
#   (convs): ModuleList(
#     (0): GCNConv(128, 256)
#     (1): GCNConv(256, 256)
#     (2): GCNConv(256, 40)
#   )
#   (bns): ModuleList(
#     (0-1): 2 x BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
#
# === CLIENT DATA LOADING ===
# Full graph size: 169343 nodes
# Number of clients: 1
# Client 0 subgraph: 169343 nodes, 128 features
# ===========================
#
# Input dim of the model in server: 128
# (FLClient pid=2264128)
# (FLClient pid=2264128) [Client 0] Initializing with:
# (FLClient pid=2264128)   - Input data nodes: 169343
# (FLClient pid=2264128)   - Input data edges: 2484941
# (FLClient pid=2264128)   - Feature shape: torch.Size([169343, 128])
# (FLClient pid=2264128)   - Data device (before moving): cuda:0
# (FLClient pid=2264128)   - Input dim: 128
# (FLClient pid=2264128)   - Data device (after moving): cuda:0
# (FLClient pid=2264128) Client 0: Using full-batch training for ogbn-arxiv dataset
# (FLClient pid=2264128) 2025-10-07 13:33:54,519 - INFO - Epoch   0| Train Loss: 4.043| Train Accuracy: 0.024| Val Loss: 3.603| Val Accuracy: 0.291
# (FLClient pid=2264128) 2025-10-07 13:33:54,672 - INFO - Epoch   1| Train Loss: 3.175| Train Accuracy: 0.252| Val Loss: 3.553| Val Accuracy: 0.264
# (FLClient pid=2264128) 2025-10-07 13:33:54,826 - INFO - Epoch   2| Train Loss: 2.647| Train Accuracy: 0.382| Val Loss: 3.538| Val Accuracy: 0.277
# Error in round 1: result type Float can't be cast to the desired output type Long
# The global test results: []
# The client test results: []
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:3904: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/numpy/_core/_methods.py:147: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/numpy/_core/_methods.py:227: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/numpy/_core/_methods.py:184: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/numpy/_core/_methods.py:219: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# The average global test results: nan
# The average client test results: nan
# The standard deviation global is: nan
# The standard deviation client is: nan
# Training CSV results saved to /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv/ogbn-arxiv_full_GCN_beta1_clients1/training_ogbn-arxiv_full_GCN_beta1_clients1_20251007_133335.csv
#
# Summary results saved to:
# - Text file: /home/brian_bosho/FP/FP/federated-gnn/results/review/results_summary/ogbn-arxiv/summary_results_20251007_133356.txt
# - JSON file: /home/brian_bosho/FP/FP/federated-gnn/results/review/results_summary/ogbn-arxiv/summary_results_20251007_133356.json
# - Detailed results saved to: /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv
#
#
#
# ================================================================================
# EXPERIMENT RESULTS SUMMARY
# ================================================================================
# +------------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+
# | Dataset    | Data Loading   | Model   |   Beta |   Clients |   Avg Global Result |   Avg Client Result |   client_std_dev |   global_std_dev | Duration   |   Hop | Use PE   |
# +============+================+=========+========+===========+=====================+=====================+==================+==================+============+=======+==========+
# | ogbn-arxiv | full           | GCN     |      1 |         1 |                 nan |                 nan |              nan |              nan | 00:00:21   |     1 | False    |
# +------------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+
#
#
# KEY RESULTS:
# --------------------------------------------------------------------------------
# ogbn-arxiv with full using GCN (beta=1.00, clients=1, hop=1, use_pe=False):
#   - Average Global Result: nan
#   - Average Client Result: nan
#   - Client StdDev: nan
#   - Global StdDev: nan
#   - Experiment Duration: 00:00:21
# --------------------------------------------------------------------------------
# wandb: ⢿ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣻ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣽ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣾ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣷ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣯ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb:
# wandb: ⣯ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: 🚀 View run GCN_ogbn-arxiv_SGD_lr0.5_decay0.0005_beta1_run1 at: https://wandb.ai/bosho/FGL3/runs/k4yq3cr7
# wandb: ⭐️ View project at: https://wandb.ai/bosho/FGL3
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251007_133338-k4yq3cr7/logs
