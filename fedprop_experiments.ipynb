# %%
# !python -m src.experiments.run_experiments --config conf/ablation/ogbn-arxiv_config.yaml

# %%
# !python -m src.experiments.run_experiments --config conf/ablation/cora_gcn_no_pe.yaml
# Out:
# Experiment Configuration:
# - Clients: [10]
# - Rounds: 100
# - Epochs: 3
# - Learning Rate: 0.1
# - Beta values: [10000]
# - Datasets: ['Cora']
# - Data Loading Options: ['adjacency', 'diffusion', 'full']
# - Model Types: ['GCN']
# - Results Directory: /home/brian_bosho/FP/FP/federated-gnn/results/cora_gcn_beta10000_no_pe_nzh
# - Save Detailed Results: False
# - Hop: 1
# - Full Training Flag: False
#
# ================================================================================
# Running experiment: Cora_adjacency_GCN_beta10000_clients10
# ================================================================================
# DEVICE: cuda
# Data loading option is adjacency
# Model type is GCN
# 2025-10-07 12:09:21,410	INFO worker.py:1807 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# wandb: Currently logged in as: bosho to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /home/brian_bosho/FP/FP/federated-gnn/wandb/run-20251007_120923-p32dkdpe
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run mild-snowball-541
# wandb: ⭐️ View project at https://wandb.ai/bosho/FGL3
# wandb: 🚀 View run at https://wandb.ai/bosho/FGL3/runs/p32dkdpe
# [WANDB DEBUG] Successfully initialized wandb run: mild-snowball-541
# Wandb config is set to: {'dataset': 'Cora', 'model': 'GCN', 'data_loading': 'adjacency', 'num_clients': [10], 'num_rounds': 100, 'epochs': 3, 'beta': 10000, 'lr': 0.1, 'optimizer': 'SGD', 'decay': 0.001, 'hop': 1, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': 64, 'pe_P': 16, 'normalize': 'qr', 'run_index': 1, 'num_iterations': None}
# {'dataset': 'Cora', 'model': 'GCN', 'data_loading': 'adjacency', 'num_clients': [10], 'num_rounds': 100, 'epochs': 3, 'beta': 10000, 'lr': 0.1, 'optimizer': 'SGD', 'decay': 0.001, 'hop': 1, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': 64, 'pe_P': 16, 'normalize': 'qr', 'run_index': 1, 'num_iterations': None}
# data_loading_option: adjacency
# Tolerance: 0.001
# feature_propagation: steps=50, converged=False, mode=adjacency, tol=0.001
# feature_propagation: steps=50, converged=False, mode=adjacency, tol=0.001
# feature_propagation: steps=50, converged=False, mode=adjacency, tol=0.001
# feature_propagation: steps=50, converged=False, mode=adjacency, tol=0.001
# feature_propagation: steps=50, converged=False, mode=adjacency, tol=0.001
# feature_propagation: steps=50, converged=False, mode=adjacency, tol=0.001
# feature_propagation: steps=50, converged=False, mode=adjacency, tol=0.001
# feature_propagation: steps=50, converged=False, mode=adjacency, tol=0.001
# feature_propagation: steps=50, converged=False, mode=adjacency, tol=0.001
# feature_propagation: steps=50, converged=False, mode=adjacency, tol=0.001
# Feature propagation logs saved to: results/cora_gcn_beta10000_no_pe_nzh/propagation_stats/prop_exp_20251007-120925_adjacency_beta_10000_hop_1.json
# partition_time_s: 1.21
# client[0] device: cuda:0 cuda:0
# client[0] feature_dim: 1433
# config.use_pe: False num_iterations: None feature_prop_device: None
# data_loading_option: adjacency hop: 1 num_clients: 10
#
# === DATA LOADING SUMMARY ===
# Full graph: 2708 nodes, 10556 edges
# Number of client subgraphs: 10
# First client subgraph shape: torch.Size([946, 1433])
# Dataset: Cora()
# Device: cuda
#
# Full graph device (before): cuda:0
# Full graph staying on CPU to save GPU memory
# ===========================
#
#
# === CLIENT DATA LOADING ===
# Full graph size: 2708 nodes
# Number of clients: 10
# Client 0 subgraph: 946 nodes, 1433 features
# Client 1 subgraph: 972 nodes, 1433 features
# Client 2 subgraph: 1085 nodes, 1433 features
# Client 3 subgraph: 997 nodes, 1433 features
# Client 4 subgraph: 1006 nodes, 1433 features
# Client 5 subgraph: 974 nodes, 1433 features
# Client 6 subgraph: 1094 nodes, 1433 features
# Client 7 subgraph: 936 nodes, 1433 features
# Client 8 subgraph: 1060 nodes, 1433 features
# Client 9 subgraph: 996 nodes, 1433 features
# ===========================
#
# Input dim of the model in server: 1433
# (FLClient pid=2210859)
# (FLClient pid=2210859) [Client 2] Initializing with:
# (FLClient pid=2210859)   - Input data nodes: 1085
# (FLClient pid=2210859)   - Input data edges: 4004
# (FLClient pid=2210859)   - Feature shape: torch.Size([1085, 1433])
# (FLClient pid=2210859)   - Data device (before moving): cuda:0
# (FLClient pid=2210859)   - Input dim: 1433
# (FLClient pid=2210859)   - Data device (after moving): cuda:0
# (FLClient pid=2210859) Client 2: Using full-batch training for Cora dataset
# (FLClient pid=2210852)
# (FLClient pid=2210859) 2025-10-07 12:09:30,841 - INFO - Epoch   0| Train Loss: 1.966| Train Accuracy: 0.133| Val Loss: 1.939| Val Accuracy: 0.196
# (FLClient pid=2210859) 2025-10-07 12:09:30,847 - INFO - Epoch   1| Train Loss: 1.922| Train Accuracy: 0.267| Val Loss: 1.950| Val Accuracy: 0.152
# (FLClient pid=2210859) 2025-10-07 12:09:30,852 - INFO - Epoch   2| Train Loss: 1.873| Train Accuracy: 0.400| Val Loss: 1.960| Val Accuracy: 0.174
# (FLClient pid=2210855)
# (FLClient pid=2210858)
# (FLClient pid=2210861)
# (FLClient pid=2210851)
# (FLClient pid=2210856)
# (FLClient pid=2210870)
# (FLClient pid=2210847)
# (FLClient pid=2210862)
# (raylet) [2025-10-07 12:09:31,399 E 2210759 2210789] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2025-10-07_12-09-20_126498_2210473 is over 95% full, available space: 29897781248; capacity: 1622224654336. Object creation will fail if spilling is required.
# (FLClient pid=2210852) 2025-10-07 12:09:35,978 - INFO - Epoch   2| Train Loss: 1.688| Train Accuracy: 0.571| Val Loss: 1.908| Val Accuracy: 0.286 [repeated 180x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (raylet) [2025-10-07 12:09:41,411 E 2210759 2210789] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2025-10-07_12-09-20_126498_2210473 is over 95% full, available space: 29897695232; capacity: 1622224654336. Object creation will fail if spilling is required.
# (FLClient pid=2210861) 2025-10-07 12:09:40,844 - INFO - Epoch   2| Train Loss: 1.580| Train Accuracy: 0.800| Val Loss: 1.819| Val Accuracy: 0.429 [repeated 237x across cluster]
# (FLClient pid=2210852) 2025-10-07 12:09:46,437 - INFO - Epoch   2| Train Loss: 1.265| Train Accuracy: 0.857| Val Loss: 1.711| Val Accuracy: 0.531 [repeated 213x across cluster]
# (raylet) [2025-10-07 12:09:51,422 E 2210759 2210789] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2025-10-07_12-09-20_126498_2210473 is over 95% full, available space: 29897617408; capacity: 1622224654336. Object creation will fail if spilling is required.
# (FLClient pid=2210852) 2025-10-07 12:09:51,461 - INFO - Epoch   2| Train Loss: 1.017| Train Accuracy: 0.929| Val Loss: 1.602| Val Accuracy: 0.653 [repeated 228x across cluster]
# (FLClient pid=2210852) 2025-10-07 12:09:57,044 - INFO - Epoch   2| Train Loss: 0.716| Train Accuracy: 0.929| Val Loss: 1.480| Val Accuracy: 0.673 [repeated 222x across cluster]
