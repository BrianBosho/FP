# %%
# !python -m src.experiments.run_experiments --config conf/ablation/ogbn-arxiv_config.yaml
# Out:
# Experiment Configuration:
# - Clients: [5]
# - Rounds: 20
# - Epochs: 3
# - Learning Rate: 0.5
# - Beta values: [1]
# - Datasets: ['Cora']
# - Data Loading Options: ['full']
# - Model Types: ['GCN']
# - Results Directory: /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv
# - Save Detailed Results: False
# - Hop: 2
# - Full Training Flag: False
#
# ================================================================================
# Running experiment: Cora_full_GCN_beta1_clients5
# ================================================================================
# DEVICE: cuda
# Data loading option is full
# Model type is GCN
# 2025-10-08 10:48:00,100	INFO worker.py:1807 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# wandb: Currently logged in as: bosho to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /home/brian_bosho/FP/FP/federated-gnn/wandb/run-20251008_104801-z5sfcfy0
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run twilight-fog-617
# wandb: ⭐️ View project at https://wandb.ai/bosho/FGL3
# wandb: 🚀 View run at https://wandb.ai/bosho/FGL3/runs/z5sfcfy0
# [WANDB DEBUG] Successfully initialized wandb run: twilight-fog-617
# Wandb config is set to: {'dataset': 'Cora', 'model': 'GCN', 'data_loading': 'full', 'num_clients': [5], 'num_rounds': 20, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 2, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': 64, 'pe_P': 16, 'normalize': 'qr', 'run_index': 1, 'num_iterations': 80}
# {'dataset': 'Cora', 'model': 'GCN', 'data_loading': 'full', 'num_clients': [5], 'num_rounds': 20, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 2, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': 64, 'pe_P': 16, 'normalize': 'qr', 'run_index': 1, 'num_iterations': 80}
# data_loading_option: full
# Tolerance: 1e-6
# partition_time_s: 0.6
# client[0] device: cuda:0 cuda:0
# client[0] feature_dim: 1433
# config.use_pe: False num_iterations: 80 feature_prop_device: cpu
# data_loading_option: full hop: 2 num_clients: 5
#
# === DATA LOADING SUMMARY ===
# Full graph: 2708 nodes, 10556 edges
# Number of client subgraphs: 5
# First client subgraph shape: torch.Size([1868, 1433])
# Dataset: Cora()
# Device: cuda
#
# Full graph device (before): cuda:0
# Full graph staying on CPU to save GPU memory
# ===========================
#
#
# === CLIENT DATA LOADING ===
# Full graph size: 2708 nodes
# Number of clients: 5
# Client 0 subgraph: 1868 nodes, 1433 features
# Client 1 subgraph: 2072 nodes, 1433 features
# Client 2 subgraph: 2069 nodes, 1433 features
# Client 3 subgraph: 2121 nodes, 1433 features
# Client 4 subgraph: 2222 nodes, 1433 features
# ===========================
#
# Input dim of the model in server: 1433
# (FLClient pid=2830072)
# (FLClient pid=2830072) [Client 0] Initializing with:
# (FLClient pid=2830072)   - Input data nodes: 1868
# (FLClient pid=2830072)   - Input data edges: 7680
# (FLClient pid=2830072)   - Feature shape: torch.Size([1868, 1433])
# (FLClient pid=2830072)   - Data device (before moving): cuda:0
# (FLClient pid=2830072)   - Input dim: 1433
# (FLClient pid=2830072)   - Data device (after moving): cuda:0
# (FLClient pid=2830072) Client 0: Using full-batch training for Cora dataset
# (FLClient pid=2830081)
# (FLClient pid=2830069)
# (FLClient pid=2830071)
# (FLClient pid=2830077)
# (FLClient pid=2830072) /home/brian_bosho/FP/FP/federated-gnn/src/train.py:38: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
# (FLClient pid=2830072)   scaler = torch.cuda.amp.GradScaler(enabled=use_amp)
# (FLClient pid=2830072) /home/brian_bosho/FP/FP/federated-gnn/src/train.py:55: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# (FLClient pid=2830072)   with torch.cuda.amp.autocast(enabled=use_amp):
# (FLClient pid=2830072) 2025-10-08 10:48:07,867 - INFO - Epoch   0| Train Loss: 1.992| Train Accuracy: 0.130| Val Loss: 1.791| Val Accuracy: 0.656
# (FLClient pid=2830072) 2025-10-08 10:48:07,874 - INFO - Epoch   1| Train Loss: 1.774| Train Accuracy: 0.522| Val Loss: 1.630| Val Accuracy: 0.656
# (FLClient pid=2830072) 2025-10-08 10:48:07,879 - INFO - Epoch   2| Train Loss: 1.628| Train Accuracy: 0.522| Val Loss: 1.478| Val Accuracy: 0.656
# (raylet) [2025-10-08 10:48:09,996 E 2829979 2830009] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2025-10-08_10-47-58_723594_2829692 is over 95% full, available space: 5115875328; capacity: 1622224654336. Object creation will fail if spilling is required.
# (FLClient pid=2830077) /home/brian_bosho/FP/FP/federated-gnn/src/train.py:38: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead. [repeated 4x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (FLClient pid=2830077)   scaler = torch.cuda.amp.GradScaler(enabled=use_amp) [repeated 4x across cluster]
# (FLClient pid=2830077) /home/brian_bosho/FP/FP/federated-gnn/src/train.py:55: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` inst
# Train Loss: 0.766, Train Accuracy: 0.870
# Train Loss: 0.908, Train Accuracy: 0.909
# Train Loss: 0.739, Train Accuracy: 1.000
# Train Loss: 0.591, Train Accuracy: 0.921
# Train Loss: 0.695, Train Accuracy: 0.892
# Round 14
# Train Loss: 0.770, Train Accuracy: 0.913
# Train Loss: 0.805, Train Accuracy: 0.955
# Train Loss: 0.679, Train Accuracy: 1.000
# Train Loss: 0.560, Train Accuracy: 0.921
# Train Loss: 0.672, Train Accuracy: 0.919
# Round 15
# Train Loss: 0.719, Train Accuracy: 0.957
# Train Loss: 0.790, Train Accuracy: 1.000
# Train Loss: 0.661, Train Accuracy: 1.000
# Train Loss: 0.596, Train Accuracy: 0.947
# Train Loss: 0.649, Train Accuracy: 0.892
# Round 16
# Train Loss: 0.680, Train Accuracy: 1.000
# Train Loss: 0.741, Train Accuracy: 1.000
# Train Loss: 0.630, Train Accuracy: 1.000
# Train Loss: 0.588, Train Accuracy: 0.947
# Train Loss: 0.630, Train Accuracy: 0.919
# Round 17
# Train Loss: 0.681, Train Accuracy: 0.826
# Train Loss: 0.712, Train Accuracy: 1.000
# Train Loss: 0.620, Train Accuracy: 1.000
# Train Loss: 0.548, Train Accuracy: 0.868
# Train Loss: 0.616, Train Accuracy: 0.919
# Round 18
# Train Loss: 0.665, Train Accuracy: 0.957
# Train Loss: 0.707, Train Accuracy: 0.955
# Train Loss: 0.601, Train Accuracy: 1.000
# Train Loss: 0.522, Train Accuracy: 1.000
# Train Loss: 0.601, Train Accuracy: 0.919
# Round 19
# Train Loss: 0.666, Train Accuracy: 0.913
# Train Loss: 0.686, Train Accuracy: 0.955
# Train Loss: 0.588, Train Accuracy: 1.000
# Train Loss: 0.503, Train Accuracy: 0.895
# Train Loss: 0.588, Train Accuracy: 0.892
# Round 20
# Train Loss: 0.635, Train Accuracy: 1.000
# Train Loss: 0.658, Train Accuracy: 0.955
# Train Loss: 0.582, Train Accuracy: 0.950
# Train Loss: 0.505, Train Accuracy: 1.000
# Train Loss: 0.582, Train Accuracy: 0.892
# Validation Loss: 0.909, Validation Accuracy: 0.721
# Validation Loss: 0.823, Validation Accuracy: 0.783
# Validation Loss: 0.573, Validation Accuracy: 0.893
# Validation Loss: 1.133, Validation Accuracy: 0.647
# Validation Loss: 0.907, Validation Accuracy: 0.762
# Training CSV results saved to /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv/Cora_full_GCN_beta1_clients5/training_Cora_full_GCN_beta1_clients5_20251008_104758.csv
#
# --- Model Parameter Comparison ---
#
# Layer 0:
# Server param shape: (16,)
# Client param shapes: [(16,), (16,), (16,), (16,), (16,)]
# ✅ Parameters match!
#
# Layer 1:
# Server param shape: (16, 1433)
# Client param shapes: [(16, 1433), (16, 1433), (16, 1433), (16, 1433), (16, 1433)]
# ✅ Parameters match!
#
# Layer 2:
# Server param shape: (7,)
# Client param shapes: [(7,), (7,), (7,), (7,), (7,)]
# ✅ Parameters match!
#
# Layer 3:
# Server param shape: (7, 16)
# Client param shapes: [(7, 16), (7, 16), (7, 16), (7, 16), (7, 16)]
# ✅ Parameters match!
#
# All model parameters are identical: True
# Input dim of the model in server: 1433
# Input dim of the test data in server: 1433
# (FLClient pid=2830072) Input dim of the model: 1433
# (FLClient pid=2830072) Input dim of the data: 1433
# (FLClient pid=2830077) [Client 4] Initializing with: [repeated 4x across cluster]
# (FLClient pid=2830077)   - Input data nodes: 2222 [repeated 4x across cluster]
# (FLClient pid=2830077)   - Input data edges: 9168 [repeated 4x across cluster]
# (FLClient pid=2830077)   - Feature shape: torch.Size([2222, 1433]) [repeated 4x across cluster]
# (FLClient pid=2830077)   - Data device (before moving): cuda:0 [repeated 4x across cluster]
# (FLClient pid=2830077)   - Input dim: 1433 [repeated 4x across cluster]
# (FLClient pid=2830077)   - Data device (after moving): cuda:0 [repeated 4x across cluster]
# (FLClient pid=2830077) Client 4: Using full-batch training for Cora dataset [repeated 4x across cluster]
# [WANDB DEBUG] Logging test metrics - Global: 0.787, Clients: [0.8014184397163121, 0.8707482993197279, 0.8344370860927153, 0.7441860465116279, 0.7511520737327189], Epoch: 20
# [WANDB DEBUG] Logging metrics: {'round': 20, 'test/global_test_acc': 0.787, 'test/avg_client_test_acc': np.float64(0.8003883890746204), 'test/client_test_acc_std': np.float64(0.0483607481345547), 'test/num_clients': 5, 'test/global_vs_avg_client_diff': np.float64(-0.013388389074620366)} with step: 20
# [WANDB DEBUG] Successfully logged test metrics
# The average client test results: 0.8003883890746204
# The final global test results: 0.787
# Round 1 is complete
# (raylet) [2025-10-08 10:48:20,003 E 2829979 2830009] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2025-10-08_10-47-58_723594_2829692 is over 95% full, available space: 5115748352; capacity: 1622224654336. Object creation will fail if spilling is required.
# (FLClient pid=2830077) 2025-10-08 10:48:17,850 - INFO - Epoch   2| Train Loss: 0.395| Train Accuracy: 0.892| Val Loss: 0.582| Val Accuracy: 0.828 [repeated 148x across cluster]
# wandb: ⢿ uploading history steps 18-20, summary, console lines 60-229 (0.1s)
# wandb: ⣻ uploading history steps 18-20, summary, console lines 60-229 (0.1s)
# wandb:
# wandb: ⣻ uploading history steps 18-20, summary, console lines 60-229 (0.1s)
# wandb:
# wandb: Run history:
# wandb:  federation/avg_client_train_acc ▁▂▃▃▅▅▅▆▆▇▆▇▇▇██▇█▇█
# wandb: federation/avg_client_train_loss █▇▆▆▅▅▄▄▃▃▃▂▂▂▂▁▁▁▁▁
# wandb:    federation/avg_client_val_acc ▁▂▄▅▅▆▆▇▇▇██████████
# wandb:   federation/avg_client_val_loss ██▇▇▆▅▅▄▄▃▃▃▂▂▂▂▁▁▁▁
# wandb:                            round ▁▁▂▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇▇██
# wandb:           run_client_test_result ▁
# wandb:           run_global_test_result ▁
# wandb:         test/avg_client_test_acc ▁
# wandb:         test/client_test_acc_std ▁
# wandb:             test/global_test_acc ▁
# wandb:   test/global_vs_avg_client_diff ▁
# wandb:                 test/num_clients ▁
# wandb:
# wandb: Run summary:
# wandb:  federation/avg_client_train_acc 0.95929
# wandb: federation/avg_client_train_loss 0.59233
# wandb:    federation/avg_client_val_acc 0.76139
# wandb:   federation/avg_client_val_loss 0.86914
# wandb:                            round 20
# wandb:           run_client_test_result 0.80039
# wandb:           run_global_test_result 0.787
# wandb:         test/avg_client_test_acc 0.80039
# wandb:         test/client_test_acc_std 0.04836
# wandb:             test/global_test_acc 0.787
# wandb:   test/global_vs_avg_client_diff -0.01339
# wandb:                 test/num_clients 5
# wandb:
# wandb: 🚀 View run GCN_Cora_SGD_lr0.5_decay0.0005_beta1_run1 at: https://wandb.ai/bosho/FGL3/runs/z5sfcfy0
# wandb: ⭐️ View project at: https://wandb.ai/bosho/FGL3
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251008_104801-z5sfcfy0/logs
# The global test results: [0.787]
# The client test results: [0.8003883890746204]
# The average global test results: 0.787
# The average client test results: 0.8003883890746204
# The standard deviation global is: 0.0
# The standard deviation client is: 0.0
# (FLClient pid=2830077) Input dim of the model: 1433 [repeated 4x across cluster]
# (FLClient pid=2830077) Input dim of the data: 1433 [repeated 4x across cluster]
# Training CSV results saved to /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv/Cora_full_GCN_beta1_clients5/training_Cora_full_GCN_beta1_clients5_20251008_104758.csv
#
# Summary results saved to:
# - Text file: /home/brian_bosho/FP/FP/federated-gnn/results/review/results_summary/ogbn-arxiv/summary_results_20251008_104822.txt
# - JSON file: /home/brian_bosho/FP/FP/federated-gnn/results/review/results_summary/ogbn-arxiv/summary_results_20251008_104822.json
# - Detailed results saved to: /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv
#
#
#
# ================================================================================
# EXPERIMENT RESULTS SUMMARY
# ================================================================================
# +-----------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+
# | Dataset   | Data Loading   | Model   |   Beta |   Clients |   Avg Global Result |   Avg Client Result |   client_std_dev |   global_std_dev | Duration   |   Hop | Use PE   |
# +===========+================+=========+========+===========+=====================+=====================+==================+==================+============+=======+==========+
# | Cora      | full           | GCN     |      1 |         5 |               0.787 |              0.8004 |                0 |                0 | 00:00:23   |     2 | False    |
# +-----------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+
#
#
# KEY RESULTS:
# --------------------------------------------------------------------------------
# Cora with full using GCN (beta=1.00, clients=5, hop=2, use_pe=False):
#   - Average Global Result: 0.7870
#   - Average Client Result: 0.8004
#   - Client StdDev: 0.0000
#   - Global StdDev: 0.0000
#   - Experiment Duration: 00:00:23
# --------------------------------------------------------------------------------

# %%
# !python -m src.experiments.run_experiments --config conf/ablation/ogbn-arxiv_config.yaml
