# %%
# !python -m src.experiments.run_experiments --config conf/ablation/ogbn-arxiv_config.yaml
# Out:
# Experiment Configuration:
# - Clients: [5]
# - Rounds: 20
# - Epochs: 3
# - Learning Rate: 0.5
# - Beta values: [1]
# - Datasets: ['Cora']
# - Data Loading Options: ['full']
# - Model Types: ['GCN']
# - Results Directory: /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv
# - Save Detailed Results: False
# - Hop: 2
# - Full Training Flag: False
#
# ================================================================================
# Running experiment: Cora_full_GCN_beta1_clients5
# ================================================================================
# DEVICE: cuda
# Data loading option is full
# Model type is GCN
# 2025-10-08 10:32:02,207	INFO worker.py:1807 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# wandb: Currently logged in as: bosho to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /home/brian_bosho/FP/FP/federated-gnn/wandb/run-20251008_103203-63l7s5bk
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run deft-dawn-615
# wandb: ⭐️ View project at https://wandb.ai/bosho/FGL3
# wandb: 🚀 View run at https://wandb.ai/bosho/FGL3/runs/63l7s5bk
# [WANDB DEBUG] Successfully initialized wandb run: deft-dawn-615
# Wandb config is set to: {'dataset': 'Cora', 'model': 'GCN', 'data_loading': 'full', 'num_clients': [5], 'num_rounds': 20, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 2, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': 64, 'pe_P': 16, 'normalize': 'qr', 'run_index': 1, 'num_iterations': 80}
# {'dataset': 'Cora', 'model': 'GCN', 'data_loading': 'full', 'num_clients': [5], 'num_rounds': 20, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 2, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': 64, 'pe_P': 16, 'normalize': 'qr', 'run_index': 1, 'num_iterations': 80}
# data_loading_option: full
# Tolerance: 1e-6
# partition_time_s: 0.6
# client[0] device: cuda:0 cuda:0
# client[0] feature_dim: 1433
# config.use_pe: False num_iterations: 80 feature_prop_device: cpu
# data_loading_option: full hop: 2 num_clients: 5
#
# === DATA LOADING SUMMARY ===
# Full graph: 2708 nodes, 10556 edges
# Number of client subgraphs: 5
# First client subgraph shape: torch.Size([1868, 1433])
# Dataset: Cora()
# Device: cuda
#
# Full graph device (before): cuda:0
# Full graph staying on CPU to save GPU memory
# ===========================
#
#
# === CLIENT DATA LOADING ===
# Full graph size: 2708 nodes
# Number of clients: 5
# Client 0 subgraph: 1868 nodes, 1433 features
# Client 1 subgraph: 2072 nodes, 1433 features
# Client 2 subgraph: 2069 nodes, 1433 features
# Client 3 subgraph: 2121 nodes, 1433 features
# Client 4 subgraph: 2222 nodes, 1433 features
# ===========================
#
# Input dim of the model in server: 1433
# (FLClient pid=2815493)
# (FLClient pid=2815493) [Client 0] Initializing with:
# (FLClient pid=2815493)   - Input data nodes: 1868
# (FLClient pid=2815493)   - Input data edges: 7680
# (FLClient pid=2815493)   - Feature shape: torch.Size([1868, 1433])
# (FLClient pid=2815493)   - Data device (before moving): cuda:0
# (FLClient pid=2815493)   - Input dim: 1433
# (FLClient pid=2815493)   - Data device (after moving): cuda:0
# (FLClient pid=2815493) Client 0: Using full-batch training for Cora dataset
# (FLClient pid=2815484)
# (FLClient pid=2815494)
# (FLClient pid=2815496)
# (FLClient pid=2815493) /home/brian_bosho/FP/FP/federated-gnn/src/train.py:38: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
# (FLClient pid=2815493)   scaler = torch.cuda.amp.GradScaler(enabled=use_amp)
# (FLClient pid=2815493) /home/brian_bosho/FP/FP/federated-gnn/src/train.py:55: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# (FLClient pid=2815493)   with torch.cuda.amp.autocast(enabled=use_amp):
# (FLClient pid=2815490)
# (FLClient pid=2815493) 2025-10-08 10:32:10,135 - INFO - Epoch   0| Train Loss: 1.981| Train Accuracy: 0.043| Val Loss: 1.828| Val Accuracy: 0.689
# (FLClient pid=2815493) 2025-10-08 10:32:10,141 - INFO - Epoch   1| Train Loss: 1.821| Train Accuracy: 0.478| Val Loss: 1.705| Val Accuracy: 0.656
# (FLClient pid=2815493) 2025-10-08 10:32:10,146 - INFO - Epoch   2| Train Loss: 1.697| Train Accuracy: 0.522| Val Loss: 1.604| Val Accuracy: 0.656
# (raylet) [2025-10-08 10:32:12,107 E 2815395 2815425] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2025-10-08_10-32-01_010107_2815117 is over 95% full, available space: 5063589888; capacity: 1622224654336. Object creation will fail if spilling is required.
# (FLClient pid=2815496) /home/brian_bosho/FP/FP/federated-gnn/src/train.py:38: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead. [repeated 4x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (FLClient pid=2815496)   scaler = torch.cuda.amp.GradScaler(enabled=use_amp) [repeated 4x across cluster]
# (FLClient pid=2815496) /home/brian_bosho/FP/FP/federated-gnn/src/train.py:55: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead. [repeated 4x across cluster]
# (FLClient pid=2815496)   with torch.cuda.amp.autocast(enabled=use_amp): [repeated 4x across cluster]
# (FLClient pid=2815484) 2025-10-08 10:32:15,586 - INFO - Epoch   2| Train Loss: 0.591| Train Accuracy: 0.909| Val Loss: 0.996| Val Accuracy: 0.739 [repeated 150x across cluster]
# training_time_s: 14.52
# Training done
# Round 1
# Train Loss: 1.604, Train Accuracy: 0.522
# Train Loss: 1.731, Train Accuracy: 0.591
# Train Loss: 0.819, Train Accuracy: 1.000
# Train Loss: 0.701, Train Accuracy: 1.000
# Train Loss: 0.687, Train Accuracy: 0.974
# Train Loss: 0.695, Train Accuracy: 0.946
# Round 15
# Train Loss: 0.761, Train Accuracy: 0.957
# Train Loss: 0.787, Train Accuracy: 1.000
# Train Loss: 0.666, Train Accuracy: 1.000
# Train Loss: 0.683, Train Accuracy: 0.921
# Train Loss: 0.667, Train Accuracy: 0.919
# Round 16
# Train Loss: 0.734, Train Accuracy: 1.000
# Train Loss: 0.747, Train Accuracy: 1.000
# Train Loss: 0.638, Train Accuracy: 1.000
# Train Loss: 0.612, Train Accuracy: 0.947
# Train Loss: 0.656, Train Accuracy: 0.946
# Round 17
# Train Loss: 0.736, Train Accuracy: 1.000
# Train Loss: 0.726, Train Accuracy: 0.955
# Train Loss: 0.609, Train Accuracy: 1.000
# Train Loss: 0.631, Train Accuracy: 0.921
# Train Loss: 0.631, Train Accuracy: 0.946
# Round 18
# Train Loss: 0.725, Train Accuracy: 0.913
# Train Loss: 0.699, Train Accuracy: 0.955
# Train Loss: 0.598, Train Accuracy: 0.950
# Train Loss: 0.588, Train Accuracy: 0.921
# Train Loss: 0.609, Train Accuracy: 0.946
# Round 19
# Train Loss: 0.647, Train Accuracy: 1.000
# Train Loss: 0.699, Train Accuracy: 1.000
# Train Loss: 0.578, Train Accuracy: 1.000
# Train Loss: 0.604, Train Accuracy: 0.974
# Train Loss: 0.600, Train Accuracy: 0.973
# Round 20
# Train Loss: 0.625, Train Accuracy: 0.957
# Train Loss: 0.679, Train Accuracy: 0.955
# Train Loss: 0.556, Train Accuracy: 1.000
# Train Loss: 0.604, Train Accuracy: 0.974
# Train Loss: 0.581, Train Accuracy: 0.919
# Validation Loss: 0.913, Validation Accuracy: 0.754
# Validation Loss: 0.842, Validation Accuracy: 0.739
# Validation Loss: 0.576, Validation Accuracy: 0.880
# Validation Loss: 1.216, Validation Accuracy: 0.653
# Validation Loss: 0.911, Validation Accuracy: 0.746
# Training CSV results saved to /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv/Cora_full_GCN_beta1_clients5/training_Cora_full_GCN_beta1_clients5_20251008_103200.csv
#
# --- Model Parameter Comparison ---
#
# Layer 0:
# Server param shape: (16,)
# Client param shapes: [(16,), (16,), (16,), (16,), (16,)]
# ✅ Parameters match!
#
# Layer 1:
# Server param shape: (16, 1433)
# Client param shapes: [(16, 1433), (16, 1433), (16, 1433), (16, 1433), (16, 1433)]
# ✅ Parameters match!
#
# Layer 2:
# Server param shape: (7,)
# Client param shapes: [(7,), (7,), (7,), (7,), (7,)]
# ✅ Parameters match!
#
# Layer 3:
# Server param shape: (7, 16)
# Client param shapes: [(7, 16), (7, 16), (7, 16), (7, 16), (7, 16)]
# ✅ Parameters match!
#
# All model parameters are identical: True
# Input dim of the model in server: 1433
# Input dim of the test data in server: 1433
# (FLClient pid=2815493) Input dim of the model: 1433
# (FLClient pid=2815493) Input dim of the data: 1433
# (FLClient pid=2815490) [Client 3] Initializing with: [repeated 4x across cluster]
# (FLClient pid=2815490)   - Input data nodes: 2121 [repeated 4x across cluster]
# (FLClient pid=2815490)   - Input data edges: 8528 [repeated 4x across cluster]
# (FLClient pid=2815490)   - Feature shape: torch.Size([2121, 1433]) [repeated 4x across cluster]
# (FLClient pid=2815490)   - Data device (before moving): cuda:0 [repeated 4x across cluster]
# (FLClient pid=2815490)   - Input dim: 1433 [repeated 4x across cluster]
# (FLClient pid=2815490)   - Data device (after moving): cuda:0 [repeated 4x across cluster]
# (FLClient pid=2815490) Client 3: Using full-batch training for Cora dataset [repeated 4x across cluster]
# [WANDB DEBUG] Logging test metrics - Global: 0.766, Clients: [0.7730496453900709, 0.8367346938775511, 0.8278145695364238, 0.7180232558139535, 0.728110599078341], Epoch: 20
# [WANDB DEBUG] Logging metrics: {'round': 20, 'test/global_test_acc': 0.766, 'test/avg_client_test_acc': np.float64(0.7767465527392681), 'test/client_test_acc_std': np.float64(0.049059286849802854), 'test/num_clients': 5, 'test/global_vs_avg_client_diff': np.float64(-0.010746552739268056)} with step: 20
# [WANDB DEBUG] Successfully logged test metrics
# The average client test results: 0.7767465527392681
# The final global test results: 0.766
# Round 1 is complete
# (raylet) [2025-10-08 10:32:22,115 E 2815395 2815425] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2025-10-08_10-32-01_010107_2815117 is over 95% full, available space: 5063434240; capacity: 1622224654336. Object creation will fail if spilling is required.
# (FLClient pid=2815496) 2025-10-08 10:32:20,299 - INFO - Epoch   2| Train Loss: 0.305| Train Accuracy: 0.919| Val Loss: 0.581| Val Accuracy: 0.844 [repeated 147x across cluster]
# wandb: ⢿ uploading output.log 11.5KB/11.5KB (0.6s)
# wandb: ⢿ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣻ uploading output.log 11.5KB/11.5KB (0.6s)
# wandb: ⣻ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣽ uploading output.log 11.5KB/11.5KB (0.6s)
# wandb: ⣽ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣾ uploading output.log 11.5KB/11.5KB (0.6s)
# wandb: ⣾ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣷ uploading output.log 11.5KB/11.5KB (0.6s)
# wandb: ⣷ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣯ uploading output.log 11.5KB/11.5KB (0.6s)
# wandb: ⣯ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣟ uploading output.log 11.5KB/11.5KB (0.6s)
# wandb: ⣟ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⡿ uploading output.log 11.5KB/11.5KB (0.6s)
# wandb: ⡿ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⢿ uploading output.log 11.5KB/11.5KB (0.6s)
# wandb: ⢿ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣻ uploading history steps 18-20, summary, console lines 60-229 (0.2s)
# wandb: ⣽ uploading history steps 18-20, summary, console lines 60-229 (0.2s)
# wandb:
# wandb: ⣽ uploading history steps 18-20, summary, console lines 60-229 (0.2s)
# wandb:
# wandb: Run history:
# wandb:  federation/avg_client_train_acc ▁▃▃▃▄▄▅▄▆▇▆▇▇█▇█▇▇█▇
# wandb: federation/avg_client_train_loss █▇▆▆▅▅▄▄▃▃▃▂▂▂▂▂▁▁▁▁
# wandb:    federation/avg_client_val_acc ▁▂▃▄▄▄▅▆▆▇▇▇████████
# wandb:   federation/avg_client_val_loss ██▇▇▆▆▅▅▄▄▃▃▃▂▂▂▂▁▁▁
# wandb:                            round ▁▁▂▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇▇██
# wandb:           run_client_test_result ▁
# wandb:           run_global_test_result ▁
# wandb:         test/avg_client_test_acc ▁
# wandb:         test/client_test_acc_std ▁
# wandb:             test/global_test_acc ▁
# wandb:   test/global_vs_avg_client_diff ▁
# wandb:                 test/num_clients ▁
# wandb:
# wandb: Run summary:
# wandb:  federation/avg_client_train_acc 0.96073
# wandb: federation/avg_client_train_loss 0.60907
# wandb:    federation/avg_client_val_acc 0.75446
# wandb:   federation/avg_client_val_loss 0.89149
# wandb:                            round 20
# wandb:           run_client_test_result 0.77675
# wandb:           run_global_test_result 0.766
# wandb:         test/avg_client_test_acc 0.77675
# wandb:         test/client_test_acc_std 0.04906
# wandb:             test/global_test_acc 0.766
# wandb:   test/global_vs_avg_client_diff -0.01075
# wandb:                 test/num_clients 5
# wandb:
# wandb: 🚀 View run GCN_Cora_SGD_lr0.5_decay0.0005_beta1_run1 at: https://wandb.ai/bosho/FGL3/runs/63l7s5bk
# wandb: ⭐️ View project at: https://wandb.ai/bosho/FGL3
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251008_103203-63l7s5bk/logs
# The global test results: [0.766]
# The client test results: [0.7767465527392681]
# The average global test results: 0.766
# The average client test results: 0.7767465527392681
# The standard deviation global is: 0.0
# The standard deviation client is: 0.0
# (FLClient pid=2815496) Input dim of the model: 1433 [repeated 4x across cluster]
# (FLClient pid=2815496) Input dim of the data: 1433 [repeated 4x across cluster]
# Training CSV results saved to /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv/Cora_full_GCN_beta1_clients5/training_Cora_full_GCN_beta1_clients5_20251008_103200.csv
#
# Summary results saved to:
# - Text file: /home/brian_bosho/FP/FP/federated-gnn/results/review/results_summary/ogbn-arxiv/summary_results_20251008_103225.txt
# - JSON file: /home/brian_bosho/FP/FP/federated-gnn/results/review/results_summary/ogbn-arxiv/summary_results_20251008_103225.json
# - Detailed results saved to: /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv
#
#
#
# ================================================================================
# EXPERIMENT RESULTS SUMMARY
# ================================================================================
# +-----------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+
# | Dataset   | Data Loading   | Model   |   Beta |   Clients |   Avg Global Result |   Avg Client Result |   client_std_dev |   global_std_dev | Duration   |   Hop | Use PE   |
# +===========+================+=========+========+===========+=====================+=====================+==================+==================+============+=======+==========+
# | Cora      | full           | GCN     |      1 |         5 |               0.766 |              0.7767 |                0 |                0 | 00:00:24   |     2 | False    |
# +-----------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+
#
#
# KEY RESULTS:
# --------------------------------------------------------------------------------
# Cora with full using GCN (beta=1.00, clients=5, hop=2, use_pe=False):
#   - Average Global Result: 0.7660
#   - Average Client Result: 0.7767
#   - Client StdDev: 0.0000
#   - Global StdDev: 0.0000
#   - Experiment Duration: 00:00:24
# --------------------------------------------------------------------------------

# %%
# !python -m src.experiments.run_experiments --config conf/ablation/ogbn-arxiv_config.yaml
