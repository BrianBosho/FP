# %%
# !python -m src.experiments.run_experiments --config conf/ablation/ogbn-arxiv_config.yaml

# %%
# !python -m src.experiments.run_experiments --config conf/ablation/amazon-computers_config.yaml
# Out:
# Experiment Configuration:
# - Clients: [3]
# - Rounds: 5
# - Epochs: 3
# - Learning Rate: 0.5
# - Beta values: [1.0]
# - Datasets: ['Computers']
# - Data Loading Options: ['adjacency', 'full', 'zero_hop']
# - Model Types: ['GCN']
# - Results Directory: /home/brian_bosho/FP/FP/results/experiments/amazon_computers
# - Save Detailed Results: True
# - Hop: 1
# - Full Training Flag: False
#
# ================================================================================
# Running experiment: Computers_adjacency_GCN_beta1.0_clients3
# ================================================================================
# DEVICE: cuda
# Data loading option is adjacency
# Model type is GCN
# 2025-10-06 09:43:58,665	INFO worker.py:1807 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# wandb: Currently logged in as: bosho to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /home/brian_bosho/FP/FP/federated-gnn/wandb/run-20251006_094400-1rfp5958
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run young-bee-394
# wandb: ⭐️ View project at https://wandb.ai/bosho/FGL3
# wandb: 🚀 View run at https://wandb.ai/bosho/FGL3/runs/1rfp5958
# [WANDB DEBUG] Successfully initialized wandb run: young-bee-394
# Wandb config is set to: {'dataset': 'Computers', 'model': 'GCN', 'data_loading': 'adjacency', 'num_clients': [3], 'num_rounds': 5, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 1, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': None, 'pe_P': None, 'normalize': None, 'run_index': 1, 'num_iterations': None}
# {'dataset': 'Computers', 'model': 'GCN', 'data_loading': 'adjacency', 'num_clients': [3], 'num_rounds': 5, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 1, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': None, 'pe_P': None, 'normalize': None, 'run_index': 1, 'num_iterations': None}
# data_loading_option: adjacency
# Feature propagation logs saved to: ../results/experiments/amazon_computers/propagation_stats/prop_exp_20251006-094403_adjacency_beta_1.0_hop_1.json
# partition_time_s: 4.0
# client[0] device: cuda:0 cuda:0
# client[0] feature_dim: 767
# config.use_pe: False num_iterations: None feature_prop_device: cpu
# data_loading_option: adjacency hop: 1 num_clients: 3
#
# === DATA LOADING SUMMARY ===
# Full graph: 13752 nodes, 505474 edges
# Number of client subgraphs: 3
# First client subgraph shape: torch.Size([11206, 767])
# Dataset: AmazonComputers()
# Device: cuda
#
# Full graph device (before): cuda:0
# Full graph staying on CPU to save GPU memory
# ===========================
#
#
# === CLIENT DATA LOADING ===
# Full graph size: 13752 nodes
# Number of clients: 3
# Client 0 subgraph: 11206 nodes, 767 features
# Client 1 subgraph: 12797 nodes, 767 features
# Client 2 subgraph: 12630 nodes, 767 features
# ===========================
#
# Input dim of the model in server: 767
# (raylet) [2025-10-06 09:44:08,563 E 1272976 1273006] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2025-10-06_09-43-57_475146_1272706 is over 95% full, available space: 30307917824; capacity: 1622224654336. Object creation will fail if spilling is required.
# (FLClient pid=1273065)
# (FLClient pid=1273065) [Client 0] Initializing with:
# (FLClient pid=1273065)   - Input data nodes: 11206
# (FLClient pid=1273065)   - Input data edges: 440156
# (FLClient pid=1273065)   - Feature shape: torch.Size([11206, 767])
# (FLClient pid=1273065)   - Data device (before moving): cuda:0
# (FLClient pid=1273065)   - Input dim: 767
# (FLClient pid=1273065)   - Data device (after moving): cuda:0
# (FLClient pid=1273068)
# (FLClient pid=1273066)
# (FLClient pid=1273065) 2025-10-06 09:44:09,841 - INFO - Epoch   0| Train Loss: 2.451| Train Accuracy: 0.043| Val Loss: 1.841| Val Accuracy: 0.497
# (FLClient pid=1273065) 2025-10-06 09:44:09,847 - INFO - Epoch   1| Train Loss: 1.842| Train Accuracy: 0.520| Val Loss: 1.449| Val Accuracy: 0.608
# (FLClient pid=1273065) 2025-10-06 09:44:09,851 - INFO - Epoch   2| Train Loss: 1.448| Train Accuracy: 0.624| Val Loss: 1.534| Val Accuracy: 0.532
# training_time_s: 5.98
# Training done
# Round 1
# Train Loss: 1.534, Train Accuracy: 0.624
# Train Loss: 2.269, Train Accuracy: 0.233
# Train Loss: 2.074, Train Accuracy: 0.275
# Round 2
# Train Loss: 1.377, Train Accuracy: 0.292
# Train Loss: 2.160, Train Accuracy: 0.364
# Train Loss: 1.940, Train Accuracy: 0.317
# Round 3
# Train Loss: 1.433, Train Accuracy: 0.441
# Train Loss: 1.951, Train Accuracy: 0.288
# Train Loss: 2.001, Train Accuracy: 0.309
# Round 4
# Train Loss: 1.391, Train Accuracy: 0.346
# Train Loss: 1.914, Train Accuracy: 0.355
# Train Loss: 1.962, Train Accuracy: 0.346
# Round 5
# Train Loss: 1.352, Train Accuracy: 0.400
# Train Loss: 2.316, Train Accuracy: 0.353
# Train Loss: 1.768, Train Accuracy: 0.399
# Validation Loss: 1.856, Validation Accuracy: 0.497
# Validation Loss: 2.008, Validation Accuracy: 0.387
# Validation Loss: 1.798, Validation Accuracy: 0.497
# Training CSV results saved to /home/brian_bosho/FP/FP/results/experiments/amazon_computers/Computers_adjacency_GCN_beta1.0_clients3/training_Computers_adjacency_GCN_beta1.0_clients3_20251006_094357.csv
#
# --- Model Parameter Comparison ---
#
# Layer 0:
# Server param shape: (16,)
# Client param shapes: [(16,), (16,), (16,)]
# ✅ Parameters match!
#
# Layer 1:
# Server param shape: (16, 767)
# Client param shapes: [(16, 767), (16, 767), (16, 767)]
# ✅ Parameters match!
#
# Layer 2:
# Server param shape: (10,)
# Client param shapes: [(10,), (10,), (10,)]
# ✅ Parameters match!
#
# Layer 3:
# Server param shape: (10, 16)
# Client param shapes: [(10, 16), (10, 16), (10, 16)]
# ✅ Parameters match!
#
# All model parameters are identical: True
# Input dim of the model in server: 767
# Input dim of the test data in server: 767
# (FLClient pid=1273065) Input dim of the model: 767
# (FLClient pid=1273065) Input dim of the data: 767
# [WANDB DEBUG] Logging test metrics - Global: 0.392, Clients: [0.5061349693251533, 0.3732193732193732, 0.43962848297213625], Epoch: 5
# [WANDB DEBUG] Logging metrics: {'round': 5, 'test/global_test_acc': 0.392, 'test/avg_client_test_acc': np.float64(0.43966094183888754), 'test/client_test_acc_std': np.float64(0.05426256974024385), 'test/num_clients': 3, 'test/global_vs_avg_client_diff': np.float64(-0.04766094183888753)} with step: 5
# [WANDB DEBUG] Successfully logged test metrics
# The average client test results: 0.43966094183888754
# The final global test results: 0.392
# Round 1 is complete
# wandb: ⢿ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣻ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣽ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣾ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb:
# wandb: ⣾ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb:
# wandb: Run history:
# wandb:  federation/avg_client_train_acc ▇▁▄▄█
# wandb: federation/avg_client_train_loss █▃▂▁▃
# wandb:    federation/avg_client_val_acc ▁▇▁▁█
# wandb:   federation/avg_client_val_loss █▅▃▁▁
# wandb:                            round ▁▂▄▅▇█
# wandb:           run_client_test_result ▁
# wandb:           run_global_test_result ▁
# wandb:         test/avg_client_test_acc ▁
# wandb:         test/client_test_acc_std ▁
# wandb:             test/global_test_acc ▁
# wandb:   test/global_vs_avg_client_diff ▁
# wandb:                 test/num_clients ▁
# wandb:
# wandb: Run summary:
# wandb:  federation/avg_client_train_acc 0.38405
# wandb: federation/avg_client_train_loss 1.81204
# wandb:    federation/avg_client_val_acc 0.46023
# wandb:   federation/avg_client_val_loss 1.88743
# wandb:                            round 5
# wandb:           run_client_test_result 0.43966
# wandb:           run_global_test_result 0.392
# wandb:         test/avg_client_test_acc 0.43966
# wandb:         test/client_test_acc_std 0.05426
# wandb:             test/global_test_acc 0.392
# wandb:   test/global_vs_avg_client_diff -0.04766
# wandb:                 test/num_clients 3
# wandb:
# wandb: 🚀 View run GCN_Computers_SGD_lr0.5_decay0.0005_beta1_run1 at: https://wandb.ai/bosho/FGL3/runs/1rfp5958
# wandb: ⭐️ View project at: https://wandb.ai/bosho/FGL3
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251006_094400-1rfp5958/logs
# The global test results: [0.392]
# The client test results: [0.43966094183888754]
# The average global test results: 0.392
# The average client test results: 0.43966094183888754
# The standard deviation global is: 0.0
# The standard deviation client is: 0.0
# (FLClient pid=1273066) [Client 2] Initializing with: [repeated 2x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (FLClient pid=1273066)   - Input data nodes: 12630 [repeated 2x across cluster]
# (FLClient pid=1273066)   - Input data edges: 493252 [repeated 2x across cluster]
# (FLClient pid=1273066)   - Feature shape: torch.Size([12630, 767]) [repeated 2x across cluster]
# (FLClient pid=1273066)   - Data device (before moving): cuda:0 [repeated 2x across cluster]
# (FLClient pid=1273066)   - Input dim: 767 [repeated 2x across cluster]
# (FLClient pid=1273066)   - Data device (after moving): cuda:0 [repeated 2x across cluster]
# (FLClient pid=1273066) Input dim of the model: 767 [repeated 2x across cluster]
# (FLClient pid=1273066) Input dim of the data: 767 [repeated 2x across cluster]
# (FLClient pid=1273065) 2025-10-06 09:44:12,024 - INFO - Epoch   2| Train Loss: 1.481| Train Accuracy: 0.400| Val Loss: 1.352| Val Accuracy: 0.532 [repeated 42x across cluster]
# Results saved to /home/brian_bosho/FP/FP/results/experiments/amazon_computers/Computers_adjacency_GCN_beta1.0_clients3/results_Computers_adjacency_GCN_beta1.0_clients3_20251006_094357.json
# Training CSV results saved to /home/brian_bosho/FP/FP/results/experiments/amazon_computers/Computers_adjacency_GCN_beta1.0_clients3/training_Computers_adjacency_GCN_beta1.0_clients3_20251006_094357.csv
#
# ================================================================================
# Running experiment: Computers_full_GCN_beta1.0_clients3
# ================================================================================
# DEVICE: cuda
# Data loading option is full
# Model type is GCN
# 2025-10-06 09:44:17,641	INFO worker.py:1807 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /home/brian_bosho/FP/FP/federated-gnn/wandb/run-20251006_094418-lugxfowh
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run wild-violet-395
# wandb: ⭐️ View project at https://wandb.ai/bosho/FGL3
# wandb: 🚀 View run at https://wandb.ai/bosho/FGL3/runs/lugxfowh
# [WANDB DEBUG] Successfully initialized wandb run: wild-violet-395
# Wandb config is set to: {'dataset': 'Computers', 'model': 'GCN', 'data_loading': 'full', 'num_clients': [3], 'num_rounds': 5, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 1, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': None, 'pe_P': None, 'normalize': None, 'run_index': 1, 'num_iterations': None}
# {'dataset': 'Computers', 'model': 'GCN', 'data_loading': 'full', 'num_clients': [3], 'num_rounds': 5, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 1, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': None, 'pe_P': None, 'normalize': None, 'run_index': 1, 'num_iterations': None}
# data_loading_option: full
# partition_time_s: 0.9
# client[0] device: cuda:0 cuda:0
# client[0] feature_dim: 767
# config.use_pe: False num_iterations: None feature_prop_device: cpu
# data_loading_option: full hop: 1 num_clients: 3
#
# === DATA LOADING SUMMARY ===
# Full graph: 13752 nodes, 505474 edges
# Number of client subgraphs: 3
# First client subgraph shape: torch.Size([11206, 767])
# Dataset: AmazonComputers()
# Device: cuda
#
# Full graph device (before): cuda:0
# Full graph staying on CPU to save GPU memory
# ===========================
#
#
# === CLIENT DATA LOADING ===
# Full graph size: 13752 nodes
# Number of clients: 3
# Client 0 subgraph: 11206 nodes, 767 features
# Client 1 subgraph: 12797 nodes, 767 features
# Client 2 subgraph: 12630 nodes, 767 features
# ===========================
#
# Input dim of the model in server: 767
# (FLClient pid=1275350)
# (FLClient pid=1275350) [Client 0] Initializing with:
# (FLClient pid=1275350)   - Input data nodes: 11206
# (FLClient pid=1275350)   - Input data edges: 440156
# (FLClient pid=1275350)   - Feature shape: torch.Size([11206, 767])
# (FLClient pid=1275350)   - Data device (before moving): cuda:0
# (FLClient pid=1275350)   - Input dim: 767
# (FLClient pid=1275350)   - Data device (after moving): cuda:0
# (FLClient pid=1275356)
# (FLClient pid=1275353)
# (FLClient pid=1275350) 2025-10-06 09:44:24,226 - INFO - Epoch   0| Train Loss: 2.349| Train Accuracy: 0.057| Val Loss: 1.712| Val Accuracy: 0.416
# (FLClient pid=1275350) 2025-10-06 09:44:24,231 - INFO - Epoch   1| Train Loss: 1.778| Train Accuracy: 0.382| Val Loss: 1.605| Val Accuracy: 0.554
# (FLClient pid=1275350) 2025-10-06 09:44:24,235 - INFO - Epoch   2| Train Loss: 1.656| Train Accuracy: 0.539| Val Loss: 1.933| Val Accuracy: 0.313
# training_time_s: 6.01
# Training done
# Round 1
# Train Loss: 1.933, Train Accuracy: 0.539
# Train Loss: 2.499, Train Accuracy: 0.135
# Train Loss: 2.226, Train Accuracy: 0.258
# Round 2
# Train Loss: 1.679, Train Accuracy: 0.297
# Train Loss: 2.140, Train Accuracy: 0.274
# Train Loss: 2.162, Train Accuracy: 0.311
# Round 3
# Train Loss: 1.461, Train Accuracy: 0.291
# Train Loss: 2.083, Train Accuracy: 0.273
# Train Loss: 1.998, Train Accuracy: 0.312
# Round 4
# Train Loss: 1.365, Train Accuracy: 0.302
# Train Loss: 2.123, Train Accuracy: 0.216
# Train Loss: 2.074, Train Accuracy: 0.272
# Round 5
# Train Loss: 1.725, Train Accuracy: 0.429
# Train Loss: 1.896, Train Accuracy: 0.384
# Train Loss: 1.918, Train Accuracy: 0.476
# Validation Loss: 1.486, Validation Accuracy: 0.554
# Validation Loss: 2.057, Validation Accuracy: 0.271
# Validation Loss: 2.132, Validation Accuracy: 0.280
# Training CSV results saved to /home/brian_bosho/FP/FP/results/experiments/amazon_computers/Computers_full_GCN_beta1.0_clients3/training_Computers_full_GCN_beta1.0_clients3_20251006_094416.csv
#
# --- Model Parameter Comparison ---
#
# Layer 0:
# Server param shape: (16,)
# Client param shapes: [(16,), (16,), (16,)]
# ✅ Parameters match!
#
# Layer 1:
# Server param shape: (16, 767)
# Client param shapes: [(16, 767), (16, 767), (16, 767)]
# ✅ Parameters match!
#
# Layer 2:
# Server param shape: (10,)
# Client param shapes: [(10,), (10,), (10,)]
# ✅ Parameters match!
#
# Layer 3:
# Server param shape: (10, 16)
# Client param shapes: [(10, 16), (10, 16), (10, 16)]
# ✅ Parameters match!
#
# All model parameters are identical: True
# Input dim of the model in server: 767
# Input dim of the test data in server: 767
# (FLClient pid=1275350) Input dim of the model: 767
# (FLClient pid=1275350) Input dim of the data: 767
# (raylet) [2025-10-06 09:44:27,615 E 1275262 1275291] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2025-10-06_09-44-16_530079_1272706 is over 95% full, available space: 30306660352; capacity: 1622224654336. Object creation will fail if spilling is required.
# [WANDB DEBUG] Logging test metrics - Global: 0.35, Clients: [0.5252225519287834, 0.24355300859598855, 0.2802547770700637], Epoch: 5
# [WANDB DEBUG] Logging metrics: {'round': 5, 'test/global_test_acc': 0.35, 'test/avg_client_test_acc': np.float64(0.3496767791982785), 'test/client_test_acc_std': np.float64(0.12503064609645032), 'test/num_clients': 3, 'test/global_vs_avg_client_diff': np.float64(0.00032322080172147993)} with step: 5
# [WANDB DEBUG] Successfully logged test metrics
# The average client test results: 0.3496767791982786
# The final global test results: 0.35
# Round 1 is complete
# wandb: ⢿ uploading history steps 0-5, summary, console lines 1-104 (0.1s)
# wandb: ⣻ uploading history steps 0-5, summary, console lines 1-104 (0.1s)
# wandb: ⣽ uploading history steps 0-5, summary, console lines 1-104 (0.1s)
# wandb: ⣾ uploading history steps 0-5, summary, console lines 1-104 (0.1s)
# wandb:
# wandb: ⣾ uploading history steps 0-5, summary, console lines 1-104 (0.1s)
# wandb:
# wandb: Run history:
# wandb:  federation/avg_client_train_acc ▃▂▂▁█
# wandb: federation/avg_client_train_loss █▄▁▁▁
# wandb:    federation/avg_client_val_acc ▁▇█▇▇
# wandb:   federation/avg_client_val_loss █▃▃▃▁
# wandb:                            round ▁▂▄▅▇█
# wandb:           run_client_test_result ▁
# wandb:           run_global_test_result ▁
# wandb:         test/avg_client_test_acc ▁
# wandb:         test/client_test_acc_std ▁
# wandb:             test/global_test_acc ▁
# wandb:   test/global_vs_avg_client_diff ▁
# wandb:                 test/num_clients ▁
# wandb:
# wandb: Run summary:
# wandb:  federation/avg_client_train_acc 0.42995
# wandb: federation/avg_client_train_loss 1.84624
# wandb:    federation/avg_client_val_acc 0.36843
# wandb:   federation/avg_client_val_loss 1.89195
# wandb:                            round 5
# wandb:           run_client_test_result 0.34968
# wandb:           run_global_test_result 0.35
# wandb:         test/avg_client_test_acc 0.34968
# wandb:         test/client_test_acc_std 0.12503
# wandb:             test/global_test_acc 0.35
# wandb:   test/global_vs_avg_client_diff 0.00032
# wandb:                 test/num_clients 3
# wandb:
# wandb: 🚀 View run GCN_Computers_SGD_lr0.5_decay0.0005_beta1_run1 at: https://wandb.ai/bosho/FGL3/runs/lugxfowh
# wandb: ⭐️ View project at: https://wandb.ai/bosho/FGL3
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251006_094418-lugxfowh/logs
# The global test results: [0.35]
# The client test results: [0.3496767791982786]
# The average global test results: 0.35
# The average client test results: 0.3496767791982786
# The standard deviation global is: 0.0
# The standard deviation client is: 0.0
# (FLClient pid=1275353) [Client 2] Initializing with: [repeated 2x across cluster]
# (FLClient pid=1275353)   - Input data nodes: 12630 [repeated 2x across cluster]
# (FLClient pid=1275353)   - Input data edges: 493252 [repeated 2x across cluster]
# (FLClient pid=1275353)   - Feature shape: torch.Size([12630, 767]) [repeated 2x across cluster]
# (FLClient pid=1275353)   - Data device (before moving): cuda:0 [repeated 2x across cluster]
# (FLClient pid=1275353)   - Input dim: 767 [repeated 2x across cluster]
# (FLClient pid=1275353)   - Data device (after moving): cuda:0 [repeated 2x across cluster]
# (FLClient pid=1275353) Input dim of the model: 767 [repeated 2x across cluster]
# (FLClient pid=1275353) Input dim of the data: 767 [repeated 2x across cluster]
# (FLClient pid=1275353) 2025-10-06 09:44:26,478 - INFO - Epoch   2| Train Loss: 1.910| Train Accuracy: 0.476| Val Loss: 1.918| Val Accuracy: 0.293 [repeated 42x across cluster]
# Results saved to /home/brian_bosho/FP/FP/results/experiments/amazon_computers/Computers_full_GCN_beta1.0_clients3/results_Computers_full_GCN_beta1.0_clients3_20251006_094416.json
# Training CSV results saved to /home/brian_bosho/FP/FP/results/experiments/amazon_computers/Computers_full_GCN_beta1.0_clients3/training_Computers_full_GCN_beta1.0_clients3_20251006_094416.csv
#
# ================================================================================
# Running experiment: Computers_zero_hop_GCN_beta1.0_clients3
# ================================================================================
# DEVICE: cuda
# Data loading option is zero_hop
# Model type is GCN
# 2025-10-06 09:44:31,941	INFO worker.py:1807 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /home/brian_bosho/FP/FP/federated-gnn/wandb/run-20251006_094432-vvd64pf4
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run ancient-snowflake-396
# wandb: ⭐️ View project at https://wandb.ai/bosho/FGL3
# wandb: 🚀 View run at https://wandb.ai/bosho/FGL3/runs/vvd64pf4
# [WANDB DEBUG] Successfully initialized wandb run: ancient-snowflake-396
# Wandb config is set to: {'dataset': 'Computers', 'model': 'GCN', 'data_loading': 'zero_hop', 'num_clients': [3], 'num_rounds': 5, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 1, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': None, 'pe_P': None, 'normalize': None, 'run_index': 1, 'num_iterations': None}
# {'dataset': 'Computers', 'model': 'GCN', 'data_loading': 'zero_hop', 'num_clients': [3], 'num_rounds': 5, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 1, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': None, 'pe_P': None, 'normalize': None, 'run_index': 1, 'num_iterations': None}
# data_loading_option: zero_hop
# partition_time_s: 0.17
# client[0] device: cuda:0 cuda:0
# client[0] feature_dim: 767
# config.use_pe: False num_iterations: None feature_prop_device: cpu
# data_loading_option: zero_hop hop: 1 num_clients: 3
#
# === DATA LOADING SUMMARY ===
# Full graph: 13752 nodes, 505474 edges
# Number of client subgraphs: 3
# First client subgraph shape: torch.Size([4670, 767])
# Dataset: AmazonComputers()
# Device: cuda
#
# Full graph device (before): cuda:0
# Full graph staying on CPU to save GPU memory
# ===========================
#
#
# === CLIENT DATA LOADING ===
# Full graph size: 13752 nodes
# Number of clients: 3
# Client 0 subgraph: 4670 nodes, 767 features
# Client 1 subgraph: 4873 nodes, 767 features
# Client 2 subgraph: 4209 nodes, 767 features
# ===========================
#
# Input dim of the model in server: 767
# (FLClient pid=1277351)
# (FLClient pid=1277351) [Client 0] Initializing with:
# (FLClient pid=1277351)   - Input data nodes: 4670
# (FLClient pid=1277351)   - Input data edges: 92742
# (FLClient pid=1277351)   - Feature shape: torch.Size([4670, 767])
# (FLClient pid=1277351)   - Data device (before moving): cuda:0
# (FLClient pid=1277351)   - Input dim: 767
# (FLClient pid=1277351)   - Data device (after moving): cuda:0
# (FLClient pid=1277342)
# (FLClient pid=1277360)
# (FLClient pid=1277351) 2025-10-06 09:44:38,195 - INFO - Epoch   0| Train Loss: 2.385| Train Accuracy: 0.104| Val Loss: 1.847| Val Accuracy: 0.585
# (FLClient pid=1277351) 2025-10-06 09:44:38,201 - INFO - Epoch   1| Train Loss: 1.965| Train Accuracy: 0.519| Val Loss: 1.452| Val Accuracy: 0.585
# (FLClient pid=1277351) 2025-10-06 09:44:38,205 - INFO - Epoch   2| Train Loss: 1.546| Train Accuracy: 0.520| Val Loss: 1.423| Val Accuracy: 0.591
# training_time_s: 6.01
# Training done
# Round 1
# Train Loss: 1.423, Train Accuracy: 0.520
# Train Loss: 2.142, Train Accuracy: 0.167
# Train Loss: 2.013, Train Accuracy: 0.265
# Round 2
# Train Loss: 1.312, Train Accuracy: 0.293
# Train Loss: 1.975, Train Accuracy: 0.282
# Train Loss: 2.133, Train Accuracy: 0.294
# Round 3
# Train Loss: 1.559, Train Accuracy: 0.328
# Train Loss: 2.240, Train Accuracy: 0.225
# Train Loss: 2.426, Train Accuracy: 0.291
# Round 4
# Train Loss: 1.512, Train Accuracy: 0.539
# Train Loss: 1.952, Train Accuracy: 0.274
# Train Loss: 1.972, Train Accuracy: 0.306
# Round 5
# Train Loss: 1.219, Train Accuracy: 0.538
# Train Loss: 1.937, Train Accuracy: 0.368
# Train Loss: 1.866, Train Accuracy: 0.311
# Validation Loss: 1.429, Validation Accuracy: 0.591
# Validation Loss: 1.965, Validation Accuracy: 0.311
# Validation Loss: 1.828, Validation Accuracy: 0.331
# Training CSV results saved to /home/brian_bosho/FP/FP/results/experiments/amazon_computers/Computers_zero_hop_GCN_beta1.0_clients3/training_Computers_zero_hop_GCN_beta1.0_clients3_20251006_094430.csv
#
# --- Model Parameter Comparison ---
#
# Layer 0:
# Server param shape: (16,)
# Client param shapes: [(16,), (16,), (16,)]
# ✅ Parameters match!
#
# Layer 1:
# Server param shape: (16, 767)
# Client param shapes: [(16, 767), (16, 767), (16, 767)]
# ✅ Parameters match!
#
# Layer 2:
# Server param shape: (10,)
# Client param shapes: [(10,), (10,), (10,)]
# ✅ Parameters match!
#
# Layer 3:
# Server param shape: (10, 16)
# Client param shapes: [(10, 16), (10, 16), (10, 16)]
# ✅ Parameters match!
#
# All model parameters are identical: True
# Input dim of the model in server: 767
# Input dim of the test data in server: 767
# (FLClient pid=1277351) Input dim of the model: 767
# (FLClient pid=1277351) Input dim of the data: 767
# [WANDB DEBUG] Logging test metrics - Global: 0.369, Clients: [0.5318559556786704, 0.25936599423631124, 0.2979452054794521], Epoch: 5
# [WANDB DEBUG] Logging metrics: {'round': 5, 'test/global_test_acc': 0.369, 'test/avg_client_test_acc': np.float64(0.3630557184648113), 'test/client_test_acc_std': np.float64(0.1203944321736601), 'test/num_clients': 3, 'test/global_vs_avg_client_diff': np.float64(0.005944281535188722)} with step: 5
# [WANDB DEBUG] Successfully logged test metrics
# The average client test results: 0.3630557184648113
# The final global test results: 0.369
# Round 1 is complete
# (raylet) [2025-10-06 09:44:41,918 E 1277255 1277284] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2025-10-06_09-44-30_940567_1272706 is over 95% full, available space: 30305464320; capacity: 1622224654336. Object creation will fail if spilling is required.
# wandb: ⢿ uploading output.log 4.8KB/4.8KB (0.6s)
# wandb: ⢿ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣻ uploading output.log 4.8KB/4.8KB (0.6s)
# wandb: ⣻ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣽ uploading output.log 4.8KB/4.8KB (0.6s)
# wandb: ⣽ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣾ uploading output.log 4.8KB/4.8KB (0.6s)
# wandb: ⣾ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣷ uploading output.log 4.8KB/4.8KB (0.6s)
# wandb: ⣷ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣯ uploading output.log 4.8KB/4.8KB (0.6s)
# wandb: ⣯ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣟ uploading output.log 4.8KB/4.8KB (0.6s)
# wandb: ⣟ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⡿ uploading output.log 4.8KB/4.8KB (0.6s)
# wandb: ⡿ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⢿ uploading output.log 4.8KB/4.8KB (0.6s)
# wandb: ⢿ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣻ uploading history steps 0-5, summary, console lines 1-103 (0.3s)
# wandb:
# wandb: ⣻ uploading history steps 0-5, summary, console lines 1-103 (0.3s)
# wandb:
# wandb: Run history:
# wandb:  federation/avg_client_train_acc ▃▁▁▆█
# wandb: federation/avg_client_train_loss ▄▃█▃▁
# wandb:    federation/avg_client_val_acc ▁▁▁█▁
# wandb:   federation/avg_client_val_loss ▄▅█▃▁
# wandb:                            round ▁▂▄▅▇█
# wandb:           run_client_test_result ▁
# wandb:           run_global_test_result ▁
# wandb:         test/avg_client_test_acc ▁
# wandb:         test/client_test_acc_std ▁
# wandb:             test/global_test_acc ▁
# wandb:   test/global_vs_avg_client_diff ▁
# wandb:                 test/num_clients ▁
# wandb:
# wandb: Run summary:
# wandb:  federation/avg_client_train_acc 0.40575
# wandb: federation/avg_client_train_loss 1.67416
# wandb:    federation/avg_client_val_acc 0.4107
# wandb:   federation/avg_client_val_loss 1.74091
# wandb:                            round 5
# wandb:           run_client_test_result 0.36306
# wandb:           run_global_test_result 0.369
# wandb:         test/avg_client_test_acc 0.36306
# wandb:         test/client_test_acc_std 0.12039
# wandb:             test/global_test_acc 0.369
# wandb:   test/global_vs_avg_client_diff 0.00594
# wandb:                 test/num_clients 3
# wandb:
# wandb: 🚀 View run GCN_Computers_SGD_lr0.5_decay0.0005_beta1_run1 at: https://wandb.ai/bosho/FGL3/runs/vvd64pf4
# wandb: ⭐️ View project at: https://wandb.ai/bosho/FGL3
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251006_094432-vvd64pf4/logs
# The global test results: [0.369]
# The client test results: [0.3630557184648113]
# The average global test results: 0.369
# The average client test results: 0.3630557184648113
# The standard deviation global is: 0.0
# The standard deviation client is: 0.0
# (FLClient pid=1277360) [Client 2] Initializing with: [repeated 2x across cluster]
# (FLClient pid=1277360)   - Input data nodes: 4209 [repeated 2x across cluster]
# (FLClient pid=1277360)   - Input data edges: 55947 [repeated 2x across cluster]
# (FLClient pid=1277360)   - Feature shape: torch.Size([4209, 767]) [repeated 2x across cluster]
# (FLClient pid=1277360)   - Data device (before moving): cuda:0 [repeated 2x across cluster]
# (FLClient pid=1277360)   - Input dim: 767 [repeated 2x across cluster]
# (FLClient pid=1277360)   - Data device (after moving): cuda:0 [repeated 2x across cluster]
# (FLClient pid=1277360) Input dim of the model: 767 [repeated 2x across cluster]
# (FLClient pid=1277360) Input dim of the data: 767 [repeated 2x across cluster]
# (FLClient pid=1277360) 2025-10-06 09:44:40,120 - INFO - Epoch   2| Train Loss: 1.978| Train Accuracy: 0.311| Val Loss: 1.866| Val Accuracy: 0.331 [repeated 42x across cluster]
# Results saved to /home/brian_bosho/FP/FP/results/experiments/amazon_computers/Computers_zero_hop_GCN_beta1.0_clients3/results_Computers_zero_hop_GCN_beta1.0_clients3_20251006_094430.json
# Training CSV results saved to /home/brian_bosho/FP/FP/results/experiments/amazon_computers/Computers_zero_hop_GCN_beta1.0_clients3/training_Computers_zero_hop_GCN_beta1.0_clients3_20251006_094430.csv
#
# Summary results saved to:
# - Text file: /home/brian_bosho/FP/FP/results/results_summary/amazon_computers/summary_results_20251006_094444.txt
# - JSON file: /home/brian_bosho/FP/FP/results/results_summary/amazon_computers/summary_results_20251006_094444.json
# - Detailed results saved to: /home/brian_bosho/FP/FP/results/experiments/amazon_computers
#
#
#
# ================================================================================
# EXPERIMENT RESULTS SUMMARY
# ================================================================================
# +-----------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+
# | Dataset   | Data Loading   | Model   |   Beta |   Clients |   Avg Global Result |   Avg Client Result |   client_std_dev |   global_std_dev | Duration   |   Hop | Use PE   |
# +===========+================+=========+========+===========+=====================+=====================+==================+==================+============+=======+==========+
# | Computers | adjacency      | GCN     |      1 |         3 |               0.392 |              0.4397 |                0 |                0 | 00:00:19   |     1 | False    |
# +-----------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+
# | Computers | full           | GCN     |      1 |         3 |               0.35  |              0.3497 |                0 |                0 | 00:00:14   |     1 | False    |
# +-----------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+
# | Computers | zero_hop       | GCN     |      1 |         3 |               0.369 |              0.3631 |                0 |                0 | 00:00:13   |     1 | False    |
# +-----------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+
#
#
# KEY RESULTS:
# --------------------------------------------------------------------------------
# Computers with adjacency using GCN (beta=1.00, clients=3, hop=1, use_pe=False):
#   - Average Global Result: 0.3920
#   - Average Client Result: 0.4397
#   - Client StdDev: 0.0000
#   - Global StdDev: 0.0000
#   - Experiment Duration: 00:00:19
# --------------------------------------------------------------------------------
# Computers with full using GCN (beta=1.00, clients=3, hop=1, use_pe=False):
#   - Average Global Result: 0.3500
#   - Average Client Result: 0.3497
#   - Client StdDev: 0.0000
#   - Global StdDev: 0.0000
#   - Experiment Duration: 00:00:14
# --------------------------------------------------------------------------------
# Computers with zero_hop using GCN (beta=1.00, clients=3, hop=1, use_pe=False):
#   - Average Global Result: 0.3690
#   - Average Client Result: 0.3631
#   - Client StdDev: 0.0000
#   - Global StdDev: 0.0000
#   - Experiment Duration: 00:00:13
# --------------------------------------------------------------------------------

# %%
# !python -m src.experiments.run_experiments --config conf/ablation/ogbn-arxiv_config.yaml
# Out:
# Experiment Configuration:
# - Clients: [10]
# - Rounds: 10
# - Epochs: 3
# - Learning Rate: 0.5
# - Beta values: [1]
# - Datasets: ['Cora']
# - Data Loading Options: ['full']
# - Model Types: ['GCN']
# - Results Directory: /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv
# - Save Detailed Results: False
# - Hop: 1
# - Full Training Flag: False
#
# ================================================================================
# Running experiment: Cora_full_GCN_beta1_clients10
# ================================================================================
# DEVICE: cuda
# Data loading option is full
# Model type is GCN
# 2025-10-02 14:15:14,286	INFO worker.py:1807 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# wandb: Currently logged in as: bosho to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /home/brian_bosho/FP/FP/federated-gnn/wandb/run-20251002_141516-cej3tzfq
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run comic-rain-393
# wandb: ⭐️ View project at https://wandb.ai/bosho/FGL3
# wandb: 🚀 View run at https://wandb.ai/bosho/FGL3/runs/cej3tzfq
# [WANDB DEBUG] Successfully initialized wandb run: comic-rain-393
# Wandb config is set to: {'dataset': 'Cora', 'model': 'GCN', 'data_loading': 'full', 'num_clients': [10], 'num_rounds': 10, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 1, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': 64, 'pe_P': 16, 'normalize': 'qr', 'run_index': 1, 'num_iterations': 10}
# {'dataset': 'Cora', 'model': 'GCN', 'data_loading': 'full', 'num_clients': [10], 'num_rounds': 10, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 1, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': 64, 'pe_P': 16, 'normalize': 'qr', 'run_index': 1, 'num_iterations': 10}
# data_loading_option: full
# partition_time_s: 0.67
# client[0] device: cuda:0 cuda:0
# client[0] feature_dim: 1433
# config.use_pe: False num_iterations: 10 feature_prop_device: None
# data_loading_option: full hop: 1 num_clients: 10
#
# === DATA LOADING SUMMARY ===
# Full graph: 2708 nodes, 10556 edges
# Number of client subgraphs: 10
# First client subgraph shape: torch.Size([1317, 1433])
# Dataset: Cora()
# Device: cuda
#
# Full graph device (before): cuda:0
# Full graph staying on CPU to save GPU memory
# ===========================
#
#
# === CLIENT DATA LOADING ===
# Full graph size: 2708 nodes
# Number of clients: 10
# Client 0 subgraph: 1317 nodes, 1433 features
# Client 1 subgraph: 946 nodes, 1433 features
# Client 2 subgraph: 904 nodes, 1433 features
# Client 3 subgraph: 597 nodes, 1433 features
# Client 4 subgraph: 972 nodes, 1433 features
# Client 5 subgraph: 535 nodes, 1433 features
# Client 6 subgraph: 849 nodes, 1433 features
# Client 7 subgraph: 510 nodes, 1433 features
# Client 8 subgraph: 1046 nodes, 1433 features
# Client 9 subgraph: 912 nodes, 1433 features
# ===========================
#
# Input dim of the model in server: 1433
# (FLClient pid=1923145)
# (FLClient pid=1923145) [Client 1] Initializing with:
# (FLClient pid=1923145)   - Input data nodes: 946
# (FLClient pid=1923145)   - Input data edges: 3492
# (FLClient pid=1923145)   - Feature shape: torch.Size([946, 1433])
# (FLClient pid=1923145)   - Data device (before moving): cuda:0
# (FLClient pid=1923145)   - Input dim: 1433
# (FLClient pid=1923145)   - Data device (after moving): cuda:0
# (FLClient pid=1923145) 2025-10-02 14:15:22,978 - INFO - Epoch   0| Train Loss: 1.921| Train Accuracy: 0.231| Val Loss: 2.007| Val Accuracy: 0.000
# (FLClient pid=1923145) 2025-10-02 14:15:22,984 - INFO - Epoch   1| Train Loss: 1.772| Train Accuracy: 0.308| Val Loss: 2.041| Val Accuracy: 0.000
# (FLClient pid=1923145) 2025-10-02 14:15:22,988 - INFO - Epoch   2| Train Loss: 1.645| Train Accuracy: 0.308| Val Loss: 2.080| Val Accuracy: 0.000
# (FLClient pid=1923139)
# (FLClient pid=1923137)
# (FLClient pid=1923142)
# (FLClient pid=1923140)
# (FLClient pid=1923146)
# (FLClient pid=1923147)
# (FLClient pid=1923150)
# (FLClient pid=1923149)
# (FLClient pid=1923148)
# (raylet) [2025-10-02 14:15:24,278 E 1923048 1923079] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2025-10-02_14-15-12_968568_1922776 is over 95% full, available space: 32541319168; capacity: 1622224654336. Object creation will fail if spilling is required.
# (FLClient pid=1923140) 2025-10-02 14:15:28,302 - INFO - Epoch   1| Train Loss: 1.084| Train Accuracy: 0.750| Val Loss: 0.964| Val Accuracy: 0.843 [repeated 209x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
, 16), (7, 16), (7, 16), (7, 16), (7, 16), (7, 16), (7, 16), (7, 16), (7, 16), (7, 16)]
# ✅ Parameters match!
#
# All model parameters are identical: True
# Input dim of the model in server: 1433
# Input dim of the test data in server: 1433
# (FLClient pid=1923140) Input dim of the model: 1433
# (FLClient pid=1923140) Input dim of the data: 1433
# (FLClient pid=1923148) [Client 8] Initializing with: [repeated 9x across cluster]
# (FLClient pid=1923148)   - Input data nodes: 1046 [repeated 9x across cluster]
# (FLClient pid=1923148)   - Input data edges: 4028 [repeated 9x across cluster]
# (FLClient pid=1923148)   - Feature shape: torch.Size([1046, 1433]) [repeated 9x across cluster]
# (FLClient pid=1923148)   - Data device (before moving): cuda:0 [repeated 9x across cluster]
# (FLClient pid=1923148)   - Input dim: 1433 [repeated 9x across cluster]
# (FLClient pid=1923148)   - Data device (after moving): cuda:0 [repeated 9x across cluster]
# [WANDB DEBUG] Logging test metrics - Global: 0.644, Clients: [0.4368932038834951, 0.7087378640776699, 0.5462962962962963, 0.6944444444444444, 0.7105263157894737, 0.8367346938775511, 0.6421052631578947, 0.7027027027027027, 0.8686868686868687, 0.6239316239316239], Epoch: 10
# [WANDB DEBUG] Logging metrics: {'round': 10, 'test/global_test_acc': 0.644, 'test/avg_client_test_acc': np.float64(0.6771059276848022), 'test/client_test_acc_std': np.float64(0.12005156649716302), 'test/num_clients': 10, 'test/global_vs_avg_client_diff': np.float64(-0.03310592768480214)} with step: 10
# [WANDB DEBUG] Successfully logged test metrics
# The average client test results: 0.677105927684802
# The final global test results: 0.644
# Round 1 is complete
# wandb: ⢿ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣻ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣽ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣾ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣷ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣯ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣟ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb:
# wandb: ⣟ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb:
# wandb: Run history:
# wandb:  federation/avg_client_train_acc ▁▁▃▄▆▇▇▇██
# wandb: federation/avg_client_train_loss █▇▇▆▅▄▃▂▂▁
# wandb:    federation/avg_client_val_acc ▁▂▄▅▆▆▇▇██
# wandb:   federation/avg_client_val_loss █▇▇▆▅▄▃▂▂▁
# wandb:                            round ▁▂▂▃▄▅▅▆▇▇█
# wandb:           run_client_test_result ▁
# wandb:           run_global_test_result ▁
# wandb:         test/avg_client_test_acc ▁
# wandb:         test/client_test_acc_std ▁
# wandb:             test/global_test_acc ▁
# wandb:   test/global_vs_avg_client_diff ▁
# wandb:                 test/num_clients ▁
# wandb:
# wandb: Run summary:
# wandb:  federation/avg_client_train_acc 0.95828
# wandb: federation/avg_client_train_loss 1.05107
# wandb:    federation/avg_client_val_acc 0.66742
# wandb:   federation/avg_client_val_loss 1.23053
# wandb:                            round 10
# wandb:           run_client_test_result 0.67711
# wandb:           run_global_test_result 0.644
# wandb:         test/avg_client_test_acc 0.67711
# wandb:         test/client_test_acc_std 0.12005
# wandb:             test/global_test_acc 0.644
# wandb:   test/global_vs_avg_client_diff -0.03311
# wandb:                 test/num_clients 10
# wandb:
# wandb: 🚀 View run GCN_Cora_SGD_lr0.5_decay0.0005_beta1_run1 at: https://wandb.ai/bosho/FGL3/runs/cej3tzfq
# wandb: ⭐️ View project at: https://wandb.ai/bosho/FGL3
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251002_141516-cej3tzfq/logs
# The global test results: [0.644]
# The client test results: [0.677105927684802]
# The average global test results: 0.644
# The average client test results: 0.677105927684802
# The standard deviation global is: 0.0
# The standard deviation client is: 0.0
# (FLClient pid=1923142) Input dim of the model: 1433 [repeated 9x across cluster]
# (FLClient pid=1923142) Input dim of the data: 1433 [repeated 9x across cluster]
# (FLClient pid=1923142) 2025-10-02 14:15:29,613 - INFO - Epoch   2| Train Loss: 0.659| Train Accuracy: 1.000| Val Loss: 1.107| Val Accuracy: 0.578 [repeated 88x across cluster]
# Training CSV results saved to /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv/Cora_full_GCN_beta1_clients10/training_Cora_full_GCN_beta1_clients10_20251002_141512.csv
#
# Summary results saved to:
# - Text file: /home/brian_bosho/FP/FP/federated-gnn/results/review/results_summary/ogbn-arxiv/summary_results_20251002_141534.txt
# - JSON file: /home/brian_bosho/FP/FP/federated-gnn/results/review/results_summary/ogbn-arxiv/summary_results_20251002_141534.json
# - Detailed results saved to: /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv
#
#
#
# ================================================================================
# EXPERIMENT RESULTS SUMMARY
# ================================================================================
# +-----------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+
# | Dataset   | Data Loading   | Model   |   Beta |   Clients |   Avg Global Result |   Avg Client Result |   client_std_dev |   global_std_dev | Duration   |   Hop | Use PE   |
# +===========+================+=========+========+===========+=====================+=====================+==================+==================+============+=======+==========+
# | Cora      | full           | GCN     |      1 |        10 |               0.644 |              0.6771 |                0 |                0 | 00:00:21   |     1 | False    |
# +-----------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+
#
#
# KEY RESULTS:
# --------------------------------------------------------------------------------
# Cora with full using GCN (beta=1.00, clients=10, hop=1, use_pe=False):
#   - Average Global Result: 0.6440
#   - Average Client Result: 0.6771
#   - Client StdDev: 0.0000
#   - Global StdDev: 0.0000
#   - Experiment Duration: 00:00:21
# --------------------------------------------------------------------------------

# %%
# !python -m src.experiments.run_experiments --config conf/ablation/amazon-photo_config.yaml
# Out:
# Experiment Configuration:
# - Clients: [10]
# - Rounds: 10
# - Epochs: 3
# - Learning Rate: 0.5
# - Beta values: [1.0]
# - Datasets: ['Photo']
# - Data Loading Options: ['full', 'zero_hop', 'adjacency', 'diffusion']
# - Model Types: ['GCN']
# - Results Directory: /home/brian_bosho/FP/FP/results/experiments/amazon_photo
# - Save Detailed Results: True
# - Hop: 1
# - Full Training Flag: False
#
# ================================================================================
# Running experiment: Photo_full_GCN_beta1.0_clients10
# ================================================================================
# DEVICE: cuda
# Data loading option is full
# Model type is GCN
# 2025-10-06 09:45:53,458	INFO worker.py:1807 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# wandb: Currently logged in as: bosho to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /home/brian_bosho/FP/FP/federated-gnn/wandb/run-20251006_094554-hdwmblfg
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run zesty-dust-397
# wandb: ⭐️ View project at https://wandb.ai/bosho/FGL3
# wandb: 🚀 View run at https://wandb.ai/bosho/FGL3/runs/hdwmblfg
# [WANDB DEBUG] Successfully initialized wandb run: zesty-dust-397
# Wandb config is set to: {'dataset': 'Photo', 'model': 'GCN', 'data_loading': 'full', 'num_clients': [10], 'num_rounds': 10, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 1, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': None, 'pe_P': None, 'normalize': None, 'run_index': 1, 'num_iterations': None}
# {'dataset': 'Photo', 'model': 'GCN', 'data_loading': 'full', 'num_clients': [10], 'num_rounds': 10, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 1, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': None, 'pe_P': None, 'normalize': None, 'run_index': 1, 'num_iterations': None}
# data_loading_option: full
# partition_time_s: 0.94
# client[0] device: cuda:0 cuda:0
# client[0] feature_dim: 745
# config.use_pe: False num_iterations: None feature_prop_device: cuda
# data_loading_option: full hop: 1 num_clients: 10
#
# === DATA LOADING SUMMARY ===
# Full graph: 7650 nodes, 245812 edges
# Number of client subgraphs: 10
# First client subgraph shape: torch.Size([3305, 745])
# Dataset: AmazonPhoto()
# Device: cuda
#
# Full graph device (before): cuda:0
# Full graph staying on CPU to save GPU memory
# ===========================
#
#
# === CLIENT DATA LOADING ===
# Full graph size: 7650 nodes
# Number of clients: 10
# Client 0 subgraph: 3305 nodes, 745 features
# Client 1 subgraph: 4042 nodes, 745 features
# Client 2 subgraph: 5002 nodes, 745 features
# Client 3 subgraph: 4723 nodes, 745 features
# Client 4 subgraph: 5732 nodes, 745 features
# Client 5 subgraph: 5555 nodes, 745 features
# Client 6 subgraph: 5709 nodes, 745 features
# Client 7 subgraph: 5752 nodes, 745 features
# Client 8 subgraph: 5929 nodes, 745 features
# Client 9 subgraph: 5985 nodes, 745 features
# ===========================
#
# Input dim of the model in server: 745
# (FLClient pid=1279878)
# (FLClient pid=1279878) [Client 0] Initializing with:
# (FLClient pid=1279878)   - Input data nodes: 3305
# (FLClient pid=1279878)   - Input data edges: 98511
# (FLClient pid=1279878)   - Feature shape: torch.Size([3305, 745])
# (FLClient pid=1279878)   - Data device (before moving): cuda:0
# (FLClient pid=1279878)   - Input dim: 745
# (FLClient pid=1279878)   - Data device (after moving): cuda:0
# (FLClient pid=1279893)
# (FLClient pid=1279877)
# (FLClient pid=1279878) 2025-10-06 09:46:01,816 - INFO - Epoch   0| Train Loss: 2.134| Train Accuracy: 0.120| Val Loss: 1.988| Val Accuracy: 0.308
# (FLClient pid=1279878) 2025-10-06 09:46:01,822 - INFO - Epoch   1| Train Loss: 2.123| Train Accuracy: 0.380| Val Loss: 1.979| Val Accuracy: 0.308
# (FLClient pid=1279878) 2025-10-06 09:46:01,827 - INFO - Epoch   2| Train Loss: 1.979| Train Accuracy: 0.380| Val Loss: 1.593| Val Accuracy: 0.308
# (FLClient pid=1279883)
# (FLClient pid=1279885)
# (FLClient pid=1279888)
# (FLClient pid=1279882)
# (FLClient pid=1279892)
# (FLClient pid=1279884)
# (FLClient pid=1279879)
# (raylet) [2025-10-06 09:46:03,355 E 1279788 1279818] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2025-10-06_09-45-52_102518_1279507 is over 95% full, available space: 30303830016; capacity: 1622224654336. Object creation will fail if spilling is required.
# (FLClient pid=1279878) 2025-10-06 09:46:07,048 - INFO - Epoch   2| Train Loss: 1.733| Train Accuracy: 0.274| Val Loss: 1.522| Val Accuracy: 0.654 [repeated 210x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
, 16), (8, 16), (8, 16), (8, 16), (8, 16), (8, 16), (8, 16), (8, 16), (8, 16), (8, 16)]
# ✅ Parameters match!
#
# All model parameters are identical: True
# Input dim of the model in server: 745
# Input dim of the test data in server: 745
# (FLClient pid=1279878) Input dim of the model: 745
# (FLClient pid=1279878) Input dim of the data: 745
# (FLClient pid=1279879) [Client 9] Initializing with: [repeated 9x across cluster]
# (FLClient pid=1279879)   - Input data nodes: 5985 [repeated 9x across cluster]
# (FLClient pid=1279879)   - Input data edges: 213593 [repeated 9x across cluster]
# (FLClient pid=1279879)   - Feature shape: torch.Size([5985, 745]) [repeated 9x across cluster]
# (FLClient pid=1279879)   - Data device (before moving): cuda:0 [repeated 9x across cluster]
# (FLClient pid=1279879)   - Input dim: 745 [repeated 9x across cluster]
# (FLClient pid=1279879)   - Data device (after moving): cuda:0 [repeated 9x across cluster]
# [WANDB DEBUG] Logging test metrics - Global: 0.685, Clients: [0.525, 0.8598130841121495, 0.5714285714285714, 0.6486486486486487, 0.5, 0.6880733944954128, 0.6633663366336634, 0.6938775510204082, 0.7244094488188977, 0.7710843373493976], Epoch: 10
# [WANDB DEBUG] Logging metrics: {'round': 10, 'test/global_test_acc': 0.685, 'test/avg_client_test_acc': np.float64(0.664570137250715), 'test/client_test_acc_std': np.float64(0.10485733233287325), 'test/num_clients': 10, 'test/global_vs_avg_client_diff': np.float64(0.020429862749285044)} with step: 10
# [WANDB DEBUG] Successfully logged test metrics
# The average client test results: 0.6645701372507149
# The final global test results: 0.685
# Round 1 is complete
# wandb: ⢿ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣻ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣽ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣾ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣷ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣯ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb:
# wandb: ⣯ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb:
# wandb: Run history:
# wandb:  federation/avg_client_train_acc ▂▂▂▆▂▁▃▄▄█
# wandb: federation/avg_client_train_loss ▇█▆▇▅▅▃▂▁▁
# wandb:    federation/avg_client_val_acc ▁▃▂▄▅▆▇█▇█
# wandb:   federation/avg_client_val_loss █▇▇▆▅▄▃▂▂▁
# wandb:                            round ▁▂▂▃▄▅▅▆▇▇█
# wandb:           run_client_test_result ▁
# wandb:           run_global_test_result ▁
# wandb:         test/avg_client_test_acc ▁
# wandb:         test/client_test_acc_std ▁
# wandb:             test/global_test_acc ▁
# wandb:   test/global_vs_avg_client_diff ▁
# wandb:                 test/num_clients ▁
# wandb:
# wandb: Run summary:
# wandb:  federation/avg_client_train_acc 0.44723
# wandb: federation/avg_client_train_loss 1.43455
# wandb:    federation/avg_client_val_acc 0.67377
# wandb:   federation/avg_client_val_loss 1.21025
# wandb:                            round 10
# wandb:           run_client_test_result 0.66457
# wandb:           run_global_test_result 0.685
# wandb:         test/avg_client_test_acc 0.66457
# wandb:         test/client_test_acc_std 0.10486
# wandb:             test/global_test_acc 0.685
# wandb:   test/global_vs_avg_client_diff 0.02043
# wandb:                 test/num_clients 10
# wandb:
# wandb: 🚀 View run GCN_Photo_SGD_lr0.5_decay0.0005_beta1_run1 at: https://wandb.ai/bosho/FGL3/runs/hdwmblfg
# wandb: ⭐️ View project at: https://wandb.ai/bosho/FGL3
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251006_094554-hdwmblfg/logs
# The global test results: [0.685]
# The client test results: [0.6645701372507149]
# The average global test results: 0.685
# The average client test results: 0.6645701372507149
# The standard deviation global is: 0.0
# The standard deviation client is: 0.0
# (FLClient pid=1279879) Input dim of the model: 745 [repeated 9x across cluster]
# (FLClient pid=1279879) Input dim of the data: 745 [repeated 9x across cluster]
# (FLClient pid=1279884) 2025-10-06 09:46:08,367 - INFO - Epoch   2| Train Loss: 1.210| Train Accuracy: 0.652| Val Loss: 1.692| Val Accuracy: 0.460 [repeated 87x across cluster]
# Results saved to /home/brian_bosho/FP/FP/results/experiments/amazon_photo/Photo_full_GCN_beta1.0_clients10/results_Photo_full_GCN_beta1.0_clients10_20251006_094552.json
# Training CSV results saved to /home/brian_bosho/FP/FP/results/experiments/amazon_photo/Photo_full_GCN_beta1.0_clients10/training_Photo_full_GCN_beta1.0_clients10_20251006_094552.csv
#
# ================================================================================
# Running experiment: Photo_zero_hop_GCN_beta1.0_clients10
# ================================================================================
# DEVICE: cuda
# Data loading option is zero_hop
# Model type is GCN
# 2025-10-06 09:46:14,503	INFO worker.py:1807 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /home/brian_bosho/FP/FP/federated-gnn/wandb/run-20251006_094615-3bt5s1fq
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run legendary-frog-398
# wandb: ⭐️ View project at https://wandb.ai/bosho/FGL3
# wandb: 🚀 View run at https://wandb.ai/bosho/FGL3/runs/3bt5s1fq
# [WANDB DEBUG] Successfully initialized wandb run: legendary-frog-398
# Wandb config is set to: {'dataset': 'Photo', 'model': 'GCN', 'data_loading': 'zero_hop', 'num_clients': [10], 'num_rounds': 10, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 1, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': None, 'pe_P': None, 'normalize': None, 'run_index': 1, 'num_iterations': None}
# {'dataset': 'Photo', 'model': 'GCN', 'data_loading': 'zero_hop', 'num_clients': [10], 'num_rounds': 10, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 1, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': None, 'pe_P': None, 'normalize': None, 'run_index': 1, 'num_iterations': None}
# data_loading_option: zero_hop
# partition_time_s: 0.1
# client[0] device: cuda:0 cuda:0
# client[0] feature_dim: 745
# config.use_pe: False num_iterations: None feature_prop_device: cuda
# data_loading_option: zero_hop hop: 1 num_clients: 10
#
# === DATA LOADING SUMMARY ===
# Full graph: 7650 nodes, 245812 edges
# Number of client subgraphs: 10
# First client subgraph shape: torch.Size([300, 745])
# Dataset: AmazonPhoto()
# Device: cuda
#
# Full graph device (before): cuda:0
# Full graph staying on CPU to save GPU memory
# ===========================
#
#
# === CLIENT DATA LOADING ===
# Full graph size: 7650 nodes
# Number of clients: 10
# Client 0 subgraph: 300 nodes, 745 features
# Client 1 subgraph: 810 nodes, 745 features
# Client 2 subgraph: 565 nodes, 745 features
# Client 3 subgraph: 552 nodes, 745 features
# Client 4 subgraph: 808 nodes, 745 features
# Client 5 subgraph: 808 nodes, 745 features
# Client 6 subgraph: 735 nodes, 745 features
# Client 7 subgraph: 803 nodes, 745 features
# Client 8 subgraph: 978 nodes, 745 features
# Client 9 subgraph: 1291 nodes, 745 features
# ===========================
#
# Input dim of the model in server: 745
# (FLClient pid=1282244)
# (FLClient pid=1282244) [Client 0] Initializing with:
# (FLClient pid=1282244)   - Input data nodes: 300
# (FLClient pid=1282244)   - Input data edges: 852
# (FLClient pid=1282244)   - Feature shape: torch.Size([300, 745])
# (FLClient pid=1282244)   - Data device (before moving): cuda:0
# (FLClient pid=1282244)   - Input dim: 745
# (FLClient pid=1282244)   - Data device (after moving): cuda:0
# (FLClient pid=1282249)
# (FLClient pid=1282252)
# (FLClient pid=1282255)
# (FLClient pid=1282246)
# (FLClient pid=1282244) 2025-10-06 09:46:21,377 - INFO - Epoch   0| Train Loss: 2.150| Train Accuracy: 0.200| Val Loss: 1.786| Val Accuracy: 0.381
# (FLClient pid=1282244) 2025-10-06 09:46:21,382 - INFO - Epoch   1| Train Loss: 2.375| Train Accuracy: 0.243| Val Loss: 2.660| Val Accuracy: 0.048
# (FLClient pid=1282244) 2025-10-06 09:46:21,387 - INFO - Epoch   2| Train Loss: 2.364| Train Accuracy: 0.213| Val Loss: 1.536| Val Accuracy: 0.381
# (FLClient pid=1282257)
# (FLClient pid=1282253)
# (FLClient pid=1282256)
# (FLClient pid=1282247)
# (FLClient pid=1282254)
# (raylet) [2025-10-06 09:46:24,479 E 1282157 1282186] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2025-10-06_09-46-13_504544_1279507 is over 95% full, available space: 30302150656; capacity: 1622224654336. Object creation will fail if spilling is required.
# (FLClient pid=1282244) 2025-10-06 09:46:26,429 - INFO - Epoch   2| Train Loss: 1.330| Train Accuracy: 0.457| Val Loss: 1.643| Val Accuracy: 0.429 [repeated 210x across cluster]
# training_time_s: 11.07
# Training done
# Round 1
# Train Loss: 1.536, Train Accuracy: 0.213
# Train Loss: 0.959, Train Accuracy: 0.630
# Train Loss: 1.941, Train Accuracy: 0.237
# Train Loss: 1.782, Train Accuracy: 0.372
# Train Loss: 1.762, Train Accuracy: 0.205
# Train Loss: 1.750, Train Accuracy: 0.266
# Train Loss: 1.848, Train Accuracy: 0.217
# Train Loss: 1.790, Train Accuracy: 0.171
# (FLClient pid=1282254)   - Data device (after moving): cuda:0 [repeated 9x across cluster]
# [WANDB DEBUG] Logging test metrics - Global: 0.731, Clients: [0.6122448979591837, 0.782608695652174, 0.5833333333333334, 0.6764705882352942, 0.6071428571428571, 0.6979166666666666, 0.7078651685393258, 0.8490566037735849, 0.7364341085271318, 0.8292682926829268], Epoch: 10
# [WANDB DEBUG] Logging metrics: {'round': 10, 'test/global_test_acc': 0.731, 'test/avg_client_test_acc': np.float64(0.7082341212512477), 'test/client_test_acc_std': np.float64(0.08772465352009777), 'test/num_clients': 10, 'test/global_vs_avg_client_diff': np.float64(0.022765878748752244)} with step: 10
# [WANDB DEBUG] Successfully logged test metrics
# The average client test results: 0.7082341212512479
# The final global test results: 0.731
# Round 1 is complete
# wandb: ⢿ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣻ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣽ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣾ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣷ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb: ⣯ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb:
# wandb: ⣯ uploading config.yaml 2.5KB/2.5KB (0.3s)
# wandb:
# wandb: Run history:
# wandb:  federation/avg_client_train_acc ▁▁▁▁▃▃▃▆▅█
# wandb: federation/avg_client_train_loss █▇▅▇▄▅▂▃▁▁
# wandb:    federation/avg_client_val_acc ▁▄▄▄▆▆▇▇██
# wandb:   federation/avg_client_val_loss █▇▆▆▄▄▂▂▂▁
# wandb:                            round ▁▂▂▃▄▅▅▆▇▇█
# wandb:           run_client_test_result ▁
# wandb:           run_global_test_result ▁
# wandb:         test/avg_client_test_acc ▁
# wandb:         test/client_test_acc_std ▁
# wandb:             test/global_test_acc ▁
# wandb:   test/global_vs_avg_client_diff ▁
# wandb:                 test/num_clients ▁
# wandb:
# wandb: Run summary:
# wandb:  federation/avg_client_train_acc 0.54118
# wandb: federation/avg_client_train_loss 1.18223
# wandb:    federation/avg_client_val_acc 0.72454
# wandb:   federation/avg_client_val_loss 1.10311
# wandb:                            round 10
# wandb:           run_client_test_result 0.70823
# wandb:           run_global_test_result 0.731
# wandb:         test/avg_client_test_acc 0.70823
# wandb:         test/client_test_acc_std 0.08772
# wandb:             test/global_test_acc 0.731
# wandb:   test/global_vs_avg_client_diff 0.02277
# wandb:                 test/num_clients 10
# wandb:
# wandb: 🚀 View run GCN_Photo_SGD_lr0.5_decay0.0005_beta1_run1 at: https://wandb.ai/bosho/FGL3/runs/3bt5s1fq
# wandb: ⭐️ View project at: https://wandb.ai/bosho/FGL3
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251006_094615-3bt5s1fq/logs
# The global test results: [0.731]
# The client test results: [0.7082341212512479]
# The average global test results: 0.731
# The average client test results: 0.7082341212512479
# The standard deviation global is: 0.0
# The standard deviation client is: 0.0
# (FLClient pid=1282254) Input dim of the model: 745 [repeated 9x across cluster]
# (FLClient pid=1282254) Input dim of the data: 745 [repeated 9x across cluster]
# (FLClient pid=1282254) 2025-10-06 09:46:27,713 - INFO - Epoch   2| Train Loss: 1.105| Train Accuracy: 0.750| Val Loss: 1.022| Val Accuracy: 0.652 [repeated 87x across cluster]
# Results saved to /home/brian_bosho/FP/FP/results/experiments/amazon_photo/Photo_zero_hop_GCN_beta1.0_clients10/results_Photo_zero_hop_GCN_beta1.0_clients10_20251006_094613.json
# Training CSV results saved to /home/brian_bosho/FP/FP/results/experiments/amazon_photo/Photo_zero_hop_GCN_beta1.0_clients10/training_Photo_zero_hop_GCN_beta1.0_clients10_20251006_094613.csv
#
# ================================================================================
# Running experiment: Photo_adjacency_GCN_beta1.0_clients10
# ================================================================================
# DEVICE: cuda
# Data loading option is adjacency
# Model type is GCN
# 2025-10-06 09:46:33,354	INFO worker.py:1807 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /home/brian_bosho/FP/FP/federated-gnn/wandb/run-20251006_094634-xn2jvjmk
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run noble-water-399
# wandb: ⭐️ View project at https://wandb.ai/bosho/FGL3
# wandb: 🚀 View run at https://wandb.ai/bosho/FGL3/runs/xn2jvjmk
# [WANDB DEBUG] Successfully initialized wandb run: noble-water-399
# Wandb config is set to: {'dataset': 'Photo', 'model': 'GCN', 'data_loading': 'adjacency', 'num_clients': [10], 'num_rounds': 10, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 1, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': None, 'pe_P': None, 'normalize': None, 'run_index': 1, 'num_iterations': None}
# {'dataset': 'Photo', 'model': 'GCN', 'data_loading': 'adjacency', 'num_clients': [10], 'num_rounds': 10, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 1, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': None, 'pe_P': None, 'normalize': None, 'run_index': 1, 'num_iterations': None}
# data_loading_option: adjacency
# Feature propagation logs saved to: ../results/experiments/amazon_photo/propagation_stats/prop_exp_20251006-094635_adjacency_beta_1.0_hop_1.json
# partition_time_s: 0.68
# client[0] device: cuda:0 cuda:0
# client[0] feature_dim: 745
# config.use_pe: False num_iterations: None feature_prop_device: cuda
# data_loading_option: adjacency hop: 1 num_clients: 10
#
# === DATA LOADING SUMMARY ===
# Full graph: 7650 nodes, 245812 edges
# Number of client subgraphs: 10
# First client subgraph shape: torch.Size([3305, 745])
# Dataset: AmazonPhoto()
# Device: cuda
#
# Full graph device (before): cuda:0
# Full graph staying on CPU to save GPU memory
# ===========================
#
#
# === CLIENT DATA LOADING ===
# Full graph size: 7650 nodes
# Number of clients: 10
# Client 0 subgraph: 3305 nodes, 745 features
# Client 1 subgraph: 4042 nodes, 745 features
# Client 2 subgraph: 5002 nodes, 745 features
# Client 3 subgraph: 4723 nodes, 745 features
# Client 4 subgraph: 5732 nodes, 745 features
# Client 5 subgraph: 5555 nodes, 745 features
# Client 6 subgraph: 5709 nodes, 745 features
# Client 7 subgraph: 5752 nodes, 745 features
# Client 8 subgraph: 5929 nodes, 745 features
# Client 9 subgraph: 5985 nodes, 745 features
# ===========================
#
# Input dim of the model in server: 745
# (FLClient pid=1284470)
# (FLClient pid=1284470) [Client 0] Initializing with:
# (FLClient pid=1284470)   - Input data nodes: 3305
# (FLClient pid=1284470)   - Input data edges: 98511
# (FLClient pid=1284470)   - Feature shape: torch.Size([3305, 745])
# (FLClient pid=1284470)   - Data device (before moving): cuda:0
# (FLClient pid=1284470)   - Input dim: 745
# (FLClient pid=1284470)   - Data device (after moving): cuda:0
# (FLClient pid=1284471)
# (FLClient pid=1284468)
# (FLClient pid=1284474)
# (FLClient pid=1284470) 2025-10-06 09:46:40,302 - INFO - Epoch   0| Train Loss: 2.085| Train Accuracy: 0.064| Val Loss: 1.954| Val Accuracy: 0.360
# (FLClient pid=1284470) 2025-10-06 09:46:40,313 - INFO - Epoch   1| Train Loss: 1.960| Train Accuracy: 0.359| Val Loss: 1.859| Val Accuracy: 0.360
# (FLClient pid=1284470) 2025-10-06 09:46:40,318 - INFO - Epoch   2| Train Loss: 1.863| Train Accuracy: 0.368| Val Loss: 1.748| Val Accuracy: 0.360
# (FLClient pid=1284476)
# (FLClient pid=1284482)
# (FLClient pid=1284478)
# (FLClient pid=1284472)
# (FLClient pid=1284467)
# (FLClient pid=1284477)
# (raylet) [2025-10-06 09:46:43,332 E 1284380 1284409] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2025-10-06_09-46-32_362256_1279507 is over 95% full, available space: 30300508160; capacity: 1622224654336. Object creation will fail if spilling is required.
# (FLClient pid=1284470) 2025-10-06 09:46:45,677 - INFO - Epoch   2| Train Loss: 1.374| Train Accuracy: 0.483| Val Loss: 1.380| Val Accuracy: 0.520 [repeated 210x across cluster]
# training_time_s: 10.68
# Training done
# Round 1
# Train Loss: 1.748, Train Accuracy: 0.368
# Train Loss: 0.883, Train Accuracy: 0.690
# Train Loss: 1.917, Train Accuracy: 0.328
# Train Loss: 1.654, Train Accuracy: 0.319
# Train Loss: 1.728, Train Accuracy: 0.315
# Train Loss: 1.880, Train Accuracy: 0.391
# Train Loss: 1.821, Train Accuracy: 0.265
# Train Loss: 1.853, Train Accuracy: 0.242
# Train Loss: 1.734, Train Accuracy: 0.341
# Train Loss: 1.339, Train Accuracy: 0.512
# Round 2
# Train Loss: 1.591, Train Accuracy: 0.359
# Train Loss: 0.793, Train Accuracy: 0.688
# Train Loss: 1.869, Train Accuracy: 0.337
# Train Loss: 1.380, Train Accuracy: 0.488
# Train Loss: 1.625, Train Accuracy: 0.312
# Train Loss: 1.740, Train Accuracy: 0.575
# Train Loss: 1.440, Train Accuracy: 0.512
# Train Loss: 1.348, Train Accuracy: 0.673
# Train Loss: 1.446, Train Accuracy: 0.600
# Train Loss: 1.494, Train Accuracy: 0.516
# Round 9
# Train Loss: 1.429, Train Accuracy: 0.470
# Train Loss: 0.912, Train Accuracy: 0.701
# Train Loss: 1.699, Train Accuracy: 0.503
# Train Loss: 1.335, Train Accuracy: 0.519
# Train Loss: 1.654, Train Accuracy: 0.361
# Train Loss: 1.738, Train Accuracy: 0.581
# Train Loss: 1.456, Train Accuracy: 0.401
# Train Loss: 1.328, Train Accuracy: 0.569
# Train Loss: 1.377, Train Accuracy: 0.555
# Train Loss: 1.340, Train Accuracy: 0.515
# Round 10
# Train Loss: 1.375, Train Accuracy: 0.487
# Train Loss: 0.809, Train Accuracy: 0.704
# Train Loss: 1.662, Train Accuracy: 0.492
# Train Loss: 1.280, Train Accuracy: 0.544
# Train Loss: 1.573, Train Accuracy: 0.351
# Train Loss: 1.657, Train Accuracy: 0.572
# Train Loss: 1.352, Train Accuracy: 0.622
# Train Loss: 1.341, Train Accuracy: 0.692
# Train Loss: 1.347, Train Accuracy: 0.671
# Train Loss: 1.168, Train Accuracy: 0.655
# Validation Loss: 1.576, Validation Accuracy: 0.440
# Validation Loss: 0.913, Validation Accuracy: 0.706
# Validation Loss: 1.695, Validation Accuracy: 0.512
# Validation Loss: 1.815, Validation Accuracy: 0.308
# Validation Loss: 1.633, Validation Accuracy: 0.500
# Validation Loss: 1.951, Validation Accuracy: 0.350
# Validation Loss: 1.480, Validation Accuracy: 0.540
# Validation Loss: 1.445, Validation Accuracy: 0.490
# Validation Loss: 1.529, Validation Accuracy: 0.582
# Validation Loss: 1.394, Validation Accuracy: 0.500
# Training CSV results saved to /home/brian_bosho/FP/FP/results/experiments/amazon_photo/Photo_adjacency_GCN_beta1.0_clients10/training_Photo_adjacency_GCN_beta1.0_clients10_20251006_094632.csv
#
# --- Model Parameter Comparison ---
#
# Layer 0:
# Server param shape: (16,)
# Client param shapes: [(16,), (16,), (16,), (16,), (16,), (16,), (16,), (16,), (16,), (16,)]
# ✅ Parameters match!
#
# Layer 1:
# Server param shape: (16, 745)
# Client param shapes: [(16, 745), (16, 745), (16, 745), (16, 745), (16, 745), (16, 745), (16, 745), (16, 745), (16, 745), (16, 745)]
# ✅ Parameters match!
#
# Layer 2:
# Server param shape: (8,)
# Client param shapes: [(8,), (8,), (8,), (8,), (8,), (8,), (8,), (8,), (8,), (8,)]
# ✅ Parameters match!
#
# Layer 3:
# Server param shape: (8, 16)
# Client param shapes: [(8, 16), (8, 16), (8, 16), (8, 16), (8, 16), (8, 16), (8, 16), (8, 16), (8, 16), (8, 16)]
# ✅ Parameters match!
#
# All model parameters are identical: True
# Input dim of the model in server: 745
# Input dim of the test data in server: 745
# (FLClient pid=1284470) Input dim of the model: 745
# (FLClient pid=1284470) Input dim of the data: 745
# (FLClient pid=1284477) [Client 9] Initializing with: [repeated 9x across cluster]
# (FLClient pid=1284477)   - Input data nodes: 5985 [repeated 9x across cluster]
# (FLClient pid=1284477)   - Input data edges: 213593 [repeated 9x across cluster]
# (FLClient pid=1284477)   - Feature shape: torch.Size([5985, 745]) [repeated 9x across cluster]
# (FLClient pid=1284477)   - Data device (before moving): cuda:0 [repeated 9x across cluster]
# (FLClient pid=1284477)   - Input dim: 745 [repeated 9x across cluster]
# (FLClient pid=1284477)   - Data device (after moving): cuda:0 [repeated 9x across cluster]
# [WANDB DEBUG] Logging test metrics - Global: 0.326, Clients: [0.5365853658536586, 0.6396396396396397, 0.4155844155844156, 0.4117647058823529, 0.46534653465346537, 0.31, 0.5051546391752577, 0.5686274509803921, 0.5, 0.5089820359281437], Epoch: 10
# [WANDB DEBUG] Logging metrics: {'round': 10, 'test/global_test_acc': 0.326, 'test/avg_client_test_acc': np.float64(0.48616847876973257), 'test/client_test_acc_std': np.float64(0.08715153649889633), 'test/num_clients': 10, 'test/global_vs_avg_client_diff': np.float64(-0.16016847876973256)} with step: 10
# [WANDB DEBUG] Successfully logged test metrics
# The average client test results: 0.48616847876973257
# The final global test results: 0.326
# Round 1 is complete
# wandb: ⢿ uploading history steps 0-10, summary, console lines 2-224 (0.1s)
# wandb: ⣻ uploading history steps 0-10, summary, console lines 2-224 (0.1s)
# wandb: ⣽ uploading history steps 0-10, summary, console lines 2-224 (0.1s)
# wandb: ⣾ uploading history steps 0-10, summary, console lines 2-224 (0.1s)
# wandb:
# wandb: ⣾ uploading history steps 0-10, summary, console lines 2-224 (0.1s)
# wandb:
# wandb: Run history:
# wandb:  federation/avg_client_train_acc ▁▁▁▂▃▄▄▆▆█
# wandb: federation/avg_client_train_loss █▆▆▄▄▄▃▃▃▁
# wandb:    federation/avg_client_val_acc ▁▂▂▃▃▄▆▆█▆
# wandb:   federation/avg_client_val_loss █▇▆▆▅▄▃▃▂▁
# wandb:                            round ▁▂▂▃▄▅▅▆▇▇█
# wandb:           run_client_test_result ▁
# wandb:           run_global_test_result ▁
# wandb:         test/avg_client_test_acc ▁
# wandb:         test/client_test_acc_std ▁
# wandb:             test/global_test_acc ▁
# wandb:   test/global_vs_avg_client_diff ▁
# wandb:                 test/num_clients ▁
# wandb:
# wandb: Run summary:
# wandb:  federation/avg_client_train_acc 0.579
# wandb: federation/avg_client_train_loss 1.35641
# wandb:    federation/avg_client_val_acc 0.49271
# wandb:   federation/avg_client_val_loss 1.54298
# wandb:                            round 10
# wandb:           run_client_test_result 0.48617
# wandb:           run_global_test_result 0.326
# wandb:         test/avg_client_test_acc 0.48617
# wandb:         test/client_test_acc_std 0.08715
# wandb:             test/global_test_acc 0.326
# wandb:   test/global_vs_avg_client_diff -0.16017
# wandb:                 test/num_clients 10
# wandb:
# wandb: 🚀 View run GCN_Photo_SGD_lr0.5_decay0.0005_beta1_run1 at: https://wandb.ai/bosho/FGL3/runs/xn2jvjmk
# wandb: ⭐️ View project at: https://wandb.ai/bosho/FGL3
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251006_094634-xn2jvjmk/logs
# The global test results: [0.326]
# The client test results: [0.48616847876973257]
# The average global test results: 0.326
# The average client test results: 0.48616847876973257
# The standard deviation global is: 0.0
# The standard deviation client is: 0.0
# (FLClient pid=1284477) Input dim of the model: 745 [repeated 9x across cluster]
# (FLClient pid=1284477) Input dim of the data: 745 [repeated 9x across cluster]
# (FLClient pid=1284477) 2025-10-06 09:46:46,990 - INFO - Epoch   2| Train Loss: 1.130| Train Accuracy: 0.655| Val Loss: 1.168| Val Accuracy: 0.610 [repeated 87x across cluster]
# Results saved to /home/brian_bosho/FP/FP/results/experiments/amazon_photo/Photo_adjacency_GCN_beta1.0_clients10/results_Photo_adjacency_GCN_beta1.0_clients10_20251006_094632.json
# Training CSV results saved to /home/brian_bosho/FP/FP/results/experiments/amazon_photo/Photo_adjacency_GCN_beta1.0_clients10/training_Photo_adjacency_GCN_beta1.0_clients10_20251006_094632.csv
#
# ================================================================================
# Running experiment: Photo_diffusion_GCN_beta1.0_clients10
# ================================================================================
# DEVICE: cuda
# Data loading option is diffusion
# Model type is GCN
# 2025-10-06 09:46:52,557	INFO worker.py:1807 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /home/brian_bosho/FP/FP/federated-gnn/wandb/run-20251006_094653-aoj1nbnf
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run apricot-tree-400
# wandb: ⭐️ View project at https://wandb.ai/bosho/FGL3
# wandb: 🚀 View run at https://wandb.ai/bosho/FGL3/runs/aoj1nbnf
# [WANDB DEBUG] Successfully initialized wandb run: apricot-tree-400
# Wandb config is set to: {'dataset': 'Photo', 'model': 'GCN', 'data_loading': 'diffusion', 'num_clients': [10], 'num_rounds': 10, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 1, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': None, 'pe_P': None, 'normalize': None, 'run_index': 1, 'num_iterations': None}
# {'dataset': 'Photo', 'model': 'GCN', 'data_loading': 'diffusion', 'num_clients': [10], 'num_rounds': 10, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 1, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': None, 'pe_P': None, 'normalize': None, 'run_index': 1, 'num_iterations': None}
# data_loading_option: diffusion
# Feature propagation logs saved to: ../results/experiments/amazon_photo/propagation_stats/prop_exp_20251006-094655_diffusion_beta_1.0_hop_1.json
# partition_time_s: 6.65
# client[0] device: cuda:0 cuda:0
# client[0] feature_dim: 745
# config.use_pe: False num_iterations: None feature_prop_device: cuda
# data_loading_option: diffusion hop: 1 num_clients: 10
#
# === DATA LOADING SUMMARY ===
# Full graph: 7650 nodes, 245812 edges
# Number of client subgraphs: 10
# First client subgraph shape: torch.Size([3305, 745])
# Dataset: AmazonPhoto()
# Device: cuda
#
# Full graph device (before): cuda:0
# Full graph staying on CPU to save GPU memory
# ===========================
#
#
# === CLIENT DATA LOADING ===
# Full graph size: 7650 nodes
# Number of clients: 10
# Client 0 subgraph: 3305 nodes, 745 features
# Client 1 subgraph: 4042 nodes, 745 features
# Client 2 subgraph: 5002 nodes, 745 features
# Client 3 subgraph: 4723 nodes, 745 features
# Client 4 subgraph: 5732 nodes, 745 features
# Client 5 subgraph: 5555 nodes, 745 features
# Client 6 subgraph: 5709 nodes, 745 features
# Client 7 subgraph: 5752 nodes, 745 features
# Client 8 subgraph: 5929 nodes, 745 features
# Client 9 subgraph: 5985 nodes, 745 features
# ===========================
#
# Input dim of the model in server: 745
# (raylet) [2025-10-06 09:47:02,527 E 1286756 1286785] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2025-10-06_09-46-51_546434_1279507 is over 95% full, available space: 30299262976; capacity: 1622224654336. Object creation will fail if spilling is required.
# (FLClient pid=1286849)
# (FLClient pid=1286849) [Client 0] Initializing with:
# (FLClient pid=1286849)   - Input data nodes: 3305
# (FLClient pid=1286849)   - Input data edges: 98511
# (FLClient pid=1286849)   - Feature shape: torch.Size([3305, 745])
# (FLClient pid=1286849)   - Data device (before moving): cuda:0
# (FLClient pid=1286849)   - Input dim: 745
# (FLClient pid=1286849)   - Data device (after moving): cuda:0
# (FLClient pid=1286854) CUDA error: out of memory
# (FLClient pid=1286854) CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# (FLClient pid=1286854) For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# (FLClient pid=1286854) Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
# (FLClient pid=1286854) Traceback (most recent call last):
# (FLClient pid=1286854)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/ray/_private/serialization.py", line 460, in deserialize_objects
# (FLClient pid=1286854)     obj = self._deserialize_object(data, metadata, object_ref)
# (FLClient pid=1286854)           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=1286854)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/ray/_private/serialization.py", line 317, in _deserialize_object
# (FLClient pid=1286854)     return self._deserialize_msgpack_data(data, metadata_fields)
# (FLClient pid=1286854)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=1286854)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/ray/_private/serialization.py", line 272, in _deserialize_msgpack_data
# (FLClient pid=1286854)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (FLClient pid=1286854)                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=1286854)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/ray/_private/serialization.py", line 262, in _deserialize_pickle5_data
# (FLClient pid=1286854)     obj = pickle.loads(in_band)
# (FLClient pid=1286854)           ^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=1286854)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/storage.py", line 520, in _load_from_bytes
# (FLClient pid=1286854)     return torch.load(io.BytesIO(b), weights_only=False)
# (FLClient pid=1286854)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=1286854)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/serialization.py", line 1384, in load
# (FLClient pid=1286854)     return _legacy_load(
# (FLClient pid=1286854)            ^^^^^^^^^^^^^
# (FLClient pid=1286854)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/serialization.py", line 1638, in _legacy_load
# (FLClient pid=1286854)     result = unpickler.load()
# (FLClient pid=1286854)              ^^^^^^^^^^^^^^^^
# (FLClient pid=1286854)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/serialization.py", line 1566, in persistent_load
# (FLClient pid=1286854)     obj = restore_location(obj, location)
# (FLClient pid=1286854)           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=1286854)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/serialization.py", line 601, in default_restore_location
# (FLClient pid=1286854)     result = fn(storage, location)
# (FLClient pid=1286854)              ^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=1286854)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/serialization.py", line 540, in _deserialize
# (FLClient pid=1286854)     return obj.to(device=device)
# (FLClient pid=1286854)            ^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=1286854)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/storage.py", line 279, in to
# (FLClient pid=1286854)     return _to(self, device, non_blocking)
# (FLClient pid=1286854)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=1286854)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/_utils.py", line 88, in _to
# (FLClient pid=1286854)     untyped_storage = torch.UntypedStorage(self.size(), device=device)
# (FLClient pid=1286854)                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=1286854) RuntimeError: CUDA error: out of memory
# (FLClient pid=1286854) CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# (FLClient pid=1286854) For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# (FLClient pid=1286854) Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
# (FLClient pid=1286854)
# (FLClient pid=1286854) Exception raised in creation task: The actor died because of an error raised in its creation task, ray::FLClient.__init__() (pid=1286854, ip=172.29.98.248, actor_id=3415855e0444ee4d170b8a7d01000000, repr=<src.client.FLClient object at 0x7fa23f5306e0>)Error in round 1: The actor died because of an error raised in its creation task, ray::FLClient.__init__() (pid=1286854, ip=172.29.98.248, actor_id=3415855e0444ee4d170b8a7d01000000, repr=<src.client.FLClient object at 0x7fa23f5306e0>)
#   At least one of the input arguments for this task could not be computed:
# ray.exceptions.RaySystemError: System error: CUDA error: out of memory
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# traceback: Traceback (most recent call last):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/storage.py", line 520, in _load_from_bytes
#     return torch.load(io.BytesIO(b), weights_only=False)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/serialization.py", line 1384, in load
#     return _legacy_load(
#            ^^^^^^^^^^^^^
#   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/serialization.py", line 1638, in _legacy_load
#     result = unpickler.load()
#              ^^^^^^^^^^^^^^^^
#   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/serialization.py", line 1566, in persistent_load
#     obj = restore_location(obj, location)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/serialization.py", line 601, in default_restore_location
#     result = fn(storage, location)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/serialization.py", line 540, in _deserialize
#     return obj.to(device=device)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/storage.py", line 279, in to
#     return _to(self, device, non_blocking)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/_utils.py", line 88, in _to
#     untyped_storage = torch.UntypedStorage(self.size(), device=device)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: CUDA error: out of memory
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# (FLClient pid=1286854)   At least one of the input arguments for this task could not be computed:
# The global test results: [](FLClient pid=1286854) ray.exceptions.RaySystemError: System error: CUDA error: out of memory
#
# The client test results: [](FLClient pid=1286854) CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
#
# (FLClient pid=1286854) For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:3904: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# (FLClient pid=1286854) Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
# (FLClient pid=1286854) /home/brian_bosho/miniconda3/lib/python3.12/site-packages/numpy/_core/_methods.py:147: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/numpy/_core/_methods.py:227: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# (FLClient pid=1286854) traceback: Traceback (most recent call last):/home/brian_bosho/miniconda3/lib/python3.12/site-packages/numpy/_core/_methods.py:184: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
#
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/numpy/_core/_methods.py:219: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# (FLClient pid=1286854)           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^The average global test results: nan
#
# (FLClient pid=1286854)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^The average client test results: nan
#
# (FLClient pid=1286854)                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^The standard deviation global is: nan
#
# (FLClient pid=1286854)           ^^^^^^^^^^^^^^^^^^^^^The standard deviation client is: nan
#
# (FLClient pid=1286854)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/storage.py", line 520, in _load_from_bytes
# (FLClient pid=1286854)     return torch.load(io.BytesIO(b), weights_only=False)
# (FLClient pid=1286854)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=1286854)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/serialization.py", line 1384, in load
# (FLClient pid=1286854)     return _legacy_load(
# (FLClient pid=1286854)            ^^^^^^^^^^^^^
# (FLClient pid=1286854)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/serialization.py", line 1638, in _legacy_load
# (FLClient pid=1286854)     result = unpickler.load()
# (FLClient pid=1286854)              ^^^^^^^^^^^^^^^^
# (FLClient pid=1286854)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/serialization.py", line 1566, in persistent_load
# (FLClient pid=1286854)     obj = restore_location(obj, location)
# (FLClient pid=1286854)           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=1286854)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/serialization.py", line 601, in default_restore_location
# (FLClient pid=1286854)     result = fn(storage, location)
# (FLClient pid=1286854)              ^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=1286854)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/serialization.py", line 540, in _deserialize
# (FLClient pid=1286854)     return obj.to(device=device)
# (FLClient pid=1286854)            ^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=1286854)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/storage.py", line 279, in to
# (FLClient pid=1286854)     return _to(self, device, non_blocking)
# (FLClient pid=1286854)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=1286854)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/_utils.py", line 88, in _to
# (FLClient pid=1286854)     untyped_storage = torch.UntypedStorage(self.size(), device=device)
# (FLClient pid=1286854)                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=1286854) RuntimeError: CUDA error: out of memory
# (FLClient pid=1286854) CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# (FLClient pid=1286854) For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# (FLClient pid=1286854) Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
# Results saved to /home/brian_bosho/FP/FP/results/experiments/amazon_photo/Photo_diffusion_GCN_beta1.0_clients10/results_Photo_diffusion_GCN_beta1.0_clients10_20251006_094651.json
# Training CSV results saved to /home/brian_bosho/FP/FP/results/experiments/amazon_photo/Photo_diffusion_GCN_beta1.0_clients10/training_Photo_diffusion_GCN_beta1.0_clients10_20251006_094651.csv
#
# Summary results saved to:
# - Text file: /home/brian_bosho/FP/FP/results/results_summary/amazon_photo/summary_results_20251006_094707.txt
# - JSON file: /home/brian_bosho/FP/FP/results/results_summary/amazon_photo/summary_results_20251006_094707.json
# - Detailed results saved to: /home/brian_bosho/FP/FP/results/experiments/amazon_photo
#
#
#
# ================================================================================
# EXPERIMENT RESULTS SUMMARY
# ================================================================================
# +-----------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+
# | Dataset   | Data Loading   | Model   |   Beta |   Clients |   Avg Global Result |   Avg Client Result |   client_std_dev |   global_std_dev | Duration   |   Hop | Use PE   |
# +===========+================+=========+========+===========+=====================+=====================+==================+==================+============+=======+==========+
# | Photo     | full           | GCN     |      1 |        10 |               0.685 |              0.6646 |                0 |                0 | 00:00:21   |     1 | False    |
# +-----------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+
# | Photo     | zero_hop       | GCN     |      1 |        10 |               0.731 |              0.7082 |                0 |                0 | 00:00:18   |     1 | False    |
# +-----------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+
# | Photo     | adjacency      | GCN     |      1 |        10 |               0.326 |              0.4862 |                0 |                0 | 00:00:19   |     1 | False    |
# +-----------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+
# | Photo     | diffusion      | GCN     |      1 |        10 |             nan     |            nan      |              nan |              nan | 00:00:16   |     1 | False    |
# +-----------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+
#
#
# KEY RESULTS:
# --------------------------------------------------------------------------------
# Photo with full using GCN (beta=1.00, clients=10, hop=1, use_pe=False):
#   - Average Global Result: 0.6850
#   - Average Client Result: 0.6646
#   - Client StdDev: 0.0000
#   - Global StdDev: 0.0000
#   - Experiment Duration: 00:00:21
# --------------------------------------------------------------------------------
# Photo with zero_hop using GCN (beta=1.00, clients=10, hop=1, use_pe=False):
#   - Average Global Result: 0.7310
#   - Average Client Result: 0.7082
#   - Client StdDev: 0.0000
#   - Global StdDev: 0.0000
#   - Experiment Duration: 00:00:18
# --------------------------------------------------------------------------------
# Photo with adjacency using GCN (beta=1.00, clients=10, hop=1, use_pe=False):
#   - Average Global Result: 0.3260
#   - Average Client Result: 0.4862
#   - Client StdDev: 0.0000
#   - Global StdDev: 0.0000
#   - Experiment Duration: 00:00:19
# --------------------------------------------------------------------------------
# Photo with diffusion using GCN (beta=1.00, clients=10, hop=1, use_pe=False):
#   - Average Global Result: nan
#   - Average Client Result: nan
#   - Client StdDev: nan
#   - Global StdDev: nan
#   - Experiment Duration: 00:00:16
# --------------------------------------------------------------------------------
# wandb: ⢿ uploading output.log 19.1KB/19.1KB (0.6s)
# wandb: ⢿ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: ⣻ uploading output.log 19.1KB/19.1KB (0.6s)
# wandb: ⣻ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: ⣽ uploading output.log 19.1KB/19.1KB (0.6s)
# wandb: ⣽ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: ⣾ uploading output.log 19.1KB/19.1KB (0.6s)
# wandb: ⣾ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: ⣷ uploading output.log 19.1KB/19.1KB (0.6s)
# wandb: ⣷ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: ⣯ uploading output.log 19.1KB/19.1KB (0.6s)
# wandb: ⣯ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: ⣟ uploading output.log 19.1KB/19.1KB (0.6s)
# wandb: ⣟ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb:
# wandb: ⣟ uploading output.log 19.1KB/19.1KB (0.6s)
# wandb: ⣟ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: 🚀 View run GCN_Photo_SGD_lr0.5_decay0.0005_beta1_run1 at: https://wandb.ai/bosho/FGL3/runs/aoj1nbnf
# wandb: ⭐️ View project at: https://wandb.ai/bosho/FGL3
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251006_094653-aoj1nbnf/logs
