# %%
# !python -m src.experiments.run_experiments --config conf/pubmed_config.yaml
# Out:
# Experiment Configuration:
# - Clients: [10]
# - Rounds: 100
# - Epochs: 3
# - Learning Rate: 0.01
# - Beta values: [10000]
# - Datasets: ['Pubmed']
# - Data Loading Options: ['full']
# - Model Types: ['GCN']
# - Results Directory: /home/brian_bosho/FP/FP/federated-gnn/results/pubmed
# - Save Detailed Results: True
# - Hop: 1
# - Full Training Flag: False
#
# ...
# Running experiment: Pubmed_full_GCN_beta10000_clients10
# ...
# 2025-10-21 20:51:57,218	INFO worker.py:1807 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# 2025-10-21 20:51:58,413 - INFO - Memory before experiment - Allocated: 0.00GB, Cached: 0.00GB, Max: 0.00GB
# Moving all 10 preprocessed subgraphs to CPU to free GPU memory...
# ✓ GPU memory freed after preprocessing - all data now on CPU
# (FLClient pid=2682645) Client 0: Using full-batch training for Pubmed dataset
# ...

# %%
# !python -m src.experiments.run_experiments --config conf/pubmed_config.yaml
# Out:
# Experiment Configuration:
# - Clients: [10]
# - Rounds: 100
# - Epochs: 3
# - Learning Rate: 0.01
# - Beta values: [10000]
# - Datasets: ['Pubmed']
# - Data Loading Options: ['full']
# - Model Types: ['GCN']
# - Results Directory: /home/brian_bosho/FP/FP/federated-gnn/results/pubmed
# - Save Detailed Results: True
# - Hop: 1
# - Full Training Flag: False
#
# ...
# Running experiment: Pubmed_full_GCN_beta10000_clients10
# ...
# 2025-10-21 21:01:37,077	INFO worker.py:1807 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# 2025-10-21 21:01:38,263 - INFO - Memory before experiment - Allocated: 0.00GB, Cached: 0.00GB, Max: 0.00GB
# Moving all 10 preprocessed subgraphs to CPU to free GPU memory...
# ✓ GPU memory freed after preprocessing - all data now on CPU
# (FLClient pid=2695903) Client 0: Using full-batch training for Pubmed dataset
# ...

# %%
# !python -m src.experiments.run_experiments --config conf/ogbn-arxiv_config.yaml

# %%
# !python -m src.experiments.run_experiments --config conf/photos_config.yaml

# %%
# !python -m src.experiments.run_experiments --config conf/computers_config.yaml
# Out:
# Experiment Configuration:
# - Clients: [10]
# - Rounds: 200
# - Epochs: 3
# - Learning Rate: 0.005
# - Beta values: [1]
# - Datasets: ['Computers']
# - Data Loading Options: ['adjacency', 'zero_hop', 'full', 'chebyshev_diffusion']
# - Model Types: ['GCN']
# - Results Directory: /home/brian_bosho/FP/FP/federated-gnn/results/computers
# - Save Detailed Results: True
# - Hop: 1
# - Full Training Flag: False
#
# ...
# Running experiment: Computers_adjacency_GCN_beta1_clients10
# ...
# 2025-10-21 20:06:22,328	INFO worker.py:1807 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# 2025-10-21 20:06:23,539 - INFO - Memory before experiment - Allocated: 0.00GB, Cached: 0.00GB, Max: 0.00GB
# Moving all 10 preprocessed subgraphs to CPU to free GPU memory...
# ✓ GPU memory freed after preprocessing - all data now on CPU
# (FLClient pid=2629206) Client 0: Using full-batch training for computers dataset
# ...

# %%
# !python -m src.experiments.run_experiments --config conf/computers_config.yaml
# Out:
# Experiment Configuration:
# - Clients: [10]
# - Rounds: 200
# - Epochs: 3
# - Learning Rate: 0.005
# - Beta values: [1]
# - Datasets: ['Computers']
# - Data Loading Options: ['diffusion']
# - Model Types: ['GCN']
# - Results Directory: /home/brian_bosho/FP/FP/federated-gnn/results/computers
# - Save Detailed Results: True
# - Hop: 1
# - Full Training Flag: False
#
# ...
# Running experiment: Computers_diffusion_GCN_beta1_clients10
# ...
# 2025-10-22 09:47:59,108	INFO worker.py:1807 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# 2025-10-22 09:48:00,672 - INFO - Memory before experiment - Allocated: 0.00GB, Cached: 0.00GB, Max: 0.00GB
# 2025-10-22 09:48:03,060 - INFO - Clearing memory for diffusion operation
# 2025-10-22 09:48:03,712 - INFO - Memory after clearing - Allocated: 0.46GB, Cached: 1.51GB
# 2025-10-22 09:48:05,362 - INFO - Clearing memory for diffusion operation
# 2025-10-22 09:48:06,013 - INFO - Memory after clearing - Allocated: 0.45GB, Cached: 1.51GB
# ...
