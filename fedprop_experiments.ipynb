# %%
# !python -m src.experiments.run_experiments --config conf/pubmed_config.yaml

# %%
# !python -m src.experiments.run_experiments --config conf/ogbn-arxiv_config.yaml
# Out:
# Experiment Configuration:
# - Clients: [10]
# - Rounds: 5
# - Epochs: 3
# - Learning Rate: 0.001
# - Beta values: [10000]
# - Datasets: ['ogbn-arxiv']
# - Data Loading Options: ['chebyshev_diffusion', 'full']
# - Model Types: ['GCN']
# - Results Directory: /home/brian_bosho/FP/FP/federated-gnn/results/ogbn-arxiv2
# - Save Detailed Results: True
# - Hop: 1
# - Full Training Flag: False
#
# ================================================================================
# Running experiment: ogbn-arxiv_chebyshev_diffusion_GCN_beta10000_clients10
# ================================================================================
# 2025-10-21 13:31:57,083	INFO worker.py:1807 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# wandb: Currently logged in as: bosho to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ creating run (0.4s)
# wandb: ⣻ creating run (0.4s)
# wandb: ⣽ creating run (0.4s)
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /home/brian_bosho/FP/FP/federated-gnn/wandb/run-20251021_133159-2wf0n3xn
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run icy-plant-83
# wandb: ⭐️ View project at https://wandb.ai/bosho/FGL3-Ogbn-Arxiv2
# wandb: 🚀 View run at https://wandb.ai/bosho/FGL3-Ogbn-Arxiv2/runs/2wf0n3xn
# [WANDB DEBUG] Successfully initialized wandb run: icy-plant-83
# Wandb config is set to: {'dataset': 'ogbn-arxiv', 'model': 'GCN', 'data_loading': 'chebyshev_diffusion', 'num_clients': [10], 'num_rounds': 5, 'epochs': 3, 'beta': 10000, 'lr': 0.001, 'optimizer': 'Adam', 'decay': 0.0005, 'hop': 1, 'fulltraining_flag': False, 'use_pe': True, 'pe_r': 64, 'pe_P': 16, 'normalize': 'qr', 'run_index': 1, 'num_iterations': 80}
# {'dataset': 'ogbn-arxiv', 'model': 'GCN', 'data_loading': 'chebyshev_diffusion', 'num_clients': [10], 'num_rounds': 5, 'epochs': 3, 'beta': 10000, 'lr': 0.001, 'optimizer': 'Adam', 'decay': 0.0005, 'hop': 1, 'fulltraining_flag': False, 'use_pe': True, 'pe_r': 64, 'pe_P': 16, 'normalize': 'qr', 'run_index': 1, 'num_iterations': 80}
# 2025-10-21 13:32:00,914 - INFO - Memory before experiment - Allocated: 0.00GB, Cached: 0.00GB, Max: 0.00GB
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/ogb/nodeproppred/dataset_pyg.py:69: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.data, self.slices = torch.load(self.processed_paths[0])
# 2025-10-21 13:32:10,565 - INFO - Clearing memory for diffusion operation
# 2025-10-21 13:32:11,007 - INFO - Memory after clearing - Allocated: 0.99GB, Cached: 1.34GB
# 2025-10-21 13:32:13,733 - INFO - Clearing memory for diffusion operation
# 2025-10-21 13:32:14,168 - INFO - Memory after clearing - Allocated: 2.20GB, Cached: 2.56GB
# 2025-10-21 13:32:16,533 - INFO - Clearing memory for diffusion operation
# 2025-10-21 13:32:16,969 - INFO - Memory after clearing - Allocated: 2.59GB, Cached: 2.99GB
# 2025-10-21 13:32:19,338 - INFO - Clearing memory for diffusion operation
# 2025-10-21 13:32:19,776 - INFO - Memory after clearing - Allocated: 2.98GB, Cached: 3.43GB
# 2025-10-21 13:32:22,113 - INFO - Clearing memory for diffusion operation
# 2025-10-21 13:32:22,547 - INFO - Memory after clearing - Allocated: 3.35GB, Cached: 3.84GB
# 2025-10-21 13:32:24,895 - INFO - Clearing memory for diffusion operation
# 2025-10-21 13:32:25,335 - INFO - Memory after clearing - Allocated: 3.74GB, Cached: 4.28GB
# 2025-10-21 13:32:27,685 - INFO - Clearing memory for diffusion operation
# 2025-10-21 13:32:28,118 - INFO - Memory after clearing - Allocated: 4.12GB, Cached: 4.71GB
# 2025-10-21 13:32:30,463 - INFO - Clearing memory for diffusion operation
# 2025-10-21 13:32:30,906 - INFO - Memory after clearing - Allocated: 4.50GB, Cached: 5.14GB
# 2025-10-21 13:32:33,234 - INFO - Clearing memory for diffusion operation
# 2025-10-21 13:32:33,689 - INFO - Memory after clearing - Allocated: 4.88GB, Cached: 5.56GB
# 2025-10-21 13:32:36,090 - INFO - Clearing memory for diffusion operation
# 2025-10-21 13:32:36,540 - INFO - Memory after clearing - Allocated: 5.28GB, Cached: 6.01GB
# Moving all 10 preprocessed subgraphs to CPU to free GPU memory...
# ✓ GPU memory freed after preprocessing - all data now on CPU
# Model is GCN_arxiv(
#   (convs): ModuleList(
#     (0): GCNConv(1216, 256)
#     (1): GCNConv(256, 256)
#     (2): GCNConv(256, 40)
#   )
#   (bns): ModuleList(
#     (0-1): 2 x BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# (FLClient pid=2293197) Client 0: Using full-batch training for ogbn-arxiv dataset
# (FLClient pid=2293204) /home/brian_bosho/FP/FP/federated-gnn/src/train.py:38: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
# (FLClient pid=2293204)   scaler = torch.cuda.amp.GradScaler(enabled=use_amp)
# (FLClient pid=2293204) /home/brian_bosho/FP/FP/federated-gnn/src/train.py:55: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# (FLClient pid=2293204)   with torch.cuda.amp.autocast(enabled=use_amp):
# (FLClient pid=2293192) Client 5: Using full-batch training for ogbn-arxiv dataset [repeated 5x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (FLClient pid=2293204) 2025-10-21 13:32:53,647 - INFO - Epoch   0| Train Loss: 4.556| Train Accuracy: 0.023| Val Loss: 3.688| Val Accuracy: 0.102
# (FLClient pid=2293199) /home/brian_bosho/FP/FP/federated-gnn/src/train.py:38: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead. [repeated 9x across cluster]
# (FLClient pid=2293199)   scaler = torch.cuda.amp.GradScaler(enabled=use_amp) [repeated 9x across cluster]
# (FLClient pid=2293199) /home/brian_bosho/FP/FP/federated-gnn/src/train.py:55: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead. [repeated 9x across cluster]
# (FLClient pid=2293199)   with torch.cuda.amp.autocast(enabled=use_amp): [repeated 9x across cluster]
# 2025-10-21 13:32:59,044 - INFO - Memory after parallel training - Allocated: 0.00GB, Cached: 0.02GB, Max: 8.02GB
# 2025-10-21 13:32:59,823 - INFO - Memory after parameter aggregation - Allocated: 0.00GB, Cached: 0.02GB, Max: 8.02GB
# (FLClient pid=2293197) Error in client 0 evaluation: CUDA out of memory. Tried to allocate 1.77 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.86 GiB is free. Process 2292837 has 555.00 MiB memory in use. Including non-PyTorch memory, this process has 1.17 GiB memory in use. Process 2293200 has 4.77 GiB memory in use. Process 2293204 has 4.76 GiB memory in use. Process 2293195 has 4.71 GiB memory in use. Process 2293201 has 4.73 GiB memory in use. Process 2293192 has 4.73 GiB memory in use. Process 2293196 has 4.84 GiB memory in use. Process 2293198 has 4.78 GiB memory in use. Process 2293203 has 1.02 GiB memory in use. Process 2293199 has 4.79 GiB memory in use. Of the allocated memory 627.08 MiB is allocated by PyTorch, and 52.92 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2293199) Client 9: Using full-batch training for ogbn-arxiv dataset [repeated 4x across cluster]
# Error in round 1: 'float' object is not subscriptable
# Traceback (most recent call last):
#   File "/home/brian_bosho/FP/FP/federated-gnn/src/run.py", line 404, in main_experiment
#     global_results, client_results = run_with_server(
#                                      ^^^^^^^^^^^^^^^^
#   File "/home/brian_bosho/FP/FP/federated-gnn/src/run.py", line 206, in run_with_server
#     results = server.train_clients(i)
#               ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/brian_bosho/FP/FP/federated-gnn/src/server.py", line 148, in train_clients
#     log_client_validation_metrics(eval_results, current_global_epoch)
#   File "/home/brian_bosho/FP/FP/federated-gnn/src/utils/wandb_utils.py", line 72, in log_client_validation_metrics
#     client_val_losses = [to_cpu_scalar(result[0]) for result in val_results]
#                                        ~~~~~~^^^
# TypeError: 'float' object is not subscriptable
# The global test results: []
# The client test results: []
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:3904: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/numpy/_core/_methods.py:147: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/numpy/_core/_methods.py:227: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/numpy/_core/_methods.py:184: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/numpy/_core/_methods.py:219: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# The average global test results: nan
# The average client test results: nan
# The standard deviation global is: nan
# The standard deviation client is: nan
# (FLClient pid=2293199) 2025-10-21 13:32:58,188 - INFO - Epoch   2| Train Loss: 3.386| Train Accuracy: 0.238| Val Loss: 3.683| Val Accuracy: 0.012 [repeated 29x across cluster]
# Cleaning up Ray processes and memory...
# 2025-10-21 13:33:04,197	INFO worker.py:1807 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# Results saved to /home/brian_bosho/FP/FP/federated-gnn/results/ogbn-arxiv2/ogbn-arxiv_chebyshev_diffusion_GCN_beta10000_clients10/results_ogbn-arxiv_chebyshev_diffusion_GCN_beta10000_clients10_20251021_133155.json
# Training CSV results saved to /home/brian_bosho/FP/FP/federated-gnn/results/ogbn-arxiv2/ogbn-arxiv_chebyshev_diffusion_GCN_beta10000_clients10/training_ogbn-arxiv_chebyshev_diffusion_GCN_beta10000_clients10_20251021_133155.csv
#
# ================================================================================
# Running experiment: ogbn-arxiv_full_GCN_beta10000_clients10
# ================================================================================
# 2025-10-21 13:33:04,881	INFO worker.py:1649 -- Calling ray.init() again after it has already been called.
# [WANDB DEBUG] Found existing run, finishing it before starting new one
# wandb: ⢿ uploading output.log 10.4KB/10.4KB (0.6s)
# wandb: ⢿ uploading config.yaml 2.5KB/2.5KB (0.1s)
# wandb: ⣻ uploading output.log 10.4KB/10.4KB (0.6s)
# wandb: ⣻ uploading config.yaml 2.5KB/2.5KB (0.1s)
# wandb: ⣽ uploading output.log 10.4KB/10.4KB (0.6s)
# wandb: ⣽ uploading config.yaml 2.5KB/2.5KB (0.1s)
# wandb: ⣾ uploading output.log 10.4KB/10.4KB (0.6s)
# wandb: ⣾ uploading config.yaml 2.5KB/2.5KB (0.1s)
# wandb: ⣷ uploading output.log 10.4KB/10.4KB (0.6s)
# wandb: ⣷ uploading config.yaml 2.5KB/2.5KB (0.1s)
# wandb: ⣯ uploading output.log 10.4KB/10.4KB (0.6s)
# wandb: ⣯ uploading config.yaml 2.5KB/2.5KB (0.1s)
# wandb: ⣟ uploading output.log 10.4KB/10.4KB (0.6s)
# wandb: ⣟ uploading config.yaml 2.5KB/2.5KB (0.1s)
# wandb: ⡿ uploading output.log 10.4KB/10.4KB (0.6s)
# wandb: ⡿ uploading config.yaml 2.5KB/2.5KB (0.1s)
# wandb: ⢿ uploading output.log 10.4KB/10.4KB (0.6s)
# wandb: ⢿ uploading config.yaml 2.5KB/2.5KB (0.1s)
# wandb: ⣻ uploading history steps 0-0, summary, console lines 70-96 (0.2s)
# wandb: ⣽ uploading history steps 0-0, summary, console lines 70-96 (0.2s)
# wandb: ⣾ uploading history steps 0-0, summary, console lines 70-96 (0.2s)
# wandb: ⣷ uploading history steps 0-0, summary, console lines 70-96 (0.2s)
# wandb:
# wandb: ⣷ uploading history steps 0-0, summary, console lines 70-96 (0.2s)
# wandb:
# wandb: Run history:
# wandb:  federation/avg_client_train_acc ▁
# wandb: federation/avg_client_train_loss ▁
# wandb:                            round ▁
# wandb:
# wandb: Run summary:
# wandb:  federation/avg_client_train_acc 0.23162
# wandb: federation/avg_client_train_loss 3.68166
# wandb:                            round 0
# wandb:
# wandb: 🚀 View run GCN_ogbn-arxiv_Adam_lr0.001_decay0.0005_beta10000_run1 at: https://wandb.ai/bosho/FGL3-Ogbn-Arxiv2/runs/2wf0n3xn
# wandb: ⭐️ View project at: https://wandb.ai/bosho/FGL3-Ogbn-Arxiv2
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251021_133159-2wf0n3xn/logs
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /home/brian_bosho/FP/FP/federated-gnn/wandb/run-20251021_133307-yg0gtxiu
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run fiery-water-84
# wandb: ⭐️ View project at https://wandb.ai/bosho/FGL3-Ogbn-Arxiv2
# wandb: 🚀 View run at https://wandb.ai/bosho/FGL3-Ogbn-Arxiv2/runs/yg0gtxiu
# [WANDB DEBUG] Successfully initialized wandb run: fiery-water-84
# Wandb config is set to: {'dataset': 'ogbn-arxiv', 'model': 'GCN', 'data_loading': 'full', 'num_clients': [10], 'num_rounds': 5, 'epochs': 3, 'beta': 10000, 'lr': 0.001, 'optimizer': 'Adam', 'decay': 0.0005, 'hop': 1, 'fulltraining_flag': False, 'use_pe': True, 'pe_r': 64, 'pe_P': 16, 'normalize': 'qr', 'run_index': 1, 'num_iterations': 80}
# {'dataset': 'ogbn-arxiv', 'model': 'GCN', 'data_loading': 'full', 'num_clients': [10], 'num_rounds': 5, 'epochs': 3, 'beta': 10000, 'lr': 0.001, 'optimizer': 'Adam', 'decay': 0.0005, 'hop': 1, 'fulltraining_flag': False, 'use_pe': True, 'pe_r': 64, 'pe_P': 16, 'normalize': 'qr', 'run_index': 1, 'num_iterations': 80}
# 2025-10-21 13:33:08,724 - INFO - Memory before experiment - Allocated: 0.00GB, Cached: 0.00GB, Max: 8.02GB
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/ogb/nodeproppred/dataset_pyg.py:69: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.data, self.slices = torch.load(self.processed_paths[0])
# Moving all 10 preprocessed subgraphs to CPU to free GPU memory...
# ✓ GPU memory freed after preprocessing - all data now on CPU
# Model is GCN_arxiv(
#   (convs): ModuleList(
#     (0): GCNConv(128, 256)
#     (1): GCNConv(256, 256)
#     (2): GCNConv(256, 40)
#   )
#   (bns): ModuleList(
#     (0-1): 2 x BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# (FLClient pid=2296558) Client 0: Using full-batch training for ogbn-arxiv dataset
# (FLClient pid=2296558) /home/brian_bosho/FP/FP/federated-gnn/src/train.py:38: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
# (FLClient pid=2296558)   scaler = torch.cuda.amp.GradScaler(enabled=use_amp)
# (FLClient pid=2296558) /home/brian_bosho/FP/FP/federated-gnn/src/train.py:55: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# (FLClient pid=2296558)   with torch.cuda.amp.autocast(enabled=use_amp):
# (FLClient pid=2296558) 2025-10-21 13:33:24,541 - INFO - Epoch   0| Train Loss: 4.160| Train Accuracy: 0.043| Val Loss: 3.701| Val Accuracy: 0.023
# (FLClient pid=2296558) 2025-10-21 13:33:24,705 - INFO - Epoch   1| Train Loss: 3.644| Train Accuracy: 0.149| Val Loss: 3.679| Val Accuracy: 0.017
# (FLClient pid=2296558) 2025-10-21 13:33:24,882 - INFO - Epoch   2| Train Loss: 3.271| Train Accuracy: 0.205| Val Loss: 3.661| Val Accuracy: 0.056
# 2025-10-21 13:33:29,684 - INFO - Memory after parallel training - Allocated: 0.00GB, Cached: 0.00GB, Max: 8.02GB
# 2025-10-21 13:33:30,432 - INFO - Memory after parameter aggregation - Allocated: 0.00GB, Cached: 0.00GB, Max: 8.02GB
# (FLClient pid=2296566) Error in client 3 evaluation: CUDA out of memory. Tried to allocate 1.73 GiB. GPU 0 has a total capacity of 47.71 GiB of which 365.38 MiB is free. Process 2292837 has 535.00 MiB memory in use. Process 2296558 has 4.42 GiB memory in use. Process 2296567 has 4.39 GiB memory in use. Process 2296559 has 4.38 GiB memory in use. Including non-PyTorch memory, this process has 2.50 GiB memory in use. Process 2296561 has 4.34 GiB memory in use. Process 2296556 has 4.35 GiB memory in use. Process 2296565 has 4.37 GiB memory in use. Process 2296564 has 4.31 GiB memory in use. Process 2296576 has 4.36 GiB memory in use. Process 2296560 has 4.40 GiB memory in use. Of the allocated memory 1.94 GiB is allocated by PyTorch, and 58.28 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2296560) Client 9: Using full-batch training for ogbn-arxiv dataset [repeated 9x across cluster]
# (FLClient pid=2296558) Error in client 0 evaluation: CUDA out of memory. Tried to allocate 94.00 MiB. GPU 0 has a total capacity of 47.71 GiB of which 365.38 MiB is free. Process 2292837 has 535.00 MiB memory in use. Including non-PyTorch memory, this process has 4.42 GiB memory in use. Process 2296567 has 4.39 GiB memory in use. Process 2296559 has 4.38 GiB memory in use. Process 2296566 has 2.50 GiB memory in use. Process 2296561 has 4.34 GiB memory in use. Process 2296556 has 4.35 GiB memory in use. Process 2296565 has 4.37 GiB memory in use. Process 2296564 has 4.31 GiB memory in use. Process 2296576 has 4.36 GiB memory in use. Process 2296560 has 4.40 GiB memory in use. Of the allocated memory 3.85 GiB is allocated by PyTorch, and 61.80 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2296567) Error in client 1 evaluation: CUDA out of memory. Tried to allocate 94.00 MiB. GPU 0 has a total capacity of 47.71 GiB of which 365.38 MiB is free. Process 2292837 has 535.00 MiB memory in use. Process 2296558 has 4.42 GiB memory in use. Including non-PyTorch memory, this process has 4.39 GiB memory in use. Process 2296559 has 4.38 GiB memory in use. Process 2296566 has 2.50 GiB memory in use. Process 2296561 has 4.34 GiB memory in use. Process 2296556 has 4.35 GiB memory in use. Process 2296565 has 4.37 GiB memory in use. Process 2296564 has 4.31 GiB memory in use. Process 2296576 has 4.36 GiB memory in use. Process 2296560 has 4.40 GiB memory in use. Of the allocated memory 3.82 GiB is allocated by PyTorch, and 59.45 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2296559) Error in client 2 evaluation: CUDA out of memory. Tried to allocate 94.00 MiB. GPU 0 has a total capacity of 47.71 GiB of which 367.38 MiB is free. Process 2292837 has 535.00 MiB memory in use. Process 2296558 has 4.42 GiB memory in use. Process 2296567 has 4.39 GiB memory in use. Including non-PyTorch memory, this process has 4.38 GiB memory in use. Process 2296566 has 2.50 GiB memory in use. Process 2296561 has 4.34 GiB memory in use. Process 2296556 has 4.35 GiB memory in use. Process 2296565 has 4.37 GiB memory in use. Process 2296564 has 4.31 GiB memory in use. Process 2296576 has 4.36 GiB memory in use. Process 2296560 has 4.40 GiB memory in use. Of the allocated memory 3.81 GiB is allocated by PyTorch, and 61.60 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2296561) Error in client 4 evaluation: CUDA out of memory. Tried to allocate 94.00 MiB. GPU 0 has a total capacity of 47.71 GiB of which 365.38 MiB is free. Process 2292837 has 535.00 MiB memory in use. Process 2296558 has 4.42 GiB memory in use. Process 2296567 has 4.39 GiB memory in use. Process 2296559 has 4.38 GiB memory in use. Process 2296566 has 2.50 GiB memory in use. Including non-PyTorch memory, this process has 4.34 GiB memory in use. Process 2296556 has 4.35 GiB memory in use. Process 2296565 has 4.37 GiB memory in use. Process 2296564 has 4.31 GiB memory in use. Process 2296576 has 4.36 GiB memory in use. Process 2296560 has 4.40 GiB memory in use. Of the allocated memory 3.78 GiB is allocated by PyTorch, and 60.50 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2296556) Error in client 5 evaluation: CUDA out of memory. Tried to allocate 94.00 MiB. GPU 0 has a total capacity of 47.71 GiB of which 367.38 MiB is free. Process 2292837 has 535.00 MiB memory in use. Process 2296558 has 4.42 GiB memory in use. Process 2296567 has 4.39 GiB memory in use. Process 2296559 has 4.38 GiB memory in use. Process 2296566 has 2.50 GiB memory in use. Process 2296561 has 4.34 GiB memory in use. Including non-PyTorch memory, this process has 4.35 GiB memory in use. Process 2296565 has 4.37 GiB memory in use. Process 2296564 has 4.31 GiB memory in use. Process 2296576 has 4.36 GiB memory in use. Process 2296560 has 4.40 GiB memory in use. Of the allocated memory 3.79 GiB is allocated by PyTorch, and 59.10 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2296565) Error in client 6 evaluation: CUDA out of memory. Tried to allocate 94.00 MiB. GPU 0 has a total capacity of 47.71 GiB of which 365.38 MiB is free. Process 2292837 has 535.00 MiB memory in use. Process 2296558 has 4.42 GiB memory in use. Process 2296567 has 4.39 GiB memory in use. Process 2296559 has 4.38 GiB memory in use. Process 2296566 has 2.50 GiB memory in use. Process 2296561 has 4.34 GiB memory in use. Process 2296556 has 4.35 GiB memory in use. Including non-PyTorch memory, this process has 4.37 GiB memory in use. Process 2296564 has 4.31 GiB memory in use. Process 2296576 has 4.36 GiB memory in use. Process 2296560 has 4.40 GiB memory in use. Of the allocated memory 3.80 GiB is allocated by PyTorch, and 62.94 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2296564) Error in client 7 evaluation: CUDA out of memory. Tried to allocate 92.00 MiB. GPU 0 has a total capacity of 47.71 GiB of which 365.38 MiB is free. Process 2292837 has 535.00 MiB memory in use. Process 2296558 has 4.42 GiB memory in use. Process 2296567 has 4.39 GiB memory in use. Process 2296559 has 4.38 GiB memory in use. Process 2296566 has 2.50 GiB memory in use. Process 2296561 has 4.34 GiB memory in use. Process 2296556 has 4.35 GiB memory in use. Process 2296565 has 4.37 GiB memory in use. Including non-PyTorch memory, this process has 4.31 GiB memory in use. Process 2296576 has 4.36 GiB memory in use. Process 2296560 has 4.40 GiB memory in use. Of the allocated memory 3.75 GiB is allocated by PyTorch, and 56.52 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2296576) Error in client 8 evaluation: CUDA out of memory. Tried to allocate 94.00 MiB. GPU 0 has a total capacity of 47.71 GiB of which 365.38 MiB is free. Process 2292837 has 535.00 MiB memory in use. Process 2296558 has 4.42 GiB memory in use. Process 2296567 has 4.39 GiB memory in use. Process 2296559 has 4.38 GiB memory in use. Process 2296566 has 2.50 GiB memory in use. Process 2296561 has 4.34 GiB memory in use. Process 2296556 has 4.35 GiB memory in use. Process 2296565 has 4.37 GiB memory in use. Process 2296564 has 4.31 GiB memory in use. Including non-PyTorch memory, this process has 4.36 GiB memory in use. Process 2296560 has 4.40 GiB memory in use. Of the allocated memory 3.81 GiB is allocated by PyTorch, and 55.66 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2296560) Error in client 9 evaluation: CUDA out of memory. Tried to allocate 94.00 MiB. GPU 0 has a total capacity of 47.71 GiB of which 365.38 MiB is free. Process 2292837 has 535.00 MiB memory in use. Process 2296558 has 4.42 GiB memory in use. Process 2296567 has 4.39 GiB memory in use. Process 2296559 has 4.38 GiB memory in use. Process 2296566 has 2.50 GiB memory in use. Process 2296561 has 4.34 GiB memory in use. Process 2296556 has 4.35 GiB memory in use. Process 2296565 has 4.37 GiB memory in use. Process 2296564 has 4.31 GiB memory in use. Process 2296576 has 4.36 GiB memory in use. Including non-PyTorch memory, this process has 4.40 GiB memory in use. Of the allocated memory 3.84 GiB is allocated by PyTorch, and 59.21 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Error in round 1: 'float' object is not subscriptable
# Traceback (most recent call last):
#   File "/home/brian_bosho/FP/FP/federated-gnn/src/run.py", line 404, in main_experiment
#     global_results, client_results = run_with_server(
#                                      ^^^^^^^^^^^^^^^^
#   File "/home/brian_bosho/FP/FP/federated-gnn/src/run.py", line 206, in run_with_server
#     results = server.train_clients(i)
#               ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/brian_bosho/FP/FP/federated-gnn/src/server.py", line 148, in train_clients
#     log_client_validation_metrics(eval_results, current_global_epoch)
#   File "/home/brian_bosho/FP/FP/federated-gnn/src/utils/wandb_utils.py", line 72, in log_client_validation_metrics
#     client_val_losses = [to_cpu_scalar(result[0]) for result in val_results]
#                                        ~~~~~~^^^
# TypeError: 'float' object is not subscriptable
# The global test results: []
# The client test results: []
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:3904: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/numpy/_core/_methods.py:147: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/numpy/_core/_methods.py:227: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/numpy/_core/_methods.py:184: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/numpy/_core/_methods.py:219: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# The average global test results: nan
# The average client test results: nan
# The standard deviation global is: nan
# The standard deviation client is: nan
# (FLClient pid=2296560) /home/brian_bosho/FP/FP/federated-gnn/src/train.py:38: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead. [repeated 9x across cluster]
# (FLClient pid=2296560)   scaler = torch.cuda.amp.GradScaler(enabled=use_amp) [repeated 9x across cluster]
# (FLClient pid=2296560) /home/brian_bosho/FP/FP/federated-gnn/src/train.py:55: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead. [repeated 9x across cluster]
# (FLClient pid=2296560)   with torch.cuda.amp.autocast(enabled=use_amp): [repeated 9x across cluster]
# (FLClient pid=2296560) 2025-10-21 13:33:28,795 - INFO - Epoch   2| Train Loss: 3.295| Train Accuracy: 0.196| Val Loss: 3.660| Val Accuracy: 0.038 [repeated 27x across cluster]
# Cleaning up Ray processes and memory...
# 2025-10-21 13:33:34,551	INFO worker.py:1807 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# Results saved to /home/brian_bosho/FP/FP/federated-gnn/results/ogbn-arxiv2/ogbn-arxiv_full_GCN_beta10000_clients10/results_ogbn-arxiv_full_GCN_beta10000_clients10_20251021_133304.json
# Training CSV results saved to /home/brian_bosho/FP/FP/federated-gnn/results/ogbn-arxiv2/ogbn-arxiv_full_GCN_beta10000_clients10/training_ogbn-arxiv_full_GCN_beta10000_clients10_20251021_133304.csv
#
# Summary results saved to:
# - Text file: /home/brian_bosho/FP/FP/federated-gnn/results_summary/ogbn-arxiv2/summary_results_20251021_133335.txt
# - JSON file: /home/brian_bosho/FP/FP/federated-gnn/results_summary/ogbn-arxiv2/summary_results_20251021_133335.json
# - Detailed results saved to: /home/brian_bosho/FP/FP/federated-gnn/results/ogbn-arxiv2
#
#
#
# ================================================================================
# EXPERIMENT RESULTS SUMMARY
# ================================================================================
# +------------+---------------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+
# | Dataset    | Data Loading        | Model   |   Beta |   Clients |   Avg Global Result |   Avg Client Result |   client_std_dev |   global_std_dev | Duration   |   Hop | Use PE   |
# +============+=====================+=========+========+===========+=====================+=====================+==================+==================+============+=======+==========+
# | ogbn-arxiv | chebyshev_diffusion | GCN     |  10000 |        10 |                 nan |                 nan |              nan |              nan | 00:01:07   |     1 | True     |
# +------------+---------------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+
# | ogbn-arxiv | full                | GCN     |  10000 |        10 |                 nan |                 nan |              nan |              nan | 00:00:28   |     1 | True     |
# +------------+---------------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+
#
#
# KEY RESULTS:
# --------------------------------------------------------------------------------
# ogbn-arxiv with chebyshev_diffusion using GCN (beta=10000.00, clients=10, hop=1, use_pe=True):
#   - Average Global Result: nan
#   - Average Client Result: nan
#   - Client StdDev: nan
#   - Global StdDev: nan
#   - Experiment Duration: 00:01:07
# --------------------------------------------------------------------------------
# ogbn-arxiv with full using GCN (beta=10000.00, clients=10, hop=1, use_pe=True):
#   - Average Global Result: nan
#   - Average Client Result: nan
#   - Client StdDev: nan
#   - Global StdDev: nan
#   - Experiment Duration: 00:00:28
# --------------------------------------------------------------------------------
# wandb: ⢿ uploading output.log 20.0KB/20.0KB (0.6s)
# wandb: ⢿ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: ⣻ uploading output.log 20.0KB/20.0KB (0.6s)
# wandb: ⣻ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: ⣽ uploading output.log 20.0KB/20.0KB (0.6s)
# wandb: ⣽ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: ⣾ uploading output.log 20.0KB/20.0KB (0.6s)
# wandb: ⣾ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: ⣷ uploading output.log 20.0KB/20.0KB (0.6s)
# wandb: ⣷ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: ⣯ uploading output.log 20.0KB/20.0KB (0.6s)
# wandb: ⣯ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: ⣟ uploading output.log 20.0KB/20.0KB (0.6s)
# wandb: ⣟ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: ⡿ uploading output.log 20.0KB/20.0KB (0.6s)
# wandb: ⡿ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: ⢿ uploading output.log 20.0KB/20.0KB (0.6s)
# wandb: ⢿ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: ⣻ uploading history steps 0-0, summary, console lines 19-116 (0.2s)
# wandb: ⣽ uploading history steps 0-0, summary, console lines 19-116 (0.2s)
# wandb: ⣾ uploading history steps 0-0, summary, console lines 19-116 (0.2s)
# wandb: ⣷ uploading history steps 0-0, summary, console lines 19-116 (0.2s)
# wandb:
# wandb: ⣷ uploading history steps 0-0, summary, console lines 19-116 (0.2s)
# wandb:
# wandb: Run history:
# wandb:  federation/avg_client_train_acc ▁
# wandb: federation/avg_client_train_loss ▁
# wandb:                            round ▁
# wandb:
# wandb: Run summary:
# wandb:  federation/avg_client_train_acc 0.20284
# wandb: federation/avg_client_train_loss 3.65888
# wandb:                            round 0
# wandb:
# wandb: 🚀 View run GCN_ogbn-arxiv_Adam_lr0.001_decay0.0005_beta10000_run1 at: https://wandb.ai/bosho/FGL3-Ogbn-Arxiv2/runs/yg0gtxiu
# wandb: ⭐️ View project at: https://wandb.ai/bosho/FGL3-Ogbn-Arxiv2
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251021_133307-yg0gtxiu/logs
