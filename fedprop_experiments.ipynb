# %%
# !python -m src.experiments.run_experiments --config conf/ablation/ogbn-arxiv_config.yaml

# %%
# !python -m src.experiments.run_experiments --config conf/ablation/cora_gcn_no_pe.yaml

# %%
# !python -m src.experiments.run_experiments --config conf/ablation/ogbn-arxiv_config.yaml

# %%
# !python -m src.experiments.run_experiments --config conf/ablation/ogbn-arxiv_config.yaml
# Out:
# Experiment Configuration:
# - Clients: [5]
# - Rounds: 10
# - Epochs: 3
# - Learning Rate: 0.5
# - Beta values: [1]
# - Datasets: ['ogbn-arxiv']
# - Data Loading Options: ['full']
# - Model Types: ['GCN']
# - Results Directory: /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv
# - Save Detailed Results: False
# - Hop: 2
# - Full Training Flag: False
#
# ================================================================================
# Running experiment: ogbn-arxiv_full_GCN_beta1_clients5
# ================================================================================
# DEVICE: cuda
# Data loading option is full
# Model type is GCN
# 2025-10-07 14:29:29,657	INFO worker.py:1807 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# wandb: Currently logged in as: bosho to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /home/brian_bosho/FP/FP/federated-gnn/wandb/run-20251007_142931-v9d8vapy
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run lively-universe-562
# wandb: ⭐️ View project at https://wandb.ai/bosho/FGL3
# wandb: 🚀 View run at https://wandb.ai/bosho/FGL3/runs/v9d8vapy
# [WANDB DEBUG] Successfully initialized wandb run: lively-universe-562
# Wandb config is set to: {'dataset': 'ogbn-arxiv', 'model': 'GCN', 'data_loading': 'full', 'num_clients': [5], 'num_rounds': 10, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 2, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': 64, 'pe_P': 16, 'normalize': 'qr', 'run_index': 1, 'num_iterations': 80}
# {'dataset': 'ogbn-arxiv', 'model': 'GCN', 'data_loading': 'full', 'num_clients': [5], 'num_rounds': 10, 'epochs': 3, 'beta': 1, 'lr': 0.5, 'optimizer': 'SGD', 'decay': 0.0005, 'hop': 2, 'fulltraining_flag': False, 'use_pe': False, 'pe_r': 64, 'pe_P': 16, 'normalize': 'qr', 'run_index': 1, 'num_iterations': 80}
# data_loading_option: full
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/ogb/nodeproppred/dataset_pyg.py:69: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.data, self.slices = torch.load(self.processed_paths[0])
# Tolerance: 1e-6
# (raylet) [2025-10-07 14:29:39,552 E 2321841 2321871] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2025-10-07_14-29-28_461041_2321588 is over 95% full, available space: 30250209280; capacity: 1622224654336. Object creation will fail if spilling is required.
# partition_time_s: 9.31
# client[0] device: cuda:0 cuda:0
# client[0] feature_dim: 128
# config.use_pe: False num_iterations: 80 feature_prop_device: cpu
# data_loading_option: full hop: 2 num_clients: 5
#
# === DATA LOADING SUMMARY ===
# Full graph: 169343 nodes, 2484941 edges
# Number of client subgraphs: 5
# First client subgraph shape: torch.Size([157871, 128])
# Dataset: PygNodePropPredDataset()
# Device: cuda
#
# Full graph device (before): cuda:0
# Full graph staying on CPU to save GPU memory
# ===========================
#
# Model is GCN_arxiv(
#   (convs): ModuleList(
#     (0): GCNConv(128, 256)
#     (1): GCNConv(256, 256)
#     (2): GCNConv(256, 40)
#   )
#   (bns): ModuleList(
#     (0-1): 2 x BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
#
# === CLIENT DATA LOADING ===
# Full graph size: 169343 nodes
# Number of clients: 5
# Client 0 subgraph: 157871 nodes, 128 features
# Client 1 subgraph: 158579 nodes, 128 features
# Client 2 subgraph: 151795 nodes, 128 features
# Client 3 subgraph: 162112 nodes, 128 features
# Client 4 subgraph: 160370 nodes, 128 features
# ===========================
#
# Input dim of the model in server: 128
# (FLClient pid=2321929)
# (FLClient pid=2321929) [Client 0] Initializing with:
# (FLClient pid=2321929)   - Input data nodes: 157871
# (FLClient pid=2321929)   - Input data edges: 2433305
# (FLClient pid=2321929)   - Feature shape: torch.Size([157871, 128])
# (FLClient pid=2321929)   - Data device (before moving): cuda:0
# (FLClient pid=2321929)   - Input dim: 128
# (FLClient pid=2321929)   - Data device (after moving): cuda:0
# (FLClient pid=2321929) Client 0: Using full-batch training for ogbn-arxiv dataset
# (FLClient pid=2321929) /home/brian_bosho/FP/FP/federated-gnn/src/train.py:38: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
# (FLClient pid=2321929)   scaler = torch.cuda.amp.GradScaler(enabled=use_amp)
# (FLClient pid=2321929) /home/brian_bosho/FP/FP/federated-gnn/src/train.py:55: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# (FLClient pid=2321929)   with torch.cuda.amp.autocast(enabled=use_amp):
# (FLClient pid=2321933)
# (FLClient pid=2321929) 2025-10-07 14:29:47,697 - INFO - Epoch   0| Train Loss: 4.171| Train Accuracy: 0.016| Val Loss: 3.594| Val Accuracy: 0.126
# (FLClient pid=2321929) 2025-10-07 14:29:47,853 - INFO - Epoch   1| Train Loss: 2.629| Train Accuracy: 0.408| Val Loss: 3.533| Val Accuracy: 0.429
# (FLClient pid=2321943)
# (FLClient pid=2321929) 2025-10-07 14:29:48,103 - INFO - Epoch   2| Train Loss: 2.156| Train Accuracy: 0.528| Val Loss: 3.526| Val Accuracy: 0.365
# (FLClient pid=2321940)
# (FLClient pid=2321949)
# (raylet) [2025-10-07 14:29:49,558 E 2321841 2321871] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2025-10-07_14-29-28_461041_2321588 is over 95% full, available space: 30249906176; capacity: 1622224654336. Object creation will fail if spilling is required.
# (FLClient pid=2321929) Error in client 0 training: CUDA out of memory. Tried to allocate 2.32 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.47 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2321588 has 4.18 GiB memory in use. Including non-PyTorch memory, this process has 5.67 GiB memory in use. Process 2321933 has 5.70 GiB memory in use. Process 2321943 has 7.89 GiB memory in use. Process 2321940 has 8.15 GiB memory in use. Process 2321949 has 8.06 GiB memory in use. Of the allocated memory 3.18 GiB is allocated by PyTorch, and 1.99 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2321929) Traceback (most recent call last):
# (FLClient pid=2321929)   File "/home/brian_bosho/FP/FP/federated-gnn/src/client.py", line 138, in train_client
# (FLClient pid=2321929)     loss, acc, loss_list, acc_list = train(
# (FLClient pid=2321929)                                      ^^^^^^
# (FLClient pid=2321929)   File "/home/brian_bosho/FP/FP/federated-gnn/src/train.py", line 59, in train
# (FLClient pid=2321929)     output = model(data.x, data.edge_index)
# (FLClient pid=2321929)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=2321929)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
# (FLClient pid=2321929)     return self._call_impl(*args, **kwargs)
# (FLClient pid=2321929)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=2321929)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
# (FLClient pid=2321929)     return forward_call(*args, **kwargs)
# (FLClient pid=2321929)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=2321929)   File "/home/brian_bosho/FP/FP/federated-gnn/src/models.py", line 85, in forward
# (FLClient pid=2321929)     x = self.convs[1](x, adj_t)
# (FLClient pid=2321929)         ^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=2321929)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
# (FLClient pid=2321929)     return self._call_impl(*args, **kwargs)
# (FLClient pid=2321929)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=2321929)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
# (FLClient pid=2321929)     return forward_call(*args, **kwargs)
# (FLClient pid=2321929)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=2321929)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch_geometric/nn/conv/gcn_conv.py", line 263, in forward
# (FLClient pid=2321929)     out = self.propagate(edge_index, x=x, edge_weight=edge_weight)
# (FLClient pid=2321929)           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=2321929)   File "/tmp/torch_geometric.nn.conv.gcn_conv_GCNConv_propagate_mdp83x1_.py", line 209, in propagate
# (FLClient pid=2321929)     out = self.message(
# (FLClient pid=2321929)           ^^^^^^^^^^^^^
# (FLClient pid=2321929)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch_geometric/nn/conv/gcn_conv.py", line 271, in message
# (FLClient pid=2321929)     return x_j if edge_weight is None else edge_weight.view(-1, 1) * x_j
# (FLClient pid=2321929)                                            ~~~~~~~~~~~~~~~~~~~~~~~~^~~~~
# (FLClient pid=2321929) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.32 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.47 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2321588 has 4.18 GiB memory in use. Including non-PyTorch memory, this process has 5.67 GiB memory in use. Process 2321933 has 5.70 GiB memory in use. Process 2321943 has 7.89 GiB memory in use. Process 2321940 has 8.15 GiB memory in use. Process 2321949 has 8.06 GiB memory in use. Of the allocated memory 3.18 GiB is allocated by PyTorch, and 1.99 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2321929)
# (FLClient pid=2321933) Error in client 1 training: CUDA out of memory. Tried to allocate 2.33 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.48 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2321588 has 4.18 GiB memory in use. Process 2321929 has 5.67 GiB memory in use. Including non-PyTorch memory, this process has 5.68 GiB memory in use. Process 2321943 has 7.89 GiB memory in use. Process 2321940 has 8.15 GiB memory in use. Process 2321949 has 8.06 GiB memory in use. Of the allocated memory 3.19 GiB is allocated by PyTorch, and 1.99 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2321933) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.33 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.48 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2321588 has 4.18 GiB memory in use. Process 2321929 has 5.67 GiB memory in use. Including non-PyTorch memory, this process has 5.68 GiB memory in use. Process 2321943 has 7.89 GiB memory in use. Process 2321940 has 8.15 GiB memory in use. Process 2321949 has 8.06 GiB memory in use. Of the allocated memory 3.19 GiB is allocated by PyTorch, and 1.99 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2321933)
# (FLClient pid=2321949) /home/brian_bosho/FP/FP/federated-gnn/src/train.py:38: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead. [repeated 4x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (FLClient pid=2321949)   scaler = torch.cuda.amp.GradScaler(enabled=use_amp) [repeated 4x across cluster]
# (FLClient pid=2321949) /home/brian_bosho/FP/FP/federated-gnn/src/train.py:55: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead. [repeated 4x across cluster]
# (FLClient pid=2321949)   with torch.cuda.amp.autocast(enabled=use_amp): [repeated 4x across cluster]
# (FLClient pid=2321943) 2025-10-07 14:29:52,844 - INFO - Epoch   2| Train Loss: 1.611| Train Accuracy: 0.566| Val Loss: 3.396| Val Accuracy: 0.365 [repeated 19x across cluster]
# (FLClient pid=2321943) Error in client 2 training: CUDA out of memory. Tried to allocate 2.29 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.46 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2321588 has 4.18 GiB memory in use. Process 2321929 has 8.01 GiB memory in use. Process 2321933 has 8.03 GiB memory in use. Including non-PyTorch memory, this process has 5.57 GiB memory in use. Process 2321940 has 8.15 GiB memory in use. Process 2321949 has 5.72 GiB memory in use. Of the allocated memory 3.12 GiB is allocated by PyTorch, and 1.95 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2321943) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.29 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.46 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2321588 has 4.18 GiB memory in use. Process 2321929 has 8.01 GiB memory in use. Process 2321933 has 8.03 GiB memory in use. Including non-PyTorch memory, this process has 5.57 GiB memory in use. Process 2321940 has 8.15 GiB memory in use. Process 2321949 has 5.72 GiB memory in use. Of the allocated memory 3.12 GiB is allocated by PyTorch, and 1.95 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2321943)
# (FLClient pid=2321949) [Client 4] Initializing with: [repeated 4x across cluster]
# (FLClient pid=2321949)   - Input data nodes: 160370 [repeated 4x across cluster]
# (FLClient pid=2321949)   - Input data edges: 2447458 [repeated 4x across cluster]
# (FLClient pid=2321949)   - Feature shape: torch.Size([160370, 128]) [repeated 4x across cluster]
# (FLClient pid=2321949)   - Data device (before moving): cuda:0 [repeated 4x across cluster]
# (FLClient pid=2321949)   - Input dim: 128 [repeated 4x across cluster]
# (FLClient pid=2321949)   - Data device (after moving): cuda:0 [repeated 4x across cluster]
# (FLClient pid=2321949) Client 4: Using full-batch training for ogbn-arxiv dataset [repeated 4x across cluster]
# (FLClient pid=2321949) Error in client 4 training: CUDA out of memory. Tried to allocate 2.34 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.49 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2321588 has 4.18 GiB memory in use. Process 2321929 has 8.01 GiB memory in use. Process 2321933 has 8.03 GiB memory in use. Process 2321943 has 5.57 GiB memory in use. Process 2321940 has 8.15 GiB memory in use. Including non-PyTorch memory, this process has 5.69 GiB memory in use. Of the allocated memory 3.21 GiB is allocated by PyTorch, and 1.98 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2321949)   File "/tmp/torch_geometric.nn.conv.gcn_conv_GCNConv_propagate_bfk_bbhu.py", line 209, in propagate
# (FLClient pid=2321949) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.34 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.49 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2321588 has 4.18 GiB memory in use. Process 2321929 has 8.01 GiB memory in use. Process 2321933 has 8.03 GiB memory in use. Process 2321943 has 5.57 GiB memory in use. Process 2321940 has 8.15 GiB memory in use. Including non-PyTorch memory, this process has 5.69 GiB memory in use. Of the allocated memory 3.21 GiB is allocated by PyTorch, and 1.98 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2321949)
# (FLClient pid=2321929) Error in client 0 training: CUDA out of memory. Tried to allocate 2.32 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.46 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2321588 has 4.18 GiB memory in use. Including non-PyTorch memory, this process has 5.67 GiB memory in use. Process 2321933 has 5.68 GiB memory in use. Process 2321943 has 7.89 GiB memory in use. Process 2321940 has 8.15 GiB memory in use. Process 2321949 has 8.06 GiB memory in use. Of the allocated memory 3.18 GiB is allocated by PyTorch, and 1.99 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2321929) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.32 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.46 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2321588 has 4.18 GiB memory in use. Including non-PyTorch memory, this process has 5.67 GiB memory in use. Process 2321933 has 5.68 GiB memory in use. Process 2321943 has 7.89 GiB memory in use. Process 2321940 has 8.15 GiB memory in use. Process 2321949 has 8.06 GiB memory in use. Of the allocated memory 3.18 GiB is allocated by PyTorch, and 1.99 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2321929)
# (FLClient pid=2321929) Traceback (most recent call last): [repeated 4x across cluster]
# (FLClient pid=2321929)   File "/home/brian_bosho/FP/FP/federated-gnn/src/client.py", line 138, in train_client [repeated 4x across cluster]
# (FLClient pid=2321929)     loss, acc, loss_list, acc_list = train( [repeated 4x across cluster]
# (FLClient pid=2321929)                                      ^^^^^^ [repeated 4x across cluster]
# (FLClient pid=2321929)   File "/home/brian_bosho/FP/FP/federated-gnn/src/train.py", line 59, in train [repeated 4x across cluster]
# (FLClient pid=2321929)     output = model(data.x, data.edge_index) [repeated 4x across cluster]
# (FLClient pid=2321929)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 4x across cluster]
# (FLClient pid=2321929)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl [repeated 8x across cluster]
# (FLClient pid=2321929)     return self._call_impl(*args, **kwargs) [repeated 8x across cluster]
# (FLClient pid=2321929)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 8x across cluster]
# (FLClient pid=2321929)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl [repeated 8x across cluster]
# (FLClient pid=2321929)     return forward_call(*args, **kwargs) [repeated 8x across cluster]
# (FLClient pid=2321929)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 8x across cluster]
# (FLClient pid=2321929)   File "/home/brian_bosho/FP/FP/federated-gnn/src/models.py", line 85, in forward [repeated 4x across cluster]
# (FLClient pid=2321929)     x = self.convs[1](x, adj_t) [repeated 4x across cluster]
# (FLClient pid=2321929)         ^^^^^^^^^^^^^^^^^^^^^^^ [repeated 4x across cluster]
# (FLClient pid=2321929)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch_geometric/nn/conv/gcn_conv.py", line 263, in forward [repeated 4x across cluster]
# (FLClient pid=2321929)     out = self.propagate(edge_index, x=x, edge_weight=edge_weight) [repeated 4x across cluster]
# (FLClient pid=2321929)           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 4x across cluster]
# (FLClient pid=2321929)   File "/tmp/torch_geometric.nn.conv.gcn_conv_GCNConv_propagate_mdp83x1_.py", line 209, in propagate [repeated 3x across cluster]
# (FLClient pid=2321929)     out = self.message( [repeated 4x across cluster]
# (FLClient pid=2321929)           ^^^^^^^^^^^^^ [repeated 4x across cluster]
# (FLClient pid=2321929)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch_geometric/nn/conv/gcn_conv.py", line 271, in message [repeated 4x across cluster]
# (FLClient pid=2321929)     return x_j if edge_weight is None else edge_weight.view(-1, 1) * x_j [repeated 4x across cluster]
# (FLClient pid=2321929)                                            ~~~~~~~~~~~~~~~~~~~~~~~~^~~~~ [repeated 4x across cluster]
# (FLClient pid=2321933) Error in client 1 training: CUDA out of memory. Tried to allocate 2.33 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.48 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2321588 has 4.18 GiB memory in use. Process 2321929 has 5.67 GiB memory in use. Including non-PyTorch memory, this process has 5.68 GiB memory in use. Process 2321943 has 7.89 GiB memory in use. Process 2321940 has 8.15 GiB memory in use. Process 2321949 has 8.06 GiB memory in use. Of the allocated memory 3.19 GiB is allocated by PyTorch, and 1.99 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2321933) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.33 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.48 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2321588 has 4.18 GiB memory in use. Process 2321929 has 5.67 GiB memory in use. Including non-PyTorch memory, this process has 5.68 GiB memory in use. Process 2321943 has 7.89 GiB memory in use. Process 2321940 has 8.15 GiB memory in use. Process 2321949 has 8.06 GiB memory in use. Of the allocated memory 3.19 GiB is allocated by PyTorch, and 1.99 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2321933)
# (FLClient pid=2321943) 2025-10-07 14:29:58,022 - INFO - Epoch   1| Train Loss: 1.444| Train Accuracy: 0.659| Val Loss: 3.320| Val Accuracy: 0.142 [repeated 15x across cluster]
# (raylet) [2025-10-07 14:29:59,564 E 2321841 2321871] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2025-10-07_14-29-28_461041_2321588 is over 95% full, available space: 30249766912; capacity: 1622224654336. Object creation will fail if spilling is required.
# (FLClient pid=2321940) Error in client 3 training: CUDA out of memory. Tried to allocate 2.34 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.51 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2321588 has 4.18 GiB memory in use. Process 2321929 has 8.01 GiB memory in use. Process 2321933 has 8.03 GiB memory in use. Process 2321943 has 7.90 GiB memory in use. Including non-PyTorch memory, this process has 5.81 GiB memory in use. Process 2321949 has 5.69 GiB memory in use. Of the allocated memory 3.22 GiB is allocated by PyTorch, and 2.08 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2321940) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.34 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.51 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2321588 has 4.18 GiB memory in use. Process 2321929 has 8.01 GiB memory in use. Process 2321933 has 8.03 GiB memory in use. Process 2321943 has 7.90 GiB memory in use. Including non-PyTorch memory, this process has 5.81 GiB memory in use. Process 2321949 has 5.69 GiB memory in use. Of the allocated memory 3.22 GiB is allocated by PyTorch, and 2.08 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2321940)
# (FLClient pid=2321949) Error in client 4 training: CUDA out of memory. Tried to allocate 2.34 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.51 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2321588 has 4.18 GiB memory in use. Process 2321929 has 8.01 GiB memory in use. Process 2321933 has 8.03 GiB memory in use. Process 2321943 has 7.90 GiB memory in use. Process 2321940 has 5.81 GiB memory in use. Including non-PyTorch memory, this process has 5.69 GiB memory in use. Of the allocated memory 3.21 GiB is allocated by PyTorch, and 1.98 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2321949)   File "/tmp/torch_geometric.nn.conv.gcn_conv_GCNConv_propagate_bfk_bbhu.py", line 209, in propagate
# (FLClient pid=2321949) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.34 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.51 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2321588 has 4.18 GiB memory in use. Process 2321929 has 8.01 GiB memory in use. Process 2321933 has 8.03 GiB memory in use. Process 2321943 has 7.90 GiB memory in use. Process 2321940 has 5.81 GiB memory in use. Including non-PyTorch memory, this process has 5.69 GiB memory in use. Of the allocated memory 3.21 GiB is allocated by PyTorch, and 1.98 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2321949)
# (FLClient pid=2321943) Error in client 2 training: CUDA out of memory. Tried to allocate 2.29 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.46 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2321588 has 4.18 GiB memory in use. Process 2321929 has 8.01 GiB memory in use. Process 2321933 has 8.03 GiB memory in use. Including non-PyTorch memory, this process has 5.57 GiB memory in use. Process 2321940 has 8.15 GiB memory in use. Process 2321949 has 5.69 GiB memory in use. Of the allocated memory 3.12 GiB is allocated by PyTorch, and 1.95 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2321943) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.29 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.46 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2321588 has 4.18 GiB memory in use. Process 2321929 has 8.01 GiB memory in use. Process 2321933 has 8.03 GiB memory in use. Including non-PyTorch memory, this process has 5.57 GiB memory in use. Process 2321940 has 8.15 GiB memory in use. Process 2321949 has 5.69 GiB memory in use. Of the allocated memory 3.12 GiB is allocated by PyTorch, and 1.95 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2321943)
# (FLClient pid=2321943) Traceback (most recent call last): [repeated 4x across cluster]
# (FLClient pid=2321943)   File "/home/brian_bosho/FP/FP/federated-gnn/src/client.py", line 138, in train_client [repeated 4x across cluster]
# (FLClient pid=2321943)     loss, acc, loss_list, acc_list = train( [repeated 4x across cluster]
# (FLClient pid=2321943)                                      ^^^^^^ [repeated 4x across cluster]
# (FLClient pid=2321943)   File "/home/brian_bosho/FP/FP/federated-gnn/src/train.py", line 59, in train [repeated 4x across cluster]
# (FLClient pid=2321943)     output = model(data.x, data.edge_index) [repeated 4x across cluster]
# (FLClient pid=2321943)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 4x across cluster]
# (FLClient pid=2321943)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl [repeated 8x across cluster]
# (FLClient pid=2321943)     return self._call_impl(*args, **kwargs) [repeated 8x across cluster]
# (FLClient pid=2321943)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 8x across cluster]
# (FLClient pid=2321943)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl [repeated 8x across cluster]
# (FLClient pid=2321943)     return forward_call(*args, **kwargs) [repeated 8x across cluster]
# (FLClient pid=2321943)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 8x across cluster]
# (FLClient pid=2321943)   File "/home/brian_bosho/FP/FP/federated-gnn/src/models.py", line 85, in forward [repeated 4x across cluster]
# (FLClient pid=2321943)     x = self.convs[1](x, adj_t) [repeated 4x across cluster]
# (FLClient pid=2321943)         ^^^^^^^^^^^^^^^^^^^^^^^ [repeated 4x across cluster]
# (FLClient pid=2321943)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch_geometric/nn/conv/gcn_conv.py", line 263, in forward [repeated 4x across cluster]
# (FLClient pid=2321943)     out = self.propagate(edge_index, x=x, edge_weight=edge_weight) [repeated 4x across cluster]
# (FLClient pid=2321943)           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 4x across cluster]
# (FLClient pid=2321943)   File "/tmp/torch_geometric.nn.conv.gcn_conv_GCNConv_propagate_hvdo33i0.py", line 209, in propagate [repeated 3x across cluster]
# (FLClient pid=2321943)     out = self.message( [repeated 4x across cluster]
# (FLClient pid=2321943)           ^^^^^^^^^^^^^ [repeated 4x across cluster]
# (FLClient pid=2321943)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch_geometric/nn/conv/gcn_conv.py", line 271, in message [repeated 4x across cluster]
# (FLClient pid=2321943)     return x_j if edge_weight is None else edge_weight.view(-1, 1) * x_j [repeated 4x across cluster]
# (FLClient pid=2321943)                                            ~~~~~~~~~~~~~~~~~~~~~~~~^~~~~ [repeated 4x across cluster]
# (FLClient pid=2321949) Error in client 4 training: CUDA out of memory. Tried to allocate 2.34 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.50 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2321588 has 4.18 GiB memory in use. Process 2321929 has 8.01 GiB memory in use. Process 2321933 has 8.03 GiB memory in use. Process 2321943 has 5.57 GiB memory in use. Process 2321940 has 8.15 GiB memory in use. Including non-PyTorch memory, this process has 5.69 GiB memory in use. Of the allocated memory 3.21 GiB is allocated by PyTorch, and 1.98 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2321949)   File "/tmp/torch_geometric.nn.conv.gcn_conv_GCNConv_propagate_bfk_bbhu.py", line 209, in propagate
# (FLClient pid=2321949) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.34 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.50 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2321588 has 4.18 GiB memory in use. Process 2321929 has 8.01 GiB memory in use. Process 2321933 has 8.03 GiB memory in use. Process 2321943 has 5.57 GiB memory in use. Process 2321940 has 8.15 GiB memory in use. Including non-PyTorch memory, this process has 5.69 GiB memory in use. Of the allocated memory 3.21 GiB is allocated by PyTorch, and 1.98 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2321949)
# (FLClient pid=2321929) 2025-10-07 14:30:03,383 - INFO - Epoch   0| Train Loss: 1.686| Train Accuracy: 0.583| Val Loss: 3.206| Val Accuracy: 0.414 [repeated 15x across cluster]
# (FLClient pid=2321929) Error in client 0 training: CUDA out of memory. Tried to allocate 2.32 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.42 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2321588 has 4.18 GiB memory in use. Including non-PyTorch memory, this process has 5.67 GiB memory in use. Process 2321933 has 8.03 GiB memory in use. Process 2321943 has 5.57 GiB memory in use. Process 2321940 has 8.15 GiB memory in use. Process 2321949 has 8.06 GiB memory in use. Of the allocated memory 3.18 GiB is allocated by PyTorch, and 1.99 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2321929) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.32 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.42 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2321588 has 4.18 GiB memory in use. Including non-PyTorch memory, this process has 5.67 GiB memory in use. Process 2321933 has 8.03 GiB memory in use. Process 2321943 has 5.57 GiB memory in use. Process 2321940 has 8.15 GiB memory in use. Process 2321949 has 8.06 GiB memory in use. Of the allocated memory 3.18 GiB is allocated by PyTorch, and 1.99 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2321929)
# (FLClient pid=2321943) Error in client 2 training: CUDA out of memory. Tried to allocate 2.29 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.46 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2321588 has 4.18 GiB memory in use. Process 2321929 has 5.67 GiB memory in use. Process 2321933 has 8.03 GiB memory in use. Including non-PyTorch memory, this process has 5.57 GiB memory in use. Process 2321940 has 8.15 GiB memory in use. Process 2321949 has 8.06 GiB memory in use. Of the allocated memory 3.12 GiB is allocated by PyTorch, and 1.95 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2321943) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.29 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.46 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2321588 has 4.18 GiB memory in use. Process 2321929 has 5.67 GiB memory in use. Process 2321933 has 8.03 GiB memory in use. Including non-PyTorch memory, this process has 5.57 GiB memory in use. Process 2321940 has 8.15 GiB memory in use. Process 2321949 has 8.06 GiB memory in use. Of the allocated memory 3.12 GiB is allocated by PyTorch, and 1.95 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2321943)
# (FLClient pid=2321933) Error in client 1 training: CUDA out of memory. Tried to allocate 2.33 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.43 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2321588 has 4.18 GiB memory in use. Process 2321929 has 8.01 GiB memory in use. Including non-PyTorch memory, this process has 5.68 GiB memory in use. Process 2321943 has 5.57 GiB memory in use. Process 2321940 has 8.15 GiB memory in use. Process 2321949 has 8.06 GiB memory in use. Of the allocated memory 3.19 GiB is allocated by PyTorch, and 1.99 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2321933) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.33 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.43 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2321588 has 4.18 GiB memory in use. Process 2321929 has 8.01 GiB memory in use. Including non-PyTorch memory, this process has 5.68 GiB memory in use. Process 2321943 has 5.57 GiB memory in use. Process 2321940 has 8.15 GiB memory in use. Process 2321949 has 8.06 GiB memory in use. Of the allocated memory 3.19 GiB is allocated by PyTorch, and 1.99 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2321933)
# (FLClient pid=2321933) Traceback (most recent call last): [repeated 4x across cluster]
# (FLClient pid=2321933)   File "/home/brian_bosho/FP/FP/federated-gnn/src/client.py", line 138, in train_client [repeated 4x across cluster]
# (FLClient pid=2321933)     loss, acc, loss_list, acc_list = train( [repeated 4x across cluster]
# (FLClient pid=2321933)                                      ^^^^^^ [repeated 4x across cluster]
# (FLClient pid=2321933)   File "/home/brian_bosho/FP/FP/federated-gnn/src/train.py", line 59, in train [repeated 4x across cluster]
# (FLClient pid=2321933)     output = model(data.x, data.edge_index) [repeated 4x across cluster]
# (FLClient pid=2321933)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 4x across cluster]
# (FLClient pid=2321933)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl [repeated 8x across cluster]
# (FLClient pid=2321933)     return self._call_impl(*args, **kwargs) [repeated 8x across cluster]
# (FLClient pid=2321933)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 8x across cluster]
# (FLClient pid=2321933)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl [repeated 8x across cluster]
# (FLClient pid=2321933)     return forward_call(*args, **kwargs) [repeated 8x across cluster]
# (FLClient pid=2321933)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 8x across cluster]
# (FLClient pid=2321933)   File "/home/brian_bosho/FP/FP/federated-gnn/src/models.py", line 85, in forward [repeated 4x across cluster]
# (FLClient pid=2321933)     x = self.convs[1](x, adj_t) [repeated 4x across cluster]
# (FLClient pid=2321933)         ^^^^^^^^^^^^^^^^^^^^^^^ [repeated 4x across cluster]
# (FLClient pid=2321933)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch_geometric/nn/conv/gcn_conv.py", line 263, in forward [repeated 4x across cluster]
# (FLClient pid=2321933)     out = self.propagate(edge_index, x=x, edge_weight=edge_weight) [repeated 4x across cluster]
# (FLClient pid=2321933)           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 4x across cluster]
# (FLClient pid=2321933)   File "/tmp/torch_geometric.nn.conv.gcn_conv_GCNConv_propagate_q18ugvtu.py", line 209, in propagate [repeated 3x across cluster]
# (FLClient pid=2321933)     out = self.message( [repeated 4x across cluster]
# (FLClient pid=2321933)           ^^^^^^^^^^^^^ [repeated 4x across cluster]
# (FLClient pid=2321933)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch_geometric/nn/conv/gcn_conv.py", line 271, in message [repeated 4x across cluster]
# (FLClient pid=2321933)     return x_j if edge_weight is None else edge_weight.view(-1, 1) * x_j [repeated 4x across cluster]
# (FLClient pid=2321933)                                            ~~~~~~~~~~~~~~~~~~~~~~~~^~~~~ [repeated 4x across cluster]
# (FLClient pid=2321943) Error in client 2 training: CUDA out of memory. Tried to allocate 2.29 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.47 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2321588 has 4.18 GiB memory in use. Process 2321929 has 8.01 GiB memory in use. Process 2321933 has 5.68 GiB memory in use. Including non-PyTorch memory, this process has 5.57 GiB memory in use. Process 2321940 has 8.15 GiB memory in use. Process 2321949 has 8.06 GiB memory in use. Of the allocated memory 3.12 GiB is allocated by PyTorch, and 1.95 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2321943) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.29 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.47 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2321588 has 4.18 GiB memory in use. Process 2321929 has 8.01 GiB memory in use. Process 2321933 has 5.68 GiB memory in use. Including non-PyTorch memory, this process has 5.57 GiB memory in use. Process 2321940 has 8.15 GiB memory in use. Process 2321949 has 8.06 GiB memory in use. Of the allocated memory 3.12 GiB is allocated by PyTorch, and 1.95 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2321943)
# (FLClient pid=2321929) 2025-10-07 14:30:09,394 - INFO - Epoch   0| Train Loss: 1.644| Train Accuracy: 0.579| Val Loss: 3.060| Val Accuracy: 0.400 [repeated 18x across cluster]
# (raylet) [2025-10-07 14:30:09,576 E 2321841 2321871] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2025-10-07_14-29-28_461041_2321588 is over 95% full, available space: 30249623552; capacity: 1622224654336. Object creation will fail if spilling is required.
# (FLClient pid=2321933) Error in client 1 training: CUDA out of memory. Tried to allocate 2.33 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.48 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2321588 has 4.18 GiB memory in use. Process 2321929 has 8.01 GiB memory in use. Including non-PyTorch memory, this process has 5.68 GiB memory in use. Process 2321943 has 7.90 GiB memory in use. Process 2321940 has 5.81 GiB memory in use. Process 2321949 has 8.06 GiB memory in use. Of the allocated memory 3.19 GiB is allocated by PyTorch, and 1.99 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2321933) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.33 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.48 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2321588 has 4.18 GiB memory in use. Process 2321929 has 8.01 GiB memory in use. Including non-PyTorch memory, this process has 5.68 GiB memory in use. Process 2321943 has 7.90 GiB memory in use. Process 2321940 has 5.81 GiB memory in use. Process 2321949 has 8.06 GiB memory in use. Of the allocated memory 3.19 GiB is allocated by PyTorch, and 1.99 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2321933)
# (FLClient pid=2321940) Error in client 3 training: CUDA out of memory. Tried to allocate 2.34 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.46 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2321588 has 4.18 GiB memory in use. Process 2321929 has 8.01 GiB memory in use. Process 2321933 has 5.70 GiB memory in use. Process 2321943 has 7.90 GiB memory in use. Including non-PyTorch memory, this process has 5.81 GiB memory in use. Process 2321949 has 8.06 GiB memory in use. Of the allocated memory 3.22 GiB is allocated by PyTorch, and 2.08 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# ...
# (FLClient pid=2321933)   File "/home/brian_bosho/FP/FP/federated-gnn/src/models.py", line 85, in forward [repeated 4x across cluster]
# (FLClient pid=2321933)     x = self.convs[1](x, adj_t) [repeated 4x across cluster]
# (FLClient pid=2321933)         ^^^^^^^^^^^^^^^^^^^^^^^ [repeated 4x across cluster]
# (FLClient pid=2321933)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch_geometric/nn/conv/gcn_conv.py", line 263, in forward [repeated 4x across cluster]
# (FLClient pid=2321933)     out = self.propagate(edge_index, x=x, edge_weight=edge_weight) [repeated 4x across cluster]
# (FLClient pid=2321933)           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 4x across cluster]
# (FLClient pid=2321933)   File "/tmp/torch_geometric.nn.conv.gcn_conv_GCNConv_propagate_q18ugvtu.py", line 209, in propagate [repeated 4x across cluster]
# (FLClient pid=2321933)     out = self.message( [repeated 4x across cluster]
# (FLClient pid=2321933)           ^^^^^^^^^^^^^ [repeated 4x across cluster]
# (FLClient pid=2321933)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch_geometric/nn/conv/gcn_conv.py", line 271, in message [repeated 4x across cluster]
# (FLClient pid=2321933)     return x_j if edge_weight is None else edge_weight.view(-1, 1) * x_j [repeated 4x across cluster]
# (FLClient pid=2321933)                                            ~~~~~~~~~~~~~~~~~~~~~~~~^~~~~ [repeated 4x across cluster]
# (FLClient pid=2321943) Error in client 2 training: CUDA out of memory. Tried to allocate 2.29 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.47 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2321588 has 4.18 GiB memory in use. Process 2321929 has 8.01 GiB memory in use. Process 2321933 has 5.68 GiB memory in use. Including non-PyTorch memory, this process has 5.57 GiB memory in use. Process 2321940 has 8.15 GiB memory in use. Process 2321949 has 8.06 GiB memory in use. Of the allocated memory 3.12 GiB is allocated by PyTorch, and 1.95 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2321943) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.29 GiB. GPU 0 has a total capacity of 47.71 GiB of which 1.47 GiB is free. Process 2161049 has 1.58 GiB memory in use. Process 2321588 has 4.18 GiB memory in use. Process 2321929 has 8.01 GiB memory in use. Process 2321933 has 5.68 GiB memory in use. Including non-PyTorch memory, this process has 5.57 GiB memory in use. Process 2321940 has 8.15 GiB memory in use. Process 2321949 has 8.06 GiB memory in use. Of the allocated memory 3.12 GiB is allocated by PyTorch, and 1.95 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (FLClient pid=2321943)
# (FLClient pid=2321929) 2025-10-07 14:30:15,404 - INFO - Epoch   0| Train Loss: 1.430| Train Accuracy: 0.634| Val Loss: 2.856| Val Accuracy: 0.428 [repeated 18x across cluster]
# training_time_s: 33.24
# Training done
# Round 1
# Train Loss: 3.526, Train Accuracy: 0.528
# Train Loss: 3.545, Train Accuracy: 0.482
# Train Loss: 3.442, Train Accuracy: 0.580
# Train Loss: 3.542, Train Accuracy: 0.408
# Train Loss: 3.542, Train Accuracy: 0.505
# Round 2
# Train Loss: 0.000, Train Accuracy: 0.000
# Train Loss: 0.000, Train Accuracy: 0.000
# Train Loss: 3.396, Train Accuracy: 0.566
# Train Loss: 3.414, Train Accuracy: 0.490
# Train Loss: 3.434, Train Accuracy: 0.601
# Round 3
# Train Loss: 3.317, Train Accuracy: 0.615
# Train Loss: 3.429, Train Accuracy: 0.544
# Train Loss: 0.000, Train Accuracy: 0.000
# Train Loss: 3.343, Train Accuracy: 0.529
# Train Loss: 0.000, Train Accuracy: 0.000
# Round 4
# Train Loss: 0.000, Train Accuracy: 0.000
# Train Loss: 0.000, Train Accuracy: 0.000
# Train Loss: 3.134, Train Accuracy: 0.665
# Train Loss: 3.285, Train Accuracy: 0.594
# Train Loss: 3.299, Train Accuracy: 0.626
# Round 5
# Train Loss: 3.202, Train Accuracy: 0.652
# Train Loss: 3.296, Train Accuracy: 0.580
# Train Loss: 3.054, Train Accuracy: 0.696
# Train Loss: 0.000, Train Accuracy: 0.000
# Train Loss: 0.000, Train Accuracy: 0.000
# Round 6
# Train Loss: 3.135, Train Accuracy: 0.661
# Train Loss: 3.208, Train Accuracy: 0.593
# Train Loss: 0.000, Train Accuracy: 0.000
# Train Loss: 3.124, Train Accuracy: 0.612
# Train Loss: 0.000, Train Accuracy: 0.000
# Round 7
# Train Loss: 0.000, Train Accuracy: 0.000
# Train Loss: 3.120, Train Accuracy: 0.606
# Train Loss: 0.000, Train Accuracy: 0.000
# Train Loss: 3.059, Train Accuracy: 0.635
# Train Loss: 3.050, Train Accuracy: 0.669
# Round 8
# Train Loss: 2.963, Train Accuracy: 0.676
# Train Loss: 0.000, Train Accuracy: 0.000
# Train Loss: 0.000, Train Accuracy: 0.000
# Train Loss: 2.958, Train Accuracy: 0.592
# Train Loss: 2.935, Train Accuracy: 0.659
# Round 9
# Train Loss: 2.863, Train Accuracy: 0.686
# Train Loss: 0.000, Train Accuracy: 0.000
# Train Loss: 2.631, Train Accuracy: 0.721
# Train Loss: 0.000, Train Accuracy: 0.000
# Train Loss: 2.827, Train Accuracy: 0.673
# Round 10
# Train Loss: 2.734, Train Accuracy: 0.687
# Train Loss: 0.000, Train Accuracy: 0.000
# Train Loss: 0.000, Train Accuracy: 0.000
# Train Loss: 2.795, Train Accuracy: 0.647
# Train Loss: 2.715, Train Accuracy: 0.684
# Validation Loss: 2.931, Validation Accuracy: 0.455
# Validation Loss: 3.167, Validation Accuracy: 0.179
# Validation Loss: 2.874, Validation Accuracy: 0.317
# Validation Loss: 2.912, Validation Accuracy: 0.390
# Validation Loss: 2.961, Validation Accuracy: 0.273
# Training CSV results saved to /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv/ogbn-arxiv_full_GCN_beta1_clients5/training_ogbn-arxiv_full_GCN_beta1_clients5_20251007_142928.csv
#
# --- Model Parameter Comparison ---
#
# Layer 0:
# Server param shape: (256,)
# Client param shapes: [(256,), (256,), (256,), (256,), (256,)]
# ✅ Parameters match!
#
# Layer 1:
# Server param shape: (256, 128)
# Client param shapes: [(256, 128), (256, 128), (256, 128), (256, 128), (256, 128)]
# ✅ Parameters match!
#
# Layer 2:
# Server param shape: (256,)
# Client param shapes: [(256,), (256,), (256,), (256,), (256,)]
# ✅ Parameters match!
#
# Layer 3:
# Server param shape: (256, 256)
# Client param shapes: [(256, 256), (256, 256), (256, 256), (256, 256), (256, 256)]
# ✅ Parameters match!
#
# Layer 4:
# Server param shape: (40,)
# Client param shapes: [(40,), (40,), (40,), (40,), (40,)]
# ✅ Parameters match!
#
# Layer 5:
# Server param shape: (40, 256)
# Client param shapes: [(40, 256), (40, 256), (40, 256), (40, 256), (40, 256)]
# ✅ Parameters match!
#
# Layer 6:
# Server param shape: (256,)
# Client param shapes: [(256,), (256,), (256,), (256,), (256,)]
# ✅ Parameters match!
#
# Layer 7:
# Server param shape: (256,)
# Client param shapes: [(256,), (256,), (256,), (256,), (256,)]
# ✅ Parameters match!
#
# Layer 8:
# Server param shape: (256,)
# Client param shapes: [(256,), (256,), (256,), (256,), (256,)]
# ✅ Parameters match!
#
# Layer 9:
# Server param shape: (256,)
# Client param shapes: [(256,), (256,), (256,), (256,), (256,)]
# ✅ Parameters match!
#
# All model parameters are identical: True
# Input dim of the model in server: 128
# Input dim of the test data in server: 128
# (FLClient pid=2321929) Input dim of the model: 128
# (FLClient pid=2321929) Input dim of the data: 128
# (raylet) [2025-10-07 14:30:19,589 E 2321841 2321871] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2025-10-07_14-29-28_461041_2321588 is over 95% full, available space: 30249484288; capacity: 1622224654336. Object creation will fail if spilling is required.
# (FLClient pid=2321943) Traceback (most recent call last):
# (FLClient pid=2321943)   File "/home/brian_bosho/FP/FP/federated-gnn/src/client.py", line 138, in train_client
# (FLClient pid=2321943)     loss, acc, loss_list, acc_list = train(
# (FLClient pid=2321943)                                      ^^^^^^
# (FLClient pid=2321943)   File "/home/brian_bosho/FP/FP/federated-gnn/src/train.py", line 59, in train
# (FLClient pid=2321943)     output = model(data.x, data.edge_index)
# (FLClient pid=2321943)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=2321943)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl [repeated 2x across cluster]
# (FLClient pid=2321943)     return self._call_impl(*args, **kwargs) [repeated 2x across cluster]
# (FLClient pid=2321943)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 2x across cluster]
# (FLClient pid=2321943)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl [repeated 2x across cluster]
# (FLClient pid=2321943)     return forward_call(*args, **kwargs) [repeated 2x across cluster]
# (FLClient pid=2321943)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 2x across cluster]
# (FLClient pid=2321943)   File "/home/brian_bosho/FP/FP/federated-gnn/src/models.py", line 85, in forward
# (FLClient pid=2321943)     x = self.convs[1](x, adj_t)
# (FLClient pid=2321943)         ^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=2321943)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch_geometric/nn/conv/gcn_conv.py", line 263, in forward
# (FLClient pid=2321943)     out = self.propagate(edge_index, x=x, edge_weight=edge_weight)
# (FLClient pid=2321943)           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (FLClient pid=2321943)   File "/tmp/torch_geometric.nn.conv.gcn_conv_GCNConv_propagate_hvdo33i0.py", line 209, in propagate
# (FLClient pid=2321943)     out = self.message(
# (FLClient pid=2321943)           ^^^^^^^^^^^^^
# (FLClient pid=2321943)   File "/home/brian_bosho/miniconda3/lib/python3.12/site-packages/torch_geometric/nn/conv/gcn_conv.py", line 271, in message
# (FLClient pid=2321943)     return x_j if edge_weight is None else edge_weight.view(-1, 1) * x_j
# (FLClient pid=2321943)                                            ~~~~~~~~~~~~~~~~~~~~~~~~^~~~~
# [WANDB DEBUG] Logging test metrics - Global: 0.3972594284303438, Clients: [0.5328809500049895, 0.22608816190740227, 0.4018139457480446, 0.4755578619615983, 0.30169840452907876], Epoch: 10
# [WANDB DEBUG] Logging metrics: {'round': 10, 'test/global_test_acc': 0.3972594284303438, 'test/avg_client_test_acc': np.float64(0.3876078648302227), 'test/client_test_acc_std': np.float64(0.111812641331969), 'test/num_clients': 5, 'test/global_vs_avg_client_diff': np.float64(0.009651563600121094)} with step: 10
# [WANDB DEBUG] Successfully logged test metrics
# The average client test results: 0.3876078648302227
# The final global test results: 0.3972594284303438
# Round 1 is complete
# wandb: ⢿ uploading output.log 63.3KB/63.3KB (0.6s)
# wandb: ⢿ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: ⣻ uploading output.log 63.3KB/63.3KB (0.6s)
# wandb: ⣻ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: ⣽ uploading output.log 63.3KB/63.3KB (0.6s)
# wandb: ⣽ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: ⣾ uploading output.log 63.3KB/63.3KB (0.6s)
# wandb: ⣾ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: ⣷ uploading output.log 63.3KB/63.3KB (0.6s)
# wandb: ⣷ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: ⣯ uploading output.log 63.3KB/63.3KB (0.6s)
# wandb: ⣯ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: ⣟ uploading output.log 63.3KB/63.3KB (0.6s)
# wandb: ⣟ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb: ⡿ uploading output.log 63.3KB/63.3KB (0.6s)
# wandb: ⡿ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb:
# wandb: ⡿ uploading output.log 63.3KB/63.3KB (0.6s)
# wandb: ⡿ uploading config.yaml 2.5KB/2.5KB (0.2s)
# wandb:
# wandb: Run history:
# wandb:  federation/avg_client_train_acc █▁▁▃▃▃▃▃▄▄
# wandb: federation/avg_client_train_loss █▂▂▂▂▂▂▁▁▁
# wandb:    federation/avg_client_val_acc ▇▂▁▂▁▁▆▅█▇
# wandb:   federation/avg_client_val_loss ██▇▆▆▅▄▃▂▁
# wandb:                            round ▁▂▂▃▄▅▅▆▇▇█
# wandb:           run_client_test_result ▁
# wandb:           run_global_test_result ▁
# wandb:         test/avg_client_test_acc ▁
# wandb:         test/client_test_acc_std ▁
# wandb:             test/global_test_acc ▁
# wandb:   test/global_vs_avg_client_diff ▁
# wandb:                 test/num_clients ▁
# wandb:
# wandb: Run summary:
# wandb:  federation/avg_client_train_acc 0.40344
# wandb: federation/avg_client_train_loss 1.64878
# wandb:    federation/avg_client_val_acc 0.32305
# wandb:   federation/avg_client_val_loss 2.96913
# wandb:                            round 10
# wandb:           run_client_test_result 0.38761
# wandb:           run_global_test_result 0.39726
# wandb:         test/avg_client_test_acc 0.38761
# wandb:         test/client_test_acc_std 0.11181
# wandb:             test/global_test_acc 0.39726
# wandb:   test/global_vs_avg_client_diff 0.00965
# wandb:                 test/num_clients 5
# wandb:
# wandb: 🚀 View run GCN_ogbn-arxiv_SGD_lr0.5_decay0.0005_beta1_run1 at: https://wandb.ai/bosho/FGL3/runs/v9d8vapy
# wandb: ⭐️ View project at: https://wandb.ai/bosho/FGL3
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251007_142931-v9d8vapy/logs
# The global test results: [0.3972594284303438]
# The client test results: [0.3876078648302227]
# The average global test results: 0.3972594284303438
# The average client test results: 0.3876078648302227
# The standard deviation global is: 0.0
# The standard deviation client is: 0.0
# (FLClient pid=2321949) Input dim of the model: 128 [repeated 4x across cluster]
# (FLClient pid=2321949) Input dim of the data: 128 [repeated 4x across cluster]
# (FLClient pid=2321949) 2025-10-07 14:30:16,402 - INFO - Epoch   2| Train Loss: 1.316| Train Accuracy: 0.684| Val Loss: 2.715| Val Accuracy: 0.452 [repeated 8x across cluster]
# Training CSV results saved to /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv/ogbn-arxiv_full_GCN_beta1_clients5/training_ogbn-arxiv_full_GCN_beta1_clients5_20251007_142928.csv
#
# Summary results saved to:
# - Text file: /home/brian_bosho/FP/FP/federated-gnn/results/review/results_summary/ogbn-arxiv/summary_results_20251007_143025.txt
# - JSON file: /home/brian_bosho/FP/FP/federated-gnn/results/review/results_summary/ogbn-arxiv/summary_results_20251007_143025.json
# - Detailed results saved to: /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv
#
#
#
# ================================================================================
# EXPERIMENT RESULTS SUMMARY
# ================================================================================
# +------------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+
# | Dataset    | Data Loading   | Model   |   Beta |   Clients |   Avg Global Result |   Avg Client Result |   client_std_dev |   global_std_dev | Duration   |   Hop | Use PE   |
# +============+================+=========+========+===========+=====================+=====================+==================+==================+============+=======+==========+
# | ogbn-arxiv | full           | GCN     |      1 |         5 |              0.3973 |              0.3876 |                0 |                0 | 00:00:56   |     2 | False    |
# +------------+----------------+---------+--------+-----------+---------------------+---------------------+------------------+------------------+------------+-------+----------+
#
#
# KEY RESULTS:
# --------------------------------------------------------------------------------
# ogbn-arxiv with full using GCN (beta=1.00, clients=5, hop=2, use_pe=False):
#   - Average Global Result: 0.3973
#   - Average Client Result: 0.3876
#   - Client StdDev: 0.0000
#   - Global StdDev: 0.0000
#   - Experiment Duration: 00:00:56
# --------------------------------------------------------------------------------
