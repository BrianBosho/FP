# %%
# !python -m src.experiments.run_experiments --config conf/pubmed_config.yaml
# Out:
# /home/brian_bosho/FP/FP/federated-gnn/src/utils/utils.py:82: SyntaxWarning: invalid escape sequence '\m'
#   """
#
# Experiment Configuration:
# - Clients: [10]
# - Rounds: 100
# - Epochs: 1
# - Learning Rate: 0.01
# - Beta values: [1]
# - Datasets: ['Pubmed']
# - Data Loading Options: ['full']
# - Model Types: ['GCN']
# - Results Directory: /home/brian_bosho/FP/FP/federated-gnn/results/pubmed
# - Save Detailed Results: True
# - Hop: 1
# - Full Training Flag: False
#
# ...
# Running experiment: Pubmed_full_GCN_beta1_clients10
# ...
# 2025-10-15 15:09:55,726	INFO worker.py:1807 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (FLClient pid=2154548) Client 0: Using full-batch training for Pubmed dataset
# (FLClient pid=2154548) /home/brian_bosho/FP/FP/federated-gnn/src/train.py:38: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
# ...
