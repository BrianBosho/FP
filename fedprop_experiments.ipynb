# %%
# !python -m src.experiments.run_experiments --config conf/ablation/ogbn-arxiv_config.yaml
# Out:
# Experiment Configuration:
# - Clients: [10]
# - Rounds: 10
# - Epochs: 3
# - Learning Rate: 0.01
# - Beta values: [1]
# - Datasets: ['ogbn-arxiv']
# - Data Loading Options: ['full']
# - Model Types: ['GCN']
# - Results Directory: /home/brian_bosho/FP/FP/federated-gnn/results/review/ablation/ogbn-arxiv
# - Save Detailed Results: False
# - Hop: 2
# - Full Training Flag: False
#
# ...
# Running experiment: ogbn-arxiv_full_GCN_beta1_clients10
# ...
# DEVICE: cuda
# Data loading option is full
# Model type is GCN
# 2025-09-30 10:39:21,590	INFO worker.py:1807 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# wandb: Currently logged in as: bosho to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /home/brian_bosho/FP/FP/federated-gnn/wandb/run-20250930_103923-y3bykalo
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run colorful-sun-1531
# ...
