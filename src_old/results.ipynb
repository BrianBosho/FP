# %%
import sys
import os
import torch
import ray

# Make sure the path is correct
module_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# Updated imports for new structure

from src.run import main_experiment, load_configuration

# Shutdown any existing Ray instances
ray.shutdown()

# Define all options
data_loading_options = ["zero_hop", "diffusion"]
model_types = ["GCN"]

# conf_path = "/home/brian_bosho/FP/FP/federated-gnn/conf/base.yaml"

# Load configuration
clients_num, beta, cfg = load_configuration()
clients_num = 10  # Hardcode if needed

results_list = []

# Main results directory
main_dir = 'propagation_results'
dataset_name = "Cora"  # Adjust if needed

# Loop through experiments
for data_loading_option in data_loading_options:
    for model_type in model_types:
        result_name = f"{dataset_name}_{data_loading_option}_{model_type}"
        results_dir = os.path.join(main_dir, result_name)
        os.makedirs(results_dir, exist_ok=True)

        print(f"Running experiment with data_loading_option: {data_loading_option}, model_type: {model_type}")
        result = main_experiment(
            clients_num, beta, data_loading_option, model_type, cfg,
            dataset_name=dataset_name, hop=2
        )

        results_list.append(result)

        # Optional: Save results
        # results_data, result_text = result
        # filename = f'results_{dataset_name}_{data_loading_option}_{model_type}.txt'
        # filepath = os.path.join(results_dir, filename)
        # with open(filepath, 'w') as f:
        #     f.write(result_text)
# Out:
# /home/brian_bosho/FP/FP/federated-gnn/src_old/utils.py:58: SyntaxWarning: invalid escape sequence '\m'
#   """
# Running experiment with data_loading_option: zero_hop, model_type: GCN
# DEVICE: cuda
# Data loading option is zero_hop
# Model type is GCN
# 2025-04-29 01:15:05,760	INFO worker.py:1816 -- Started a local Ray instance.
# data_loading_option: zero_hop
# Data loaded
# Device is cuda
# Cora()
# 10
# (FLClient pid=3171264) 2025-04-29 01:15:12,436 - INFO - Epoch   0| Train Loss: 1.946| Train Accuracy: 0.071
# (FLClient pid=3171264) 2025-04-29 01:15:12,440 - INFO - Epoch   1| Train Loss: 1.885| Train Accuracy: 0.357
# (FLClient pid=3171264) 2025-04-29 01:15:12,449 - INFO - Epoch   1| Validation Loss: 2.000, Validation Accuracy: 0.039
# Training done
# Round 1
# Train Loss: 2.000, Train Accuracy: 0.357
# Train Loss: 2.005, Train Accuracy: 0.312
# Train Loss: 2.002, Train Accuracy: 0.133
# Train Loss: 1.879, Train Accuracy: 0.200
# Train Loss: 1.926, Train Accuracy: 0.357
# Train Loss: 1.893, Train Accuracy: 0.267
# Train Loss: 1.983, Train Accuracy: 0.286
# Train Loss: 1.974, Train Accuracy: 0.200
# Train Loss: 1.955, Train Accuracy: 0.214
# Train Loss: 1.912, Train Accuracy: 0.231
# Round 2
# Train Loss: 2.006, Train Accuracy: 0.429
# Train Loss: 2.013, Train Accuracy: 0.312
# Train Loss: 2.015, Train Accuracy: 0.267
# Train Loss: 1.876, Train Accuracy: 0.300
# Train Loss: 1.931, Train Accuracy: 0.357
# Train Loss: 1.863, Train Accuracy: 0.267
# Train Loss: 1.978, Train Accuracy: 0.357
# Train Loss: 1.979, Train Accuracy: 0.133
# Train Loss: 1.962, Train Accuracy: 0.143
# Train Loss: 1.910, Train Accuracy: 0.308
# Round 3
# Train Loss: 2.000, Train Accuracy: 0.357
# Train Loss: 2.004, Train Accuracy: 0.312
# Train Loss: 2.037, Train Accuracy: 0.333
# Train Loss: 1.885, Train Accuracy: 0.400
# Train Loss: 1.928, Train Accuracy: 0.357
# Train Loss: 1.877, Train Accuracy: 0.267
# Train Loss: 2.009, Train Accuracy: 0.286
# Train Loss: 1.964, Train Accuracy: 0.133
# Train Loss: 1.966, Train Accuracy: 0.214
# Train Loss: 1.885, Train Accuracy: 0.154
# Validation Loss: 1.942, Validation Accuracy: 0.196
# Validation Loss: 1.946, Validation Accuracy: 0.222
# Validation Loss: 1.942, Validation Accuracy: 0.174
# Validation Loss: 1.935, Validation Accuracy: 0.448
# Validation Loss: 1.945, Validation Accuracy: 0.100
# Validation Loss: 1.941, Validation Accuracy: 0.233
# Validation Loss: 1.945, Validation Accuracy: 0.193
# Validation Loss: 1.943, Validation Accuracy: 0.254
# Validation Loss: 1.947, Validation Accuracy: 0.172
# Validation Loss: 1.944, Validation Accuracy: 0.156
#
# --- Model Parameter Comparison ---
#
# Layer 0:
# Server param shape: (16,)
# Client param shapes: [(16,), (16,), (16,), (16,), (16,), (16,), (16,), (16,), (16,), (16,)]
# ✅ Parameters match!
#
# Layer 1:
# Server param shape: (16, 1433)
# Client param shapes: [(16, 1433), (16, 1433), (16, 1433), (16, 1433), (16, 1433), (16, 1433), (16, 1433), (16, 1433), (16, 1433), (16, 1433)]
# ✅ Parameters match!
#
# Layer 2:
# Server param shape: (7,)
# Client param shapes: [(7,), (7,), (7,), (7,), (7,), (7,), (7,), (7,), (7,), (7,)]
# ✅ Parameters match!
#
# Layer 3:
# Server param shape: (7, 16)
# Client param shapes: [(7, 16), (7, 16), (7, 16), (7, 16), (7, 16), (7, 16), (7, 16), (7, 16), (7, 16), (7, 16)]
# ✅ Parameters match!
#
# All model parameters are identical: True
# Error in round 1: name 'GraphSAGEProducts' is not defined
# The global test results: []
# The client test results: []
# The average global test results: nan
# The average client test results: nan
# The standad deviation global is: nan
# The standad deviation client is: nan
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:3904: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/numpy/_core/_methods.py:147: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/numpy/_core/_methods.py:227: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/numpy/_core/_methods.py:184: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/brian_bosho/miniconda3/lib/python3.12/site-packages/numpy/_core/_methods.py:219: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# (FLClient pid=3171276) 2025-04-29 01:15:13,188 - INFO - Epoch   1| Train Loss: 1.919| Train Accuracy: 0.154 [repeated 58x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (FLClient pid=3171276) 2025-04-29 01:15:13,191 - INFO - Epoch   1| Validation Loss: 1.885, Validation Accuracy: 0.356 [repeated 29x across cluster]
# Running experiment with data_loading_option: diffusion, model_type: GCN
# DEVICE: cuda
# Data loading option is diffusion
# Model type is GCN
# 2025-04-29 01:15:16,191	INFO worker.py:1816 -- Started a local Ray instance.
# data_loading_option: diffusion
# Data loaded
# Device is cuda
# Cora()
# 10
# (FLClient pid=3173087) 2025-04-29 01:15:22,656 - INFO - Epoch   0| Train Loss: 1.945| Train Accuracy: 0.250
# (FLClient pid=3173087) 2025-04-29 01:15:22,660 - INFO - Epoch   1| Train Loss: 1.902| Train Accuracy: 0.312
# (FLClient pid=3173087) 2025-04-29 01:15:22,669 - INFO - Epoch   1| Validation Loss: 2.033, Validation Accuracy: 0.111
# Training done
# Round 1
# Train Loss: 1.997, Train Accuracy: 0.429
# Train Loss: 2.033, Train Accuracy: 0.312
# Train Loss: 1.992, Train Accuracy: 0.400
# Train Loss: 1.856, Train Accuracy: 0.300
# Train Loss: 1.920, Train Accuracy: 0.357
# Train Loss: 1.884, Train Accuracy: 0.267
# Train Loss: 1.977, Train Accuracy: 0.286
# Train Loss: 1.961, Train Accuracy: 0.200
# Train Loss: 1.947, Train Accuracy: 0.357
# Train Loss: 1.924, Train Accuracy: 0.231
# Round 2
# Train Loss: 1.999, Train Accuracy: 0.357
# Train Loss: 2.044, Train Accuracy: 0.312
# Train Loss: 2.014, Train Accuracy: 0.200
# Train Loss: 1.846, Train Accuracy: 0.300
# Train Loss: 1.923, Train Accuracy: 0.357
# Train Loss: 1.863, Train Accuracy: 0.333
# Train Loss: 1.979, Train Accuracy: 0.429
# Train Loss: 1.972, Train Accuracy: 0.200
# Train Loss: 1.948, Train Accuracy: 0.071
# Train Loss: 1.904, Train Accuracy: 0.308
# Round 3
# Train Loss: 2.002, Train Accuracy: 0.357
# Train Loss: 2.065, Train Accuracy: 0.312
# Train Loss: 2.016, Train Accuracy: 0.267
# Train Loss: 1.843, Train Accuracy: 0.300
# Train Loss: 1.918, Train Accuracy: 0.357
# Train Loss: 1.857, Train Accuracy: 0.267
# Train Loss: 1.999, Train Accuracy: 0.214
# Train Loss: 1.970, Train Accuracy: 0.200
# Train Loss: 1.952, Train Accuracy: 0.214
# Train Loss: 1.913, Train Accuracy: 0.231
# Validation Loss: 1.939, Validation Accuracy: 0.255
# Validation Loss: 1.945, Validation Accuracy: 0.250
# Validation Loss: 1.935, Validation Accuracy: 0.326
# Validation Loss: 1.930, Validation Accuracy: 0.448
# Validation Loss: 1.940, Validation Accuracy: 0.217
# Validation Loss: 1.929, Validation Accuracy: 0.367
# Validation Loss: 1.938, Validation Accuracy: 0.281
# Validation Loss: 1.937, Validation Accuracy: 0.288
# Validation Loss: 1.941, Validation Accuracy: 0.241
# Validation Loss: 1.933, Validation Accuracy: 0.356
#
# --- Model Parameter Comparison ---
#
# Layer 0:
# Server param shape: (16,)
# Client param shapes: [(16,), (16,), (16,), (16,), (16,), (16,), (16,), (16,), (16,), (16,)]
# ✅ Parameters match!
#
# Layer 1:
# Server param shape: (16, 1433)
# Client param shapes: [(16, 1433), (16, 1433), (16, 1433), (16, 1433), (16, 1433), (16, 1433), (16, 1433), (16, 1433), (16, 1433), (16, 1433)]
# ✅ Parameters match!
#
# Layer 2:
# Server param shape: (7,)
# Client param shapes: [(7,), (7,), (7,), (7,), (7,), (7,), (7,), (7,), (7,), (7,)]
# ✅ Parameters match!
#
# Layer 3:
# Server param shape: (7, 16)
# Client param shapes: [(7, 16), (7, 16), (7, 16), (7, 16), (7, 16), (7, 16), (7, 16), (7, 16), (7, 16), (7, 16)]
# ✅ Parameters match!
#
# All model parameters are identical: True
# Error in round 1: name 'GraphSAGEProducts' is not defined
# The global test results: []
# The client test results: []
# The average global test results: nan
# The average client test results: nan
# The standad deviation global is: nan
# The standad deviation client is: nan
# (FLClient pid=3173084) 2025-04-29 01:15:23,743 - INFO - Epoch   1| Train Loss: 1.928| Train Accuracy: 0.231 [repeated 58x across cluster]
# (FLClient pid=3173084) 2025-04-29 01:15:23,746 - INFO - Epoch   1| Validation Loss: 1.913, Validation Accuracy: 0.333 [repeated 29x across cluster]

# %%
/home/brian_bosho/FP/FP/federated-gnn/src/test.py
